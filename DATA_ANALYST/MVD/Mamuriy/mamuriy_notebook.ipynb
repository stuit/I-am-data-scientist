# %%
import pandas as pd

# %%
df = pd.read_csv('export_protocols_emi.csv', ';', encoding='cp1251')
# Out:
# /Users/ilkhom/Library/Python/3.8/lib/python/site-packages/IPython/core/interactiveshell.py:3444: FutureWarning: In a future version of pandas all arguments of read_csv except for the argument 'filepath_or_buffer' will be keyword-only.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
df.head()
# Out:
#     asosiy_modda_nomi  asosiy_modda_kodi asosiy_jazo_nomi kiritilgan_sana  \
# 0  "125  - PRIM-1 1Q"            1250101              NaN      2021-12-13
# 1          "52  - 2Q"             520002              NaN      2021-12-20
# 2  "135  - PRIM-1 1Q"            1350101              NaN      2021-12-22
# 3       "183 - MODDA"            1830000              NaN      2021-12-01
# 4         "128  - 1Q"            1280001              NaN      2022-02-02
#
#                   korib_chiqgan_shaxs  \
# 0                                 NaN
# 1  URAZALIYEV G‘ULOMJON NAZARKULOVICH
# 2                                 NaN
# 3   SAIDOV ABDULAZIZ AXMATSULTANOVICH
# 4                                 NaN
#
#    inspektorning_pinfli_yoki_uning_fotosurati  korib_chiqgan_organ  \
# 0                                         NaN          YXXBB (GAI)
# 1                                3.230191e+13  XPBB (PROFILAKTIKA)
# 2                                         NaN          YXXBB (GAI)
# ...
