# %% [markdown]
# <img src="stat&basic6_img1.png" width="800px"/>

# %%
def f(x, y):
    return (1 - x) ** 2 + 100 * (y - x ** 2) ** 2
def grad(x, y):
    dx = 2 * x - 2 + 100 * (-4 * y * x + 4 * x ** 3)
    dy = 100 * (2 * y - 2 * x ** 2)
    return (dx, dy)

# %%
def dist(x1, x2):
    return (x1[0] - x2[0]) ** 2 + (x1[1] - x2[1]) ** 2

# %%
x0 = (0, 2)
gamma = 1e-3
x_cur = x0

vals = []
coords = []
i = 0
while True:
    x_new = (x_cur[0] - gamma * grad(*x_cur)[0],
            x_cur[1] - gamma * grad(*x_cur)[1])
    if dist(x_new, x_cur) < 1e-9:
        break
    x_cur = x_new
    vals.append(f(*x_cur))
    coords.append(x_cur)
    i += 1
    print(f"iter={i}; x=({x_cur[0]:.2f}, {x_cur[1]:.2f});"
          f" f(x)={f(*x_cur):.2f}; grad f(x)=({grad(*x_cur)[0]:.2f}, {grad(*x_cur)[1]:.2f})")
# Out:
# iter=1; x=(0.00, 1.60); f(x)=256.99; grad f(x)=(-3.28, 320.00)
# iter=2; x=(0.01, 1.28); f(x)=164.82; grad f(x)=(-4.69, 255.99)
# iter=3; x=(0.01, 1.02); f(x)=105.82; grad f(x)=(-6.06, 204.78)
# iter=4; x=(0.02, 0.82); f(x)=68.04; grad f(x)=(-7.22, 163.79)
# iter=5; x=(0.02, 0.66); f(x)=43.84; grad f(x)=(-8.04, 130.98)
# iter=6; x=(0.03, 0.52); f(x)=28.34; grad f(x)=(-8.49, 104.69)
# iter=7; x=(0.04, 0.42); f(x)=18.41; grad f(x)=(-8.57, 83.64)
# iter=8; x=(0.05, 0.34); f(x)=12.05; grad f(x)=(-8.36, 66.76)
# iter=9; x=(0.06, 0.27); f(x)=7.97; grad f(x)=(-7.92, 53.23)
# iter=10; x=(0.06, 0.22); f(x)=5.37; grad f(x)=(-7.35, 42.39)
# iter=11; x=(0.07, 0.17); f(x)=3.70; grad f(x)=(-6.71, 33.71)
# iter=12; x=(0.08, 0.14); f(x)=2.64; grad f(x)=(-6.06, 26.77)
# iter=13; x=(0.08, 0.11); f(x)=1.96; grad f(x)=(-5.43, 21.22)
# iter=14; x=(0.09, 0.09); f(x)=1.53; grad f(x)=(-4.85, 16.78)
# iter=15; x=(0.10, 0.08); f(x)=1.26; grad f(x)=(-4.33, 13.25)
# iter=16; x=(0.10, 0.06); f(x)=1.08; grad f(x)=(-3.87, 10.43)
# iter=17; x=(0.10, 0.05); f(x)=0.97; grad f(x)=(-3.48, 8.19)
# iter=18; x=(0.11, 0.04); f(x)=0.90; grad f(x)=(-3.15, 6.40)
# iter=19; x=(0.11, 0.04); f(x)=0.85; grad f(x)=(-2.88, 4.99)
# iter=20; x=(0.11, 0.03); f(x)=0.82; grad f(x)=(-2.65, 3.86)
# iter=21; x=(0.12, 0.03); f(x)=0.80; grad f(x)=(-2.45, 2.97)
# iter=22; x=(0.12, 0.03); f(x)=0.79; grad f(x)=(-2.30, 2.26)
# iter=23; x=(0.12, 0.02); f(x)=0.78; grad f(x)=(-2.17, 1.70)
# iter=24; x=(0.12, 0.02); f(x)=0.77; grad f(x)=(-2.06, 1.25)
# iter=25; x=(0.12, 0.02); f(x)=0.77; grad f(x)=(-1.98, 0.90)
# iter=26; x=(0.13, 0.02); f(x)=0.76; grad f(x)=(-1.90, 0.62)
# iter=27; x=(0.13, 0.02); f(x)=0.76; grad f(x)=(-1.85, 0.40)
# iter=28; x=(0.13, 0.02); f(x)=0.76; grad f(x)=(-1.80, 0.23)
# iter=29; x=(0.13, 0.02); f(x)=0.75; grad f(x)=(-1.76, 0.09)
# iter=30; x=(0.13, 0.02); f(x)=0.75; grad f(x)=(-1.73, -0.02)
# iter=31; x=(0.14, 0.02); f(x)=0.75; grad f(x)=(-1.70, -0.11)
# iter=32; x=(0.14, 0.02); f(x)=0.74; grad f(x)=(-1.68, -0.18)
# iter=33; x=(0.14, 0.02); f(x)=0.74; grad f(x)=(-1.66, -0.24)
# iter=34; x=(0.14, 0.02); f(x)=0.74; grad f(x)=(-1.64, -0.28)
# iter=35; x=(0.14, 0.02); f(x)=0.74; grad f(x)=(-1.63, -0.32)
# iter=36; x=(0.14, 0.02); f(x)=0.73; grad f(x)=(-1.61, -0.35)
# iter=37; x=(0.15, 0.02); f(x)=0.73; grad f(x)=(-1.60, -0.37)
# iter=38; x=(0.15, 0.02); f(x)=0.73; grad f(x)=(-1.59, -0.39)
# iter=39; x=(0.15, 0.02); f(x)=0.73; grad f(x)=(-1.58, -0.41)
# iter=40; x=(0.15, 0.02); f(x)=0.72; grad f(x)=(-1.57, -0.42)
# iter=41; x=(0.15, 0.02); f(x)=0.72; grad f(x)=(-1.57, -0.43)
# iter=42; x=(0.15, 0.02); f(x)=0.72; grad f(x)=(-1.56, -0.44)
# iter=43; x=(0.15, 0.02); f(x)=0.71; grad f(x)=(-1.55, -0.45)
# iter=44; x=(0.16, 0.02); f(x)=0.71; grad f(x)=(-1.55, -0.46)
# iter=45; x=(0.16, 0.02); f(x)=0.71; grad f(x)=(-1.54, -0.46)
# iter=46; x=(0.16, 0.02); f(x)=0.71; grad f(x)=(-1.53, -0.47)
# iter=47; x=(0.16, 0.02); f(x)=0.70; grad f(x)=(-1.53, -0.47)
# iter=48; x=(0.16, 0.02); f(x)=0.70; grad f(x)=(-1.52, -0.48)
# iter=49; x=(0.16, 0.02); f(x)=0.70; grad f(x)=(-1.51, -0.48)
# iter=50; x=(0.17, 0.02); f(x)=0.70; grad f(x)=(-1.51, -0.48)
# iter=51; x=(0.17, 0.03); f(x)=0.69; grad f(x)=(-1.50, -0.49)
# iter=52; x=(0.17, 0.03); f(x)=0.69; grad f(x)=(-1.50, -0.49)
# iter=53; x=(0.17, 0.03); f(x)=0.69; grad f(x)=(-1.49, -0.49)
# iter=54; x=(0.17, 0.03); f(x)=0.69; grad f(x)=(-1.49, -0.50)
# iter=55; x=(0.17, 0.03); f(x)=0.68; grad f(x)=(-1.48, -0.50)
# iter=56; x=(0.17, 0.03); f(x)=0.68; grad f(x)=(-1.48, -0.50)
# iter=57; x=(0.18, 0.03); f(x)=0.68; grad f(x)=(-1.47, -0.51)
# iter=58; x=(0.18, 0.03); f(x)=0.68; grad f(x)=(-1.46, -0.51)
# iter=59; x=(0.18, 0.03); f(x)=0.67; grad f(x)=(-1.46, -0.51)
# iter=60; x=(0.18, 0.03); f(x)=0.67; grad f(x)=(-1.45, -0.51)
# iter=61; x=(0.18, 0.03); f(x)=0.67; grad f(x)=(-1.45, -0.52)
# iter=62; x=(0.18, 0.03); f(x)=0.67; grad f(x)=(-1.44, -0.52)
# iter=63; x=(0.18, 0.03); f(x)=0.67; grad f(x)=(-1.44, -0.52)
# iter=64; x=(0.19, 0.03); f(x)=0.66; grad f(x)=(-1.43, -0.52)
# iter=65; x=(0.19, 0.03); f(x)=0.66; grad f(x)=(-1.43, -0.53)
# iter=66; x=(0.19, 0.03); f(x)=0.66; grad f(x)=(-1.42, -0.53)
# iter=67; x=(0.19, 0.03); f(x)=0.66; grad f(x)=(-1.42, -0.53)
# iter=68; x=(0.19, 0.03); f(x)=0.65; grad f(x)=(-1.41, -0.53)
# iter=69; x=(0.19, 0.03); f(x)=0.65; grad f(x)=(-1.41, -0.53)
# iter=70; x=(0.19, 0.04); f(x)=0.65; grad f(x)=(-1.40, -0.54)
# iter=71; x=(0.20, 0.04); f(x)=0.65; grad f(x)=(-1.40, -0.54)
# iter=72; x=(0.20, 0.04); f(x)=0.64; grad f(x)=(-1.39, -0.54)
# iter=73; x=(0.20, 0.04); f(x)=0.64; grad f(x)=(-1.39, -0.54)
# iter=74; x=(0.20, 0.04); f(x)=0.64; grad f(x)=(-1.38, -0.55)
# iter=75; x=(0.20, 0.04); f(x)=0.64; grad f(x)=(-1.38, -0.55)
# iter=76; x=(0.20, 0.04); f(x)=0.64; grad f(x)=(-1.37, -0.55)
# iter=77; x=(0.20, 0.04); f(x)=0.63; grad f(x)=(-1.37, -0.55)
# iter=78; x=(0.21, 0.04); f(x)=0.63; grad f(x)=(-1.36, -0.55)
# iter=79; x=(0.21, 0.04); f(x)=0.63; grad f(x)=(-1.36, -0.55)
# iter=80; x=(0.21, 0.04); f(x)=0.63; grad f(x)=(-1.35, -0.56)
# iter=81; x=(0.21, 0.04); f(x)=0.63; grad f(x)=(-1.35, -0.56)
# iter=82; x=(0.21, 0.04); f(x)=0.62; grad f(x)=(-1.34, -0.56)
# iter=83; x=(0.21, 0.04); f(x)=0.62; grad f(x)=(-1.34, -0.56)
# iter=84; x=(0.21, 0.04); f(x)=0.62; grad f(x)=(-1.33, -0.56)
# iter=85; x=(0.22, 0.04); f(x)=0.62; grad f(x)=(-1.33, -0.56)
# iter=86; x=(0.22, 0.04); f(x)=0.61; grad f(x)=(-1.32, -0.57)
# iter=87; x=(0.22, 0.04); f(x)=0.61; grad f(x)=(-1.32, -0.57)
# iter=88; x=(0.22, 0.05); f(x)=0.61; grad f(x)=(-1.31, -0.57)
# iter=89; x=(0.22, 0.05); f(x)=0.61; grad f(x)=(-1.31, -0.57)
# iter=90; x=(0.22, 0.05); f(x)=0.61; grad f(x)=(-1.30, -0.57)
# iter=91; x=(0.22, 0.05); f(x)=0.60; grad f(x)=(-1.30, -0.57)
# iter=92; x=(0.22, 0.05); f(x)=0.60; grad f(x)=(-1.29, -0.58)
# iter=93; x=(0.23, 0.05); f(x)=0.60; grad f(x)=(-1.29, -0.58)
# iter=94; x=(0.23, 0.05); f(x)=0.60; grad f(x)=(-1.28, -0.58)
# iter=95; x=(0.23, 0.05); f(x)=0.60; grad f(x)=(-1.28, -0.58)
# iter=96; x=(0.23, 0.05); f(x)=0.59; grad f(x)=(-1.27, -0.58)
# iter=97; x=(0.23, 0.05); f(x)=0.59; grad f(x)=(-1.27, -0.58)
# iter=98; x=(0.23, 0.05); f(x)=0.59; grad f(x)=(-1.27, -0.58)
# iter=99; x=(0.23, 0.05); f(x)=0.59; grad f(x)=(-1.26, -0.58)
# iter=100; x=(0.23, 0.05); f(x)=0.59; grad f(x)=(-1.26, -0.59)
# iter=101; x=(0.24, 0.05); f(x)=0.58; grad f(x)=(-1.25, -0.59)
# iter=102; x=(0.24, 0.05); f(x)=0.58; grad f(x)=(-1.25, -0.59)
# iter=103; x=(0.24, 0.05); f(x)=0.58; grad f(x)=(-1.24, -0.59)
# iter=104; x=(0.24, 0.05); f(x)=0.58; grad f(x)=(-1.24, -0.59)
# iter=105; x=(0.24, 0.06); f(x)=0.58; grad f(x)=(-1.23, -0.59)
# iter=106; x=(0.24, 0.06); f(x)=0.58; grad f(x)=(-1.23, -0.59)
# iter=107; x=(0.24, 0.06); f(x)=0.57; grad f(x)=(-1.23, -0.59)
# iter=108; x=(0.24, 0.06); f(x)=0.57; grad f(x)=(-1.22, -0.59)
# iter=109; x=(0.25, 0.06); f(x)=0.57; grad f(x)=(-1.22, -0.59)
# iter=110; x=(0.25, 0.06); f(x)=0.57; grad f(x)=(-1.21, -0.60)
# iter=111; x=(0.25, 0.06); f(x)=0.57; grad f(x)=(-1.21, -0.60)
# iter=112; x=(0.25, 0.06); f(x)=0.56; grad f(x)=(-1.20, -0.60)
# iter=113; x=(0.25, 0.06); f(x)=0.56; grad f(x)=(-1.20, -0.60)
# iter=114; x=(0.25, 0.06); f(x)=0.56; grad f(x)=(-1.20, -0.60)
# iter=115; x=(0.25, 0.06); f(x)=0.56; grad f(x)=(-1.19, -0.60)
# iter=116; x=(0.25, 0.06); f(x)=0.56; grad f(x)=(-1.19, -0.60)
# iter=117; x=(0.26, 0.06); f(x)=0.56; grad f(x)=(-1.18, -0.60)
# iter=118; x=(0.26, 0.06); f(x)=0.55; grad f(x)=(-1.18, -0.60)
# iter=119; x=(0.26, 0.06); f(x)=0.55; grad f(x)=(-1.17, -0.60)
# iter=120; x=(0.26, 0.06); f(x)=0.55; grad f(x)=(-1.17, -0.60)
# iter=121; x=(0.26, 0.06); f(x)=0.55; grad f(x)=(-1.17, -0.60)
# iter=122; x=(0.26, 0.07); f(x)=0.55; grad f(x)=(-1.16, -0.60)
# iter=123; x=(0.26, 0.07); f(x)=0.55; grad f(x)=(-1.16, -0.61)
# iter=124; x=(0.26, 0.07); f(x)=0.54; grad f(x)=(-1.15, -0.61)
# iter=125; x=(0.26, 0.07); f(x)=0.54; grad f(x)=(-1.15, -0.61)
# iter=126; x=(0.27, 0.07); f(x)=0.54; grad f(x)=(-1.15, -0.61)
# iter=127; x=(0.27, 0.07); f(x)=0.54; grad f(x)=(-1.14, -0.61)
# iter=128; x=(0.27, 0.07); f(x)=0.54; grad f(x)=(-1.14, -0.61)
# iter=129; x=(0.27, 0.07); f(x)=0.53; grad f(x)=(-1.13, -0.61)
# iter=130; x=(0.27, 0.07); f(x)=0.53; grad f(x)=(-1.13, -0.61)
# iter=131; x=(0.27, 0.07); f(x)=0.53; grad f(x)=(-1.13, -0.61)
# iter=132; x=(0.27, 0.07); f(x)=0.53; grad f(x)=(-1.12, -0.61)
# iter=133; x=(0.27, 0.07); f(x)=0.53; grad f(x)=(-1.12, -0.61)
# iter=134; x=(0.27, 0.07); f(x)=0.53; grad f(x)=(-1.11, -0.61)
# iter=135; x=(0.28, 0.07); f(x)=0.53; grad f(x)=(-1.11, -0.61)
# iter=136; x=(0.28, 0.07); f(x)=0.52; grad f(x)=(-1.11, -0.61)
# iter=137; x=(0.28, 0.07); f(x)=0.52; grad f(x)=(-1.10, -0.61)
# iter=138; x=(0.28, 0.07); f(x)=0.52; grad f(x)=(-1.10, -0.61)
# iter=139; x=(0.28, 0.08); f(x)=0.52; grad f(x)=(-1.10, -0.61)
# iter=140; x=(0.28, 0.08); f(x)=0.52; grad f(x)=(-1.09, -0.61)
# iter=141; x=(0.28, 0.08); f(x)=0.52; grad f(x)=(-1.09, -0.61)
# iter=142; x=(0.28, 0.08); f(x)=0.51; grad f(x)=(-1.08, -0.61)
# iter=143; x=(0.28, 0.08); f(x)=0.51; grad f(x)=(-1.08, -0.61)
# iter=144; x=(0.29, 0.08); f(x)=0.51; grad f(x)=(-1.08, -0.62)
# iter=145; x=(0.29, 0.08); f(x)=0.51; grad f(x)=(-1.07, -0.62)
# iter=146; x=(0.29, 0.08); f(x)=0.51; grad f(x)=(-1.07, -0.62)
# iter=147; x=(0.29, 0.08); f(x)=0.51; grad f(x)=(-1.07, -0.62)
# iter=148; x=(0.29, 0.08); f(x)=0.50; grad f(x)=(-1.06, -0.62)
# iter=149; x=(0.29, 0.08); f(x)=0.50; grad f(x)=(-1.06, -0.62)
# iter=150; x=(0.29, 0.08); f(x)=0.50; grad f(x)=(-1.06, -0.62)
# iter=151; x=(0.29, 0.08); f(x)=0.50; grad f(x)=(-1.05, -0.62)
# iter=152; x=(0.29, 0.08); f(x)=0.50; grad f(x)=(-1.05, -0.62)
# iter=153; x=(0.30, 0.08); f(x)=0.50; grad f(x)=(-1.04, -0.62)
# iter=154; x=(0.30, 0.08); f(x)=0.50; grad f(x)=(-1.04, -0.62)
# iter=155; x=(0.30, 0.09); f(x)=0.49; grad f(x)=(-1.04, -0.62)
# iter=156; x=(0.30, 0.09); f(x)=0.49; grad f(x)=(-1.03, -0.62)
# iter=157; x=(0.30, 0.09); f(x)=0.49; grad f(x)=(-1.03, -0.62)
# iter=158; x=(0.30, 0.09); f(x)=0.49; grad f(x)=(-1.03, -0.62)
# iter=159; x=(0.30, 0.09); f(x)=0.49; grad f(x)=(-1.02, -0.62)
# iter=160; x=(0.30, 0.09); f(x)=0.49; grad f(x)=(-1.02, -0.62)
# iter=161; x=(0.30, 0.09); f(x)=0.49; grad f(x)=(-1.02, -0.62)
# iter=162; x=(0.30, 0.09); f(x)=0.48; grad f(x)=(-1.01, -0.62)
# iter=163; x=(0.31, 0.09); f(x)=0.48; grad f(x)=(-1.01, -0.62)
# iter=164; x=(0.31, 0.09); f(x)=0.48; grad f(x)=(-1.01, -0.62)
# iter=165; x=(0.31, 0.09); f(x)=0.48; grad f(x)=(-1.00, -0.62)
# iter=166; x=(0.31, 0.09); f(x)=0.48; grad f(x)=(-1.00, -0.62)
# iter=167; x=(0.31, 0.09); f(x)=0.48; grad f(x)=(-1.00, -0.62)
# iter=168; x=(0.31, 0.09); f(x)=0.48; grad f(x)=(-0.99, -0.62)
# iter=169; x=(0.31, 0.09); f(x)=0.47; grad f(x)=(-0.99, -0.62)
# iter=170; x=(0.31, 0.09); f(x)=0.47; grad f(x)=(-0.99, -0.62)
# iter=171; x=(0.31, 0.10); f(x)=0.47; grad f(x)=(-0.98, -0.62)
# iter=172; x=(0.31, 0.10); f(x)=0.47; grad f(x)=(-0.98, -0.62)
# iter=173; x=(0.32, 0.10); f(x)=0.47; grad f(x)=(-0.98, -0.62)
# iter=174; x=(0.32, 0.10); f(x)=0.47; grad f(x)=(-0.98, -0.62)
# iter=175; x=(0.32, 0.10); f(x)=0.47; grad f(x)=(-0.97, -0.62)
# iter=176; x=(0.32, 0.10); f(x)=0.47; grad f(x)=(-0.97, -0.62)
# iter=177; x=(0.32, 0.10); f(x)=0.46; grad f(x)=(-0.97, -0.62)
# iter=178; x=(0.32, 0.10); f(x)=0.46; grad f(x)=(-0.96, -0.62)
# iter=179; x=(0.32, 0.10); f(x)=0.46; grad f(x)=(-0.96, -0.62)
# iter=180; x=(0.32, 0.10); f(x)=0.46; grad f(x)=(-0.96, -0.62)
# iter=181; x=(0.32, 0.10); f(x)=0.46; grad f(x)=(-0.95, -0.62)
# iter=182; x=(0.32, 0.10); f(x)=0.46; grad f(x)=(-0.95, -0.62)
# iter=183; x=(0.33, 0.10); f(x)=0.46; grad f(x)=(-0.95, -0.62)
# iter=184; x=(0.33, 0.10); f(x)=0.45; grad f(x)=(-0.94, -0.62)
# iter=185; x=(0.33, 0.10); f(x)=0.45; grad f(x)=(-0.94, -0.62)
# iter=186; x=(0.33, 0.10); f(x)=0.45; grad f(x)=(-0.94, -0.62)
# iter=187; x=(0.33, 0.11); f(x)=0.45; grad f(x)=(-0.94, -0.62)
# iter=188; x=(0.33, 0.11); f(x)=0.45; grad f(x)=(-0.93, -0.62)
# iter=189; x=(0.33, 0.11); f(x)=0.45; grad f(x)=(-0.93, -0.62)
# iter=190; x=(0.33, 0.11); f(x)=0.45; grad f(x)=(-0.93, -0.62)
# iter=191; x=(0.33, 0.11); f(x)=0.45; grad f(x)=(-0.92, -0.62)
# iter=192; x=(0.33, 0.11); f(x)=0.44; grad f(x)=(-0.92, -0.62)
# iter=193; x=(0.33, 0.11); f(x)=0.44; grad f(x)=(-0.92, -0.62)
# iter=194; x=(0.34, 0.11); f(x)=0.44; grad f(x)=(-0.92, -0.62)
# iter=195; x=(0.34, 0.11); f(x)=0.44; grad f(x)=(-0.91, -0.62)
# iter=196; x=(0.34, 0.11); f(x)=0.44; grad f(x)=(-0.91, -0.62)
# iter=197; x=(0.34, 0.11); f(x)=0.44; grad f(x)=(-0.91, -0.62)
# iter=198; x=(0.34, 0.11); f(x)=0.44; grad f(x)=(-0.90, -0.62)
# iter=199; x=(0.34, 0.11); f(x)=0.44; grad f(x)=(-0.90, -0.62)
# iter=200; x=(0.34, 0.11); f(x)=0.44; grad f(x)=(-0.90, -0.61)
# iter=201; x=(0.34, 0.11); f(x)=0.43; grad f(x)=(-0.90, -0.61)
# iter=202; x=(0.34, 0.11); f(x)=0.43; grad f(x)=(-0.89, -0.61)
# iter=203; x=(0.34, 0.12); f(x)=0.43; grad f(x)=(-0.89, -0.61)
# iter=204; x=(0.34, 0.12); f(x)=0.43; grad f(x)=(-0.89, -0.61)
# iter=205; x=(0.35, 0.12); f(x)=0.43; grad f(x)=(-0.89, -0.61)
# iter=206; x=(0.35, 0.12); f(x)=0.43; grad f(x)=(-0.88, -0.61)
# iter=207; x=(0.35, 0.12); f(x)=0.43; grad f(x)=(-0.88, -0.61)
# iter=208; x=(0.35, 0.12); f(x)=0.43; grad f(x)=(-0.88, -0.61)
# iter=209; x=(0.35, 0.12); f(x)=0.42; grad f(x)=(-0.87, -0.61)
# iter=210; x=(0.35, 0.12); f(x)=0.42; grad f(x)=(-0.87, -0.61)
# iter=211; x=(0.35, 0.12); f(x)=0.42; grad f(x)=(-0.87, -0.61)
# iter=212; x=(0.35, 0.12); f(x)=0.42; grad f(x)=(-0.87, -0.61)
# iter=213; x=(0.35, 0.12); f(x)=0.42; grad f(x)=(-0.86, -0.61)
# iter=214; x=(0.35, 0.12); f(x)=0.42; grad f(x)=(-0.86, -0.61)
# iter=215; x=(0.35, 0.12); f(x)=0.42; grad f(x)=(-0.86, -0.61)
# iter=216; x=(0.36, 0.12); f(x)=0.42; grad f(x)=(-0.86, -0.61)
# iter=217; x=(0.36, 0.12); f(x)=0.42; grad f(x)=(-0.85, -0.61)
# iter=218; x=(0.36, 0.12); f(x)=0.41; grad f(x)=(-0.85, -0.61)
# iter=219; x=(0.36, 0.12); f(x)=0.41; grad f(x)=(-0.85, -0.61)
# iter=220; x=(0.36, 0.13); f(x)=0.41; grad f(x)=(-0.85, -0.61)
# iter=221; x=(0.36, 0.13); f(x)=0.41; grad f(x)=(-0.84, -0.61)
# iter=222; x=(0.36, 0.13); f(x)=0.41; grad f(x)=(-0.84, -0.61)
# iter=223; x=(0.36, 0.13); f(x)=0.41; grad f(x)=(-0.84, -0.61)
# iter=224; x=(0.36, 0.13); f(x)=0.41; grad f(x)=(-0.84, -0.61)
# iter=225; x=(0.36, 0.13); f(x)=0.41; grad f(x)=(-0.83, -0.61)
# iter=226; x=(0.36, 0.13); f(x)=0.41; grad f(x)=(-0.83, -0.61)
# iter=227; x=(0.36, 0.13); f(x)=0.41; grad f(x)=(-0.83, -0.61)
# iter=228; x=(0.37, 0.13); f(x)=0.40; grad f(x)=(-0.83, -0.61)
# iter=229; x=(0.37, 0.13); f(x)=0.40; grad f(x)=(-0.82, -0.61)
# iter=230; x=(0.37, 0.13); f(x)=0.40; grad f(x)=(-0.82, -0.61)
# iter=231; x=(0.37, 0.13); f(x)=0.40; grad f(x)=(-0.82, -0.61)
# iter=232; x=(0.37, 0.13); f(x)=0.40; grad f(x)=(-0.82, -0.60)
# iter=233; x=(0.37, 0.13); f(x)=0.40; grad f(x)=(-0.82, -0.60)
# iter=234; x=(0.37, 0.13); f(x)=0.40; grad f(x)=(-0.81, -0.60)
# iter=235; x=(0.37, 0.13); f(x)=0.40; grad f(x)=(-0.81, -0.60)
# iter=236; x=(0.37, 0.14); f(x)=0.40; grad f(x)=(-0.81, -0.60)
# iter=237; x=(0.37, 0.14); f(x)=0.39; grad f(x)=(-0.81, -0.60)
# iter=238; x=(0.37, 0.14); f(x)=0.39; grad f(x)=(-0.80, -0.60)
# iter=239; x=(0.37, 0.14); f(x)=0.39; grad f(x)=(-0.80, -0.60)
# iter=240; x=(0.37, 0.14); f(x)=0.39; grad f(x)=(-0.80, -0.60)
# iter=241; x=(0.38, 0.14); f(x)=0.39; grad f(x)=(-0.80, -0.60)
# iter=242; x=(0.38, 0.14); f(x)=0.39; grad f(x)=(-0.79, -0.60)
# iter=243; x=(0.38, 0.14); f(x)=0.39; grad f(x)=(-0.79, -0.60)
# iter=244; x=(0.38, 0.14); f(x)=0.39; grad f(x)=(-0.79, -0.60)
# iter=245; x=(0.38, 0.14); f(x)=0.39; grad f(x)=(-0.79, -0.60)
# iter=246; x=(0.38, 0.14); f(x)=0.39; grad f(x)=(-0.79, -0.60)
# iter=247; x=(0.38, 0.14); f(x)=0.38; grad f(x)=(-0.78, -0.60)
# iter=248; x=(0.38, 0.14); f(x)=0.38; grad f(x)=(-0.78, -0.60)
# iter=249; x=(0.38, 0.14); f(x)=0.38; grad f(x)=(-0.78, -0.60)
# iter=250; x=(0.38, 0.14); f(x)=0.38; grad f(x)=(-0.78, -0.60)
# iter=251; x=(0.38, 0.14); f(x)=0.38; grad f(x)=(-0.77, -0.60)
# iter=252; x=(0.38, 0.14); f(x)=0.38; grad f(x)=(-0.77, -0.60)
# iter=253; x=(0.39, 0.15); f(x)=0.38; grad f(x)=(-0.77, -0.60)
# iter=254; x=(0.39, 0.15); f(x)=0.38; grad f(x)=(-0.77, -0.60)
# iter=255; x=(0.39, 0.15); f(x)=0.38; grad f(x)=(-0.77, -0.60)
# iter=256; x=(0.39, 0.15); f(x)=0.38; grad f(x)=(-0.76, -0.59)
# iter=257; x=(0.39, 0.15); f(x)=0.38; grad f(x)=(-0.76, -0.59)
# iter=258; x=(0.39, 0.15); f(x)=0.37; grad f(x)=(-0.76, -0.59)
# iter=259; x=(0.39, 0.15); f(x)=0.37; grad f(x)=(-0.76, -0.59)
# iter=260; x=(0.39, 0.15); f(x)=0.37; grad f(x)=(-0.76, -0.59)
# iter=261; x=(0.39, 0.15); f(x)=0.37; grad f(x)=(-0.75, -0.59)
# iter=262; x=(0.39, 0.15); f(x)=0.37; grad f(x)=(-0.75, -0.59)
# iter=263; x=(0.39, 0.15); f(x)=0.37; grad f(x)=(-0.75, -0.59)
# iter=264; x=(0.39, 0.15); f(x)=0.37; grad f(x)=(-0.75, -0.59)
# iter=265; x=(0.39, 0.15); f(x)=0.37; grad f(x)=(-0.75, -0.59)
# iter=266; x=(0.39, 0.15); f(x)=0.37; grad f(x)=(-0.74, -0.59)
# iter=267; x=(0.40, 0.15); f(x)=0.37; grad f(x)=(-0.74, -0.59)
# iter=268; x=(0.40, 0.15); f(x)=0.37; grad f(x)=(-0.74, -0.59)
# iter=269; x=(0.40, 0.15); f(x)=0.36; grad f(x)=(-0.74, -0.59)
# iter=270; x=(0.40, 0.16); f(x)=0.36; grad f(x)=(-0.74, -0.59)
# iter=271; x=(0.40, 0.16); f(x)=0.36; grad f(x)=(-0.73, -0.59)
# iter=272; x=(0.40, 0.16); f(x)=0.36; grad f(x)=(-0.73, -0.59)
# iter=273; x=(0.40, 0.16); f(x)=0.36; grad f(x)=(-0.73, -0.59)
# iter=274; x=(0.40, 0.16); f(x)=0.36; grad f(x)=(-0.73, -0.59)
# iter=275; x=(0.40, 0.16); f(x)=0.36; grad f(x)=(-0.73, -0.59)
# iter=276; x=(0.40, 0.16); f(x)=0.36; grad f(x)=(-0.72, -0.59)
# iter=277; x=(0.40, 0.16); f(x)=0.36; grad f(x)=(-0.72, -0.59)
# iter=278; x=(0.40, 0.16); f(x)=0.36; grad f(x)=(-0.72, -0.58)
# iter=279; x=(0.40, 0.16); f(x)=0.36; grad f(x)=(-0.72, -0.58)
# iter=280; x=(0.41, 0.16); f(x)=0.35; grad f(x)=(-0.72, -0.58)
# iter=281; x=(0.41, 0.16); f(x)=0.35; grad f(x)=(-0.71, -0.58)
# iter=282; x=(0.41, 0.16); f(x)=0.35; grad f(x)=(-0.71, -0.58)
# iter=283; x=(0.41, 0.16); f(x)=0.35; grad f(x)=(-0.71, -0.58)
# iter=284; x=(0.41, 0.16); f(x)=0.35; grad f(x)=(-0.71, -0.58)
# iter=285; x=(0.41, 0.16); f(x)=0.35; grad f(x)=(-0.71, -0.58)
# iter=286; x=(0.41, 0.16); f(x)=0.35; grad f(x)=(-0.71, -0.58)
# iter=287; x=(0.41, 0.17); f(x)=0.35; grad f(x)=(-0.70, -0.58)
# iter=288; x=(0.41, 0.17); f(x)=0.35; grad f(x)=(-0.70, -0.58)
# iter=289; x=(0.41, 0.17); f(x)=0.35; grad f(x)=(-0.70, -0.58)
# iter=290; x=(0.41, 0.17); f(x)=0.35; grad f(x)=(-0.70, -0.58)
# iter=291; x=(0.41, 0.17); f(x)=0.35; grad f(x)=(-0.70, -0.58)
# iter=292; x=(0.41, 0.17); f(x)=0.34; grad f(x)=(-0.69, -0.58)
# iter=293; x=(0.41, 0.17); f(x)=0.34; grad f(x)=(-0.69, -0.58)
# iter=294; x=(0.42, 0.17); f(x)=0.34; grad f(x)=(-0.69, -0.58)
# iter=295; x=(0.42, 0.17); f(x)=0.34; grad f(x)=(-0.69, -0.58)
# iter=296; x=(0.42, 0.17); f(x)=0.34; grad f(x)=(-0.69, -0.58)
# iter=297; x=(0.42, 0.17); f(x)=0.34; grad f(x)=(-0.69, -0.58)
# iter=298; x=(0.42, 0.17); f(x)=0.34; grad f(x)=(-0.68, -0.57)
# iter=299; x=(0.42, 0.17); f(x)=0.34; grad f(x)=(-0.68, -0.57)
# iter=300; x=(0.42, 0.17); f(x)=0.34; grad f(x)=(-0.68, -0.57)
# iter=301; x=(0.42, 0.17); f(x)=0.34; grad f(x)=(-0.68, -0.57)
# iter=302; x=(0.42, 0.17); f(x)=0.34; grad f(x)=(-0.68, -0.57)
# iter=303; x=(0.42, 0.17); f(x)=0.34; grad f(x)=(-0.68, -0.57)
# iter=304; x=(0.42, 0.18); f(x)=0.34; grad f(x)=(-0.67, -0.57)
# iter=305; x=(0.42, 0.18); f(x)=0.33; grad f(x)=(-0.67, -0.57)
# iter=306; x=(0.42, 0.18); f(x)=0.33; grad f(x)=(-0.67, -0.57)
# iter=307; x=(0.42, 0.18); f(x)=0.33; grad f(x)=(-0.67, -0.57)
# iter=308; x=(0.42, 0.18); f(x)=0.33; grad f(x)=(-0.67, -0.57)
# iter=309; x=(0.43, 0.18); f(x)=0.33; grad f(x)=(-0.67, -0.57)
# iter=310; x=(0.43, 0.18); f(x)=0.33; grad f(x)=(-0.66, -0.57)
# iter=311; x=(0.43, 0.18); f(x)=0.33; grad f(x)=(-0.66, -0.57)
# iter=312; x=(0.43, 0.18); f(x)=0.33; grad f(x)=(-0.66, -0.57)
# iter=313; x=(0.43, 0.18); f(x)=0.33; grad f(x)=(-0.66, -0.57)
# iter=314; x=(0.43, 0.18); f(x)=0.33; grad f(x)=(-0.66, -0.57)
# iter=315; x=(0.43, 0.18); f(x)=0.33; grad f(x)=(-0.66, -0.57)
# iter=316; x=(0.43, 0.18); f(x)=0.33; grad f(x)=(-0.65, -0.57)
# iter=317; x=(0.43, 0.18); f(x)=0.33; grad f(x)=(-0.65, -0.56)
# iter=318; x=(0.43, 0.18); f(x)=0.32; grad f(x)=(-0.65, -0.56)
# iter=319; x=(0.43, 0.18); f(x)=0.32; grad f(x)=(-0.65, -0.56)
# iter=320; x=(0.43, 0.18); f(x)=0.32; grad f(x)=(-0.65, -0.56)
# iter=321; x=(0.43, 0.18); f(x)=0.32; grad f(x)=(-0.65, -0.56)
# iter=322; x=(0.43, 0.19); f(x)=0.32; grad f(x)=(-0.64, -0.56)
# iter=323; x=(0.43, 0.19); f(x)=0.32; grad f(x)=(-0.64, -0.56)
# iter=324; x=(0.44, 0.19); f(x)=0.32; grad f(x)=(-0.64, -0.56)
# iter=325; x=(0.44, 0.19); f(x)=0.32; grad f(x)=(-0.64, -0.56)
# iter=326; x=(0.44, 0.19); f(x)=0.32; grad f(x)=(-0.64, -0.56)
# iter=327; x=(0.44, 0.19); f(x)=0.32; grad f(x)=(-0.64, -0.56)
# iter=328; x=(0.44, 0.19); f(x)=0.32; grad f(x)=(-0.64, -0.56)
# iter=329; x=(0.44, 0.19); f(x)=0.32; grad f(x)=(-0.63, -0.56)
# iter=330; x=(0.44, 0.19); f(x)=0.32; grad f(x)=(-0.63, -0.56)
# iter=331; x=(0.44, 0.19); f(x)=0.31; grad f(x)=(-0.63, -0.56)
# iter=332; x=(0.44, 0.19); f(x)=0.31; grad f(x)=(-0.63, -0.56)
# iter=333; x=(0.44, 0.19); f(x)=0.31; grad f(x)=(-0.63, -0.56)
# iter=334; x=(0.44, 0.19); f(x)=0.31; grad f(x)=(-0.63, -0.56)
# iter=335; x=(0.44, 0.19); f(x)=0.31; grad f(x)=(-0.62, -0.56)
# iter=336; x=(0.44, 0.19); f(x)=0.31; grad f(x)=(-0.62, -0.55)
# iter=337; x=(0.44, 0.19); f(x)=0.31; grad f(x)=(-0.62, -0.55)
# iter=338; x=(0.44, 0.19); f(x)=0.31; grad f(x)=(-0.62, -0.55)
# iter=339; x=(0.44, 0.19); f(x)=0.31; grad f(x)=(-0.62, -0.55)
# iter=340; x=(0.45, 0.20); f(x)=0.31; grad f(x)=(-0.62, -0.55)
# iter=341; x=(0.45, 0.20); f(x)=0.31; grad f(x)=(-0.62, -0.55)
# iter=342; x=(0.45, 0.20); f(x)=0.31; grad f(x)=(-0.61, -0.55)
# iter=343; x=(0.45, 0.20); f(x)=0.31; grad f(x)=(-0.61, -0.55)
# iter=344; x=(0.45, 0.20); f(x)=0.31; grad f(x)=(-0.61, -0.55)
# iter=345; x=(0.45, 0.20); f(x)=0.31; grad f(x)=(-0.61, -0.55)
# iter=346; x=(0.45, 0.20); f(x)=0.30; grad f(x)=(-0.61, -0.55)
# iter=347; x=(0.45, 0.20); f(x)=0.30; grad f(x)=(-0.61, -0.55)
# iter=348; x=(0.45, 0.20); f(x)=0.30; grad f(x)=(-0.61, -0.55)
# iter=349; x=(0.45, 0.20); f(x)=0.30; grad f(x)=(-0.60, -0.55)
# iter=350; x=(0.45, 0.20); f(x)=0.30; grad f(x)=(-0.60, -0.55)
# iter=351; x=(0.45, 0.20); f(x)=0.30; grad f(x)=(-0.60, -0.55)
# iter=352; x=(0.45, 0.20); f(x)=0.30; grad f(x)=(-0.60, -0.55)
# iter=353; x=(0.45, 0.20); f(x)=0.30; grad f(x)=(-0.60, -0.55)
# iter=354; x=(0.45, 0.20); f(x)=0.30; grad f(x)=(-0.60, -0.55)
# iter=355; x=(0.45, 0.20); f(x)=0.30; grad f(x)=(-0.60, -0.54)
# iter=356; x=(0.45, 0.20); f(x)=0.30; grad f(x)=(-0.60, -0.54)
# iter=357; x=(0.46, 0.20); f(x)=0.30; grad f(x)=(-0.59, -0.54)
# iter=358; x=(0.46, 0.21); f(x)=0.30; grad f(x)=(-0.59, -0.54)
# iter=359; x=(0.46, 0.21); f(x)=0.30; grad f(x)=(-0.59, -0.54)
# iter=360; x=(0.46, 0.21); f(x)=0.30; grad f(x)=(-0.59, -0.54)
# iter=361; x=(0.46, 0.21); f(x)=0.29; grad f(x)=(-0.59, -0.54)
# iter=362; x=(0.46, 0.21); f(x)=0.29; grad f(x)=(-0.59, -0.54)
# iter=363; x=(0.46, 0.21); f(x)=0.29; grad f(x)=(-0.59, -0.54)
# iter=364; x=(0.46, 0.21); f(x)=0.29; grad f(x)=(-0.58, -0.54)
# iter=365; x=(0.46, 0.21); f(x)=0.29; grad f(x)=(-0.58, -0.54)
# iter=366; x=(0.46, 0.21); f(x)=0.29; grad f(x)=(-0.58, -0.54)
# iter=367; x=(0.46, 0.21); f(x)=0.29; grad f(x)=(-0.58, -0.54)
# iter=368; x=(0.46, 0.21); f(x)=0.29; grad f(x)=(-0.58, -0.54)
# iter=369; x=(0.46, 0.21); f(x)=0.29; grad f(x)=(-0.58, -0.54)
# iter=370; x=(0.46, 0.21); f(x)=0.29; grad f(x)=(-0.58, -0.54)
# iter=371; x=(0.46, 0.21); f(x)=0.29; grad f(x)=(-0.58, -0.54)
# iter=372; x=(0.46, 0.21); f(x)=0.29; grad f(x)=(-0.57, -0.54)
# iter=373; x=(0.46, 0.21); f(x)=0.29; grad f(x)=(-0.57, -0.54)
# iter=374; x=(0.47, 0.21); f(x)=0.29; grad f(x)=(-0.57, -0.53)
# iter=375; x=(0.47, 0.21); f(x)=0.29; grad f(x)=(-0.57, -0.53)
# iter=376; x=(0.47, 0.21); f(x)=0.29; grad f(x)=(-0.57, -0.53)
# iter=377; x=(0.47, 0.22); f(x)=0.28; grad f(x)=(-0.57, -0.53)
# iter=378; x=(0.47, 0.22); f(x)=0.28; grad f(x)=(-0.57, -0.53)
# iter=379; x=(0.47, 0.22); f(x)=0.28; grad f(x)=(-0.57, -0.53)
# iter=380; x=(0.47, 0.22); f(x)=0.28; grad f(x)=(-0.56, -0.53)
# iter=381; x=(0.47, 0.22); f(x)=0.28; grad f(x)=(-0.56, -0.53)
# iter=382; x=(0.47, 0.22); f(x)=0.28; grad f(x)=(-0.56, -0.53)
# iter=383; x=(0.47, 0.22); f(x)=0.28; grad f(x)=(-0.56, -0.53)
# iter=384; x=(0.47, 0.22); f(x)=0.28; grad f(x)=(-0.56, -0.53)
# iter=385; x=(0.47, 0.22); f(x)=0.28; grad f(x)=(-0.56, -0.53)
# iter=386; x=(0.47, 0.22); f(x)=0.28; grad f(x)=(-0.56, -0.53)
# iter=387; x=(0.47, 0.22); f(x)=0.28; grad f(x)=(-0.56, -0.53)
# iter=388; x=(0.47, 0.22); f(x)=0.28; grad f(x)=(-0.55, -0.53)
# iter=389; x=(0.47, 0.22); f(x)=0.28; grad f(x)=(-0.55, -0.53)
# iter=390; x=(0.47, 0.22); f(x)=0.28; grad f(x)=(-0.55, -0.53)
# iter=391; x=(0.47, 0.22); f(x)=0.28; grad f(x)=(-0.55, -0.53)
# iter=392; x=(0.48, 0.22); f(x)=0.28; grad f(x)=(-0.55, -0.53)
# iter=393; x=(0.48, 0.22); f(x)=0.28; grad f(x)=(-0.55, -0.52)
# iter=394; x=(0.48, 0.22); f(x)=0.27; grad f(x)=(-0.55, -0.52)
# iter=395; x=(0.48, 0.23); f(x)=0.27; grad f(x)=(-0.55, -0.52)
# iter=396; x=(0.48, 0.23); f(x)=0.27; grad f(x)=(-0.54, -0.52)
# iter=397; x=(0.48, 0.23); f(x)=0.27; grad f(x)=(-0.54, -0.52)
# iter=398; x=(0.48, 0.23); f(x)=0.27; grad f(x)=(-0.54, -0.52)
# iter=399; x=(0.48, 0.23); f(x)=0.27; grad f(x)=(-0.54, -0.52)
# iter=400; x=(0.48, 0.23); f(x)=0.27; grad f(x)=(-0.54, -0.52)
# iter=401; x=(0.48, 0.23); f(x)=0.27; grad f(x)=(-0.54, -0.52)
# iter=402; x=(0.48, 0.23); f(x)=0.27; grad f(x)=(-0.54, -0.52)
# iter=403; x=(0.48, 0.23); f(x)=0.27; grad f(x)=(-0.54, -0.52)
# iter=404; x=(0.48, 0.23); f(x)=0.27; grad f(x)=(-0.54, -0.52)
# iter=405; x=(0.48, 0.23); f(x)=0.27; grad f(x)=(-0.53, -0.52)
# iter=406; x=(0.48, 0.23); f(x)=0.27; grad f(x)=(-0.53, -0.52)
# iter=407; x=(0.48, 0.23); f(x)=0.27; grad f(x)=(-0.53, -0.52)
# iter=408; x=(0.48, 0.23); f(x)=0.27; grad f(x)=(-0.53, -0.52)
# iter=409; x=(0.48, 0.23); f(x)=0.27; grad f(x)=(-0.53, -0.52)
# iter=410; x=(0.49, 0.23); f(x)=0.27; grad f(x)=(-0.53, -0.52)
# iter=411; x=(0.49, 0.23); f(x)=0.27; grad f(x)=(-0.53, -0.52)
# iter=412; x=(0.49, 0.23); f(x)=0.26; grad f(x)=(-0.53, -0.52)
# iter=413; x=(0.49, 0.23); f(x)=0.26; grad f(x)=(-0.53, -0.51)
# iter=414; x=(0.49, 0.23); f(x)=0.26; grad f(x)=(-0.52, -0.51)
# iter=415; x=(0.49, 0.24); f(x)=0.26; grad f(x)=(-0.52, -0.51)
# iter=416; x=(0.49, 0.24); f(x)=0.26; grad f(x)=(-0.52, -0.51)
# iter=417; x=(0.49, 0.24); f(x)=0.26; grad f(x)=(-0.52, -0.51)
# iter=418; x=(0.49, 0.24); f(x)=0.26; grad f(x)=(-0.52, -0.51)
# iter=419; x=(0.49, 0.24); f(x)=0.26; grad f(x)=(-0.52, -0.51)
# iter=420; x=(0.49, 0.24); f(x)=0.26; grad f(x)=(-0.52, -0.51)
# iter=421; x=(0.49, 0.24); f(x)=0.26; grad f(x)=(-0.52, -0.51)
# iter=422; x=(0.49, 0.24); f(x)=0.26; grad f(x)=(-0.52, -0.51)
# iter=423; x=(0.49, 0.24); f(x)=0.26; grad f(x)=(-0.51, -0.51)
# iter=424; x=(0.49, 0.24); f(x)=0.26; grad f(x)=(-0.51, -0.51)
# iter=425; x=(0.49, 0.24); f(x)=0.26; grad f(x)=(-0.51, -0.51)
# iter=426; x=(0.49, 0.24); f(x)=0.26; grad f(x)=(-0.51, -0.51)
# iter=427; x=(0.49, 0.24); f(x)=0.26; grad f(x)=(-0.51, -0.51)
# iter=428; x=(0.49, 0.24); f(x)=0.26; grad f(x)=(-0.51, -0.51)
# iter=429; x=(0.50, 0.24); f(x)=0.26; grad f(x)=(-0.51, -0.51)
# iter=430; x=(0.50, 0.24); f(x)=0.26; grad f(x)=(-0.51, -0.51)
# iter=431; x=(0.50, 0.24); f(x)=0.25; grad f(x)=(-0.51, -0.51)
# iter=432; x=(0.50, 0.24); f(x)=0.25; grad f(x)=(-0.51, -0.50)
# iter=433; x=(0.50, 0.24); f(x)=0.25; grad f(x)=(-0.50, -0.50)
# iter=434; x=(0.50, 0.25); f(x)=0.25; grad f(x)=(-0.50, -0.50)
# iter=435; x=(0.50, 0.25); f(x)=0.25; grad f(x)=(-0.50, -0.50)
# iter=436; x=(0.50, 0.25); f(x)=0.25; grad f(x)=(-0.50, -0.50)
# iter=437; x=(0.50, 0.25); f(x)=0.25; grad f(x)=(-0.50, -0.50)
# iter=438; x=(0.50, 0.25); f(x)=0.25; grad f(x)=(-0.50, -0.50)
# iter=439; x=(0.50, 0.25); f(x)=0.25; grad f(x)=(-0.50, -0.50)
# iter=440; x=(0.50, 0.25); f(x)=0.25; grad f(x)=(-0.50, -0.50)
# iter=441; x=(0.50, 0.25); f(x)=0.25; grad f(x)=(-0.50, -0.50)
# iter=442; x=(0.50, 0.25); f(x)=0.25; grad f(x)=(-0.50, -0.50)
# iter=443; x=(0.50, 0.25); f(x)=0.25; grad f(x)=(-0.49, -0.50)
# iter=444; x=(0.50, 0.25); f(x)=0.25; grad f(x)=(-0.49, -0.50)
# iter=445; x=(0.50, 0.25); f(x)=0.25; grad f(x)=(-0.49, -0.50)
# iter=446; x=(0.50, 0.25); f(x)=0.25; grad f(x)=(-0.49, -0.50)
# iter=447; x=(0.50, 0.25); f(x)=0.25; grad f(x)=(-0.49, -0.50)
# iter=448; x=(0.50, 0.25); f(x)=0.25; grad f(x)=(-0.49, -0.50)
# iter=449; x=(0.51, 0.25); f(x)=0.25; grad f(x)=(-0.49, -0.50)
# iter=450; x=(0.51, 0.25); f(x)=0.25; grad f(x)=(-0.49, -0.50)
# iter=451; x=(0.51, 0.25); f(x)=0.24; grad f(x)=(-0.49, -0.50)
# iter=452; x=(0.51, 0.25); f(x)=0.24; grad f(x)=(-0.49, -0.49)
# iter=453; x=(0.51, 0.25); f(x)=0.24; grad f(x)=(-0.48, -0.49)
# iter=454; x=(0.51, 0.26); f(x)=0.24; grad f(x)=(-0.48, -0.49)
# iter=455; x=(0.51, 0.26); f(x)=0.24; grad f(x)=(-0.48, -0.49)
# iter=456; x=(0.51, 0.26); f(x)=0.24; grad f(x)=(-0.48, -0.49)
# iter=457; x=(0.51, 0.26); f(x)=0.24; grad f(x)=(-0.48, -0.49)
# iter=458; x=(0.51, 0.26); f(x)=0.24; grad f(x)=(-0.48, -0.49)
# iter=459; x=(0.51, 0.26); f(x)=0.24; grad f(x)=(-0.48, -0.49)
# iter=460; x=(0.51, 0.26); f(x)=0.24; grad f(x)=(-0.48, -0.49)
# iter=461; x=(0.51, 0.26); f(x)=0.24; grad f(x)=(-0.48, -0.49)
# iter=462; x=(0.51, 0.26); f(x)=0.24; grad f(x)=(-0.48, -0.49)
# iter=463; x=(0.51, 0.26); f(x)=0.24; grad f(x)=(-0.48, -0.49)
# iter=464; x=(0.51, 0.26); f(x)=0.24; grad f(x)=(-0.47, -0.49)
# iter=465; x=(0.51, 0.26); f(x)=0.24; grad f(x)=(-0.47, -0.49)
# iter=466; x=(0.51, 0.26); f(x)=0.24; grad f(x)=(-0.47, -0.49)
# iter=467; x=(0.51, 0.26); f(x)=0.24; grad f(x)=(-0.47, -0.49)
# iter=468; x=(0.51, 0.26); f(x)=0.24; grad f(x)=(-0.47, -0.49)
# iter=469; x=(0.51, 0.26); f(x)=0.24; grad f(x)=(-0.47, -0.49)
# iter=470; x=(0.52, 0.26); f(x)=0.24; grad f(x)=(-0.47, -0.49)
# iter=471; x=(0.52, 0.26); f(x)=0.24; grad f(x)=(-0.47, -0.49)
# iter=472; x=(0.52, 0.26); f(x)=0.23; grad f(x)=(-0.47, -0.49)
# iter=473; x=(0.52, 0.26); f(x)=0.23; grad f(x)=(-0.47, -0.48)
# iter=474; x=(0.52, 0.26); f(x)=0.23; grad f(x)=(-0.47, -0.48)
# iter=475; x=(0.52, 0.27); f(x)=0.23; grad f(x)=(-0.46, -0.48)
# iter=476; x=(0.52, 0.27); f(x)=0.23; grad f(x)=(-0.46, -0.48)
# iter=477; x=(0.52, 0.27); f(x)=0.23; grad f(x)=(-0.46, -0.48)
# iter=478; x=(0.52, 0.27); f(x)=0.23; grad f(x)=(-0.46, -0.48)
# iter=479; x=(0.52, 0.27); f(x)=0.23; grad f(x)=(-0.46, -0.48)
# iter=480; x=(0.52, 0.27); f(x)=0.23; grad f(x)=(-0.46, -0.48)
# iter=481; x=(0.52, 0.27); f(x)=0.23; grad f(x)=(-0.46, -0.48)
# iter=482; x=(0.52, 0.27); f(x)=0.23; grad f(x)=(-0.46, -0.48)
# iter=483; x=(0.52, 0.27); f(x)=0.23; grad f(x)=(-0.46, -0.48)
# iter=484; x=(0.52, 0.27); f(x)=0.23; grad f(x)=(-0.46, -0.48)
# iter=485; x=(0.52, 0.27); f(x)=0.23; grad f(x)=(-0.46, -0.48)
# iter=486; x=(0.52, 0.27); f(x)=0.23; grad f(x)=(-0.46, -0.48)
# iter=487; x=(0.52, 0.27); f(x)=0.23; grad f(x)=(-0.45, -0.48)
# iter=488; x=(0.52, 0.27); f(x)=0.23; grad f(x)=(-0.45, -0.48)
# iter=489; x=(0.52, 0.27); f(x)=0.23; grad f(x)=(-0.45, -0.48)
# iter=490; x=(0.52, 0.27); f(x)=0.23; grad f(x)=(-0.45, -0.48)
# iter=491; x=(0.52, 0.27); f(x)=0.23; grad f(x)=(-0.45, -0.48)
# iter=492; x=(0.53, 0.27); f(x)=0.23; grad f(x)=(-0.45, -0.48)
# iter=493; x=(0.53, 0.27); f(x)=0.23; grad f(x)=(-0.45, -0.47)
# iter=494; x=(0.53, 0.27); f(x)=0.23; grad f(x)=(-0.45, -0.47)
# iter=495; x=(0.53, 0.27); f(x)=0.22; grad f(x)=(-0.45, -0.47)
# iter=496; x=(0.53, 0.28); f(x)=0.22; grad f(x)=(-0.45, -0.47)
# iter=497; x=(0.53, 0.28); f(x)=0.22; grad f(x)=(-0.45, -0.47)
# iter=498; x=(0.53, 0.28); f(x)=0.22; grad f(x)=(-0.45, -0.47)
# iter=499; x=(0.53, 0.28); f(x)=0.22; grad f(x)=(-0.44, -0.47)
# iter=500; x=(0.53, 0.28); f(x)=0.22; grad f(x)=(-0.44, -0.47)
# iter=501; x=(0.53, 0.28); f(x)=0.22; grad f(x)=(-0.44, -0.47)
# iter=502; x=(0.53, 0.28); f(x)=0.22; grad f(x)=(-0.44, -0.47)
# iter=503; x=(0.53, 0.28); f(x)=0.22; grad f(x)=(-0.44, -0.47)
# iter=504; x=(0.53, 0.28); f(x)=0.22; grad f(x)=(-0.44, -0.47)
# iter=505; x=(0.53, 0.28); f(x)=0.22; grad f(x)=(-0.44, -0.47)
# iter=506; x=(0.53, 0.28); f(x)=0.22; grad f(x)=(-0.44, -0.47)
# iter=507; x=(0.53, 0.28); f(x)=0.22; grad f(x)=(-0.44, -0.47)
# iter=508; x=(0.53, 0.28); f(x)=0.22; grad f(x)=(-0.44, -0.47)
# iter=509; x=(0.53, 0.28); f(x)=0.22; grad f(x)=(-0.44, -0.47)
# iter=510; x=(0.53, 0.28); f(x)=0.22; grad f(x)=(-0.44, -0.47)
# iter=511; x=(0.53, 0.28); f(x)=0.22; grad f(x)=(-0.43, -0.47)
# iter=512; x=(0.53, 0.28); f(x)=0.22; grad f(x)=(-0.43, -0.47)
# iter=513; x=(0.53, 0.28); f(x)=0.22; grad f(x)=(-0.43, -0.47)
# iter=514; x=(0.53, 0.28); f(x)=0.22; grad f(x)=(-0.43, -0.47)
# iter=515; x=(0.54, 0.28); f(x)=0.22; grad f(x)=(-0.43, -0.46)
# iter=516; x=(0.54, 0.28); f(x)=0.22; grad f(x)=(-0.43, -0.46)
# iter=517; x=(0.54, 0.29); f(x)=0.22; grad f(x)=(-0.43, -0.46)
# iter=518; x=(0.54, 0.29); f(x)=0.22; grad f(x)=(-0.43, -0.46)
# iter=519; x=(0.54, 0.29); f(x)=0.21; grad f(x)=(-0.43, -0.46)
# iter=520; x=(0.54, 0.29); f(x)=0.21; grad f(x)=(-0.43, -0.46)
# iter=521; x=(0.54, 0.29); f(x)=0.21; grad f(x)=(-0.43, -0.46)
# iter=522; x=(0.54, 0.29); f(x)=0.21; grad f(x)=(-0.43, -0.46)
# iter=523; x=(0.54, 0.29); f(x)=0.21; grad f(x)=(-0.43, -0.46)
# iter=524; x=(0.54, 0.29); f(x)=0.21; grad f(x)=(-0.42, -0.46)
# iter=525; x=(0.54, 0.29); f(x)=0.21; grad f(x)=(-0.42, -0.46)
# iter=526; x=(0.54, 0.29); f(x)=0.21; grad f(x)=(-0.42, -0.46)
# iter=527; x=(0.54, 0.29); f(x)=0.21; grad f(x)=(-0.42, -0.46)
# iter=528; x=(0.54, 0.29); f(x)=0.21; grad f(x)=(-0.42, -0.46)
# iter=529; x=(0.54, 0.29); f(x)=0.21; grad f(x)=(-0.42, -0.46)
# iter=530; x=(0.54, 0.29); f(x)=0.21; grad f(x)=(-0.42, -0.46)
# iter=531; x=(0.54, 0.29); f(x)=0.21; grad f(x)=(-0.42, -0.46)
# iter=532; x=(0.54, 0.29); f(x)=0.21; grad f(x)=(-0.42, -0.46)
# iter=533; x=(0.54, 0.29); f(x)=0.21; grad f(x)=(-0.42, -0.46)
# iter=534; x=(0.54, 0.29); f(x)=0.21; grad f(x)=(-0.42, -0.46)
# iter=535; x=(0.54, 0.29); f(x)=0.21; grad f(x)=(-0.42, -0.46)
# iter=536; x=(0.54, 0.29); f(x)=0.21; grad f(x)=(-0.42, -0.46)
# iter=537; x=(0.54, 0.29); f(x)=0.21; grad f(x)=(-0.42, -0.45)
# iter=538; x=(0.55, 0.29); f(x)=0.21; grad f(x)=(-0.41, -0.45)
# iter=539; x=(0.55, 0.30); f(x)=0.21; grad f(x)=(-0.41, -0.45)
# iter=540; x=(0.55, 0.30); f(x)=0.21; grad f(x)=(-0.41, -0.45)
# iter=541; x=(0.55, 0.30); f(x)=0.21; grad f(x)=(-0.41, -0.45)
# iter=542; x=(0.55, 0.30); f(x)=0.21; grad f(x)=(-0.41, -0.45)
# iter=543; x=(0.55, 0.30); f(x)=0.21; grad f(x)=(-0.41, -0.45)
# iter=544; x=(0.55, 0.30); f(x)=0.21; grad f(x)=(-0.41, -0.45)
# iter=545; x=(0.55, 0.30); f(x)=0.20; grad f(x)=(-0.41, -0.45)
# iter=546; x=(0.55, 0.30); f(x)=0.20; grad f(x)=(-0.41, -0.45)
# iter=547; x=(0.55, 0.30); f(x)=0.20; grad f(x)=(-0.41, -0.45)
# iter=548; x=(0.55, 0.30); f(x)=0.20; grad f(x)=(-0.41, -0.45)
# iter=549; x=(0.55, 0.30); f(x)=0.20; grad f(x)=(-0.41, -0.45)
# iter=550; x=(0.55, 0.30); f(x)=0.20; grad f(x)=(-0.41, -0.45)
# iter=551; x=(0.55, 0.30); f(x)=0.20; grad f(x)=(-0.41, -0.45)
# iter=552; x=(0.55, 0.30); f(x)=0.20; grad f(x)=(-0.40, -0.45)
# iter=553; x=(0.55, 0.30); f(x)=0.20; grad f(x)=(-0.40, -0.45)
# iter=554; x=(0.55, 0.30); f(x)=0.20; grad f(x)=(-0.40, -0.45)
# iter=555; x=(0.55, 0.30); f(x)=0.20; grad f(x)=(-0.40, -0.45)
# iter=556; x=(0.55, 0.30); f(x)=0.20; grad f(x)=(-0.40, -0.45)
# iter=557; x=(0.55, 0.30); f(x)=0.20; grad f(x)=(-0.40, -0.45)
# iter=558; x=(0.55, 0.30); f(x)=0.20; grad f(x)=(-0.40, -0.45)
# iter=559; x=(0.55, 0.30); f(x)=0.20; grad f(x)=(-0.40, -0.45)
# iter=560; x=(0.55, 0.30); f(x)=0.20; grad f(x)=(-0.40, -0.44)
# iter=561; x=(0.55, 0.31); f(x)=0.20; grad f(x)=(-0.40, -0.44)
# iter=562; x=(0.55, 0.31); f(x)=0.20; grad f(x)=(-0.40, -0.44)
# iter=563; x=(0.56, 0.31); f(x)=0.20; grad f(x)=(-0.40, -0.44)
# iter=564; x=(0.56, 0.31); f(x)=0.20; grad f(x)=(-0.40, -0.44)
# iter=565; x=(0.56, 0.31); f(x)=0.20; grad f(x)=(-0.40, -0.44)
# iter=566; x=(0.56, 0.31); f(x)=0.20; grad f(x)=(-0.40, -0.44)
# iter=567; x=(0.56, 0.31); f(x)=0.20; grad f(x)=(-0.39, -0.44)
# iter=568; x=(0.56, 0.31); f(x)=0.20; grad f(x)=(-0.39, -0.44)
# iter=569; x=(0.56, 0.31); f(x)=0.20; grad f(x)=(-0.39, -0.44)
# iter=570; x=(0.56, 0.31); f(x)=0.20; grad f(x)=(-0.39, -0.44)
# iter=571; x=(0.56, 0.31); f(x)=0.20; grad f(x)=(-0.39, -0.44)
# iter=572; x=(0.56, 0.31); f(x)=0.20; grad f(x)=(-0.39, -0.44)
# iter=573; x=(0.56, 0.31); f(x)=0.19; grad f(x)=(-0.39, -0.44)
# iter=574; x=(0.56, 0.31); f(x)=0.19; grad f(x)=(-0.39, -0.44)
# iter=575; x=(0.56, 0.31); f(x)=0.19; grad f(x)=(-0.39, -0.44)
# iter=576; x=(0.56, 0.31); f(x)=0.19; grad f(x)=(-0.39, -0.44)
# iter=577; x=(0.56, 0.31); f(x)=0.19; grad f(x)=(-0.39, -0.44)
# iter=578; x=(0.56, 0.31); f(x)=0.19; grad f(x)=(-0.39, -0.44)
# iter=579; x=(0.56, 0.31); f(x)=0.19; grad f(x)=(-0.39, -0.44)
# iter=580; x=(0.56, 0.31); f(x)=0.19; grad f(x)=(-0.39, -0.44)
# iter=581; x=(0.56, 0.31); f(x)=0.19; grad f(x)=(-0.39, -0.44)
# iter=582; x=(0.56, 0.31); f(x)=0.19; grad f(x)=(-0.38, -0.44)
# iter=583; x=(0.56, 0.31); f(x)=0.19; grad f(x)=(-0.38, -0.43)
# iter=584; x=(0.56, 0.32); f(x)=0.19; grad f(x)=(-0.38, -0.43)
# iter=585; x=(0.56, 0.32); f(x)=0.19; grad f(x)=(-0.38, -0.43)
# iter=586; x=(0.56, 0.32); f(x)=0.19; grad f(x)=(-0.38, -0.43)
# iter=587; x=(0.56, 0.32); f(x)=0.19; grad f(x)=(-0.38, -0.43)
# iter=588; x=(0.56, 0.32); f(x)=0.19; grad f(x)=(-0.38, -0.43)
# iter=589; x=(0.57, 0.32); f(x)=0.19; grad f(x)=(-0.38, -0.43)
# iter=590; x=(0.57, 0.32); f(x)=0.19; grad f(x)=(-0.38, -0.43)
# iter=591; x=(0.57, 0.32); f(x)=0.19; grad f(x)=(-0.38, -0.43)
# iter=592; x=(0.57, 0.32); f(x)=0.19; grad f(x)=(-0.38, -0.43)
# iter=593; x=(0.57, 0.32); f(x)=0.19; grad f(x)=(-0.38, -0.43)
# iter=594; x=(0.57, 0.32); f(x)=0.19; grad f(x)=(-0.38, -0.43)
# iter=595; x=(0.57, 0.32); f(x)=0.19; grad f(x)=(-0.38, -0.43)
# iter=596; x=(0.57, 0.32); f(x)=0.19; grad f(x)=(-0.38, -0.43)
# iter=597; x=(0.57, 0.32); f(x)=0.19; grad f(x)=(-0.38, -0.43)
# iter=598; x=(0.57, 0.32); f(x)=0.19; grad f(x)=(-0.37, -0.43)
# iter=599; x=(0.57, 0.32); f(x)=0.19; grad f(x)=(-0.37, -0.43)
# iter=600; x=(0.57, 0.32); f(x)=0.19; grad f(x)=(-0.37, -0.43)
# iter=601; x=(0.57, 0.32); f(x)=0.19; grad f(x)=(-0.37, -0.43)
# iter=602; x=(0.57, 0.32); f(x)=0.19; grad f(x)=(-0.37, -0.43)
# iter=603; x=(0.57, 0.32); f(x)=0.18; grad f(x)=(-0.37, -0.43)
# iter=604; x=(0.57, 0.32); f(x)=0.18; grad f(x)=(-0.37, -0.43)
# iter=605; x=(0.57, 0.32); f(x)=0.18; grad f(x)=(-0.37, -0.43)
# iter=606; x=(0.57, 0.32); f(x)=0.18; grad f(x)=(-0.37, -0.43)
# iter=607; x=(0.57, 0.33); f(x)=0.18; grad f(x)=(-0.37, -0.42)
# iter=608; x=(0.57, 0.33); f(x)=0.18; grad f(x)=(-0.37, -0.42)
# iter=609; x=(0.57, 0.33); f(x)=0.18; grad f(x)=(-0.37, -0.42)
# iter=610; x=(0.57, 0.33); f(x)=0.18; grad f(x)=(-0.37, -0.42)
# iter=611; x=(0.57, 0.33); f(x)=0.18; grad f(x)=(-0.37, -0.42)
# iter=612; x=(0.57, 0.33); f(x)=0.18; grad f(x)=(-0.37, -0.42)
# iter=613; x=(0.57, 0.33); f(x)=0.18; grad f(x)=(-0.37, -0.42)
# iter=614; x=(0.57, 0.33); f(x)=0.18; grad f(x)=(-0.37, -0.42)
# iter=615; x=(0.58, 0.33); f(x)=0.18; grad f(x)=(-0.36, -0.42)
# iter=616; x=(0.58, 0.33); f(x)=0.18; grad f(x)=(-0.36, -0.42)
# iter=617; x=(0.58, 0.33); f(x)=0.18; grad f(x)=(-0.36, -0.42)
# iter=618; x=(0.58, 0.33); f(x)=0.18; grad f(x)=(-0.36, -0.42)
# iter=619; x=(0.58, 0.33); f(x)=0.18; grad f(x)=(-0.36, -0.42)
# iter=620; x=(0.58, 0.33); f(x)=0.18; grad f(x)=(-0.36, -0.42)
# iter=621; x=(0.58, 0.33); f(x)=0.18; grad f(x)=(-0.36, -0.42)
# iter=622; x=(0.58, 0.33); f(x)=0.18; grad f(x)=(-0.36, -0.42)
# iter=623; x=(0.58, 0.33); f(x)=0.18; grad f(x)=(-0.36, -0.42)
# iter=624; x=(0.58, 0.33); f(x)=0.18; grad f(x)=(-0.36, -0.42)
# iter=625; x=(0.58, 0.33); f(x)=0.18; grad f(x)=(-0.36, -0.42)
# iter=626; x=(0.58, 0.33); f(x)=0.18; grad f(x)=(-0.36, -0.42)
# iter=627; x=(0.58, 0.33); f(x)=0.18; grad f(x)=(-0.36, -0.42)
# iter=628; x=(0.58, 0.33); f(x)=0.18; grad f(x)=(-0.36, -0.42)
# iter=629; x=(0.58, 0.33); f(x)=0.18; grad f(x)=(-0.36, -0.42)
# iter=630; x=(0.58, 0.33); f(x)=0.18; grad f(x)=(-0.36, -0.42)
# iter=631; x=(0.58, 0.34); f(x)=0.18; grad f(x)=(-0.36, -0.42)
# iter=632; x=(0.58, 0.34); f(x)=0.18; grad f(x)=(-0.36, -0.42)
# iter=633; x=(0.58, 0.34); f(x)=0.18; grad f(x)=(-0.35, -0.41)
# iter=634; x=(0.58, 0.34); f(x)=0.18; grad f(x)=(-0.35, -0.41)
# iter=635; x=(0.58, 0.34); f(x)=0.17; grad f(x)=(-0.35, -0.41)
# iter=636; x=(0.58, 0.34); f(x)=0.17; grad f(x)=(-0.35, -0.41)
# iter=637; x=(0.58, 0.34); f(x)=0.17; grad f(x)=(-0.35, -0.41)
# iter=638; x=(0.58, 0.34); f(x)=0.17; grad f(x)=(-0.35, -0.41)
# iter=639; x=(0.58, 0.34); f(x)=0.17; grad f(x)=(-0.35, -0.41)
# iter=640; x=(0.58, 0.34); f(x)=0.17; grad f(x)=(-0.35, -0.41)
# iter=641; x=(0.58, 0.34); f(x)=0.17; grad f(x)=(-0.35, -0.41)
# iter=642; x=(0.58, 0.34); f(x)=0.17; grad f(x)=(-0.35, -0.41)
# iter=643; x=(0.59, 0.34); f(x)=0.17; grad f(x)=(-0.35, -0.41)
# iter=644; x=(0.59, 0.34); f(x)=0.17; grad f(x)=(-0.35, -0.41)
# iter=645; x=(0.59, 0.34); f(x)=0.17; grad f(x)=(-0.35, -0.41)
# iter=646; x=(0.59, 0.34); f(x)=0.17; grad f(x)=(-0.35, -0.41)
# iter=647; x=(0.59, 0.34); f(x)=0.17; grad f(x)=(-0.35, -0.41)
# iter=648; x=(0.59, 0.34); f(x)=0.17; grad f(x)=(-0.35, -0.41)
# iter=649; x=(0.59, 0.34); f(x)=0.17; grad f(x)=(-0.35, -0.41)
# iter=650; x=(0.59, 0.34); f(x)=0.17; grad f(x)=(-0.35, -0.41)
# iter=651; x=(0.59, 0.34); f(x)=0.17; grad f(x)=(-0.35, -0.41)
# iter=652; x=(0.59, 0.34); f(x)=0.17; grad f(x)=(-0.34, -0.41)
# iter=653; x=(0.59, 0.34); f(x)=0.17; grad f(x)=(-0.34, -0.41)
# iter=654; x=(0.59, 0.34); f(x)=0.17; grad f(x)=(-0.34, -0.41)
# iter=655; x=(0.59, 0.35); f(x)=0.17; grad f(x)=(-0.34, -0.41)
# iter=656; x=(0.59, 0.35); f(x)=0.17; grad f(x)=(-0.34, -0.41)
# iter=657; x=(0.59, 0.35); f(x)=0.17; grad f(x)=(-0.34, -0.41)
# iter=658; x=(0.59, 0.35); f(x)=0.17; grad f(x)=(-0.34, -0.41)
# iter=659; x=(0.59, 0.35); f(x)=0.17; grad f(x)=(-0.34, -0.40)
# iter=660; x=(0.59, 0.35); f(x)=0.17; grad f(x)=(-0.34, -0.40)
# iter=661; x=(0.59, 0.35); f(x)=0.17; grad f(x)=(-0.34, -0.40)
# iter=662; x=(0.59, 0.35); f(x)=0.17; grad f(x)=(-0.34, -0.40)
# iter=663; x=(0.59, 0.35); f(x)=0.17; grad f(x)=(-0.34, -0.40)
# iter=664; x=(0.59, 0.35); f(x)=0.17; grad f(x)=(-0.34, -0.40)
# iter=665; x=(0.59, 0.35); f(x)=0.17; grad f(x)=(-0.34, -0.40)
# iter=666; x=(0.59, 0.35); f(x)=0.17; grad f(x)=(-0.34, -0.40)
# iter=667; x=(0.59, 0.35); f(x)=0.17; grad f(x)=(-0.34, -0.40)
# iter=668; x=(0.59, 0.35); f(x)=0.17; grad f(x)=(-0.34, -0.40)
# iter=669; x=(0.59, 0.35); f(x)=0.17; grad f(x)=(-0.34, -0.40)
# iter=670; x=(0.59, 0.35); f(x)=0.16; grad f(x)=(-0.34, -0.40)
# iter=671; x=(0.59, 0.35); f(x)=0.16; grad f(x)=(-0.33, -0.40)
# iter=672; x=(0.59, 0.35); f(x)=0.16; grad f(x)=(-0.33, -0.40)
# iter=673; x=(0.60, 0.35); f(x)=0.16; grad f(x)=(-0.33, -0.40)
# iter=674; x=(0.60, 0.35); f(x)=0.16; grad f(x)=(-0.33, -0.40)
# iter=675; x=(0.60, 0.35); f(x)=0.16; grad f(x)=(-0.33, -0.40)
# iter=676; x=(0.60, 0.35); f(x)=0.16; grad f(x)=(-0.33, -0.40)
# iter=677; x=(0.60, 0.35); f(x)=0.16; grad f(x)=(-0.33, -0.40)
# iter=678; x=(0.60, 0.35); f(x)=0.16; grad f(x)=(-0.33, -0.40)
# iter=679; x=(0.60, 0.35); f(x)=0.16; grad f(x)=(-0.33, -0.40)
# iter=680; x=(0.60, 0.36); f(x)=0.16; grad f(x)=(-0.33, -0.40)
# iter=681; x=(0.60, 0.36); f(x)=0.16; grad f(x)=(-0.33, -0.40)
# iter=682; x=(0.60, 0.36); f(x)=0.16; grad f(x)=(-0.33, -0.40)
# iter=683; x=(0.60, 0.36); f(x)=0.16; grad f(x)=(-0.33, -0.40)
# iter=684; x=(0.60, 0.36); f(x)=0.16; grad f(x)=(-0.33, -0.40)
# iter=685; x=(0.60, 0.36); f(x)=0.16; grad f(x)=(-0.33, -0.40)
# iter=686; x=(0.60, 0.36); f(x)=0.16; grad f(x)=(-0.33, -0.39)
# iter=687; x=(0.60, 0.36); f(x)=0.16; grad f(x)=(-0.33, -0.39)
# iter=688; x=(0.60, 0.36); f(x)=0.16; grad f(x)=(-0.33, -0.39)
# iter=689; x=(0.60, 0.36); f(x)=0.16; grad f(x)=(-0.33, -0.39)
# iter=690; x=(0.60, 0.36); f(x)=0.16; grad f(x)=(-0.33, -0.39)
# iter=691; x=(0.60, 0.36); f(x)=0.16; grad f(x)=(-0.33, -0.39)
# iter=692; x=(0.60, 0.36); f(x)=0.16; grad f(x)=(-0.32, -0.39)
# iter=693; x=(0.60, 0.36); f(x)=0.16; grad f(x)=(-0.32, -0.39)
# iter=694; x=(0.60, 0.36); f(x)=0.16; grad f(x)=(-0.32, -0.39)
# iter=695; x=(0.60, 0.36); f(x)=0.16; grad f(x)=(-0.32, -0.39)
# iter=696; x=(0.60, 0.36); f(x)=0.16; grad f(x)=(-0.32, -0.39)
# iter=697; x=(0.60, 0.36); f(x)=0.16; grad f(x)=(-0.32, -0.39)
# iter=698; x=(0.60, 0.36); f(x)=0.16; grad f(x)=(-0.32, -0.39)
# iter=699; x=(0.60, 0.36); f(x)=0.16; grad f(x)=(-0.32, -0.39)
# iter=700; x=(0.60, 0.36); f(x)=0.16; grad f(x)=(-0.32, -0.39)
# iter=701; x=(0.60, 0.36); f(x)=0.16; grad f(x)=(-0.32, -0.39)
# iter=702; x=(0.60, 0.36); f(x)=0.16; grad f(x)=(-0.32, -0.39)
# iter=703; x=(0.61, 0.36); f(x)=0.16; grad f(x)=(-0.32, -0.39)
# iter=704; x=(0.61, 0.36); f(x)=0.16; grad f(x)=(-0.32, -0.39)
# iter=705; x=(0.61, 0.36); f(x)=0.16; grad f(x)=(-0.32, -0.39)
# iter=706; x=(0.61, 0.37); f(x)=0.16; grad f(x)=(-0.32, -0.39)
# iter=707; x=(0.61, 0.37); f(x)=0.16; grad f(x)=(-0.32, -0.39)
# iter=708; x=(0.61, 0.37); f(x)=0.16; grad f(x)=(-0.32, -0.39)
# iter=709; x=(0.61, 0.37); f(x)=0.15; grad f(x)=(-0.32, -0.39)
# iter=710; x=(0.61, 0.37); f(x)=0.15; grad f(x)=(-0.32, -0.39)
# iter=711; x=(0.61, 0.37); f(x)=0.15; grad f(x)=(-0.32, -0.39)
# iter=712; x=(0.61, 0.37); f(x)=0.15; grad f(x)=(-0.32, -0.39)
# iter=713; x=(0.61, 0.37); f(x)=0.15; grad f(x)=(-0.31, -0.39)
# iter=714; x=(0.61, 0.37); f(x)=0.15; grad f(x)=(-0.31, -0.38)
# iter=715; x=(0.61, 0.37); f(x)=0.15; grad f(x)=(-0.31, -0.38)
# iter=716; x=(0.61, 0.37); f(x)=0.15; grad f(x)=(-0.31, -0.38)
# iter=717; x=(0.61, 0.37); f(x)=0.15; grad f(x)=(-0.31, -0.38)
# iter=718; x=(0.61, 0.37); f(x)=0.15; grad f(x)=(-0.31, -0.38)
# iter=719; x=(0.61, 0.37); f(x)=0.15; grad f(x)=(-0.31, -0.38)
# iter=720; x=(0.61, 0.37); f(x)=0.15; grad f(x)=(-0.31, -0.38)
# iter=721; x=(0.61, 0.37); f(x)=0.15; grad f(x)=(-0.31, -0.38)
# iter=722; x=(0.61, 0.37); f(x)=0.15; grad f(x)=(-0.31, -0.38)
# iter=723; x=(0.61, 0.37); f(x)=0.15; grad f(x)=(-0.31, -0.38)
# iter=724; x=(0.61, 0.37); f(x)=0.15; grad f(x)=(-0.31, -0.38)
# iter=725; x=(0.61, 0.37); f(x)=0.15; grad f(x)=(-0.31, -0.38)
# iter=726; x=(0.61, 0.37); f(x)=0.15; grad f(x)=(-0.31, -0.38)
# iter=727; x=(0.61, 0.37); f(x)=0.15; grad f(x)=(-0.31, -0.38)
# iter=728; x=(0.61, 0.37); f(x)=0.15; grad f(x)=(-0.31, -0.38)
# iter=729; x=(0.61, 0.37); f(x)=0.15; grad f(x)=(-0.31, -0.38)
# iter=730; x=(0.61, 0.37); f(x)=0.15; grad f(x)=(-0.31, -0.38)
# iter=731; x=(0.61, 0.37); f(x)=0.15; grad f(x)=(-0.31, -0.38)
# iter=732; x=(0.61, 0.38); f(x)=0.15; grad f(x)=(-0.31, -0.38)
# iter=733; x=(0.61, 0.38); f(x)=0.15; grad f(x)=(-0.31, -0.38)
# iter=734; x=(0.61, 0.38); f(x)=0.15; grad f(x)=(-0.31, -0.38)
# iter=735; x=(0.62, 0.38); f(x)=0.15; grad f(x)=(-0.31, -0.38)
# iter=736; x=(0.62, 0.38); f(x)=0.15; grad f(x)=(-0.30, -0.38)
# iter=737; x=(0.62, 0.38); f(x)=0.15; grad f(x)=(-0.30, -0.38)
# iter=738; x=(0.62, 0.38); f(x)=0.15; grad f(x)=(-0.30, -0.38)
# iter=739; x=(0.62, 0.38); f(x)=0.15; grad f(x)=(-0.30, -0.38)
# iter=740; x=(0.62, 0.38); f(x)=0.15; grad f(x)=(-0.30, -0.38)
# iter=741; x=(0.62, 0.38); f(x)=0.15; grad f(x)=(-0.30, -0.38)
# iter=742; x=(0.62, 0.38); f(x)=0.15; grad f(x)=(-0.30, -0.38)
# iter=743; x=(0.62, 0.38); f(x)=0.15; grad f(x)=(-0.30, -0.37)
# iter=744; x=(0.62, 0.38); f(x)=0.15; grad f(x)=(-0.30, -0.37)
# iter=745; x=(0.62, 0.38); f(x)=0.15; grad f(x)=(-0.30, -0.37)
# iter=746; x=(0.62, 0.38); f(x)=0.15; grad f(x)=(-0.30, -0.37)
# iter=747; x=(0.62, 0.38); f(x)=0.15; grad f(x)=(-0.30, -0.37)
# iter=748; x=(0.62, 0.38); f(x)=0.15; grad f(x)=(-0.30, -0.37)
# iter=749; x=(0.62, 0.38); f(x)=0.15; grad f(x)=(-0.30, -0.37)
# iter=750; x=(0.62, 0.38); f(x)=0.15; grad f(x)=(-0.30, -0.37)
# iter=751; x=(0.62, 0.38); f(x)=0.14; grad f(x)=(-0.30, -0.37)
# iter=752; x=(0.62, 0.38); f(x)=0.14; grad f(x)=(-0.30, -0.37)
# iter=753; x=(0.62, 0.38); f(x)=0.14; grad f(x)=(-0.30, -0.37)
# iter=754; x=(0.62, 0.38); f(x)=0.14; grad f(x)=(-0.30, -0.37)
# iter=755; x=(0.62, 0.38); f(x)=0.14; grad f(x)=(-0.30, -0.37)
# iter=756; x=(0.62, 0.38); f(x)=0.14; grad f(x)=(-0.30, -0.37)
# iter=757; x=(0.62, 0.38); f(x)=0.14; grad f(x)=(-0.30, -0.37)
# iter=758; x=(0.62, 0.39); f(x)=0.14; grad f(x)=(-0.30, -0.37)
# iter=759; x=(0.62, 0.39); f(x)=0.14; grad f(x)=(-0.30, -0.37)
# iter=760; x=(0.62, 0.39); f(x)=0.14; grad f(x)=(-0.30, -0.37)
# iter=761; x=(0.62, 0.39); f(x)=0.14; grad f(x)=(-0.29, -0.37)
# iter=762; x=(0.62, 0.39); f(x)=0.14; grad f(x)=(-0.29, -0.37)
# iter=763; x=(0.62, 0.39); f(x)=0.14; grad f(x)=(-0.29, -0.37)
# iter=764; x=(0.62, 0.39); f(x)=0.14; grad f(x)=(-0.29, -0.37)
# iter=765; x=(0.62, 0.39); f(x)=0.14; grad f(x)=(-0.29, -0.37)
# iter=766; x=(0.62, 0.39); f(x)=0.14; grad f(x)=(-0.29, -0.37)
# iter=767; x=(0.62, 0.39); f(x)=0.14; grad f(x)=(-0.29, -0.37)
# iter=768; x=(0.62, 0.39); f(x)=0.14; grad f(x)=(-0.29, -0.37)
# iter=769; x=(0.63, 0.39); f(x)=0.14; grad f(x)=(-0.29, -0.37)
# iter=770; x=(0.63, 0.39); f(x)=0.14; grad f(x)=(-0.29, -0.37)
# iter=771; x=(0.63, 0.39); f(x)=0.14; grad f(x)=(-0.29, -0.37)
# iter=772; x=(0.63, 0.39); f(x)=0.14; grad f(x)=(-0.29, -0.37)
# iter=773; x=(0.63, 0.39); f(x)=0.14; grad f(x)=(-0.29, -0.36)
# iter=774; x=(0.63, 0.39); f(x)=0.14; grad f(x)=(-0.29, -0.36)
# iter=775; x=(0.63, 0.39); f(x)=0.14; grad f(x)=(-0.29, -0.36)
# ...
# iter=5275; x=(0.96, 0.92); f(x)=0.00; grad f(x)=(-0.02, -0.03)
# iter=5276; x=(0.96, 0.92); f(x)=0.00; grad f(x)=(-0.02, -0.03)
# iter=5277; x=(0.96, 0.92); f(x)=0.00; grad f(x)=(-0.02, -0.03)
# iter=5278; x=(0.96, 0.92); f(x)=0.00; grad f(x)=(-0.02, -0.03)
# iter=5279; x=(0.96, 0.92); f(x)=0.00; grad f(x)=(-0.02, -0.03)
# iter=5280; x=(0.96, 0.92); f(x)=0.00; grad f(x)=(-0.02, -0.03)
# iter=5281; x=(0.96, 0.92); f(x)=0.00; grad f(x)=(-0.02, -0.03)
# iter=5282; x=(0.96, 0.93); f(x)=0.00; grad f(x)=(-0.02, -0.03)
# iter=5283; x=(0.96, 0.93); f(x)=0.00; grad f(x)=(-0.02, -0.03)
# iter=5284; x=(0.96, 0.93); f(x)=0.00; grad f(x)=(-0.02, -0.03)
# iter=5285; x=(0.96, 0.93); f(x)=0.00; grad f(x)=(-0.02, -0.03)
# iter=5286; x=(0.96, 0.93); f(x)=0.00; grad f(x)=(-0.02, -0.03)
# iter=5287; x=(0.96, 0.93); f(x)=0.00; grad f(x)=(-0.02, -0.03)
# iter=5288; x=(0.96, 0.93); f(x)=0.00; grad f(x)=(-0.02, -0.03)
# iter=5289; x=(0.96, 0.93); f(x)=0.00; grad f(x)=(-0.02, -0.03)
# iter=5290; x=(0.96, 0.93); f(x)=0.00; grad f(x)=(-0.02, -0.03)
# iter=5291; x=(0.96, 0.93); f(x)=0.00; grad f(x)=(-0.02, -0.03)
# iter=5292; x=(0.96, 0.93); f(x)=0.00; grad f(x)=(-0.02, -0.03)
# iter=5293; x=(0.96, 0.93); f(x)=0.00; grad f(x)=(-0.02, -0.03)
# iter=5294; x=(0.96, 0.93); f(x)=0.00; grad f(x)=(-0.02, -0.03)
# iter=5295; x=(0.96, 0.93); f(x)=0.00; grad f(x)=(-0.02, -0.03)
# iter=5296; x=(0.96, 0.93); f(x)=0.00; grad f(x)=(-0.02, -0.03)
# iter=5297; x=(0.96, 0.93); f(x)=0.00; grad f(x)=(-0.02, -0.03)
# iter=5298; x=(0.96, 0.93); f(x)=0.00; grad f(x)=(-0.02, -0.03)
# iter=5299; x=(0.96, 0.93); f(x)=0.00; grad f(x)=(-0.02, -0.03)
# iter=5300; x=(0.96, 0.93); f(x)=0.00; grad f(x)=(-0.02, -0.03)
# iter=5301; x=(0.96, 0.93); f(x)=0.00; grad f(x)=(-0.02, -0.03)
# iter=5302; x=(0.96, 0.93); f(x)=0.00; grad f(x)=(-0.02, -0.03)
# iter=5303; x=(0.96, 0.93); f(x)=0.00; grad f(x)=(-0.02, -0.03)
# iter=5304; x=(0.96, 0.93); f(x)=0.00; grad f(x)=(-0.02, -0.03)
# iter=5305; x=(0.96, 0.93); f(x)=0.00; grad f(x)=(-0.02, -0.03)
# iter=5306; x=(0.96, 0.93); f(x)=0.00; grad f(x)=(-0.02, -0.03)
# iter=5307; x=(0.96, 0.93); f(x)=0.00; grad f(x)=(-0.02, -0.03)
# iter=5308; x=(0.96, 0.93); f(x)=0.00; grad f(x)=(-0.02, -0.03)
# iter=5309; x=(0.96, 0.93); f(x)=0.00; grad f(x)=(-0.02, -0.03)
# iter=5310; x=(0.96, 0.93); f(x)=0.00; grad f(x)=(-0.02, -0.03)
# iter=5311; x=(0.96, 0.93); f(x)=0.00; grad f(x)=(-0.02, -0.03)
# iter=5312; x=(0.96, 0.93); f(x)=0.00; grad f(x)=(-0.02, -0.03)
# iter=5313; x=(0.96, 0.93); f(x)=0.00; grad f(x)=(-0.02, -0.03)
# iter=5314; x=(0.96, 0.93); f(x)=0.00; grad f(x)=(-0.02, -0.03)
# iter=5315; x=(0.96, 0.93); f(x)=0.00; grad f(x)=(-0.02, -0.03)
# iter=5316; x=(0.96, 0.93); f(x)=0.00; grad f(x)=(-0.02, -0.03)
# iter=5317; x=(0.96, 0.93); f(x)=0.00; grad f(x)=(-0.02, -0.03)
# iter=5318; x=(0.96, 0.93); f(x)=0.00; grad f(x)=(-0.02, -0.03)
# iter=5319; x=(0.96, 0.93); f(x)=0.00; grad f(x)=(-0.02, -0.03)
# iter=5320; x=(0.96, 0.93); f(x)=0.00; grad f(x)=(-0.02, -0.03)
# iter=5321; x=(0.96, 0.93); f(x)=0.00; grad f(x)=(-0.02, -0.03)
# iter=5322; x=(0.96, 0.93); f(x)=0.00; grad f(x)=(-0.02, -0.03)
# iter=5323; x=(0.96, 0.93); f(x)=0.00; grad f(x)=(-0.02, -0.03)
# iter=5324; x=(0.96, 0.93); f(x)=0.00; grad f(x)=(-0.02, -0.03)
# iter=5325; x=(0.96, 0.93); f(x)=0.00; grad f(x)=(-0.02, -0.03)
# iter=5326; x=(0.96, 0.93); f(x)=0.00; grad f(x)=(-0.02, -0.03)
# iter=5327; x=(0.96, 0.93); f(x)=0.00; grad f(x)=(-0.02, -0.03)
# iter=5328; x=(0.96, 0.93); f(x)=0.00; grad f(x)=(-0.02, -0.03)
# iter=5329; x=(0.96, 0.93); f(x)=0.00; grad f(x)=(-0.02, -0.03)
# iter=5330; x=(0.96, 0.93); f(x)=0.00; grad f(x)=(-0.02, -0.03)
# iter=5331; x=(0.96, 0.93); f(x)=0.00; grad f(x)=(-0.02, -0.03)
# iter=5332; x=(0.96, 0.93); f(x)=0.00; grad f(x)=(-0.02, -0.03)
# iter=5333; x=(0.96, 0.93); f(x)=0.00; grad f(x)=(-0.02, -0.03)
# iter=5334; x=(0.96, 0.93); f(x)=0.00; grad f(x)=(-0.02, -0.03)
# iter=5335; x=(0.96, 0.93); f(x)=0.00; grad f(x)=(-0.02, -0.03)
# iter=5336; x=(0.96, 0.93); f(x)=0.00; grad f(x)=(-0.02, -0.03)
# iter=5337; x=(0.96, 0.93); f(x)=0.00; grad f(x)=(-0.02, -0.03)
# iter=5338; x=(0.96, 0.93); f(x)=0.00; grad f(x)=(-0.02, -0.03)
# iter=5339; x=(0.96, 0.93); f(x)=0.00; grad f(x)=(-0.02, -0.03)
# iter=5340; x=(0.96, 0.93); f(x)=0.00; grad f(x)=(-0.02, -0.03)
# iter=5341; x=(0.96, 0.93); f(x)=0.00; grad f(x)=(-0.02, -0.03)
# iter=5342; x=(0.96, 0.93); f(x)=0.00; grad f(x)=(-0.02, -0.03)
# iter=5343; x=(0.96, 0.93); f(x)=0.00; grad f(x)=(-0.02, -0.03)
# iter=5344; x=(0.96, 0.93); f(x)=0.00; grad f(x)=(-0.02, -0.03)
# iter=5345; x=(0.96, 0.93); f(x)=0.00; grad f(x)=(-0.02, -0.03)
# iter=5346; x=(0.96, 0.93); f(x)=0.00; grad f(x)=(-0.02, -0.03)
# iter=5347; x=(0.96, 0.93); f(x)=0.00; grad f(x)=(-0.02, -0.03)
# iter=5348; x=(0.96, 0.93); f(x)=0.00; grad f(x)=(-0.02, -0.03)
# iter=5349; x=(0.96, 0.93); f(x)=0.00; grad f(x)=(-0.02, -0.03)
# iter=5350; x=(0.96, 0.93); f(x)=0.00; grad f(x)=(-0.02, -0.03)
# iter=5351; x=(0.96, 0.93); f(x)=0.00; grad f(x)=(-0.02, -0.03)
# iter=5352; x=(0.96, 0.93); f(x)=0.00; grad f(x)=(-0.02, -0.03)
# iter=5353; x=(0.96, 0.93); f(x)=0.00; grad f(x)=(-0.02, -0.03)
# iter=5354; x=(0.96, 0.93); f(x)=0.00; grad f(x)=(-0.02, -0.03)
# iter=5355; x=(0.96, 0.93); f(x)=0.00; grad f(x)=(-0.02, -0.03)
# iter=5356; x=(0.96, 0.93); f(x)=0.00; grad f(x)=(-0.02, -0.03)
# iter=5357; x=(0.96, 0.93); f(x)=0.00; grad f(x)=(-0.02, -0.03)
# iter=5358; x=(0.96, 0.93); f(x)=0.00; grad f(x)=(-0.02, -0.03)
# iter=5359; x=(0.96, 0.93); f(x)=0.00; grad f(x)=(-0.02, -0.03)
# iter=5360; x=(0.96, 0.93); f(x)=0.00; grad f(x)=(-0.02, -0.03)
# iter=5361; x=(0.96, 0.93); f(x)=0.00; grad f(x)=(-0.02, -0.03)
# iter=5362; x=(0.96, 0.93); f(x)=0.00; grad f(x)=(-0.02, -0.03)
# iter=5363; x=(0.96, 0.93); f(x)=0.00; grad f(x)=(-0.02, -0.03)
# iter=5364; x=(0.96, 0.93); f(x)=0.00; grad f(x)=(-0.02, -0.03)
# iter=5365; x=(0.96, 0.93); f(x)=0.00; grad f(x)=(-0.02, -0.03)
# iter=5366; x=(0.96, 0.93); f(x)=0.00; grad f(x)=(-0.02, -0.03)
# iter=5367; x=(0.96, 0.93); f(x)=0.00; grad f(x)=(-0.02, -0.03)
# iter=5368; x=(0.96, 0.93); f(x)=0.00; grad f(x)=(-0.02, -0.03)
# iter=5369; x=(0.96, 0.93); f(x)=0.00; grad f(x)=(-0.02, -0.03)
# iter=5370; x=(0.96, 0.93); f(x)=0.00; grad f(x)=(-0.02, -0.03)
# iter=5371; x=(0.96, 0.93); f(x)=0.00; grad f(x)=(-0.02, -0.03)
# iter=5372; x=(0.96, 0.93); f(x)=0.00; grad f(x)=(-0.02, -0.03)
# iter=5373; x=(0.96, 0.93); f(x)=0.00; grad f(x)=(-0.02, -0.03)
# iter=5374; x=(0.96, 0.93); f(x)=0.00; grad f(x)=(-0.02, -0.03)
# iter=5375; x=(0.96, 0.93); f(x)=0.00; grad f(x)=(-0.02, -0.03)
# iter=5376; x=(0.96, 0.93); f(x)=0.00; grad f(x)=(-0.02, -0.03)
# iter=5377; x=(0.96, 0.93); f(x)=0.00; grad f(x)=(-0.02, -0.03)
# iter=5378; x=(0.96, 0.93); f(x)=0.00; grad f(x)=(-0.02, -0.03)
# iter=5379; x=(0.96, 0.93); f(x)=0.00; grad f(x)=(-0.02, -0.03)
# iter=5380; x=(0.96, 0.93); f(x)=0.00; grad f(x)=(-0.02, -0.03)
# iter=5381; x=(0.96, 0.93); f(x)=0.00; grad f(x)=(-0.02, -0.03)
# iter=5382; x=(0.96, 0.93); f(x)=0.00; grad f(x)=(-0.02, -0.03)
# iter=5383; x=(0.96, 0.93); f(x)=0.00; grad f(x)=(-0.02, -0.03)
# iter=5384; x=(0.96, 0.93); f(x)=0.00; grad f(x)=(-0.02, -0.03)
# iter=5385; x=(0.96, 0.93); f(x)=0.00; grad f(x)=(-0.02, -0.03)
# iter=5386; x=(0.96, 0.93); f(x)=0.00; grad f(x)=(-0.02, -0.03)
# iter=5387; x=(0.96, 0.93); f(x)=0.00; grad f(x)=(-0.02, -0.03)
# iter=5388; x=(0.96, 0.93); f(x)=0.00; grad f(x)=(-0.02, -0.03)
# iter=5389; x=(0.96, 0.93); f(x)=0.00; grad f(x)=(-0.02, -0.03)
# iter=5390; x=(0.96, 0.93); f(x)=0.00; grad f(x)=(-0.02, -0.03)
# iter=5391; x=(0.96, 0.93); f(x)=0.00; grad f(x)=(-0.02, -0.03)
# iter=5392; x=(0.96, 0.93); f(x)=0.00; grad f(x)=(-0.02, -0.03)
# iter=5393; x=(0.96, 0.93); f(x)=0.00; grad f(x)=(-0.02, -0.03)
# iter=5394; x=(0.96, 0.93); f(x)=0.00; grad f(x)=(-0.02, -0.03)
# iter=5395; x=(0.96, 0.93); f(x)=0.00; grad f(x)=(-0.02, -0.03)
# iter=5396; x=(0.96, 0.93); f(x)=0.00; grad f(x)=(-0.02, -0.03)
# iter=5397; x=(0.96, 0.93); f(x)=0.00; grad f(x)=(-0.02, -0.03)
# iter=5398; x=(0.96, 0.93); f(x)=0.00; grad f(x)=(-0.02, -0.03)
# iter=5399; x=(0.96, 0.93); f(x)=0.00; grad f(x)=(-0.02, -0.03)
# iter=5400; x=(0.96, 0.93); f(x)=0.00; grad f(x)=(-0.02, -0.03)
# iter=5401; x=(0.96, 0.93); f(x)=0.00; grad f(x)=(-0.02, -0.03)
# iter=5402; x=(0.96, 0.93); f(x)=0.00; grad f(x)=(-0.02, -0.03)
# iter=5403; x=(0.96, 0.93); f(x)=0.00; grad f(x)=(-0.02, -0.03)
# iter=5404; x=(0.96, 0.93); f(x)=0.00; grad f(x)=(-0.02, -0.03)
# iter=5405; x=(0.96, 0.93); f(x)=0.00; grad f(x)=(-0.02, -0.03)
# iter=5406; x=(0.96, 0.93); f(x)=0.00; grad f(x)=(-0.02, -0.03)
# iter=5407; x=(0.96, 0.93); f(x)=0.00; grad f(x)=(-0.02, -0.03)
# iter=5408; x=(0.96, 0.93); f(x)=0.00; grad f(x)=(-0.02, -0.03)
# iter=5409; x=(0.96, 0.93); f(x)=0.00; grad f(x)=(-0.02, -0.03)
# iter=5410; x=(0.96, 0.93); f(x)=0.00; grad f(x)=(-0.02, -0.03)
# iter=5411; x=(0.96, 0.93); f(x)=0.00; grad f(x)=(-0.02, -0.03)
# iter=5412; x=(0.96, 0.93); f(x)=0.00; grad f(x)=(-0.02, -0.03)
# iter=5413; x=(0.96, 0.93); f(x)=0.00; grad f(x)=(-0.02, -0.03)
# iter=5414; x=(0.96, 0.93); f(x)=0.00; grad f(x)=(-0.02, -0.03)
# iter=5415; x=(0.96, 0.93); f(x)=0.00; grad f(x)=(-0.02, -0.03)
# iter=5416; x=(0.96, 0.93); f(x)=0.00; grad f(x)=(-0.02, -0.03)
# iter=5417; x=(0.96, 0.93); f(x)=0.00; grad f(x)=(-0.02, -0.03)
# iter=5418; x=(0.96, 0.93); f(x)=0.00; grad f(x)=(-0.02, -0.03)
# iter=5419; x=(0.96, 0.93); f(x)=0.00; grad f(x)=(-0.02, -0.03)
# iter=5420; x=(0.96, 0.93); f(x)=0.00; grad f(x)=(-0.02, -0.03)
# iter=5421; x=(0.96, 0.93); f(x)=0.00; grad f(x)=(-0.02, -0.03)
# iter=5422; x=(0.96, 0.93); f(x)=0.00; grad f(x)=(-0.02, -0.03)
# iter=5423; x=(0.96, 0.93); f(x)=0.00; grad f(x)=(-0.02, -0.03)
# iter=5424; x=(0.96, 0.93); f(x)=0.00; grad f(x)=(-0.02, -0.03)
# iter=5425; x=(0.96, 0.93); f(x)=0.00; grad f(x)=(-0.02, -0.03)
# iter=5426; x=(0.96, 0.93); f(x)=0.00; grad f(x)=(-0.02, -0.03)
# iter=5427; x=(0.96, 0.93); f(x)=0.00; grad f(x)=(-0.02, -0.03)
# iter=5428; x=(0.96, 0.93); f(x)=0.00; grad f(x)=(-0.02, -0.03)
# iter=5429; x=(0.96, 0.93); f(x)=0.00; grad f(x)=(-0.02, -0.03)
# iter=5430; x=(0.96, 0.93); f(x)=0.00; grad f(x)=(-0.02, -0.03)
# iter=5431; x=(0.96, 0.93); f(x)=0.00; grad f(x)=(-0.02, -0.03)
# iter=5432; x=(0.96, 0.93); f(x)=0.00; grad f(x)=(-0.02, -0.03)
# iter=5433; x=(0.96, 0.93); f(x)=0.00; grad f(x)=(-0.02, -0.03)
# iter=5434; x=(0.96, 0.93); f(x)=0.00; grad f(x)=(-0.02, -0.03)
# iter=5435; x=(0.96, 0.93); f(x)=0.00; grad f(x)=(-0.02, -0.03)
# iter=5436; x=(0.96, 0.93); f(x)=0.00; grad f(x)=(-0.02, -0.03)
# iter=5437; x=(0.96, 0.93); f(x)=0.00; grad f(x)=(-0.02, -0.03)
# iter=5438; x=(0.96, 0.93); f(x)=0.00; grad f(x)=(-0.02, -0.03)
# iter=5439; x=(0.96, 0.93); f(x)=0.00; grad f(x)=(-0.02, -0.03)
# iter=5440; x=(0.96, 0.93); f(x)=0.00; grad f(x)=(-0.02, -0.03)
# iter=5441; x=(0.96, 0.93); f(x)=0.00; grad f(x)=(-0.02, -0.03)
# iter=5442; x=(0.96, 0.93); f(x)=0.00; grad f(x)=(-0.02, -0.03)
# iter=5443; x=(0.96, 0.93); f(x)=0.00; grad f(x)=(-0.02, -0.03)
# iter=5444; x=(0.96, 0.93); f(x)=0.00; grad f(x)=(-0.02, -0.03)
# iter=5445; x=(0.96, 0.93); f(x)=0.00; grad f(x)=(-0.02, -0.03)
# iter=5446; x=(0.96, 0.93); f(x)=0.00; grad f(x)=(-0.02, -0.03)
# iter=5447; x=(0.96, 0.93); f(x)=0.00; grad f(x)=(-0.02, -0.03)
# iter=5448; x=(0.96, 0.93); f(x)=0.00; grad f(x)=(-0.02, -0.03)
# iter=5449; x=(0.96, 0.93); f(x)=0.00; grad f(x)=(-0.02, -0.03)
# iter=5450; x=(0.96, 0.93); f(x)=0.00; grad f(x)=(-0.02, -0.03)
# iter=5451; x=(0.96, 0.93); f(x)=0.00; grad f(x)=(-0.02, -0.03)
# iter=5452; x=(0.96, 0.93); f(x)=0.00; grad f(x)=(-0.02, -0.03)
# iter=5453; x=(0.96, 0.93); f(x)=0.00; grad f(x)=(-0.01, -0.03)
# iter=5454; x=(0.96, 0.93); f(x)=0.00; grad f(x)=(-0.01, -0.03)
# iter=5455; x=(0.96, 0.93); f(x)=0.00; grad f(x)=(-0.01, -0.03)
# iter=5456; x=(0.96, 0.93); f(x)=0.00; grad f(x)=(-0.01, -0.03)
# iter=5457; x=(0.96, 0.93); f(x)=0.00; grad f(x)=(-0.01, -0.03)
# iter=5458; x=(0.96, 0.93); f(x)=0.00; grad f(x)=(-0.01, -0.03)
# iter=5459; x=(0.96, 0.93); f(x)=0.00; grad f(x)=(-0.01, -0.03)
# iter=5460; x=(0.96, 0.93); f(x)=0.00; grad f(x)=(-0.01, -0.03)
# iter=5461; x=(0.96, 0.93); f(x)=0.00; grad f(x)=(-0.01, -0.03)
# iter=5462; x=(0.96, 0.93); f(x)=0.00; grad f(x)=(-0.01, -0.03)
# iter=5463; x=(0.96, 0.93); f(x)=0.00; grad f(x)=(-0.01, -0.03)
# iter=5464; x=(0.96, 0.93); f(x)=0.00; grad f(x)=(-0.01, -0.03)
# iter=5465; x=(0.96, 0.93); f(x)=0.00; grad f(x)=(-0.01, -0.03)
# iter=5466; x=(0.96, 0.93); f(x)=0.00; grad f(x)=(-0.01, -0.03)
# iter=5467; x=(0.96, 0.93); f(x)=0.00; grad f(x)=(-0.01, -0.03)
# iter=5468; x=(0.96, 0.93); f(x)=0.00; grad f(x)=(-0.01, -0.03)
# iter=5469; x=(0.96, 0.93); f(x)=0.00; grad f(x)=(-0.01, -0.03)
# iter=5470; x=(0.96, 0.93); f(x)=0.00; grad f(x)=(-0.01, -0.03)
# iter=5471; x=(0.96, 0.93); f(x)=0.00; grad f(x)=(-0.01, -0.03)
# iter=5472; x=(0.96, 0.93); f(x)=0.00; grad f(x)=(-0.01, -0.03)
# iter=5473; x=(0.96, 0.93); f(x)=0.00; grad f(x)=(-0.01, -0.03)
# iter=5474; x=(0.96, 0.93); f(x)=0.00; grad f(x)=(-0.01, -0.03)
# iter=5475; x=(0.96, 0.93); f(x)=0.00; grad f(x)=(-0.01, -0.03)
# iter=5476; x=(0.96, 0.93); f(x)=0.00; grad f(x)=(-0.01, -0.03)
# iter=5477; x=(0.96, 0.93); f(x)=0.00; grad f(x)=(-0.01, -0.03)
# iter=5478; x=(0.96, 0.93); f(x)=0.00; grad f(x)=(-0.01, -0.03)
# iter=5479; x=(0.96, 0.93); f(x)=0.00; grad f(x)=(-0.01, -0.03)
# iter=5480; x=(0.96, 0.93); f(x)=0.00; grad f(x)=(-0.01, -0.03)
# iter=5481; x=(0.96, 0.93); f(x)=0.00; grad f(x)=(-0.01, -0.03)
# iter=5482; x=(0.96, 0.93); f(x)=0.00; grad f(x)=(-0.01, -0.03)
# iter=5483; x=(0.96, 0.93); f(x)=0.00; grad f(x)=(-0.01, -0.03)
# iter=5484; x=(0.96, 0.93); f(x)=0.00; grad f(x)=(-0.01, -0.03)
# iter=5485; x=(0.97, 0.93); f(x)=0.00; grad f(x)=(-0.01, -0.03)
# iter=5486; x=(0.97, 0.93); f(x)=0.00; grad f(x)=(-0.01, -0.03)
# iter=5487; x=(0.97, 0.93); f(x)=0.00; grad f(x)=(-0.01, -0.03)
# iter=5488; x=(0.97, 0.93); f(x)=0.00; grad f(x)=(-0.01, -0.03)
# iter=5489; x=(0.97, 0.93); f(x)=0.00; grad f(x)=(-0.01, -0.03)
# iter=5490; x=(0.97, 0.93); f(x)=0.00; grad f(x)=(-0.01, -0.03)
# iter=5491; x=(0.97, 0.93); f(x)=0.00; grad f(x)=(-0.01, -0.03)
# iter=5492; x=(0.97, 0.93); f(x)=0.00; grad f(x)=(-0.01, -0.03)
# iter=5493; x=(0.97, 0.93); f(x)=0.00; grad f(x)=(-0.01, -0.03)
# iter=5494; x=(0.97, 0.93); f(x)=0.00; grad f(x)=(-0.01, -0.03)
# iter=5495; x=(0.97, 0.93); f(x)=0.00; grad f(x)=(-0.01, -0.03)
# iter=5496; x=(0.97, 0.93); f(x)=0.00; grad f(x)=(-0.01, -0.03)
# iter=5497; x=(0.97, 0.93); f(x)=0.00; grad f(x)=(-0.01, -0.03)
# iter=5498; x=(0.97, 0.93); f(x)=0.00; grad f(x)=(-0.01, -0.03)
# iter=5499; x=(0.97, 0.93); f(x)=0.00; grad f(x)=(-0.01, -0.03)
# iter=5500; x=(0.97, 0.93); f(x)=0.00; grad f(x)=(-0.01, -0.03)
# iter=5501; x=(0.97, 0.93); f(x)=0.00; grad f(x)=(-0.01, -0.03)
# iter=5502; x=(0.97, 0.93); f(x)=0.00; grad f(x)=(-0.01, -0.03)
# iter=5503; x=(0.97, 0.93); f(x)=0.00; grad f(x)=(-0.01, -0.03)
# iter=5504; x=(0.97, 0.93); f(x)=0.00; grad f(x)=(-0.01, -0.03)
# iter=5505; x=(0.97, 0.93); f(x)=0.00; grad f(x)=(-0.01, -0.03)
# iter=5506; x=(0.97, 0.93); f(x)=0.00; grad f(x)=(-0.01, -0.03)
# iter=5507; x=(0.97, 0.93); f(x)=0.00; grad f(x)=(-0.01, -0.03)
# iter=5508; x=(0.97, 0.93); f(x)=0.00; grad f(x)=(-0.01, -0.03)
# iter=5509; x=(0.97, 0.93); f(x)=0.00; grad f(x)=(-0.01, -0.03)
# iter=5510; x=(0.97, 0.93); f(x)=0.00; grad f(x)=(-0.01, -0.03)
# iter=5511; x=(0.97, 0.93); f(x)=0.00; grad f(x)=(-0.01, -0.03)
# iter=5512; x=(0.97, 0.93); f(x)=0.00; grad f(x)=(-0.01, -0.03)
# iter=5513; x=(0.97, 0.93); f(x)=0.00; grad f(x)=(-0.01, -0.03)
# iter=5514; x=(0.97, 0.93); f(x)=0.00; grad f(x)=(-0.01, -0.03)
# iter=5515; x=(0.97, 0.93); f(x)=0.00; grad f(x)=(-0.01, -0.03)
# iter=5516; x=(0.97, 0.93); f(x)=0.00; grad f(x)=(-0.01, -0.03)
# iter=5517; x=(0.97, 0.93); f(x)=0.00; grad f(x)=(-0.01, -0.03)
# iter=5518; x=(0.97, 0.93); f(x)=0.00; grad f(x)=(-0.01, -0.03)
# iter=5519; x=(0.97, 0.93); f(x)=0.00; grad f(x)=(-0.01, -0.03)
# iter=5520; x=(0.97, 0.93); f(x)=0.00; grad f(x)=(-0.01, -0.03)
# iter=5521; x=(0.97, 0.93); f(x)=0.00; grad f(x)=(-0.01, -0.03)
# iter=5522; x=(0.97, 0.93); f(x)=0.00; grad f(x)=(-0.01, -0.03)
# iter=5523; x=(0.97, 0.93); f(x)=0.00; grad f(x)=(-0.01, -0.03)
# iter=5524; x=(0.97, 0.93); f(x)=0.00; grad f(x)=(-0.01, -0.03)
# iter=5525; x=(0.97, 0.93); f(x)=0.00; grad f(x)=(-0.01, -0.03)
# iter=5526; x=(0.97, 0.93); f(x)=0.00; grad f(x)=(-0.01, -0.03)
# iter=5527; x=(0.97, 0.93); f(x)=0.00; grad f(x)=(-0.01, -0.03)

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
plt.plot(vals)

# %%
n = 100 # number of discretization points along the x-axis
m = 100 # number of discretization points along the x-axis
a=-0.5; b=2. # extreme points in the x-axis
c=-1.5; d=4. # extreme points in the y-axis
X,Y = np.meshgrid(np.linspace(a,b,n), np.linspace(c,d,m))

Z = f(X,Y)

plt.xlim(a,b)
plt.ylim(c,d)

plt.contour(X,Y,Z, np.logspace(-0.5, 3, 31),cmap='gray_r')
plt.plot([c[0] for c in coords], [c[1] for c in coords])
plt.scatter(1,1,c='red')

# %%
def dist(x1, x2):
    return (x1[0] - x2[0]) ** 2 + (x1[1] - x2[1]) ** 2

# %%
from scipy import optimize

# %%
def f_for_scipy(x):
    return f(x[0], x[1])

# %%
optimize.minimize(lambda x: f(*x), x0=(0, 0))
# Out:
#       fun: 2.8439854262904333e-11
#  hess_inv: array([[0.49482461, 0.98957648],
#        [0.98957648, 1.98394242]])
#       jac: array([ 3.98678486e-06, -2.84414614e-06])
#   message: 'Optimization terminated successfully.'
#      nfev: 72
#       nit: 19
#      njev: 24
#    status: 0
#   success: True
#         x: array([0.99999467, 0.99998932])

# %%
# 2x^2 - 4xy + y^4 + 2

def f(x, y):
    return 2*(x**2) - 4*x*y + y**4 + 2
def grad(x, y):
    dx = 4*x - 4*y
    dy = -4*x + 4*(y**3)
    return (dx, dy)

x0 = (0, 2)
gamma = 1e-3
x_cur = x0

vals = []
coords = []
i = 0
while True:
    x_new = (x_cur[0] - gamma * grad(*x_cur)[0],
            x_cur[1] - gamma * grad(*x_cur)[1])
    if dist(x_new, x_cur) < 1e-9:
        break
    x_cur = x_new
    vals.append(f(*x_cur))
    coords.append(x_cur)
    i += 1
    print(f"iter={i}; x=({x_cur[0]:.2f}, {x_cur[1]:.2f});"
          f" f(x)={f(*x_cur):.2f}; grad f(x)=({grad(*x_cur)[0]:.2f}, {grad(*x_cur)[1]:.2f})")
# Out:
# iter=1; x=(0.01, 1.97); f(x)=16.94; grad f(x)=(-7.84, 30.46)
# iter=2; x=(0.02, 1.94); f(x)=15.97; grad f(x)=(-7.69, 29.03)
# iter=3; x=(0.02, 1.91); f(x)=15.09; grad f(x)=(-7.54, 27.71)
# iter=4; x=(0.03, 1.88); f(x)=14.28; grad f(x)=(-7.40, 26.49)
# iter=5; x=(0.04, 1.85); f(x)=13.54; grad f(x)=(-7.26, 25.35)
# iter=6; x=(0.05, 1.83); f(x)=12.86; grad f(x)=(-7.13, 24.29)
# iter=7; x=(0.05, 1.80); f(x)=12.23; grad f(x)=(-7.01, 23.30)
# iter=8; x=(0.06, 1.78); f(x)=11.65; grad f(x)=(-6.89, 22.37)
# iter=9; x=(0.07, 1.76); f(x)=11.11; grad f(x)=(-6.77, 21.50)
# iter=10; x=(0.07, 1.74); f(x)=10.61; grad f(x)=(-6.66, 20.69)
# iter=11; x=(0.08, 1.72); f(x)=10.15; grad f(x)=(-6.55, 19.92)
# iter=12; x=(0.09, 1.70); f(x)=9.72; grad f(x)=(-6.44, 19.20)
# iter=13; x=(0.09, 1.68); f(x)=9.31; grad f(x)=(-6.34, 18.52)
# iter=14; x=(0.10, 1.66); f(x)=8.94; grad f(x)=(-6.24, 17.87)
# iter=15; x=(0.11, 1.64); f(x)=8.59; grad f(x)=(-6.14, 17.26)
# iter=16; x=(0.11, 1.62); f(x)=8.25; grad f(x)=(-6.05, 16.69)
# iter=17; x=(0.12, 1.61); f(x)=7.94; grad f(x)=(-5.96, 16.14)
# iter=18; x=(0.12, 1.59); f(x)=7.65; grad f(x)=(-5.87, 15.62)
# iter=19; x=(0.13, 1.58); f(x)=7.38; grad f(x)=(-5.78, 15.13)
# iter=20; x=(0.14, 1.56); f(x)=7.12; grad f(x)=(-5.70, 14.66)
# iter=21; x=(0.14, 1.55); f(x)=6.88; grad f(x)=(-5.62, 14.21)
# iter=22; x=(0.15, 1.53); f(x)=6.65; grad f(x)=(-5.54, 13.78)
# iter=23; x=(0.15, 1.52); f(x)=6.43; grad f(x)=(-5.46, 13.38)
# iter=24; x=(0.16, 1.50); f(x)=6.22; grad f(x)=(-5.39, 12.99)
# iter=25; x=(0.16, 1.49); f(x)=6.03; grad f(x)=(-5.31, 12.62)
# iter=26; x=(0.17, 1.48); f(x)=5.84; grad f(x)=(-5.24, 12.26)
# iter=27; x=(0.17, 1.47); f(x)=5.67; grad f(x)=(-5.17, 11.92)
# iter=28; x=(0.18, 1.45); f(x)=5.50; grad f(x)=(-5.10, 11.60)
# iter=29; x=(0.18, 1.44); f(x)=5.34; grad f(x)=(-5.04, 11.28)
# iter=30; x=(0.19, 1.43); f(x)=5.19; grad f(x)=(-4.97, 10.98)
# iter=31; x=(0.19, 1.42); f(x)=5.05; grad f(x)=(-4.91, 10.70)
# iter=32; x=(0.20, 1.41); f(x)=4.91; grad f(x)=(-4.84, 10.42)
# iter=33; x=(0.20, 1.40); f(x)=4.78; grad f(x)=(-4.78, 10.15)
# iter=34; x=(0.21, 1.39); f(x)=4.66; grad f(x)=(-4.72, 9.90)
# iter=35; x=(0.21, 1.38); f(x)=4.54; grad f(x)=(-4.67, 9.65)
# iter=36; x=(0.22, 1.37); f(x)=4.42; grad f(x)=(-4.61, 9.41)
# iter=37; x=(0.22, 1.36); f(x)=4.31; grad f(x)=(-4.55, 9.18)
# iter=38; x=(0.23, 1.35); f(x)=4.21; grad f(x)=(-4.50, 8.96)
# iter=39; x=(0.23, 1.34); f(x)=4.11; grad f(x)=(-4.44, 8.75)
# iter=40; x=(0.24, 1.33); f(x)=4.02; grad f(x)=(-4.39, 8.54)
# iter=41; x=(0.24, 1.33); f(x)=3.92; grad f(x)=(-4.34, 8.35)
# iter=42; x=(0.24, 1.32); f(x)=3.84; grad f(x)=(-4.29, 8.15)
# iter=43; x=(0.25, 1.31); f(x)=3.75; grad f(x)=(-4.24, 7.97)
# iter=44; x=(0.25, 1.30); f(x)=3.67; grad f(x)=(-4.19, 7.79)
# iter=45; x=(0.26, 1.29); f(x)=3.59; grad f(x)=(-4.14, 7.61)
# iter=46; x=(0.26, 1.29); f(x)=3.52; grad f(x)=(-4.09, 7.45)
# iter=47; x=(0.27, 1.28); f(x)=3.45; grad f(x)=(-4.05, 7.28)
# iter=48; x=(0.27, 1.27); f(x)=3.38; grad f(x)=(-4.00, 7.12)
# iter=49; x=(0.27, 1.26); f(x)=3.31; grad f(x)=(-3.96, 6.97)
# iter=50; x=(0.28, 1.26); f(x)=3.25; grad f(x)=(-3.91, 6.82)
# iter=51; x=(0.28, 1.25); f(x)=3.19; grad f(x)=(-3.87, 6.68)
# iter=52; x=(0.29, 1.24); f(x)=3.13; grad f(x)=(-3.83, 6.54)
# iter=53; x=(0.29, 1.24); f(x)=3.07; grad f(x)=(-3.79, 6.40)
# iter=54; x=(0.29, 1.23); f(x)=3.02; grad f(x)=(-3.75, 6.27)
# iter=55; x=(0.30, 1.22); f(x)=2.97; grad f(x)=(-3.71, 6.14)
# iter=56; x=(0.30, 1.22); f(x)=2.91; grad f(x)=(-3.67, 6.02)
# iter=57; x=(0.30, 1.21); f(x)=2.87; grad f(x)=(-3.63, 5.90)
# iter=58; x=(0.31, 1.21); f(x)=2.82; grad f(x)=(-3.59, 5.78)
# iter=59; x=(0.31, 1.20); f(x)=2.77; grad f(x)=(-3.55, 5.66)
# iter=60; x=(0.32, 1.19); f(x)=2.73; grad f(x)=(-3.52, 5.55)
# iter=61; x=(0.32, 1.19); f(x)=2.68; grad f(x)=(-3.48, 5.44)
# iter=62; x=(0.32, 1.18); f(x)=2.64; grad f(x)=(-3.44, 5.34)
# iter=63; x=(0.33, 1.18); f(x)=2.60; grad f(x)=(-3.41, 5.23)
# iter=64; x=(0.33, 1.17); f(x)=2.56; grad f(x)=(-3.37, 5.13)
# iter=65; x=(0.33, 1.17); f(x)=2.53; grad f(x)=(-3.34, 5.04)
# iter=66; x=(0.34, 1.16); f(x)=2.49; grad f(x)=(-3.31, 4.94)
# iter=67; x=(0.34, 1.16); f(x)=2.46; grad f(x)=(-3.27, 4.85)
# iter=68; x=(0.34, 1.15); f(x)=2.42; grad f(x)=(-3.24, 4.76)
# iter=69; x=(0.35, 1.15); f(x)=2.39; grad f(x)=(-3.21, 4.67)
# iter=70; x=(0.35, 1.14); f(x)=2.36; grad f(x)=(-3.18, 4.58)
# iter=71; x=(0.35, 1.14); f(x)=2.33; grad f(x)=(-3.15, 4.50)
# iter=72; x=(0.36, 1.13); f(x)=2.30; grad f(x)=(-3.12, 4.42)
# iter=73; x=(0.36, 1.13); f(x)=2.27; grad f(x)=(-3.09, 4.34)
# iter=74; x=(0.36, 1.13); f(x)=2.24; grad f(x)=(-3.06, 4.26)
# iter=75; x=(0.36, 1.12); f(x)=2.21; grad f(x)=(-3.03, 4.18)
# iter=76; x=(0.37, 1.12); f(x)=2.19; grad f(x)=(-3.00, 4.11)
# iter=77; x=(0.37, 1.11); f(x)=2.16; grad f(x)=(-2.97, 4.03)
# iter=78; x=(0.37, 1.11); f(x)=2.13; grad f(x)=(-2.94, 3.96)
# iter=79; x=(0.38, 1.10); f(x)=2.11; grad f(x)=(-2.91, 3.89)
# iter=80; x=(0.38, 1.10); f(x)=2.09; grad f(x)=(-2.89, 3.82)
# iter=81; x=(0.38, 1.10); f(x)=2.06; grad f(x)=(-2.86, 3.76)
# iter=82; x=(0.38, 1.09); f(x)=2.04; grad f(x)=(-2.83, 3.69)
# iter=83; x=(0.39, 1.09); f(x)=2.02; grad f(x)=(-2.81, 3.63)
# iter=84; x=(0.39, 1.09); f(x)=2.00; grad f(x)=(-2.78, 3.56)
# iter=85; x=(0.39, 1.08); f(x)=1.98; grad f(x)=(-2.76, 3.50)
# iter=86; x=(0.40, 1.08); f(x)=1.96; grad f(x)=(-2.73, 3.44)
# iter=87; x=(0.40, 1.08); f(x)=1.94; grad f(x)=(-2.71, 3.38)
# iter=88; x=(0.40, 1.07); f(x)=1.92; grad f(x)=(-2.68, 3.32)
# iter=89; x=(0.40, 1.07); f(x)=1.90; grad f(x)=(-2.66, 3.27)
# iter=90; x=(0.41, 1.07); f(x)=1.89; grad f(x)=(-2.64, 3.21)
# iter=91; x=(0.41, 1.06); f(x)=1.87; grad f(x)=(-2.61, 3.16)
# iter=92; x=(0.41, 1.06); f(x)=1.85; grad f(x)=(-2.59, 3.11)
# iter=93; x=(0.41, 1.06); f(x)=1.84; grad f(x)=(-2.57, 3.05)
# iter=94; x=(0.42, 1.05); f(x)=1.82; grad f(x)=(-2.54, 3.00)
# iter=95; x=(0.42, 1.05); f(x)=1.81; grad f(x)=(-2.52, 2.95)
# iter=96; x=(0.42, 1.05); f(x)=1.79; grad f(x)=(-2.50, 2.90)
# iter=97; x=(0.42, 1.04); f(x)=1.78; grad f(x)=(-2.48, 2.86)
# iter=98; x=(0.43, 1.04); f(x)=1.76; grad f(x)=(-2.46, 2.81)
# iter=99; x=(0.43, 1.04); f(x)=1.75; grad f(x)=(-2.44, 2.76)
# iter=100; x=(0.43, 1.04); f(x)=1.73; grad f(x)=(-2.41, 2.72)
# iter=101; x=(0.43, 1.03); f(x)=1.72; grad f(x)=(-2.39, 2.67)
# iter=102; x=(0.44, 1.03); f(x)=1.71; grad f(x)=(-2.37, 2.63)
# iter=103; x=(0.44, 1.03); f(x)=1.70; grad f(x)=(-2.35, 2.59)
# iter=104; x=(0.44, 1.03); f(x)=1.68; grad f(x)=(-2.33, 2.54)
# iter=105; x=(0.44, 1.02); f(x)=1.67; grad f(x)=(-2.31, 2.50)
# iter=106; x=(0.45, 1.02); f(x)=1.66; grad f(x)=(-2.30, 2.46)
# iter=107; x=(0.45, 1.02); f(x)=1.65; grad f(x)=(-2.28, 2.42)
# iter=108; x=(0.45, 1.02); f(x)=1.64; grad f(x)=(-2.26, 2.38)
# iter=109; x=(0.45, 1.01); f(x)=1.63; grad f(x)=(-2.24, 2.34)
# iter=110; x=(0.46, 1.01); f(x)=1.62; grad f(x)=(-2.22, 2.31)
# iter=111; x=(0.46, 1.01); f(x)=1.61; grad f(x)=(-2.20, 2.27)
# iter=112; x=(0.46, 1.01); f(x)=1.60; grad f(x)=(-2.18, 2.23)
# iter=113; x=(0.46, 1.00); f(x)=1.59; grad f(x)=(-2.17, 2.20)
# iter=114; x=(0.46, 1.00); f(x)=1.58; grad f(x)=(-2.15, 2.16)
# iter=115; x=(0.47, 1.00); f(x)=1.57; grad f(x)=(-2.13, 2.13)
# iter=116; x=(0.47, 1.00); f(x)=1.56; grad f(x)=(-2.12, 2.09)
# iter=117; x=(0.47, 1.00); f(x)=1.55; grad f(x)=(-2.10, 2.06)
# iter=118; x=(0.47, 0.99); f(x)=1.54; grad f(x)=(-2.08, 2.03)
# iter=119; x=(0.47, 0.99); f(x)=1.53; grad f(x)=(-2.07, 1.99)
# iter=120; x=(0.48, 0.99); f(x)=1.53; grad f(x)=(-2.05, 1.96)
# iter=121; x=(0.48, 0.99); f(x)=1.52; grad f(x)=(-2.03, 1.93)
# iter=122; x=(0.48, 0.99); f(x)=1.51; grad f(x)=(-2.02, 1.90)
# iter=123; x=(0.48, 0.98); f(x)=1.50; grad f(x)=(-2.00, 1.87)
# iter=124; x=(0.48, 0.98); f(x)=1.49; grad f(x)=(-1.99, 1.84)
# iter=125; x=(0.49, 0.98); f(x)=1.49; grad f(x)=(-1.97, 1.81)
# iter=126; x=(0.49, 0.98); f(x)=1.48; grad f(x)=(-1.96, 1.78)
# iter=127; x=(0.49, 0.98); f(x)=1.47; grad f(x)=(-1.94, 1.76)
# iter=128; x=(0.49, 0.97); f(x)=1.47; grad f(x)=(-1.93, 1.73)
# iter=129; x=(0.49, 0.97); f(x)=1.46; grad f(x)=(-1.91, 1.70)
# iter=130; x=(0.50, 0.97); f(x)=1.45; grad f(x)=(-1.90, 1.67)
# iter=131; x=(0.50, 0.97); f(x)=1.45; grad f(x)=(-1.88, 1.65)
# iter=132; x=(0.50, 0.97); f(x)=1.44; grad f(x)=(-1.87, 1.62)
# iter=133; x=(0.50, 0.97); f(x)=1.43; grad f(x)=(-1.85, 1.60)
# iter=134; x=(0.50, 0.96); f(x)=1.43; grad f(x)=(-1.84, 1.57)
# iter=135; x=(0.51, 0.96); f(x)=1.42; grad f(x)=(-1.83, 1.54)
# iter=136; x=(0.51, 0.96); f(x)=1.42; grad f(x)=(-1.81, 1.52)
# iter=137; x=(0.51, 0.96); f(x)=1.41; grad f(x)=(-1.80, 1.50)
# iter=138; x=(0.51, 0.96); f(x)=1.41; grad f(x)=(-1.79, 1.47)
# iter=139; x=(0.51, 0.96); f(x)=1.40; grad f(x)=(-1.77, 1.45)
# iter=140; x=(0.51, 0.96); f(x)=1.40; grad f(x)=(-1.76, 1.43)
# iter=141; x=(0.52, 0.95); f(x)=1.39; grad f(x)=(-1.75, 1.40)
# iter=142; x=(0.52, 0.95); f(x)=1.39; grad f(x)=(-1.74, 1.38)
# iter=143; x=(0.52, 0.95); f(x)=1.38; grad f(x)=(-1.72, 1.36)
# iter=144; x=(0.52, 0.95); f(x)=1.38; grad f(x)=(-1.71, 1.34)
# iter=145; x=(0.52, 0.95); f(x)=1.37; grad f(x)=(-1.70, 1.32)
# iter=146; x=(0.53, 0.95); f(x)=1.37; grad f(x)=(-1.69, 1.30)
# iter=147; x=(0.53, 0.95); f(x)=1.36; grad f(x)=(-1.67, 1.27)
# iter=148; x=(0.53, 0.94); f(x)=1.36; grad f(x)=(-1.66, 1.25)
# iter=149; x=(0.53, 0.94); f(x)=1.35; grad f(x)=(-1.65, 1.23)
# iter=150; x=(0.53, 0.94); f(x)=1.35; grad f(x)=(-1.64, 1.21)
# iter=151; x=(0.53, 0.94); f(x)=1.34; grad f(x)=(-1.63, 1.20)
# iter=152; x=(0.54, 0.94); f(x)=1.34; grad f(x)=(-1.62, 1.18)
# iter=153; x=(0.54, 0.94); f(x)=1.34; grad f(x)=(-1.61, 1.16)
# iter=154; x=(0.54, 0.94); f(x)=1.33; grad f(x)=(-1.59, 1.14)
# iter=155; x=(0.54, 0.94); f(x)=1.33; grad f(x)=(-1.58, 1.12)
# iter=156; x=(0.54, 0.93); f(x)=1.33; grad f(x)=(-1.57, 1.10)
# iter=157; x=(0.54, 0.93); f(x)=1.32; grad f(x)=(-1.56, 1.08)
# iter=158; x=(0.54, 0.93); f(x)=1.32; grad f(x)=(-1.55, 1.07)
# iter=159; x=(0.55, 0.93); f(x)=1.31; grad f(x)=(-1.54, 1.05)
# iter=160; x=(0.55, 0.93); f(x)=1.31; grad f(x)=(-1.53, 1.03)
# iter=161; x=(0.55, 0.93); f(x)=1.31; grad f(x)=(-1.52, 1.02)
# iter=162; x=(0.55, 0.93); f(x)=1.30; grad f(x)=(-1.51, 1.00)
# iter=163; x=(0.55, 0.93); f(x)=1.30; grad f(x)=(-1.50, 0.98)
# iter=164; x=(0.55, 0.93); f(x)=1.30; grad f(x)=(-1.49, 0.97)
# iter=165; x=(0.56, 0.93); f(x)=1.29; grad f(x)=(-1.48, 0.95)
# iter=166; x=(0.56, 0.92); f(x)=1.29; grad f(x)=(-1.47, 0.93)
# iter=167; x=(0.56, 0.92); f(x)=1.29; grad f(x)=(-1.46, 0.92)
# iter=168; x=(0.56, 0.92); f(x)=1.29; grad f(x)=(-1.45, 0.90)
# iter=169; x=(0.56, 0.92); f(x)=1.28; grad f(x)=(-1.44, 0.89)
# iter=170; x=(0.56, 0.92); f(x)=1.28; grad f(x)=(-1.43, 0.87)
# iter=171; x=(0.56, 0.92); f(x)=1.28; grad f(x)=(-1.42, 0.86)
# iter=172; x=(0.57, 0.92); f(x)=1.27; grad f(x)=(-1.41, 0.85)
# iter=173; x=(0.57, 0.92); f(x)=1.27; grad f(x)=(-1.41, 0.83)
# iter=174; x=(0.57, 0.92); f(x)=1.27; grad f(x)=(-1.40, 0.82)
# iter=175; x=(0.57, 0.92); f(x)=1.27; grad f(x)=(-1.39, 0.80)
# iter=176; x=(0.57, 0.92); f(x)=1.26; grad f(x)=(-1.38, 0.79)
# iter=177; x=(0.57, 0.92); f(x)=1.26; grad f(x)=(-1.37, 0.78)
# iter=178; x=(0.57, 0.91); f(x)=1.26; grad f(x)=(-1.36, 0.76)
# iter=179; x=(0.58, 0.91); f(x)=1.26; grad f(x)=(-1.35, 0.75)
# iter=180; x=(0.58, 0.91); f(x)=1.25; grad f(x)=(-1.34, 0.74)
# iter=181; x=(0.58, 0.91); f(x)=1.25; grad f(x)=(-1.34, 0.72)
# iter=182; x=(0.58, 0.91); f(x)=1.25; grad f(x)=(-1.33, 0.71)
# iter=183; x=(0.58, 0.91); f(x)=1.25; grad f(x)=(-1.32, 0.70)
# iter=184; x=(0.58, 0.91); f(x)=1.24; grad f(x)=(-1.31, 0.69)
# iter=185; x=(0.58, 0.91); f(x)=1.24; grad f(x)=(-1.30, 0.67)
# iter=186; x=(0.58, 0.91); f(x)=1.24; grad f(x)=(-1.30, 0.66)
# iter=187; x=(0.59, 0.91); f(x)=1.24; grad f(x)=(-1.29, 0.65)
# iter=188; x=(0.59, 0.91); f(x)=1.24; grad f(x)=(-1.28, 0.64)
# iter=189; x=(0.59, 0.91); f(x)=1.23; grad f(x)=(-1.27, 0.63)
# iter=190; x=(0.59, 0.91); f(x)=1.23; grad f(x)=(-1.27, 0.62)
# iter=191; x=(0.59, 0.91); f(x)=1.23; grad f(x)=(-1.26, 0.61)
# iter=192; x=(0.59, 0.90); f(x)=1.23; grad f(x)=(-1.25, 0.59)
# iter=193; x=(0.59, 0.90); f(x)=1.23; grad f(x)=(-1.24, 0.58)
# iter=194; x=(0.59, 0.90); f(x)=1.22; grad f(x)=(-1.24, 0.57)
# iter=195; x=(0.60, 0.90); f(x)=1.22; grad f(x)=(-1.23, 0.56)
# iter=196; x=(0.60, 0.90); f(x)=1.22; grad f(x)=(-1.22, 0.55)
# iter=197; x=(0.60, 0.90); f(x)=1.22; grad f(x)=(-1.21, 0.54)
# iter=198; x=(0.60, 0.90); f(x)=1.22; grad f(x)=(-1.21, 0.53)
# iter=199; x=(0.60, 0.90); f(x)=1.22; grad f(x)=(-1.20, 0.52)
# iter=200; x=(0.60, 0.90); f(x)=1.21; grad f(x)=(-1.19, 0.51)
# iter=201; x=(0.60, 0.90); f(x)=1.21; grad f(x)=(-1.19, 0.50)
# iter=202; x=(0.60, 0.90); f(x)=1.21; grad f(x)=(-1.18, 0.49)
# iter=203; x=(0.61, 0.90); f(x)=1.21; grad f(x)=(-1.17, 0.48)
# iter=204; x=(0.61, 0.90); f(x)=1.21; grad f(x)=(-1.17, 0.47)
# iter=205; x=(0.61, 0.90); f(x)=1.21; grad f(x)=(-1.16, 0.46)
# iter=206; x=(0.61, 0.90); f(x)=1.20; grad f(x)=(-1.15, 0.46)
# iter=207; x=(0.61, 0.90); f(x)=1.20; grad f(x)=(-1.15, 0.45)
# iter=208; x=(0.61, 0.90); f(x)=1.20; grad f(x)=(-1.14, 0.44)
# iter=209; x=(0.61, 0.90); f(x)=1.20; grad f(x)=(-1.13, 0.43)
# iter=210; x=(0.61, 0.90); f(x)=1.20; grad f(x)=(-1.13, 0.42)
# iter=211; x=(0.61, 0.90); f(x)=1.20; grad f(x)=(-1.12, 0.41)
# iter=212; x=(0.62, 0.89); f(x)=1.20; grad f(x)=(-1.12, 0.40)
# iter=213; x=(0.62, 0.89); f(x)=1.19; grad f(x)=(-1.11, 0.39)
# iter=214; x=(0.62, 0.89); f(x)=1.19; grad f(x)=(-1.10, 0.39)
# iter=215; x=(0.62, 0.89); f(x)=1.19; grad f(x)=(-1.10, 0.38)
# iter=216; x=(0.62, 0.89); f(x)=1.19; grad f(x)=(-1.09, 0.37)
# iter=217; x=(0.62, 0.89); f(x)=1.19; grad f(x)=(-1.09, 0.36)
# iter=218; x=(0.62, 0.89); f(x)=1.19; grad f(x)=(-1.08, 0.35)
# iter=219; x=(0.62, 0.89); f(x)=1.19; grad f(x)=(-1.07, 0.35)
# iter=220; x=(0.62, 0.89); f(x)=1.18; grad f(x)=(-1.07, 0.34)
# iter=221; x=(0.63, 0.89); f(x)=1.18; grad f(x)=(-1.06, 0.33)
# iter=222; x=(0.63, 0.89); f(x)=1.18; grad f(x)=(-1.06, 0.32)
# iter=223; x=(0.63, 0.89); f(x)=1.18; grad f(x)=(-1.05, 0.32)
# iter=224; x=(0.63, 0.89); f(x)=1.18; grad f(x)=(-1.05, 0.31)
# iter=225; x=(0.63, 0.89); f(x)=1.18; grad f(x)=(-1.04, 0.30)
# iter=226; x=(0.63, 0.89); f(x)=1.18; grad f(x)=(-1.04, 0.30)
# iter=227; x=(0.63, 0.89); f(x)=1.18; grad f(x)=(-1.03, 0.29)
# iter=228; x=(0.63, 0.89); f(x)=1.17; grad f(x)=(-1.02, 0.28)
# iter=229; x=(0.63, 0.89); f(x)=1.17; grad f(x)=(-1.02, 0.27)
# iter=230; x=(0.64, 0.89); f(x)=1.17; grad f(x)=(-1.01, 0.27)
# iter=231; x=(0.64, 0.89); f(x)=1.17; grad f(x)=(-1.01, 0.26)
# iter=232; x=(0.64, 0.89); f(x)=1.17; grad f(x)=(-1.00, 0.26)
# iter=233; x=(0.64, 0.89); f(x)=1.17; grad f(x)=(-1.00, 0.25)
# iter=234; x=(0.64, 0.89); f(x)=1.17; grad f(x)=(-0.99, 0.24)
# iter=235; x=(0.64, 0.89); f(x)=1.17; grad f(x)=(-0.99, 0.24)
# iter=236; x=(0.64, 0.89); f(x)=1.17; grad f(x)=(-0.98, 0.23)
# iter=237; x=(0.64, 0.89); f(x)=1.17; grad f(x)=(-0.98, 0.22)
# iter=238; x=(0.64, 0.89); f(x)=1.16; grad f(x)=(-0.97, 0.22)
# iter=239; x=(0.64, 0.89); f(x)=1.16; grad f(x)=(-0.97, 0.21)
# iter=240; x=(0.65, 0.89); f(x)=1.16; grad f(x)=(-0.97, 0.21)
# iter=241; x=(0.65, 0.89); f(x)=1.16; grad f(x)=(-0.96, 0.20)
# iter=242; x=(0.65, 0.89); f(x)=1.16; grad f(x)=(-0.96, 0.19)
# iter=243; x=(0.65, 0.89); f(x)=1.16; grad f(x)=(-0.95, 0.19)
# iter=244; x=(0.65, 0.89); f(x)=1.16; grad f(x)=(-0.95, 0.18)
# iter=245; x=(0.65, 0.89); f(x)=1.16; grad f(x)=(-0.94, 0.18)
# iter=246; x=(0.65, 0.89); f(x)=1.16; grad f(x)=(-0.94, 0.17)
# iter=247; x=(0.65, 0.89); f(x)=1.16; grad f(x)=(-0.93, 0.17)
# iter=248; x=(0.65, 0.88); f(x)=1.15; grad f(x)=(-0.93, 0.16)
# iter=249; x=(0.65, 0.88); f(x)=1.15; grad f(x)=(-0.92, 0.16)
# iter=250; x=(0.65, 0.88); f(x)=1.15; grad f(x)=(-0.92, 0.15)
# iter=251; x=(0.66, 0.88); f(x)=1.15; grad f(x)=(-0.92, 0.15)
# iter=252; x=(0.66, 0.88); f(x)=1.15; grad f(x)=(-0.91, 0.14)
# iter=253; x=(0.66, 0.88); f(x)=1.15; grad f(x)=(-0.91, 0.14)
# iter=254; x=(0.66, 0.88); f(x)=1.15; grad f(x)=(-0.90, 0.13)
# iter=255; x=(0.66, 0.88); f(x)=1.15; grad f(x)=(-0.90, 0.13)
# iter=256; x=(0.66, 0.88); f(x)=1.15; grad f(x)=(-0.90, 0.12)
# iter=257; x=(0.66, 0.88); f(x)=1.15; grad f(x)=(-0.89, 0.12)
# iter=258; x=(0.66, 0.88); f(x)=1.15; grad f(x)=(-0.89, 0.11)
# iter=259; x=(0.66, 0.88); f(x)=1.15; grad f(x)=(-0.88, 0.11)
# iter=260; x=(0.66, 0.88); f(x)=1.14; grad f(x)=(-0.88, 0.10)
# iter=261; x=(0.66, 0.88); f(x)=1.14; grad f(x)=(-0.88, 0.10)
# iter=262; x=(0.67, 0.88); f(x)=1.14; grad f(x)=(-0.87, 0.09)
# iter=263; x=(0.67, 0.88); f(x)=1.14; grad f(x)=(-0.87, 0.09)
# iter=264; x=(0.67, 0.88); f(x)=1.14; grad f(x)=(-0.86, 0.09)
# iter=265; x=(0.67, 0.88); f(x)=1.14; grad f(x)=(-0.86, 0.08)
# iter=266; x=(0.67, 0.88); f(x)=1.14; grad f(x)=(-0.86, 0.08)
# iter=267; x=(0.67, 0.88); f(x)=1.14; grad f(x)=(-0.85, 0.07)
# iter=268; x=(0.67, 0.88); f(x)=1.14; grad f(x)=(-0.85, 0.07)
# iter=269; x=(0.67, 0.88); f(x)=1.14; grad f(x)=(-0.84, 0.06)
# iter=270; x=(0.67, 0.88); f(x)=1.14; grad f(x)=(-0.84, 0.06)
# iter=271; x=(0.67, 0.88); f(x)=1.14; grad f(x)=(-0.84, 0.06)
# iter=272; x=(0.67, 0.88); f(x)=1.14; grad f(x)=(-0.83, 0.05)
# iter=273; x=(0.67, 0.88); f(x)=1.14; grad f(x)=(-0.83, 0.05)
# iter=274; x=(0.68, 0.88); f(x)=1.13; grad f(x)=(-0.83, 0.05)
# iter=275; x=(0.68, 0.88); f(x)=1.13; grad f(x)=(-0.82, 0.04)
# iter=276; x=(0.68, 0.88); f(x)=1.13; grad f(x)=(-0.82, 0.04)
# iter=277; x=(0.68, 0.88); f(x)=1.13; grad f(x)=(-0.82, 0.03)
# iter=278; x=(0.68, 0.88); f(x)=1.13; grad f(x)=(-0.81, 0.03)
# iter=279; x=(0.68, 0.88); f(x)=1.13; grad f(x)=(-0.81, 0.03)
# iter=280; x=(0.68, 0.88); f(x)=1.13; grad f(x)=(-0.81, 0.02)
# iter=281; x=(0.68, 0.88); f(x)=1.13; grad f(x)=(-0.80, 0.02)
# iter=282; x=(0.68, 0.88); f(x)=1.13; grad f(x)=(-0.80, 0.02)
# iter=283; x=(0.68, 0.88); f(x)=1.13; grad f(x)=(-0.80, 0.01)
# iter=284; x=(0.68, 0.88); f(x)=1.13; grad f(x)=(-0.79, 0.01)
# iter=285; x=(0.68, 0.88); f(x)=1.13; grad f(x)=(-0.79, 0.01)
# iter=286; x=(0.69, 0.88); f(x)=1.13; grad f(x)=(-0.79, 0.00)
# iter=287; x=(0.69, 0.88); f(x)=1.13; grad f(x)=(-0.78, 0.00)
# iter=288; x=(0.69, 0.88); f(x)=1.13; grad f(x)=(-0.78, -0.00)
# iter=289; x=(0.69, 0.88); f(x)=1.12; grad f(x)=(-0.78, -0.01)
# iter=290; x=(0.69, 0.88); f(x)=1.12; grad f(x)=(-0.77, -0.01)
# iter=291; x=(0.69, 0.88); f(x)=1.12; grad f(x)=(-0.77, -0.01)
# iter=292; x=(0.69, 0.88); f(x)=1.12; grad f(x)=(-0.77, -0.01)
# iter=293; x=(0.69, 0.88); f(x)=1.12; grad f(x)=(-0.77, -0.02)
# iter=294; x=(0.69, 0.88); f(x)=1.12; grad f(x)=(-0.76, -0.02)
# iter=295; x=(0.69, 0.88); f(x)=1.12; grad f(x)=(-0.76, -0.02)
# iter=296; x=(0.69, 0.88); f(x)=1.12; grad f(x)=(-0.76, -0.03)
# iter=297; x=(0.69, 0.88); f(x)=1.12; grad f(x)=(-0.75, -0.03)
# iter=298; x=(0.69, 0.88); f(x)=1.12; grad f(x)=(-0.75, -0.03)
# iter=299; x=(0.70, 0.88); f(x)=1.12; grad f(x)=(-0.75, -0.03)
# iter=300; x=(0.70, 0.88); f(x)=1.12; grad f(x)=(-0.74, -0.04)
# iter=301; x=(0.70, 0.88); f(x)=1.12; grad f(x)=(-0.74, -0.04)
# iter=302; x=(0.70, 0.88); f(x)=1.12; grad f(x)=(-0.74, -0.04)
# iter=303; x=(0.70, 0.88); f(x)=1.12; grad f(x)=(-0.74, -0.05)
# iter=304; x=(0.70, 0.88); f(x)=1.12; grad f(x)=(-0.73, -0.05)
# iter=305; x=(0.70, 0.88); f(x)=1.12; grad f(x)=(-0.73, -0.05)
# iter=306; x=(0.70, 0.88); f(x)=1.12; grad f(x)=(-0.73, -0.05)
# iter=307; x=(0.70, 0.88); f(x)=1.11; grad f(x)=(-0.73, -0.06)
# iter=308; x=(0.70, 0.88); f(x)=1.11; grad f(x)=(-0.72, -0.06)
# iter=309; x=(0.70, 0.88); f(x)=1.11; grad f(x)=(-0.72, -0.06)
# iter=310; x=(0.70, 0.88); f(x)=1.11; grad f(x)=(-0.72, -0.06)
# iter=311; x=(0.70, 0.88); f(x)=1.11; grad f(x)=(-0.71, -0.06)
# iter=312; x=(0.70, 0.88); f(x)=1.11; grad f(x)=(-0.71, -0.07)
# iter=313; x=(0.71, 0.88); f(x)=1.11; grad f(x)=(-0.71, -0.07)
# iter=314; x=(0.71, 0.88); f(x)=1.11; grad f(x)=(-0.71, -0.07)
# iter=315; x=(0.71, 0.88); f(x)=1.11; grad f(x)=(-0.70, -0.07)
# iter=316; x=(0.71, 0.88); f(x)=1.11; grad f(x)=(-0.70, -0.08)
# iter=317; x=(0.71, 0.88); f(x)=1.11; grad f(x)=(-0.70, -0.08)
# iter=318; x=(0.71, 0.88); f(x)=1.11; grad f(x)=(-0.70, -0.08)
# iter=319; x=(0.71, 0.88); f(x)=1.11; grad f(x)=(-0.69, -0.08)
# iter=320; x=(0.71, 0.88); f(x)=1.11; grad f(x)=(-0.69, -0.08)
# iter=321; x=(0.71, 0.88); f(x)=1.11; grad f(x)=(-0.69, -0.09)
# iter=322; x=(0.71, 0.88); f(x)=1.11; grad f(x)=(-0.69, -0.09)
# iter=323; x=(0.71, 0.88); f(x)=1.11; grad f(x)=(-0.68, -0.09)
# iter=324; x=(0.71, 0.88); f(x)=1.11; grad f(x)=(-0.68, -0.09)
# iter=325; x=(0.71, 0.88); f(x)=1.11; grad f(x)=(-0.68, -0.09)
# iter=326; x=(0.71, 0.88); f(x)=1.11; grad f(x)=(-0.68, -0.10)
# iter=327; x=(0.72, 0.88); f(x)=1.10; grad f(x)=(-0.68, -0.10)
# iter=328; x=(0.72, 0.88); f(x)=1.10; grad f(x)=(-0.67, -0.10)
# iter=329; x=(0.72, 0.88); f(x)=1.10; grad f(x)=(-0.67, -0.10)
# iter=330; x=(0.72, 0.88); f(x)=1.10; grad f(x)=(-0.67, -0.10)
# iter=331; x=(0.72, 0.88); f(x)=1.10; grad f(x)=(-0.67, -0.10)
# iter=332; x=(0.72, 0.88); f(x)=1.10; grad f(x)=(-0.66, -0.11)
# iter=333; x=(0.72, 0.88); f(x)=1.10; grad f(x)=(-0.66, -0.11)
# iter=334; x=(0.72, 0.88); f(x)=1.10; grad f(x)=(-0.66, -0.11)
# iter=335; x=(0.72, 0.88); f(x)=1.10; grad f(x)=(-0.66, -0.11)
# iter=336; x=(0.72, 0.88); f(x)=1.10; grad f(x)=(-0.66, -0.11)
# iter=337; x=(0.72, 0.89); f(x)=1.10; grad f(x)=(-0.65, -0.11)
# iter=338; x=(0.72, 0.89); f(x)=1.10; grad f(x)=(-0.65, -0.12)
# iter=339; x=(0.72, 0.89); f(x)=1.10; grad f(x)=(-0.65, -0.12)
# iter=340; x=(0.72, 0.89); f(x)=1.10; grad f(x)=(-0.65, -0.12)
# iter=341; x=(0.72, 0.89); f(x)=1.10; grad f(x)=(-0.64, -0.12)
# iter=342; x=(0.73, 0.89); f(x)=1.10; grad f(x)=(-0.64, -0.12)
# iter=343; x=(0.73, 0.89); f(x)=1.10; grad f(x)=(-0.64, -0.12)
# iter=344; x=(0.73, 0.89); f(x)=1.10; grad f(x)=(-0.64, -0.12)
# iter=345; x=(0.73, 0.89); f(x)=1.10; grad f(x)=(-0.64, -0.13)
# iter=346; x=(0.73, 0.89); f(x)=1.10; grad f(x)=(-0.63, -0.13)
# iter=347; x=(0.73, 0.89); f(x)=1.10; grad f(x)=(-0.63, -0.13)
# iter=348; x=(0.73, 0.89); f(x)=1.10; grad f(x)=(-0.63, -0.13)
# iter=349; x=(0.73, 0.89); f(x)=1.10; grad f(x)=(-0.63, -0.13)
# iter=350; x=(0.73, 0.89); f(x)=1.09; grad f(x)=(-0.63, -0.13)
# iter=351; x=(0.73, 0.89); f(x)=1.09; grad f(x)=(-0.62, -0.13)
# iter=352; x=(0.73, 0.89); f(x)=1.09; grad f(x)=(-0.62, -0.13)
# iter=353; x=(0.73, 0.89); f(x)=1.09; grad f(x)=(-0.62, -0.14)
# iter=354; x=(0.73, 0.89); f(x)=1.09; grad f(x)=(-0.62, -0.14)
# iter=355; x=(0.73, 0.89); f(x)=1.09; grad f(x)=(-0.62, -0.14)
# iter=356; x=(0.73, 0.89); f(x)=1.09; grad f(x)=(-0.61, -0.14)
# iter=357; x=(0.73, 0.89); f(x)=1.09; grad f(x)=(-0.61, -0.14)
# iter=358; x=(0.74, 0.89); f(x)=1.09; grad f(x)=(-0.61, -0.14)
# iter=359; x=(0.74, 0.89); f(x)=1.09; grad f(x)=(-0.61, -0.14)
# iter=360; x=(0.74, 0.89); f(x)=1.09; grad f(x)=(-0.61, -0.14)
# iter=361; x=(0.74, 0.89); f(x)=1.09; grad f(x)=(-0.61, -0.14)
# iter=362; x=(0.74, 0.89); f(x)=1.09; grad f(x)=(-0.60, -0.15)
# iter=363; x=(0.74, 0.89); f(x)=1.09; grad f(x)=(-0.60, -0.15)
# iter=364; x=(0.74, 0.89); f(x)=1.09; grad f(x)=(-0.60, -0.15)
# iter=365; x=(0.74, 0.89); f(x)=1.09; grad f(x)=(-0.60, -0.15)
# iter=366; x=(0.74, 0.89); f(x)=1.09; grad f(x)=(-0.60, -0.15)
# iter=367; x=(0.74, 0.89); f(x)=1.09; grad f(x)=(-0.59, -0.15)
# iter=368; x=(0.74, 0.89); f(x)=1.09; grad f(x)=(-0.59, -0.15)
# iter=369; x=(0.74, 0.89); f(x)=1.09; grad f(x)=(-0.59, -0.15)
# iter=370; x=(0.74, 0.89); f(x)=1.09; grad f(x)=(-0.59, -0.15)
# iter=371; x=(0.74, 0.89); f(x)=1.09; grad f(x)=(-0.59, -0.15)
# iter=372; x=(0.74, 0.89); f(x)=1.09; grad f(x)=(-0.59, -0.16)
# iter=373; x=(0.74, 0.89); f(x)=1.09; grad f(x)=(-0.58, -0.16)
# iter=374; x=(0.74, 0.89); f(x)=1.09; grad f(x)=(-0.58, -0.16)
# iter=375; x=(0.75, 0.89); f(x)=1.09; grad f(x)=(-0.58, -0.16)
# iter=376; x=(0.75, 0.89); f(x)=1.08; grad f(x)=(-0.58, -0.16)
# iter=377; x=(0.75, 0.89); f(x)=1.08; grad f(x)=(-0.58, -0.16)
# iter=378; x=(0.75, 0.89); f(x)=1.08; grad f(x)=(-0.58, -0.16)
# iter=379; x=(0.75, 0.89); f(x)=1.08; grad f(x)=(-0.57, -0.16)
# iter=380; x=(0.75, 0.89); f(x)=1.08; grad f(x)=(-0.57, -0.16)
# iter=381; x=(0.75, 0.89); f(x)=1.08; grad f(x)=(-0.57, -0.16)
# iter=382; x=(0.75, 0.89); f(x)=1.08; grad f(x)=(-0.57, -0.16)
# iter=383; x=(0.75, 0.89); f(x)=1.08; grad f(x)=(-0.57, -0.16)
# iter=384; x=(0.75, 0.89); f(x)=1.08; grad f(x)=(-0.57, -0.16)
# iter=385; x=(0.75, 0.89); f(x)=1.08; grad f(x)=(-0.56, -0.17)
# iter=386; x=(0.75, 0.89); f(x)=1.08; grad f(x)=(-0.56, -0.17)
# iter=387; x=(0.75, 0.89); f(x)=1.08; grad f(x)=(-0.56, -0.17)
# iter=388; x=(0.75, 0.89); f(x)=1.08; grad f(x)=(-0.56, -0.17)
# iter=389; x=(0.75, 0.89); f(x)=1.08; grad f(x)=(-0.56, -0.17)
# iter=390; x=(0.75, 0.89); f(x)=1.08; grad f(x)=(-0.56, -0.17)
# iter=391; x=(0.75, 0.89); f(x)=1.08; grad f(x)=(-0.55, -0.17)
# iter=392; x=(0.75, 0.89); f(x)=1.08; grad f(x)=(-0.55, -0.17)
# iter=393; x=(0.76, 0.89); f(x)=1.08; grad f(x)=(-0.55, -0.17)
# iter=394; x=(0.76, 0.89); f(x)=1.08; grad f(x)=(-0.55, -0.17)
# iter=395; x=(0.76, 0.89); f(x)=1.08; grad f(x)=(-0.55, -0.17)
# iter=396; x=(0.76, 0.89); f(x)=1.08; grad f(x)=(-0.55, -0.17)
# iter=397; x=(0.76, 0.89); f(x)=1.08; grad f(x)=(-0.55, -0.17)
# iter=398; x=(0.76, 0.89); f(x)=1.08; grad f(x)=(-0.54, -0.17)
# iter=399; x=(0.76, 0.89); f(x)=1.08; grad f(x)=(-0.54, -0.17)
# iter=400; x=(0.76, 0.89); f(x)=1.08; grad f(x)=(-0.54, -0.17)
# iter=401; x=(0.76, 0.89); f(x)=1.08; grad f(x)=(-0.54, -0.17)
# iter=402; x=(0.76, 0.89); f(x)=1.08; grad f(x)=(-0.54, -0.18)
# iter=403; x=(0.76, 0.90); f(x)=1.08; grad f(x)=(-0.54, -0.18)
# iter=404; x=(0.76, 0.90); f(x)=1.08; grad f(x)=(-0.54, -0.18)
# iter=405; x=(0.76, 0.90); f(x)=1.07; grad f(x)=(-0.53, -0.18)
# iter=406; x=(0.76, 0.90); f(x)=1.07; grad f(x)=(-0.53, -0.18)
# iter=407; x=(0.76, 0.90); f(x)=1.07; grad f(x)=(-0.53, -0.18)
# iter=408; x=(0.76, 0.90); f(x)=1.07; grad f(x)=(-0.53, -0.18)
# iter=409; x=(0.76, 0.90); f(x)=1.07; grad f(x)=(-0.53, -0.18)
# iter=410; x=(0.76, 0.90); f(x)=1.07; grad f(x)=(-0.53, -0.18)
# iter=411; x=(0.77, 0.90); f(x)=1.07; grad f(x)=(-0.53, -0.18)
# iter=412; x=(0.77, 0.90); f(x)=1.07; grad f(x)=(-0.52, -0.18)
# iter=413; x=(0.77, 0.90); f(x)=1.07; grad f(x)=(-0.52, -0.18)
# iter=414; x=(0.77, 0.90); f(x)=1.07; grad f(x)=(-0.52, -0.18)
# iter=415; x=(0.77, 0.90); f(x)=1.07; grad f(x)=(-0.52, -0.18)
# iter=416; x=(0.77, 0.90); f(x)=1.07; grad f(x)=(-0.52, -0.18)
# iter=417; x=(0.77, 0.90); f(x)=1.07; grad f(x)=(-0.52, -0.18)
# iter=418; x=(0.77, 0.90); f(x)=1.07; grad f(x)=(-0.52, -0.18)
# iter=419; x=(0.77, 0.90); f(x)=1.07; grad f(x)=(-0.51, -0.18)
# iter=420; x=(0.77, 0.90); f(x)=1.07; grad f(x)=(-0.51, -0.18)
# iter=421; x=(0.77, 0.90); f(x)=1.07; grad f(x)=(-0.51, -0.18)
# iter=422; x=(0.77, 0.90); f(x)=1.07; grad f(x)=(-0.51, -0.18)
# iter=423; x=(0.77, 0.90); f(x)=1.07; grad f(x)=(-0.51, -0.18)
# iter=424; x=(0.77, 0.90); f(x)=1.07; grad f(x)=(-0.51, -0.18)
# iter=425; x=(0.77, 0.90); f(x)=1.07; grad f(x)=(-0.51, -0.18)
# iter=426; x=(0.77, 0.90); f(x)=1.07; grad f(x)=(-0.51, -0.18)
# iter=427; x=(0.77, 0.90); f(x)=1.07; grad f(x)=(-0.50, -0.18)
# iter=428; x=(0.77, 0.90); f(x)=1.07; grad f(x)=(-0.50, -0.18)
# iter=429; x=(0.77, 0.90); f(x)=1.07; grad f(x)=(-0.50, -0.18)
# iter=430; x=(0.77, 0.90); f(x)=1.07; grad f(x)=(-0.50, -0.18)
# iter=431; x=(0.78, 0.90); f(x)=1.07; grad f(x)=(-0.50, -0.18)
# iter=432; x=(0.78, 0.90); f(x)=1.07; grad f(x)=(-0.50, -0.18)
# iter=433; x=(0.78, 0.90); f(x)=1.07; grad f(x)=(-0.50, -0.19)
# iter=434; x=(0.78, 0.90); f(x)=1.07; grad f(x)=(-0.50, -0.19)
# iter=435; x=(0.78, 0.90); f(x)=1.07; grad f(x)=(-0.49, -0.19)
# iter=436; x=(0.78, 0.90); f(x)=1.07; grad f(x)=(-0.49, -0.19)
# iter=437; x=(0.78, 0.90); f(x)=1.07; grad f(x)=(-0.49, -0.19)
# iter=438; x=(0.78, 0.90); f(x)=1.07; grad f(x)=(-0.49, -0.19)
# iter=439; x=(0.78, 0.90); f(x)=1.06; grad f(x)=(-0.49, -0.19)
# iter=440; x=(0.78, 0.90); f(x)=1.06; grad f(x)=(-0.49, -0.19)
# iter=441; x=(0.78, 0.90); f(x)=1.06; grad f(x)=(-0.49, -0.19)
# iter=442; x=(0.78, 0.90); f(x)=1.06; grad f(x)=(-0.49, -0.19)
# iter=443; x=(0.78, 0.90); f(x)=1.06; grad f(x)=(-0.48, -0.19)
# iter=444; x=(0.78, 0.90); f(x)=1.06; grad f(x)=(-0.48, -0.19)
# iter=445; x=(0.78, 0.90); f(x)=1.06; grad f(x)=(-0.48, -0.19)
# iter=446; x=(0.78, 0.90); f(x)=1.06; grad f(x)=(-0.48, -0.19)
# iter=447; x=(0.78, 0.90); f(x)=1.06; grad f(x)=(-0.48, -0.19)
# iter=448; x=(0.78, 0.90); f(x)=1.06; grad f(x)=(-0.48, -0.19)
# iter=449; x=(0.78, 0.90); f(x)=1.06; grad f(x)=(-0.48, -0.19)
# iter=450; x=(0.78, 0.90); f(x)=1.06; grad f(x)=(-0.48, -0.19)
# iter=451; x=(0.79, 0.90); f(x)=1.06; grad f(x)=(-0.47, -0.19)
# iter=452; x=(0.79, 0.90); f(x)=1.06; grad f(x)=(-0.47, -0.19)
# iter=453; x=(0.79, 0.90); f(x)=1.06; grad f(x)=(-0.47, -0.19)
# iter=454; x=(0.79, 0.90); f(x)=1.06; grad f(x)=(-0.47, -0.19)
# iter=455; x=(0.79, 0.90); f(x)=1.06; grad f(x)=(-0.47, -0.19)
# iter=456; x=(0.79, 0.90); f(x)=1.06; grad f(x)=(-0.47, -0.19)
# iter=457; x=(0.79, 0.90); f(x)=1.06; grad f(x)=(-0.47, -0.19)
# iter=458; x=(0.79, 0.91); f(x)=1.06; grad f(x)=(-0.47, -0.19)
# iter=459; x=(0.79, 0.91); f(x)=1.06; grad f(x)=(-0.47, -0.19)
# iter=460; x=(0.79, 0.91); f(x)=1.06; grad f(x)=(-0.46, -0.19)
# iter=461; x=(0.79, 0.91); f(x)=1.06; grad f(x)=(-0.46, -0.19)
# iter=462; x=(0.79, 0.91); f(x)=1.06; grad f(x)=(-0.46, -0.19)
# iter=463; x=(0.79, 0.91); f(x)=1.06; grad f(x)=(-0.46, -0.19)
# iter=464; x=(0.79, 0.91); f(x)=1.06; grad f(x)=(-0.46, -0.19)
# iter=465; x=(0.79, 0.91); f(x)=1.06; grad f(x)=(-0.46, -0.19)
# iter=466; x=(0.79, 0.91); f(x)=1.06; grad f(x)=(-0.46, -0.19)
# iter=467; x=(0.79, 0.91); f(x)=1.06; grad f(x)=(-0.46, -0.19)
# iter=468; x=(0.79, 0.91); f(x)=1.06; grad f(x)=(-0.46, -0.19)
# iter=469; x=(0.79, 0.91); f(x)=1.06; grad f(x)=(-0.45, -0.19)
# iter=470; x=(0.79, 0.91); f(x)=1.06; grad f(x)=(-0.45, -0.19)
# iter=471; x=(0.79, 0.91); f(x)=1.06; grad f(x)=(-0.45, -0.19)
# iter=472; x=(0.79, 0.91); f(x)=1.06; grad f(x)=(-0.45, -0.19)
# iter=473; x=(0.80, 0.91); f(x)=1.06; grad f(x)=(-0.45, -0.19)
# iter=474; x=(0.80, 0.91); f(x)=1.06; grad f(x)=(-0.45, -0.19)
# iter=475; x=(0.80, 0.91); f(x)=1.06; grad f(x)=(-0.45, -0.19)
# iter=476; x=(0.80, 0.91); f(x)=1.06; grad f(x)=(-0.45, -0.19)
# iter=477; x=(0.80, 0.91); f(x)=1.06; grad f(x)=(-0.45, -0.19)
# iter=478; x=(0.80, 0.91); f(x)=1.06; grad f(x)=(-0.45, -0.19)
# iter=479; x=(0.80, 0.91); f(x)=1.05; grad f(x)=(-0.44, -0.19)
# iter=480; x=(0.80, 0.91); f(x)=1.05; grad f(x)=(-0.44, -0.19)
# iter=481; x=(0.80, 0.91); f(x)=1.05; grad f(x)=(-0.44, -0.19)
# iter=482; x=(0.80, 0.91); f(x)=1.05; grad f(x)=(-0.44, -0.19)
# iter=483; x=(0.80, 0.91); f(x)=1.05; grad f(x)=(-0.44, -0.19)
# iter=484; x=(0.80, 0.91); f(x)=1.05; grad f(x)=(-0.44, -0.19)
# iter=485; x=(0.80, 0.91); f(x)=1.05; grad f(x)=(-0.44, -0.19)
# iter=486; x=(0.80, 0.91); f(x)=1.05; grad f(x)=(-0.44, -0.19)
# iter=487; x=(0.80, 0.91); f(x)=1.05; grad f(x)=(-0.44, -0.19)
# iter=488; x=(0.80, 0.91); f(x)=1.05; grad f(x)=(-0.44, -0.19)
# iter=489; x=(0.80, 0.91); f(x)=1.05; grad f(x)=(-0.43, -0.19)
# iter=490; x=(0.80, 0.91); f(x)=1.05; grad f(x)=(-0.43, -0.19)
# iter=491; x=(0.80, 0.91); f(x)=1.05; grad f(x)=(-0.43, -0.19)
# iter=492; x=(0.80, 0.91); f(x)=1.05; grad f(x)=(-0.43, -0.19)
# iter=493; x=(0.80, 0.91); f(x)=1.05; grad f(x)=(-0.43, -0.19)
# iter=494; x=(0.80, 0.91); f(x)=1.05; grad f(x)=(-0.43, -0.19)
# iter=495; x=(0.80, 0.91); f(x)=1.05; grad f(x)=(-0.43, -0.19)
# iter=496; x=(0.81, 0.91); f(x)=1.05; grad f(x)=(-0.43, -0.19)
# iter=497; x=(0.81, 0.91); f(x)=1.05; grad f(x)=(-0.43, -0.19)
# iter=498; x=(0.81, 0.91); f(x)=1.05; grad f(x)=(-0.43, -0.18)
# iter=499; x=(0.81, 0.91); f(x)=1.05; grad f(x)=(-0.42, -0.18)
# iter=500; x=(0.81, 0.91); f(x)=1.05; grad f(x)=(-0.42, -0.18)
# iter=501; x=(0.81, 0.91); f(x)=1.05; grad f(x)=(-0.42, -0.18)
# iter=502; x=(0.81, 0.91); f(x)=1.05; grad f(x)=(-0.42, -0.18)
# iter=503; x=(0.81, 0.91); f(x)=1.05; grad f(x)=(-0.42, -0.18)
# iter=504; x=(0.81, 0.91); f(x)=1.05; grad f(x)=(-0.42, -0.18)
# iter=505; x=(0.81, 0.91); f(x)=1.05; grad f(x)=(-0.42, -0.18)
# iter=506; x=(0.81, 0.91); f(x)=1.05; grad f(x)=(-0.42, -0.18)
# iter=507; x=(0.81, 0.91); f(x)=1.05; grad f(x)=(-0.42, -0.18)
# iter=508; x=(0.81, 0.91); f(x)=1.05; grad f(x)=(-0.42, -0.18)
# iter=509; x=(0.81, 0.91); f(x)=1.05; grad f(x)=(-0.41, -0.18)
# iter=510; x=(0.81, 0.91); f(x)=1.05; grad f(x)=(-0.41, -0.18)
# iter=511; x=(0.81, 0.91); f(x)=1.05; grad f(x)=(-0.41, -0.18)
# iter=512; x=(0.81, 0.92); f(x)=1.05; grad f(x)=(-0.41, -0.18)
# iter=513; x=(0.81, 0.92); f(x)=1.05; grad f(x)=(-0.41, -0.18)
# iter=514; x=(0.81, 0.92); f(x)=1.05; grad f(x)=(-0.41, -0.18)
# iter=515; x=(0.81, 0.92); f(x)=1.05; grad f(x)=(-0.41, -0.18)
# iter=516; x=(0.81, 0.92); f(x)=1.05; grad f(x)=(-0.41, -0.18)
# iter=517; x=(0.81, 0.92); f(x)=1.05; grad f(x)=(-0.41, -0.18)
# iter=518; x=(0.81, 0.92); f(x)=1.05; grad f(x)=(-0.41, -0.18)
# iter=519; x=(0.81, 0.92); f(x)=1.05; grad f(x)=(-0.41, -0.18)
# iter=520; x=(0.82, 0.92); f(x)=1.05; grad f(x)=(-0.40, -0.18)
# iter=521; x=(0.82, 0.92); f(x)=1.05; grad f(x)=(-0.40, -0.18)
# iter=522; x=(0.82, 0.92); f(x)=1.05; grad f(x)=(-0.40, -0.18)
# iter=523; x=(0.82, 0.92); f(x)=1.05; grad f(x)=(-0.40, -0.18)
# iter=524; x=(0.82, 0.92); f(x)=1.05; grad f(x)=(-0.40, -0.18)
# iter=525; x=(0.82, 0.92); f(x)=1.05; grad f(x)=(-0.40, -0.18)
# iter=526; x=(0.82, 0.92); f(x)=1.04; grad f(x)=(-0.40, -0.18)
# iter=527; x=(0.82, 0.92); f(x)=1.04; grad f(x)=(-0.40, -0.18)
# iter=528; x=(0.82, 0.92); f(x)=1.04; grad f(x)=(-0.40, -0.18)
# iter=529; x=(0.82, 0.92); f(x)=1.04; grad f(x)=(-0.40, -0.18)
# iter=530; x=(0.82, 0.92); f(x)=1.04; grad f(x)=(-0.40, -0.18)
# iter=531; x=(0.82, 0.92); f(x)=1.04; grad f(x)=(-0.40, -0.18)
# iter=532; x=(0.82, 0.92); f(x)=1.04; grad f(x)=(-0.39, -0.18)
# iter=533; x=(0.82, 0.92); f(x)=1.04; grad f(x)=(-0.39, -0.18)
# iter=534; x=(0.82, 0.92); f(x)=1.04; grad f(x)=(-0.39, -0.18)
# iter=535; x=(0.82, 0.92); f(x)=1.04; grad f(x)=(-0.39, -0.18)
# iter=536; x=(0.82, 0.92); f(x)=1.04; grad f(x)=(-0.39, -0.18)
# iter=537; x=(0.82, 0.92); f(x)=1.04; grad f(x)=(-0.39, -0.18)
# iter=538; x=(0.82, 0.92); f(x)=1.04; grad f(x)=(-0.39, -0.18)
# iter=539; x=(0.82, 0.92); f(x)=1.04; grad f(x)=(-0.39, -0.18)
# iter=540; x=(0.82, 0.92); f(x)=1.04; grad f(x)=(-0.39, -0.18)
# iter=541; x=(0.82, 0.92); f(x)=1.04; grad f(x)=(-0.39, -0.18)
# iter=542; x=(0.82, 0.92); f(x)=1.04; grad f(x)=(-0.39, -0.18)
# iter=543; x=(0.82, 0.92); f(x)=1.04; grad f(x)=(-0.38, -0.18)
# iter=544; x=(0.82, 0.92); f(x)=1.04; grad f(x)=(-0.38, -0.18)
# iter=545; x=(0.83, 0.92); f(x)=1.04; grad f(x)=(-0.38, -0.18)
# iter=546; x=(0.83, 0.92); f(x)=1.04; grad f(x)=(-0.38, -0.18)
# iter=547; x=(0.83, 0.92); f(x)=1.04; grad f(x)=(-0.38, -0.17)
# iter=548; x=(0.83, 0.92); f(x)=1.04; grad f(x)=(-0.38, -0.17)
# iter=549; x=(0.83, 0.92); f(x)=1.04; grad f(x)=(-0.38, -0.17)
# iter=550; x=(0.83, 0.92); f(x)=1.04; grad f(x)=(-0.38, -0.17)
# iter=551; x=(0.83, 0.92); f(x)=1.04; grad f(x)=(-0.38, -0.17)
# iter=552; x=(0.83, 0.92); f(x)=1.04; grad f(x)=(-0.38, -0.17)
# iter=553; x=(0.83, 0.92); f(x)=1.04; grad f(x)=(-0.38, -0.17)
# iter=554; x=(0.83, 0.92); f(x)=1.04; grad f(x)=(-0.38, -0.17)
# iter=555; x=(0.83, 0.92); f(x)=1.04; grad f(x)=(-0.38, -0.17)
# iter=556; x=(0.83, 0.92); f(x)=1.04; grad f(x)=(-0.37, -0.17)
# iter=557; x=(0.83, 0.92); f(x)=1.04; grad f(x)=(-0.37, -0.17)
# iter=558; x=(0.83, 0.92); f(x)=1.04; grad f(x)=(-0.37, -0.17)
# iter=559; x=(0.83, 0.92); f(x)=1.04; grad f(x)=(-0.37, -0.17)
# iter=560; x=(0.83, 0.92); f(x)=1.04; grad f(x)=(-0.37, -0.17)
# iter=561; x=(0.83, 0.92); f(x)=1.04; grad f(x)=(-0.37, -0.17)
# iter=562; x=(0.83, 0.92); f(x)=1.04; grad f(x)=(-0.37, -0.17)
# iter=563; x=(0.83, 0.92); f(x)=1.04; grad f(x)=(-0.37, -0.17)
# iter=564; x=(0.83, 0.92); f(x)=1.04; grad f(x)=(-0.37, -0.17)
# iter=565; x=(0.83, 0.92); f(x)=1.04; grad f(x)=(-0.37, -0.17)
# iter=566; x=(0.83, 0.92); f(x)=1.04; grad f(x)=(-0.37, -0.17)
# iter=567; x=(0.83, 0.92); f(x)=1.04; grad f(x)=(-0.37, -0.17)
# iter=568; x=(0.83, 0.93); f(x)=1.04; grad f(x)=(-0.36, -0.17)
# iter=569; x=(0.83, 0.93); f(x)=1.04; grad f(x)=(-0.36, -0.17)
# iter=570; x=(0.83, 0.93); f(x)=1.04; grad f(x)=(-0.36, -0.17)
# iter=571; x=(0.83, 0.93); f(x)=1.04; grad f(x)=(-0.36, -0.17)
# iter=572; x=(0.84, 0.93); f(x)=1.04; grad f(x)=(-0.36, -0.17)
# iter=573; x=(0.84, 0.93); f(x)=1.04; grad f(x)=(-0.36, -0.17)
# iter=574; x=(0.84, 0.93); f(x)=1.04; grad f(x)=(-0.36, -0.17)
# iter=575; x=(0.84, 0.93); f(x)=1.04; grad f(x)=(-0.36, -0.17)
# iter=576; x=(0.84, 0.93); f(x)=1.04; grad f(x)=(-0.36, -0.17)
# iter=577; x=(0.84, 0.93); f(x)=1.04; grad f(x)=(-0.36, -0.17)
# iter=578; x=(0.84, 0.93); f(x)=1.04; grad f(x)=(-0.36, -0.17)
# iter=579; x=(0.84, 0.93); f(x)=1.04; grad f(x)=(-0.36, -0.17)
# iter=580; x=(0.84, 0.93); f(x)=1.04; grad f(x)=(-0.36, -0.17)
# iter=581; x=(0.84, 0.93); f(x)=1.04; grad f(x)=(-0.35, -0.17)
# iter=582; x=(0.84, 0.93); f(x)=1.04; grad f(x)=(-0.35, -0.17)
# iter=583; x=(0.84, 0.93); f(x)=1.04; grad f(x)=(-0.35, -0.16)
# iter=584; x=(0.84, 0.93); f(x)=1.03; grad f(x)=(-0.35, -0.16)
# iter=585; x=(0.84, 0.93); f(x)=1.03; grad f(x)=(-0.35, -0.16)
# iter=586; x=(0.84, 0.93); f(x)=1.03; grad f(x)=(-0.35, -0.16)
# iter=587; x=(0.84, 0.93); f(x)=1.03; grad f(x)=(-0.35, -0.16)
# iter=588; x=(0.84, 0.93); f(x)=1.03; grad f(x)=(-0.35, -0.16)
# iter=589; x=(0.84, 0.93); f(x)=1.03; grad f(x)=(-0.35, -0.16)
# iter=590; x=(0.84, 0.93); f(x)=1.03; grad f(x)=(-0.35, -0.16)
# iter=591; x=(0.84, 0.93); f(x)=1.03; grad f(x)=(-0.35, -0.16)
# iter=592; x=(0.84, 0.93); f(x)=1.03; grad f(x)=(-0.35, -0.16)
# iter=593; x=(0.84, 0.93); f(x)=1.03; grad f(x)=(-0.35, -0.16)
# iter=594; x=(0.84, 0.93); f(x)=1.03; grad f(x)=(-0.34, -0.16)
# iter=595; x=(0.84, 0.93); f(x)=1.03; grad f(x)=(-0.34, -0.16)
# iter=596; x=(0.84, 0.93); f(x)=1.03; grad f(x)=(-0.34, -0.16)
# iter=597; x=(0.84, 0.93); f(x)=1.03; grad f(x)=(-0.34, -0.16)
# iter=598; x=(0.84, 0.93); f(x)=1.03; grad f(x)=(-0.34, -0.16)
# iter=599; x=(0.84, 0.93); f(x)=1.03; grad f(x)=(-0.34, -0.16)
# iter=600; x=(0.85, 0.93); f(x)=1.03; grad f(x)=(-0.34, -0.16)
# iter=601; x=(0.85, 0.93); f(x)=1.03; grad f(x)=(-0.34, -0.16)
# iter=602; x=(0.85, 0.93); f(x)=1.03; grad f(x)=(-0.34, -0.16)
# iter=603; x=(0.85, 0.93); f(x)=1.03; grad f(x)=(-0.34, -0.16)
# iter=604; x=(0.85, 0.93); f(x)=1.03; grad f(x)=(-0.34, -0.16)
# iter=605; x=(0.85, 0.93); f(x)=1.03; grad f(x)=(-0.34, -0.16)
# iter=606; x=(0.85, 0.93); f(x)=1.03; grad f(x)=(-0.34, -0.16)
# iter=607; x=(0.85, 0.93); f(x)=1.03; grad f(x)=(-0.34, -0.16)
# iter=608; x=(0.85, 0.93); f(x)=1.03; grad f(x)=(-0.33, -0.16)
# iter=609; x=(0.85, 0.93); f(x)=1.03; grad f(x)=(-0.33, -0.16)
# iter=610; x=(0.85, 0.93); f(x)=1.03; grad f(x)=(-0.33, -0.16)
# iter=611; x=(0.85, 0.93); f(x)=1.03; grad f(x)=(-0.33, -0.16)
# iter=612; x=(0.85, 0.93); f(x)=1.03; grad f(x)=(-0.33, -0.16)
# iter=613; x=(0.85, 0.93); f(x)=1.03; grad f(x)=(-0.33, -0.16)
# iter=614; x=(0.85, 0.93); f(x)=1.03; grad f(x)=(-0.33, -0.16)
# iter=615; x=(0.85, 0.93); f(x)=1.03; grad f(x)=(-0.33, -0.16)
# iter=616; x=(0.85, 0.93); f(x)=1.03; grad f(x)=(-0.33, -0.16)
# iter=617; x=(0.85, 0.93); f(x)=1.03; grad f(x)=(-0.33, -0.15)
# iter=618; x=(0.85, 0.93); f(x)=1.03; grad f(x)=(-0.33, -0.15)
# iter=619; x=(0.85, 0.93); f(x)=1.03; grad f(x)=(-0.33, -0.15)
# iter=620; x=(0.85, 0.93); f(x)=1.03; grad f(x)=(-0.33, -0.15)
# iter=621; x=(0.85, 0.93); f(x)=1.03; grad f(x)=(-0.33, -0.15)
# iter=622; x=(0.85, 0.93); f(x)=1.03; grad f(x)=(-0.33, -0.15)
# iter=623; x=(0.85, 0.93); f(x)=1.03; grad f(x)=(-0.32, -0.15)
# iter=624; x=(0.85, 0.93); f(x)=1.03; grad f(x)=(-0.32, -0.15)
# iter=625; x=(0.85, 0.93); f(x)=1.03; grad f(x)=(-0.32, -0.15)
# iter=626; x=(0.85, 0.93); f(x)=1.03; grad f(x)=(-0.32, -0.15)
# iter=627; x=(0.85, 0.93); f(x)=1.03; grad f(x)=(-0.32, -0.15)
# iter=628; x=(0.85, 0.93); f(x)=1.03; grad f(x)=(-0.32, -0.15)
# iter=629; x=(0.85, 0.93); f(x)=1.03; grad f(x)=(-0.32, -0.15)
# iter=630; x=(0.86, 0.93); f(x)=1.03; grad f(x)=(-0.32, -0.15)
# iter=631; x=(0.86, 0.94); f(x)=1.03; grad f(x)=(-0.32, -0.15)
# iter=632; x=(0.86, 0.94); f(x)=1.03; grad f(x)=(-0.32, -0.15)
# iter=633; x=(0.86, 0.94); f(x)=1.03; grad f(x)=(-0.32, -0.15)
# iter=634; x=(0.86, 0.94); f(x)=1.03; grad f(x)=(-0.32, -0.15)
# iter=635; x=(0.86, 0.94); f(x)=1.03; grad f(x)=(-0.32, -0.15)
# iter=636; x=(0.86, 0.94); f(x)=1.03; grad f(x)=(-0.32, -0.15)
# iter=637; x=(0.86, 0.94); f(x)=1.03; grad f(x)=(-0.31, -0.15)
# iter=638; x=(0.86, 0.94); f(x)=1.03; grad f(x)=(-0.31, -0.15)
# iter=639; x=(0.86, 0.94); f(x)=1.03; grad f(x)=(-0.31, -0.15)
# iter=640; x=(0.86, 0.94); f(x)=1.03; grad f(x)=(-0.31, -0.15)
# iter=641; x=(0.86, 0.94); f(x)=1.03; grad f(x)=(-0.31, -0.15)
# iter=642; x=(0.86, 0.94); f(x)=1.03; grad f(x)=(-0.31, -0.15)
# iter=643; x=(0.86, 0.94); f(x)=1.03; grad f(x)=(-0.31, -0.15)
# iter=644; x=(0.86, 0.94); f(x)=1.03; grad f(x)=(-0.31, -0.15)
# iter=645; x=(0.86, 0.94); f(x)=1.03; grad f(x)=(-0.31, -0.15)
# iter=646; x=(0.86, 0.94); f(x)=1.03; grad f(x)=(-0.31, -0.15)
# iter=647; x=(0.86, 0.94); f(x)=1.03; grad f(x)=(-0.31, -0.15)
# iter=648; x=(0.86, 0.94); f(x)=1.03; grad f(x)=(-0.31, -0.15)
# iter=649; x=(0.86, 0.94); f(x)=1.03; grad f(x)=(-0.31, -0.15)
# iter=650; x=(0.86, 0.94); f(x)=1.03; grad f(x)=(-0.31, -0.14)
# iter=651; x=(0.86, 0.94); f(x)=1.03; grad f(x)=(-0.31, -0.14)
# iter=652; x=(0.86, 0.94); f(x)=1.03; grad f(x)=(-0.31, -0.14)
# iter=653; x=(0.86, 0.94); f(x)=1.03; grad f(x)=(-0.30, -0.14)
# iter=654; x=(0.86, 0.94); f(x)=1.03; grad f(x)=(-0.30, -0.14)
# iter=655; x=(0.86, 0.94); f(x)=1.03; grad f(x)=(-0.30, -0.14)
# iter=656; x=(0.86, 0.94); f(x)=1.03; grad f(x)=(-0.30, -0.14)
# iter=657; x=(0.86, 0.94); f(x)=1.03; grad f(x)=(-0.30, -0.14)
# iter=658; x=(0.86, 0.94); f(x)=1.03; grad f(x)=(-0.30, -0.14)
# iter=659; x=(0.86, 0.94); f(x)=1.03; grad f(x)=(-0.30, -0.14)
# iter=660; x=(0.86, 0.94); f(x)=1.03; grad f(x)=(-0.30, -0.14)
# iter=661; x=(0.86, 0.94); f(x)=1.02; grad f(x)=(-0.30, -0.14)
# iter=662; x=(0.86, 0.94); f(x)=1.02; grad f(x)=(-0.30, -0.14)
# iter=663; x=(0.87, 0.94); f(x)=1.02; grad f(x)=(-0.30, -0.14)
# iter=664; x=(0.87, 0.94); f(x)=1.02; grad f(x)=(-0.30, -0.14)
# iter=665; x=(0.87, 0.94); f(x)=1.02; grad f(x)=(-0.30, -0.14)
# iter=666; x=(0.87, 0.94); f(x)=1.02; grad f(x)=(-0.30, -0.14)
# iter=667; x=(0.87, 0.94); f(x)=1.02; grad f(x)=(-0.30, -0.14)
# iter=668; x=(0.87, 0.94); f(x)=1.02; grad f(x)=(-0.29, -0.14)
# iter=669; x=(0.87, 0.94); f(x)=1.02; grad f(x)=(-0.29, -0.14)
# iter=670; x=(0.87, 0.94); f(x)=1.02; grad f(x)=(-0.29, -0.14)
# iter=671; x=(0.87, 0.94); f(x)=1.02; grad f(x)=(-0.29, -0.14)
# iter=672; x=(0.87, 0.94); f(x)=1.02; grad f(x)=(-0.29, -0.14)
# iter=673; x=(0.87, 0.94); f(x)=1.02; grad f(x)=(-0.29, -0.14)
# iter=674; x=(0.87, 0.94); f(x)=1.02; grad f(x)=(-0.29, -0.14)
# iter=675; x=(0.87, 0.94); f(x)=1.02; grad f(x)=(-0.29, -0.14)
# iter=676; x=(0.87, 0.94); f(x)=1.02; grad f(x)=(-0.29, -0.14)
# iter=677; x=(0.87, 0.94); f(x)=1.02; grad f(x)=(-0.29, -0.14)
# iter=678; x=(0.87, 0.94); f(x)=1.02; grad f(x)=(-0.29, -0.14)
# iter=679; x=(0.87, 0.94); f(x)=1.02; grad f(x)=(-0.29, -0.14)
# iter=680; x=(0.87, 0.94); f(x)=1.02; grad f(x)=(-0.29, -0.14)
# iter=681; x=(0.87, 0.94); f(x)=1.02; grad f(x)=(-0.29, -0.14)
# iter=682; x=(0.87, 0.94); f(x)=1.02; grad f(x)=(-0.29, -0.14)
# iter=683; x=(0.87, 0.94); f(x)=1.02; grad f(x)=(-0.29, -0.13)
# iter=684; x=(0.87, 0.94); f(x)=1.02; grad f(x)=(-0.29, -0.13)
# iter=685; x=(0.87, 0.94); f(x)=1.02; grad f(x)=(-0.28, -0.13)
# iter=686; x=(0.87, 0.94); f(x)=1.02; grad f(x)=(-0.28, -0.13)
# iter=687; x=(0.87, 0.94); f(x)=1.02; grad f(x)=(-0.28, -0.13)
# iter=688; x=(0.87, 0.94); f(x)=1.02; grad f(x)=(-0.28, -0.13)
# iter=689; x=(0.87, 0.94); f(x)=1.02; grad f(x)=(-0.28, -0.13)
# iter=690; x=(0.87, 0.94); f(x)=1.02; grad f(x)=(-0.28, -0.13)
# iter=691; x=(0.87, 0.94); f(x)=1.02; grad f(x)=(-0.28, -0.13)
# iter=692; x=(0.87, 0.94); f(x)=1.02; grad f(x)=(-0.28, -0.13)
# iter=693; x=(0.87, 0.94); f(x)=1.02; grad f(x)=(-0.28, -0.13)
# iter=694; x=(0.87, 0.94); f(x)=1.02; grad f(x)=(-0.28, -0.13)
# iter=695; x=(0.87, 0.94); f(x)=1.02; grad f(x)=(-0.28, -0.13)
# iter=696; x=(0.87, 0.94); f(x)=1.02; grad f(x)=(-0.28, -0.13)
# iter=697; x=(0.88, 0.94); f(x)=1.02; grad f(x)=(-0.28, -0.13)
# iter=698; x=(0.88, 0.94); f(x)=1.02; grad f(x)=(-0.28, -0.13)
# iter=699; x=(0.88, 0.94); f(x)=1.02; grad f(x)=(-0.28, -0.13)
# iter=700; x=(0.88, 0.94); f(x)=1.02; grad f(x)=(-0.28, -0.13)
# iter=701; x=(0.88, 0.94); f(x)=1.02; grad f(x)=(-0.28, -0.13)
# iter=702; x=(0.88, 0.95); f(x)=1.02; grad f(x)=(-0.27, -0.13)
# iter=703; x=(0.88, 0.95); f(x)=1.02; grad f(x)=(-0.27, -0.13)
# iter=704; x=(0.88, 0.95); f(x)=1.02; grad f(x)=(-0.27, -0.13)
# iter=705; x=(0.88, 0.95); f(x)=1.02; grad f(x)=(-0.27, -0.13)
# iter=706; x=(0.88, 0.95); f(x)=1.02; grad f(x)=(-0.27, -0.13)
# iter=707; x=(0.88, 0.95); f(x)=1.02; grad f(x)=(-0.27, -0.13)
# iter=708; x=(0.88, 0.95); f(x)=1.02; grad f(x)=(-0.27, -0.13)
# iter=709; x=(0.88, 0.95); f(x)=1.02; grad f(x)=(-0.27, -0.13)
# iter=710; x=(0.88, 0.95); f(x)=1.02; grad f(x)=(-0.27, -0.13)
# iter=711; x=(0.88, 0.95); f(x)=1.02; grad f(x)=(-0.27, -0.13)
# iter=712; x=(0.88, 0.95); f(x)=1.02; grad f(x)=(-0.27, -0.13)
# iter=713; x=(0.88, 0.95); f(x)=1.02; grad f(x)=(-0.27, -0.13)
# iter=714; x=(0.88, 0.95); f(x)=1.02; grad f(x)=(-0.27, -0.13)
# iter=715; x=(0.88, 0.95); f(x)=1.02; grad f(x)=(-0.27, -0.13)
# iter=716; x=(0.88, 0.95); f(x)=1.02; grad f(x)=(-0.27, -0.13)
# iter=717; x=(0.88, 0.95); f(x)=1.02; grad f(x)=(-0.27, -0.13)
# iter=718; x=(0.88, 0.95); f(x)=1.02; grad f(x)=(-0.27, -0.12)
# iter=719; x=(0.88, 0.95); f(x)=1.02; grad f(x)=(-0.26, -0.12)
# iter=720; x=(0.88, 0.95); f(x)=1.02; grad f(x)=(-0.26, -0.12)
# iter=721; x=(0.88, 0.95); f(x)=1.02; grad f(x)=(-0.26, -0.12)
# iter=722; x=(0.88, 0.95); f(x)=1.02; grad f(x)=(-0.26, -0.12)
# iter=723; x=(0.88, 0.95); f(x)=1.02; grad f(x)=(-0.26, -0.12)
# iter=724; x=(0.88, 0.95); f(x)=1.02; grad f(x)=(-0.26, -0.12)
# iter=725; x=(0.88, 0.95); f(x)=1.02; grad f(x)=(-0.26, -0.12)
# iter=726; x=(0.88, 0.95); f(x)=1.02; grad f(x)=(-0.26, -0.12)
# iter=727; x=(0.88, 0.95); f(x)=1.02; grad f(x)=(-0.26, -0.12)
# iter=728; x=(0.88, 0.95); f(x)=1.02; grad f(x)=(-0.26, -0.12)
# iter=729; x=(0.88, 0.95); f(x)=1.02; grad f(x)=(-0.26, -0.12)
# iter=730; x=(0.88, 0.95); f(x)=1.02; grad f(x)=(-0.26, -0.12)
# iter=731; x=(0.88, 0.95); f(x)=1.02; grad f(x)=(-0.26, -0.12)
# iter=732; x=(0.88, 0.95); f(x)=1.02; grad f(x)=(-0.26, -0.12)
# iter=733; x=(0.88, 0.95); f(x)=1.02; grad f(x)=(-0.26, -0.12)
# iter=734; x=(0.88, 0.95); f(x)=1.02; grad f(x)=(-0.26, -0.12)
# iter=735; x=(0.89, 0.95); f(x)=1.02; grad f(x)=(-0.26, -0.12)
# iter=736; x=(0.89, 0.95); f(x)=1.02; grad f(x)=(-0.26, -0.12)
# iter=737; x=(0.89, 0.95); f(x)=1.02; grad f(x)=(-0.25, -0.12)
# iter=738; x=(0.89, 0.95); f(x)=1.02; grad f(x)=(-0.25, -0.12)
# iter=739; x=(0.89, 0.95); f(x)=1.02; grad f(x)=(-0.25, -0.12)
# iter=740; x=(0.89, 0.95); f(x)=1.02; grad f(x)=(-0.25, -0.12)
# iter=741; x=(0.89, 0.95); f(x)=1.02; grad f(x)=(-0.25, -0.12)
# iter=742; x=(0.89, 0.95); f(x)=1.02; grad f(x)=(-0.25, -0.12)
# iter=743; x=(0.89, 0.95); f(x)=1.02; grad f(x)=(-0.25, -0.12)
# iter=744; x=(0.89, 0.95); f(x)=1.02; grad f(x)=(-0.25, -0.12)
# iter=745; x=(0.89, 0.95); f(x)=1.02; grad f(x)=(-0.25, -0.12)
# iter=746; x=(0.89, 0.95); f(x)=1.02; grad f(x)=(-0.25, -0.12)
# iter=747; x=(0.89, 0.95); f(x)=1.02; grad f(x)=(-0.25, -0.12)
# iter=748; x=(0.89, 0.95); f(x)=1.02; grad f(x)=(-0.25, -0.12)
# iter=749; x=(0.89, 0.95); f(x)=1.02; grad f(x)=(-0.25, -0.12)
# iter=750; x=(0.89, 0.95); f(x)=1.02; grad f(x)=(-0.25, -0.12)
# iter=751; x=(0.89, 0.95); f(x)=1.02; grad f(x)=(-0.25, -0.12)
# iter=752; x=(0.89, 0.95); f(x)=1.02; grad f(x)=(-0.25, -0.12)
# iter=753; x=(0.89, 0.95); f(x)=1.02; grad f(x)=(-0.25, -0.12)
# iter=754; x=(0.89, 0.95); f(x)=1.02; grad f(x)=(-0.25, -0.11)
# iter=755; x=(0.89, 0.95); f(x)=1.02; grad f(x)=(-0.25, -0.11)
# iter=756; x=(0.89, 0.95); f(x)=1.02; grad f(x)=(-0.24, -0.11)
# iter=757; x=(0.89, 0.95); f(x)=1.02; grad f(x)=(-0.24, -0.11)
# iter=758; x=(0.89, 0.95); f(x)=1.02; grad f(x)=(-0.24, -0.11)
# iter=759; x=(0.89, 0.95); f(x)=1.02; grad f(x)=(-0.24, -0.11)
# iter=760; x=(0.89, 0.95); f(x)=1.02; grad f(x)=(-0.24, -0.11)
# iter=761; x=(0.89, 0.95); f(x)=1.02; grad f(x)=(-0.24, -0.11)
# iter=762; x=(0.89, 0.95); f(x)=1.02; grad f(x)=(-0.24, -0.11)
# iter=763; x=(0.89, 0.95); f(x)=1.02; grad f(x)=(-0.24, -0.11)
# iter=764; x=(0.89, 0.95); f(x)=1.02; grad f(x)=(-0.24, -0.11)
# iter=765; x=(0.89, 0.95); f(x)=1.02; grad f(x)=(-0.24, -0.11)
# iter=766; x=(0.89, 0.95); f(x)=1.02; grad f(x)=(-0.24, -0.11)
# iter=767; x=(0.89, 0.95); f(x)=1.02; grad f(x)=(-0.24, -0.11)
# iter=768; x=(0.89, 0.95); f(x)=1.02; grad f(x)=(-0.24, -0.11)
# iter=769; x=(0.89, 0.95); f(x)=1.02; grad f(x)=(-0.24, -0.11)
# iter=770; x=(0.89, 0.95); f(x)=1.02; grad f(x)=(-0.24, -0.11)
# iter=771; x=(0.89, 0.95); f(x)=1.02; grad f(x)=(-0.24, -0.11)
# iter=772; x=(0.89, 0.95); f(x)=1.02; grad f(x)=(-0.24, -0.11)
# iter=773; x=(0.89, 0.95); f(x)=1.02; grad f(x)=(-0.24, -0.11)
# iter=774; x=(0.89, 0.95); f(x)=1.02; grad f(x)=(-0.24, -0.11)
# iter=775; x=(0.90, 0.95); f(x)=1.02; grad f(x)=(-0.24, -0.11)
# iter=776; x=(0.90, 0.95); f(x)=1.01; grad f(x)=(-0.23, -0.11)
# iter=777; x=(0.90, 0.95); f(x)=1.01; grad f(x)=(-0.23, -0.11)
# iter=778; x=(0.90, 0.95); f(x)=1.01; grad f(x)=(-0.23, -0.11)
# iter=779; x=(0.90, 0.95); f(x)=1.01; grad f(x)=(-0.23, -0.11)
# ...
# iter=1447; x=(0.98, 0.99); f(x)=1.00; grad f(x)=(-0.05, -0.02)
# iter=1448; x=(0.98, 0.99); f(x)=1.00; grad f(x)=(-0.05, -0.02)
# iter=1449; x=(0.98, 0.99); f(x)=1.00; grad f(x)=(-0.05, -0.02)
# iter=1450; x=(0.98, 0.99); f(x)=1.00; grad f(x)=(-0.05, -0.02)
# iter=1451; x=(0.98, 0.99); f(x)=1.00; grad f(x)=(-0.05, -0.02)
# iter=1452; x=(0.98, 0.99); f(x)=1.00; grad f(x)=(-0.05, -0.02)
# iter=1453; x=(0.98, 0.99); f(x)=1.00; grad f(x)=(-0.05, -0.02)
# iter=1454; x=(0.98, 0.99); f(x)=1.00; grad f(x)=(-0.05, -0.02)
# iter=1455; x=(0.98, 0.99); f(x)=1.00; grad f(x)=(-0.05, -0.02)
# iter=1456; x=(0.98, 0.99); f(x)=1.00; grad f(x)=(-0.05, -0.02)
# iter=1457; x=(0.98, 0.99); f(x)=1.00; grad f(x)=(-0.05, -0.02)
# iter=1458; x=(0.98, 0.99); f(x)=1.00; grad f(x)=(-0.05, -0.02)
# iter=1459; x=(0.98, 0.99); f(x)=1.00; grad f(x)=(-0.05, -0.02)
# iter=1460; x=(0.98, 0.99); f(x)=1.00; grad f(x)=(-0.05, -0.02)
# iter=1461; x=(0.98, 0.99); f(x)=1.00; grad f(x)=(-0.05, -0.02)
# iter=1462; x=(0.98, 0.99); f(x)=1.00; grad f(x)=(-0.05, -0.02)
# iter=1463; x=(0.98, 0.99); f(x)=1.00; grad f(x)=(-0.05, -0.02)
# iter=1464; x=(0.98, 0.99); f(x)=1.00; grad f(x)=(-0.05, -0.02)
# iter=1465; x=(0.98, 0.99); f(x)=1.00; grad f(x)=(-0.05, -0.02)
# iter=1466; x=(0.98, 0.99); f(x)=1.00; grad f(x)=(-0.05, -0.02)
# iter=1467; x=(0.98, 0.99); f(x)=1.00; grad f(x)=(-0.05, -0.02)
# iter=1468; x=(0.98, 0.99); f(x)=1.00; grad f(x)=(-0.05, -0.02)
# iter=1469; x=(0.98, 0.99); f(x)=1.00; grad f(x)=(-0.05, -0.02)
# iter=1470; x=(0.98, 0.99); f(x)=1.00; grad f(x)=(-0.05, -0.02)
# iter=1471; x=(0.98, 0.99); f(x)=1.00; grad f(x)=(-0.05, -0.02)
# iter=1472; x=(0.98, 0.99); f(x)=1.00; grad f(x)=(-0.05, -0.02)
# iter=1473; x=(0.98, 0.99); f(x)=1.00; grad f(x)=(-0.05, -0.02)
# iter=1474; x=(0.98, 0.99); f(x)=1.00; grad f(x)=(-0.05, -0.02)
# iter=1475; x=(0.98, 0.99); f(x)=1.00; grad f(x)=(-0.05, -0.02)
# iter=1476; x=(0.98, 0.99); f(x)=1.00; grad f(x)=(-0.05, -0.02)
# iter=1477; x=(0.98, 0.99); f(x)=1.00; grad f(x)=(-0.05, -0.02)
# iter=1478; x=(0.98, 0.99); f(x)=1.00; grad f(x)=(-0.05, -0.02)
# iter=1479; x=(0.98, 0.99); f(x)=1.00; grad f(x)=(-0.05, -0.02)
# iter=1480; x=(0.98, 0.99); f(x)=1.00; grad f(x)=(-0.05, -0.02)
# iter=1481; x=(0.98, 0.99); f(x)=1.00; grad f(x)=(-0.05, -0.02)
# iter=1482; x=(0.98, 0.99); f(x)=1.00; grad f(x)=(-0.05, -0.02)
# iter=1483; x=(0.98, 0.99); f(x)=1.00; grad f(x)=(-0.05, -0.02)
# iter=1484; x=(0.98, 0.99); f(x)=1.00; grad f(x)=(-0.05, -0.02)
# iter=1485; x=(0.98, 0.99); f(x)=1.00; grad f(x)=(-0.05, -0.02)
# iter=1486; x=(0.98, 0.99); f(x)=1.00; grad f(x)=(-0.05, -0.02)
# iter=1487; x=(0.98, 0.99); f(x)=1.00; grad f(x)=(-0.05, -0.02)
# iter=1488; x=(0.98, 0.99); f(x)=1.00; grad f(x)=(-0.05, -0.02)
# iter=1489; x=(0.98, 0.99); f(x)=1.00; grad f(x)=(-0.05, -0.02)
# iter=1490; x=(0.98, 0.99); f(x)=1.00; grad f(x)=(-0.05, -0.02)
# iter=1491; x=(0.98, 0.99); f(x)=1.00; grad f(x)=(-0.05, -0.02)
# iter=1492; x=(0.98, 0.99); f(x)=1.00; grad f(x)=(-0.05, -0.02)
# iter=1493; x=(0.98, 0.99); f(x)=1.00; grad f(x)=(-0.05, -0.02)
# iter=1494; x=(0.98, 0.99); f(x)=1.00; grad f(x)=(-0.05, -0.02)
# iter=1495; x=(0.98, 0.99); f(x)=1.00; grad f(x)=(-0.05, -0.02)
# iter=1496; x=(0.98, 0.99); f(x)=1.00; grad f(x)=(-0.05, -0.02)
# iter=1497; x=(0.98, 0.99); f(x)=1.00; grad f(x)=(-0.05, -0.02)
# iter=1498; x=(0.98, 0.99); f(x)=1.00; grad f(x)=(-0.05, -0.02)
# iter=1499; x=(0.98, 0.99); f(x)=1.00; grad f(x)=(-0.05, -0.02)
# iter=1500; x=(0.98, 0.99); f(x)=1.00; grad f(x)=(-0.05, -0.02)
# iter=1501; x=(0.98, 0.99); f(x)=1.00; grad f(x)=(-0.05, -0.02)
# iter=1502; x=(0.98, 0.99); f(x)=1.00; grad f(x)=(-0.05, -0.02)
# iter=1503; x=(0.98, 0.99); f(x)=1.00; grad f(x)=(-0.05, -0.02)
# iter=1504; x=(0.98, 0.99); f(x)=1.00; grad f(x)=(-0.05, -0.02)
# iter=1505; x=(0.98, 0.99); f(x)=1.00; grad f(x)=(-0.05, -0.02)
# iter=1506; x=(0.98, 0.99); f(x)=1.00; grad f(x)=(-0.05, -0.02)
# iter=1507; x=(0.98, 0.99); f(x)=1.00; grad f(x)=(-0.05, -0.02)
# iter=1508; x=(0.98, 0.99); f(x)=1.00; grad f(x)=(-0.05, -0.02)
# iter=1509; x=(0.98, 0.99); f(x)=1.00; grad f(x)=(-0.05, -0.02)
# iter=1510; x=(0.98, 0.99); f(x)=1.00; grad f(x)=(-0.05, -0.02)
# iter=1511; x=(0.98, 0.99); f(x)=1.00; grad f(x)=(-0.05, -0.02)
# iter=1512; x=(0.98, 0.99); f(x)=1.00; grad f(x)=(-0.04, -0.02)
# iter=1513; x=(0.98, 0.99); f(x)=1.00; grad f(x)=(-0.04, -0.02)
# iter=1514; x=(0.98, 0.99); f(x)=1.00; grad f(x)=(-0.04, -0.02)
# iter=1515; x=(0.98, 0.99); f(x)=1.00; grad f(x)=(-0.04, -0.02)
# iter=1516; x=(0.98, 0.99); f(x)=1.00; grad f(x)=(-0.04, -0.02)
# iter=1517; x=(0.98, 0.99); f(x)=1.00; grad f(x)=(-0.04, -0.02)
# iter=1518; x=(0.98, 0.99); f(x)=1.00; grad f(x)=(-0.04, -0.02)
# iter=1519; x=(0.98, 0.99); f(x)=1.00; grad f(x)=(-0.04, -0.02)
# iter=1520; x=(0.98, 0.99); f(x)=1.00; grad f(x)=(-0.04, -0.02)
# iter=1521; x=(0.98, 0.99); f(x)=1.00; grad f(x)=(-0.04, -0.02)
# iter=1522; x=(0.98, 0.99); f(x)=1.00; grad f(x)=(-0.04, -0.02)
# iter=1523; x=(0.98, 0.99); f(x)=1.00; grad f(x)=(-0.04, -0.02)
# iter=1524; x=(0.98, 0.99); f(x)=1.00; grad f(x)=(-0.04, -0.02)
# iter=1525; x=(0.98, 0.99); f(x)=1.00; grad f(x)=(-0.04, -0.02)
# iter=1526; x=(0.98, 0.99); f(x)=1.00; grad f(x)=(-0.04, -0.02)
# iter=1527; x=(0.98, 0.99); f(x)=1.00; grad f(x)=(-0.04, -0.02)
# iter=1528; x=(0.98, 0.99); f(x)=1.00; grad f(x)=(-0.04, -0.02)
# iter=1529; x=(0.98, 0.99); f(x)=1.00; grad f(x)=(-0.04, -0.02)
# iter=1530; x=(0.98, 0.99); f(x)=1.00; grad f(x)=(-0.04, -0.02)
# iter=1531; x=(0.98, 0.99); f(x)=1.00; grad f(x)=(-0.04, -0.02)
# iter=1532; x=(0.98, 0.99); f(x)=1.00; grad f(x)=(-0.04, -0.02)
# iter=1533; x=(0.98, 0.99); f(x)=1.00; grad f(x)=(-0.04, -0.02)
# iter=1534; x=(0.98, 0.99); f(x)=1.00; grad f(x)=(-0.04, -0.02)
# iter=1535; x=(0.98, 0.99); f(x)=1.00; grad f(x)=(-0.04, -0.02)
# iter=1536; x=(0.98, 0.99); f(x)=1.00; grad f(x)=(-0.04, -0.02)
# iter=1537; x=(0.98, 0.99); f(x)=1.00; grad f(x)=(-0.04, -0.02)
# iter=1538; x=(0.98, 0.99); f(x)=1.00; grad f(x)=(-0.04, -0.02)
# iter=1539; x=(0.98, 0.99); f(x)=1.00; grad f(x)=(-0.04, -0.02)
# iter=1540; x=(0.98, 0.99); f(x)=1.00; grad f(x)=(-0.04, -0.02)
# iter=1541; x=(0.98, 0.99); f(x)=1.00; grad f(x)=(-0.04, -0.02)
# iter=1542; x=(0.98, 0.99); f(x)=1.00; grad f(x)=(-0.04, -0.02)
# iter=1543; x=(0.98, 0.99); f(x)=1.00; grad f(x)=(-0.04, -0.02)
# iter=1544; x=(0.98, 0.99); f(x)=1.00; grad f(x)=(-0.04, -0.02)
# iter=1545; x=(0.98, 0.99); f(x)=1.00; grad f(x)=(-0.04, -0.02)
# iter=1546; x=(0.98, 0.99); f(x)=1.00; grad f(x)=(-0.04, -0.02)
# iter=1547; x=(0.98, 0.99); f(x)=1.00; grad f(x)=(-0.04, -0.02)
# iter=1548; x=(0.98, 0.99); f(x)=1.00; grad f(x)=(-0.04, -0.02)
# iter=1549; x=(0.98, 0.99); f(x)=1.00; grad f(x)=(-0.04, -0.02)
# iter=1550; x=(0.98, 0.99); f(x)=1.00; grad f(x)=(-0.04, -0.02)
# iter=1551; x=(0.98, 0.99); f(x)=1.00; grad f(x)=(-0.04, -0.02)
# iter=1552; x=(0.98, 0.99); f(x)=1.00; grad f(x)=(-0.04, -0.02)
# iter=1553; x=(0.98, 0.99); f(x)=1.00; grad f(x)=(-0.04, -0.02)
# iter=1554; x=(0.98, 0.99); f(x)=1.00; grad f(x)=(-0.04, -0.02)
# iter=1555; x=(0.98, 0.99); f(x)=1.00; grad f(x)=(-0.04, -0.02)
# iter=1556; x=(0.98, 0.99); f(x)=1.00; grad f(x)=(-0.04, -0.02)
# iter=1557; x=(0.98, 0.99); f(x)=1.00; grad f(x)=(-0.04, -0.02)
# iter=1558; x=(0.98, 0.99); f(x)=1.00; grad f(x)=(-0.04, -0.02)
# iter=1559; x=(0.98, 0.99); f(x)=1.00; grad f(x)=(-0.04, -0.02)
# iter=1560; x=(0.98, 0.99); f(x)=1.00; grad f(x)=(-0.04, -0.02)
# iter=1561; x=(0.98, 0.99); f(x)=1.00; grad f(x)=(-0.04, -0.02)
# iter=1562; x=(0.98, 0.99); f(x)=1.00; grad f(x)=(-0.04, -0.02)
# iter=1563; x=(0.98, 0.99); f(x)=1.00; grad f(x)=(-0.04, -0.02)
# iter=1564; x=(0.98, 0.99); f(x)=1.00; grad f(x)=(-0.04, -0.02)
# iter=1565; x=(0.98, 0.99); f(x)=1.00; grad f(x)=(-0.04, -0.02)
# iter=1566; x=(0.98, 0.99); f(x)=1.00; grad f(x)=(-0.04, -0.02)
# iter=1567; x=(0.98, 0.99); f(x)=1.00; grad f(x)=(-0.04, -0.02)
# iter=1568; x=(0.98, 0.99); f(x)=1.00; grad f(x)=(-0.04, -0.02)
# iter=1569; x=(0.98, 0.99); f(x)=1.00; grad f(x)=(-0.04, -0.02)
# iter=1570; x=(0.98, 0.99); f(x)=1.00; grad f(x)=(-0.04, -0.02)
# iter=1571; x=(0.98, 0.99); f(x)=1.00; grad f(x)=(-0.04, -0.02)
# iter=1572; x=(0.98, 0.99); f(x)=1.00; grad f(x)=(-0.04, -0.02)
# iter=1573; x=(0.98, 0.99); f(x)=1.00; grad f(x)=(-0.04, -0.02)
# iter=1574; x=(0.98, 0.99); f(x)=1.00; grad f(x)=(-0.04, -0.02)
# iter=1575; x=(0.98, 0.99); f(x)=1.00; grad f(x)=(-0.04, -0.02)
# iter=1576; x=(0.98, 0.99); f(x)=1.00; grad f(x)=(-0.04, -0.02)
# iter=1577; x=(0.98, 0.99); f(x)=1.00; grad f(x)=(-0.04, -0.02)
# iter=1578; x=(0.98, 0.99); f(x)=1.00; grad f(x)=(-0.04, -0.02)
# iter=1579; x=(0.98, 0.99); f(x)=1.00; grad f(x)=(-0.04, -0.02)
# iter=1580; x=(0.98, 0.99); f(x)=1.00; grad f(x)=(-0.04, -0.02)
# iter=1581; x=(0.98, 0.99); f(x)=1.00; grad f(x)=(-0.04, -0.02)
# iter=1582; x=(0.98, 0.99); f(x)=1.00; grad f(x)=(-0.04, -0.02)
# iter=1583; x=(0.98, 0.99); f(x)=1.00; grad f(x)=(-0.04, -0.02)
# iter=1584; x=(0.98, 0.99); f(x)=1.00; grad f(x)=(-0.04, -0.02)
# iter=1585; x=(0.98, 0.99); f(x)=1.00; grad f(x)=(-0.04, -0.02)
# iter=1586; x=(0.98, 0.99); f(x)=1.00; grad f(x)=(-0.04, -0.02)
# iter=1587; x=(0.98, 0.99); f(x)=1.00; grad f(x)=(-0.04, -0.02)
# iter=1588; x=(0.98, 0.99); f(x)=1.00; grad f(x)=(-0.04, -0.02)
# iter=1589; x=(0.98, 0.99); f(x)=1.00; grad f(x)=(-0.04, -0.02)
# iter=1590; x=(0.98, 0.99); f(x)=1.00; grad f(x)=(-0.04, -0.02)
# iter=1591; x=(0.98, 0.99); f(x)=1.00; grad f(x)=(-0.04, -0.02)
# iter=1592; x=(0.98, 0.99); f(x)=1.00; grad f(x)=(-0.04, -0.02)
# iter=1593; x=(0.98, 0.99); f(x)=1.00; grad f(x)=(-0.04, -0.02)
# iter=1594; x=(0.98, 0.99); f(x)=1.00; grad f(x)=(-0.04, -0.02)
# iter=1595; x=(0.98, 0.99); f(x)=1.00; grad f(x)=(-0.04, -0.02)
# iter=1596; x=(0.98, 0.99); f(x)=1.00; grad f(x)=(-0.04, -0.02)
# iter=1597; x=(0.98, 0.99); f(x)=1.00; grad f(x)=(-0.04, -0.02)
# iter=1598; x=(0.98, 0.99); f(x)=1.00; grad f(x)=(-0.04, -0.02)
# iter=1599; x=(0.98, 0.99); f(x)=1.00; grad f(x)=(-0.04, -0.02)
# iter=1600; x=(0.98, 0.99); f(x)=1.00; grad f(x)=(-0.04, -0.02)
# iter=1601; x=(0.98, 0.99); f(x)=1.00; grad f(x)=(-0.04, -0.02)
# iter=1602; x=(0.98, 0.99); f(x)=1.00; grad f(x)=(-0.04, -0.02)
# iter=1603; x=(0.98, 0.99); f(x)=1.00; grad f(x)=(-0.04, -0.02)
# iter=1604; x=(0.98, 0.99); f(x)=1.00; grad f(x)=(-0.04, -0.02)
# iter=1605; x=(0.98, 0.99); f(x)=1.00; grad f(x)=(-0.04, -0.02)
# iter=1606; x=(0.98, 0.99); f(x)=1.00; grad f(x)=(-0.04, -0.02)
# iter=1607; x=(0.98, 0.99); f(x)=1.00; grad f(x)=(-0.04, -0.02)
# iter=1608; x=(0.98, 0.99); f(x)=1.00; grad f(x)=(-0.04, -0.02)
# iter=1609; x=(0.98, 0.99); f(x)=1.00; grad f(x)=(-0.04, -0.02)
# iter=1610; x=(0.98, 0.99); f(x)=1.00; grad f(x)=(-0.04, -0.02)
# iter=1611; x=(0.98, 0.99); f(x)=1.00; grad f(x)=(-0.04, -0.02)
# iter=1612; x=(0.98, 0.99); f(x)=1.00; grad f(x)=(-0.04, -0.02)
# iter=1613; x=(0.98, 0.99); f(x)=1.00; grad f(x)=(-0.04, -0.01)
# iter=1614; x=(0.98, 0.99); f(x)=1.00; grad f(x)=(-0.04, -0.01)
# iter=1615; x=(0.98, 0.99); f(x)=1.00; grad f(x)=(-0.04, -0.01)
# iter=1616; x=(0.98, 0.99); f(x)=1.00; grad f(x)=(-0.04, -0.01)
# iter=1617; x=(0.98, 0.99); f(x)=1.00; grad f(x)=(-0.04, -0.01)
# iter=1618; x=(0.98, 0.99); f(x)=1.00; grad f(x)=(-0.04, -0.01)
# iter=1619; x=(0.98, 0.99); f(x)=1.00; grad f(x)=(-0.04, -0.01)
# iter=1620; x=(0.98, 0.99); f(x)=1.00; grad f(x)=(-0.03, -0.01)
# iter=1621; x=(0.99, 0.99); f(x)=1.00; grad f(x)=(-0.03, -0.01)
# iter=1622; x=(0.99, 0.99); f(x)=1.00; grad f(x)=(-0.03, -0.01)
# iter=1623; x=(0.99, 0.99); f(x)=1.00; grad f(x)=(-0.03, -0.01)
# iter=1624; x=(0.99, 0.99); f(x)=1.00; grad f(x)=(-0.03, -0.01)
# iter=1625; x=(0.99, 0.99); f(x)=1.00; grad f(x)=(-0.03, -0.01)
# iter=1626; x=(0.99, 0.99); f(x)=1.00; grad f(x)=(-0.03, -0.01)
# iter=1627; x=(0.99, 0.99); f(x)=1.00; grad f(x)=(-0.03, -0.01)
# iter=1628; x=(0.99, 0.99); f(x)=1.00; grad f(x)=(-0.03, -0.01)
# iter=1629; x=(0.99, 0.99); f(x)=1.00; grad f(x)=(-0.03, -0.01)
# iter=1630; x=(0.99, 0.99); f(x)=1.00; grad f(x)=(-0.03, -0.01)
# iter=1631; x=(0.99, 0.99); f(x)=1.00; grad f(x)=(-0.03, -0.01)
# iter=1632; x=(0.99, 0.99); f(x)=1.00; grad f(x)=(-0.03, -0.01)
# iter=1633; x=(0.99, 0.99); f(x)=1.00; grad f(x)=(-0.03, -0.01)
# iter=1634; x=(0.99, 0.99); f(x)=1.00; grad f(x)=(-0.03, -0.01)
# iter=1635; x=(0.99, 0.99); f(x)=1.00; grad f(x)=(-0.03, -0.01)
# iter=1636; x=(0.99, 0.99); f(x)=1.00; grad f(x)=(-0.03, -0.01)
# iter=1637; x=(0.99, 0.99); f(x)=1.00; grad f(x)=(-0.03, -0.01)
# iter=1638; x=(0.99, 0.99); f(x)=1.00; grad f(x)=(-0.03, -0.01)
# iter=1639; x=(0.99, 0.99); f(x)=1.00; grad f(x)=(-0.03, -0.01)
# iter=1640; x=(0.99, 0.99); f(x)=1.00; grad f(x)=(-0.03, -0.01)
# iter=1641; x=(0.99, 0.99); f(x)=1.00; grad f(x)=(-0.03, -0.01)
# iter=1642; x=(0.99, 0.99); f(x)=1.00; grad f(x)=(-0.03, -0.01)
# iter=1643; x=(0.99, 0.99); f(x)=1.00; grad f(x)=(-0.03, -0.01)
# iter=1644; x=(0.99, 0.99); f(x)=1.00; grad f(x)=(-0.03, -0.01)
# iter=1645; x=(0.99, 0.99); f(x)=1.00; grad f(x)=(-0.03, -0.01)
# iter=1646; x=(0.99, 0.99); f(x)=1.00; grad f(x)=(-0.03, -0.01)
# iter=1647; x=(0.99, 0.99); f(x)=1.00; grad f(x)=(-0.03, -0.01)
# iter=1648; x=(0.99, 0.99); f(x)=1.00; grad f(x)=(-0.03, -0.01)
# iter=1649; x=(0.99, 0.99); f(x)=1.00; grad f(x)=(-0.03, -0.01)
# iter=1650; x=(0.99, 0.99); f(x)=1.00; grad f(x)=(-0.03, -0.01)
# iter=1651; x=(0.99, 0.99); f(x)=1.00; grad f(x)=(-0.03, -0.01)
# iter=1652; x=(0.99, 0.99); f(x)=1.00; grad f(x)=(-0.03, -0.01)
# iter=1653; x=(0.99, 0.99); f(x)=1.00; grad f(x)=(-0.03, -0.01)
# iter=1654; x=(0.99, 0.99); f(x)=1.00; grad f(x)=(-0.03, -0.01)
# iter=1655; x=(0.99, 0.99); f(x)=1.00; grad f(x)=(-0.03, -0.01)
# iter=1656; x=(0.99, 0.99); f(x)=1.00; grad f(x)=(-0.03, -0.01)
# iter=1657; x=(0.99, 0.99); f(x)=1.00; grad f(x)=(-0.03, -0.01)
# iter=1658; x=(0.99, 0.99); f(x)=1.00; grad f(x)=(-0.03, -0.01)
# iter=1659; x=(0.99, 0.99); f(x)=1.00; grad f(x)=(-0.03, -0.01)
# iter=1660; x=(0.99, 0.99); f(x)=1.00; grad f(x)=(-0.03, -0.01)
# iter=1661; x=(0.99, 0.99); f(x)=1.00; grad f(x)=(-0.03, -0.01)
# iter=1662; x=(0.99, 0.99); f(x)=1.00; grad f(x)=(-0.03, -0.01)
# iter=1663; x=(0.99, 0.99); f(x)=1.00; grad f(x)=(-0.03, -0.01)
# iter=1664; x=(0.99, 0.99); f(x)=1.00; grad f(x)=(-0.03, -0.01)
# iter=1665; x=(0.99, 0.99); f(x)=1.00; grad f(x)=(-0.03, -0.01)
# iter=1666; x=(0.99, 0.99); f(x)=1.00; grad f(x)=(-0.03, -0.01)
# iter=1667; x=(0.99, 0.99); f(x)=1.00; grad f(x)=(-0.03, -0.01)
# iter=1668; x=(0.99, 0.99); f(x)=1.00; grad f(x)=(-0.03, -0.01)
# iter=1669; x=(0.99, 0.99); f(x)=1.00; grad f(x)=(-0.03, -0.01)
# iter=1670; x=(0.99, 0.99); f(x)=1.00; grad f(x)=(-0.03, -0.01)
# iter=1671; x=(0.99, 0.99); f(x)=1.00; grad f(x)=(-0.03, -0.01)
# iter=1672; x=(0.99, 0.99); f(x)=1.00; grad f(x)=(-0.03, -0.01)
# iter=1673; x=(0.99, 0.99); f(x)=1.00; grad f(x)=(-0.03, -0.01)
# iter=1674; x=(0.99, 0.99); f(x)=1.00; grad f(x)=(-0.03, -0.01)
# iter=1675; x=(0.99, 0.99); f(x)=1.00; grad f(x)=(-0.03, -0.01)
# iter=1676; x=(0.99, 0.99); f(x)=1.00; grad f(x)=(-0.03, -0.01)
# iter=1677; x=(0.99, 0.99); f(x)=1.00; grad f(x)=(-0.03, -0.01)
# iter=1678; x=(0.99, 0.99); f(x)=1.00; grad f(x)=(-0.03, -0.01)
# iter=1679; x=(0.99, 0.99); f(x)=1.00; grad f(x)=(-0.03, -0.01)
# iter=1680; x=(0.99, 0.99); f(x)=1.00; grad f(x)=(-0.03, -0.01)
# iter=1681; x=(0.99, 0.99); f(x)=1.00; grad f(x)=(-0.03, -0.01)
# iter=1682; x=(0.99, 0.99); f(x)=1.00; grad f(x)=(-0.03, -0.01)
# iter=1683; x=(0.99, 0.99); f(x)=1.00; grad f(x)=(-0.03, -0.01)
# iter=1684; x=(0.99, 0.99); f(x)=1.00; grad f(x)=(-0.03, -0.01)
# iter=1685; x=(0.99, 0.99); f(x)=1.00; grad f(x)=(-0.03, -0.01)
# iter=1686; x=(0.99, 0.99); f(x)=1.00; grad f(x)=(-0.03, -0.01)
# iter=1687; x=(0.99, 0.99); f(x)=1.00; grad f(x)=(-0.03, -0.01)
# iter=1688; x=(0.99, 0.99); f(x)=1.00; grad f(x)=(-0.03, -0.01)
# iter=1689; x=(0.99, 0.99); f(x)=1.00; grad f(x)=(-0.03, -0.01)
# iter=1690; x=(0.99, 0.99); f(x)=1.00; grad f(x)=(-0.03, -0.01)
# iter=1691; x=(0.99, 0.99); f(x)=1.00; grad f(x)=(-0.03, -0.01)
# iter=1692; x=(0.99, 0.99); f(x)=1.00; grad f(x)=(-0.03, -0.01)
# iter=1693; x=(0.99, 0.99); f(x)=1.00; grad f(x)=(-0.03, -0.01)
# iter=1694; x=(0.99, 0.99); f(x)=1.00; grad f(x)=(-0.03, -0.01)
# iter=1695; x=(0.99, 0.99); f(x)=1.00; grad f(x)=(-0.03, -0.01)
# iter=1696; x=(0.99, 0.99); f(x)=1.00; grad f(x)=(-0.03, -0.01)
# iter=1697; x=(0.99, 0.99); f(x)=1.00; grad f(x)=(-0.03, -0.01)
# iter=1698; x=(0.99, 0.99); f(x)=1.00; grad f(x)=(-0.03, -0.01)
# iter=1699; x=(0.99, 0.99); f(x)=1.00; grad f(x)=(-0.03, -0.01)

# %%
optimize.minimize(lambda x: f(*x), x0=(10, 20))
# Out:
#       fun: 1.0000000000000013
#  hess_inv: array([[0.35300891, 0.12487411],
#        [0.12487411, 0.12487296]])
#       jac: array([-2.98023224e-08,  2.98023224e-08])
#   message: 'Optimization terminated successfully.'
#      nfev: 60
#       nit: 18
#      njev: 20
#    status: 0
#   success: True
#         x: array([0.99999997, 0.99999999])

# %%
import numpy as np
import matplotlib.pyplot as plt

def f(x, y):
    return 1*x ** 2 -4*x*y+y**4+2

x = np.linspace(-1.1, 1.1)
y = np.linspace(-1.1, 1.1)

X, Y = np.meshgrid(x, y)
F = f(X, Y)

fig = plt.figure(figsize=(16, 10))
ax = fig.gca(projection='3d')
surf = ax.plot_surface(X, Y, F, cmap='Paired')
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('f')
ax.view_init(30, 50)
# Out:
# /var/folders/ww/67t1k6ss6bqfd8tw6ntmpfgm0000gn/T/ipykernel_93453/2497299276.py:14: MatplotlibDeprecationWarning: Calling gca() with keyword arguments was deprecated in Matplotlib 3.4. Starting two minor releases later, gca() will take no keyword arguments. The gca() function should only be used to get the current axes, or if no axes exist, create new axes with default keyword arguments. To create a new axes with non-default arguments, use plt.axes() or plt.subplot().
#   ax = fig.gca(projection='3d')

# %%
# Loss = (2.1 - x - y)^2 - (2.9 - x - 3y)^2 + (4.1 - x - 5y)^2

def f(x, y):
    return (2.1 - x - y)**2 - (2.9 - x - 3*y)**2 + (4.1 - x - 5*y)**2

optimize.minimize(lambda x: f(*x), x0=(1, 1))
# Out:
#       fun: -0.07999999999999878
#  hess_inv: array([[ 1.0625, -0.1875],
#        [-0.1875,  0.0625]])
#       jac: array([-9.31322575e-10, -9.31322575e-10])
#   message: 'Optimization terminated successfully.'
#      nfev: 15
#       nit: 3
#      njev: 5
#    status: 0
#   success: True
#         x: array([1.80000003, 0.49999999])

# %%
f(1.80000003, 0.49999999)
# Out:
# -0.07999999999999921

# %%
# L = x^3 -2x^2 + y^2 + z^2 - 2xy + xz - yz + 3z

def f(x, y, z):
    return x**3 - 2*x**2 + y**2 + z**2 - 2*x*y + x*z - y*z + 3*z
def grad(x, y, z):
    dx = 3*(x**2) - 4*x - 2*y + z
    dy = 2*y - 2*x - z
    dz = 2*z + x - y + 3
    return (dx, dy, dz)
def dist(x1, x2):
    return (x1[0] - x2[0]) ** 2 + (x1[1] - x2[1]) ** 2

optimize.minimize(lambda x: f(*x), x0=(1, 1, 1))
# Out:
#       fun: -6.999999999998417
#  hess_inv: array([[1.66090661e-01, 1.67198544e-01, 3.52907842e-04],
#        [1.67198544e-01, 8.39385857e-01, 3.37986923e-01],
#        [3.52907842e-04, 3.37986923e-01, 6.65101542e-01]])
#       jac: array([-4.41074371e-06,  2.02655792e-06, -8.34465027e-07])
#   message: 'Optimization terminated successfully.'
#      nfev: 36
#       nit: 7
#      njev: 9
#    status: 0
#   success: True
#         x: array([ 1.9999996 ,  1.00000072, -1.99999985])

# %% [markdown]
# <img src="stat&basic6_img2.png" width="800px"/>

# %%
# 2x^2 - 4xz + 4y^2 - 8yz + 9z^2 + 4x + 8y - 20z

def f(x, y, z):
    return 2*(x**2) - 4*x*z + 4*(y**2) - 8*y*z + 9*(z**2) + 4*x + 8*y - 20*z
def grad(x, y, z):
    dx = 4*x - 4*z + 4
    dy = 8*y - 8*z + 8
    dz = -4*x - 8*y + 18*z - 20
    return (dx, dy, dz)

x0 = (0, 0, 0)
gamma = 1e-3
x_cur = x0

vals = []
coords = []
i = 0
while True:
    x_new = (x_cur[0] - gamma * grad(*x_cur)[0],
            x_cur[1] - gamma * grad(*x_cur)[1],
            x_cur[2] - gamma * grad(*x_cur)[2])
    if i > 10000:
        break
    x_cur = x_new
    vals.append(f(*x_cur))
    coords.append(x_cur)
    i += 1
    print(f"iter={i}; x=({x_cur[0]:.2f}, {x_cur[1]:.2f}, {x_cur[2]:.2f});"
          f" f(x)={f(*x_cur):.2f}; grad f(x)=({grad(*x_cur)[0]:.2f}, {grad(*x_cur)[1]:.2f}, {grad(*x_cur)[2]:.2f})")
# Out:
# iter=1; x=(-0.00, -0.01, 0.02); f(x)=-0.47; grad f(x)=(3.90, 7.78, -19.56)
# iter=2; x=(-0.01, -0.02, 0.04); f(x)=-0.93; grad f(x)=(3.81, 7.56, -19.13)
# iter=3; x=(-0.01, -0.02, 0.06); f(x)=-1.36; grad f(x)=(3.72, 7.34, -18.71)
# iter=4; x=(-0.02, -0.03, 0.08); f(x)=-1.77; grad f(x)=(3.63, 7.14, -18.30)
# iter=5; x=(-0.02, -0.04, 0.10); f(x)=-2.17; grad f(x)=(3.54, 6.93, -17.90)
# iter=6; x=(-0.02, -0.04, 0.11); f(x)=-2.54; grad f(x)=(3.46, 6.73, -17.51)
# iter=7; x=(-0.03, -0.05, 0.13); f(x)=-2.90; grad f(x)=(3.37, 6.54, -17.12)
# iter=8; x=(-0.03, -0.06, 0.15); f(x)=-3.25; grad f(x)=(3.29, 6.35, -16.75)
# iter=9; x=(-0.03, -0.06, 0.16); f(x)=-3.58; grad f(x)=(3.21, 6.17, -16.38)
# iter=10; x=(-0.04, -0.07, 0.18); f(x)=-3.89; grad f(x)=(3.13, 5.98, -16.03)
# iter=11; x=(-0.04, -0.08, 0.20); f(x)=-4.19; grad f(x)=(3.05, 5.81, -15.68)
# iter=12; x=(-0.04, -0.08, 0.21); f(x)=-4.47; grad f(x)=(2.98, 5.64, -15.34)
# iter=13; x=(-0.05, -0.09, 0.23); f(x)=-4.75; grad f(x)=(2.91, 5.47, -15.00)
# iter=14; x=(-0.05, -0.09, 0.24); f(x)=-5.01; grad f(x)=(2.83, 5.31, -14.68)
# iter=15; x=(-0.05, -0.10, 0.26); f(x)=-5.26; grad f(x)=(2.76, 5.15, -14.36)
# iter=16; x=(-0.05, -0.10, 0.27); f(x)=-5.49; grad f(x)=(2.70, 4.99, -14.05)
# iter=17; x=(-0.06, -0.11, 0.29); f(x)=-5.72; grad f(x)=(2.63, 4.84, -13.75)
# iter=18; x=(-0.06, -0.11, 0.30); f(x)=-5.94; grad f(x)=(2.56, 4.69, -13.45)
# iter=19; x=(-0.06, -0.12, 0.31); f(x)=-6.14; grad f(x)=(2.50, 4.54, -13.16)
# iter=20; x=(-0.06, -0.12, 0.33); f(x)=-6.34; grad f(x)=(2.44, 4.40, -12.88)
# iter=21; x=(-0.07, -0.13, 0.34); f(x)=-6.53; grad f(x)=(2.38, 4.26, -12.60)
# iter=22; x=(-0.07, -0.13, 0.35); f(x)=-6.71; grad f(x)=(2.32, 4.13, -12.33)
# iter=23; x=(-0.07, -0.14, 0.36); f(x)=-6.88; grad f(x)=(2.26, 4.00, -12.07)
# iter=24; x=(-0.07, -0.14, 0.38); f(x)=-7.05; grad f(x)=(2.20, 3.87, -11.81)
# iter=25; x=(-0.08, -0.14, 0.39); f(x)=-7.21; grad f(x)=(2.14, 3.74, -11.56)
# iter=26; x=(-0.08, -0.15, 0.40); f(x)=-7.36; grad f(x)=(2.09, 3.62, -11.31)
# iter=27; x=(-0.08, -0.15, 0.41); f(x)=-7.50; grad f(x)=(2.04, 3.50, -11.07)
# iter=28; x=(-0.08, -0.15, 0.42); f(x)=-7.64; grad f(x)=(1.98, 3.38, -10.83)
# iter=29; x=(-0.08, -0.16, 0.43); f(x)=-7.77; grad f(x)=(1.93, 3.27, -10.60)
# iter=30; x=(-0.09, -0.16, 0.44); f(x)=-7.89; grad f(x)=(1.88, 3.16, -10.38)
# iter=31; x=(-0.09, -0.16, 0.45); f(x)=-8.01; grad f(x)=(1.83, 3.05, -10.16)
# iter=32; x=(-0.09, -0.17, 0.46); f(x)=-8.13; grad f(x)=(1.78, 2.95, -9.94)
# iter=33; x=(-0.09, -0.17, 0.47); f(x)=-8.24; grad f(x)=(1.74, 2.84, -9.73)
# iter=34; x=(-0.09, -0.17, 0.48); f(x)=-8.34; grad f(x)=(1.69, 2.74, -9.53)
# iter=35; x=(-0.09, -0.18, 0.49); f(x)=-8.44; grad f(x)=(1.65, 2.64, -9.33)
# iter=36; x=(-0.10, -0.18, 0.50); f(x)=-8.54; grad f(x)=(1.60, 2.55, -9.13)
# iter=37; x=(-0.10, -0.18, 0.51); f(x)=-8.63; grad f(x)=(1.56, 2.45, -8.94)
# iter=38; x=(-0.10, -0.18, 0.52); f(x)=-8.72; grad f(x)=(1.52, 2.36, -8.76)
# iter=39; x=(-0.10, -0.19, 0.53); f(x)=-8.80; grad f(x)=(1.48, 2.27, -8.57)
# iter=40; x=(-0.10, -0.19, 0.54); f(x)=-8.88; grad f(x)=(1.44, 2.19, -8.39)
# iter=41; x=(-0.10, -0.19, 0.55); f(x)=-8.96; grad f(x)=(1.40, 2.10, -8.22)
# iter=42; x=(-0.11, -0.19, 0.55); f(x)=-9.03; grad f(x)=(1.36, 2.02, -8.05)
# iter=43; x=(-0.11, -0.19, 0.56); f(x)=-9.10; grad f(x)=(1.32, 1.94, -7.88)
# iter=44; x=(-0.11, -0.20, 0.57); f(x)=-9.17; grad f(x)=(1.28, 1.86, -7.72)
# iter=45; x=(-0.11, -0.20, 0.58); f(x)=-9.23; grad f(x)=(1.25, 1.78, -7.56)
# iter=46; x=(-0.11, -0.20, 0.59); f(x)=-9.29; grad f(x)=(1.21, 1.71, -7.41)
# iter=47; x=(-0.11, -0.20, 0.59); f(x)=-9.35; grad f(x)=(1.18, 1.64, -7.25)
# iter=48; x=(-0.11, -0.20, 0.60); f(x)=-9.41; grad f(x)=(1.14, 1.57, -7.11)
# iter=49; x=(-0.11, -0.20, 0.61); f(x)=-9.46; grad f(x)=(1.11, 1.50, -6.96)
# iter=50; x=(-0.12, -0.21, 0.61); f(x)=-9.51; grad f(x)=(1.08, 1.43, -6.82)
# iter=51; x=(-0.12, -0.21, 0.62); f(x)=-9.56; grad f(x)=(1.05, 1.36, -6.68)
# iter=52; x=(-0.12, -0.21, 0.63); f(x)=-9.61; grad f(x)=(1.02, 1.30, -6.55)
# iter=53; x=(-0.12, -0.21, 0.63); f(x)=-9.65; grad f(x)=(0.99, 1.24, -6.41)
# iter=54; x=(-0.12, -0.21, 0.64); f(x)=-9.70; grad f(x)=(0.96, 1.17, -6.28)
# iter=55; x=(-0.12, -0.21, 0.65); f(x)=-9.74; grad f(x)=(0.93, 1.11, -6.16)
# iter=56; x=(-0.12, -0.21, 0.65); f(x)=-9.78; grad f(x)=(0.90, 1.06, -6.03)
# iter=57; x=(-0.12, -0.22, 0.66); f(x)=-9.82; grad f(x)=(0.87, 1.00, -5.91)
# iter=58; x=(-0.12, -0.22, 0.67); f(x)=-9.85; grad f(x)=(0.85, 0.94, -5.80)
# iter=59; x=(-0.12, -0.22, 0.67); f(x)=-9.89; grad f(x)=(0.82, 0.89, -5.68)
# iter=60; x=(-0.12, -0.22, 0.68); f(x)=-9.92; grad f(x)=(0.79, 0.84, -5.57)
# iter=61; x=(-0.13, -0.22, 0.68); f(x)=-9.95; grad f(x)=(0.77, 0.79, -5.46)
# iter=62; x=(-0.13, -0.22, 0.69); f(x)=-9.98; grad f(x)=(0.74, 0.74, -5.35)
# iter=63; x=(-0.13, -0.22, 0.69); f(x)=-10.01; grad f(x)=(0.72, 0.69, -5.24)
# iter=64; x=(-0.13, -0.22, 0.70); f(x)=-10.04; grad f(x)=(0.69, 0.64, -5.14)
# iter=65; x=(-0.13, -0.22, 0.70); f(x)=-10.07; grad f(x)=(0.67, 0.59, -5.04)
# iter=66; x=(-0.13, -0.22, 0.71); f(x)=-10.09; grad f(x)=(0.65, 0.55, -4.94)
# iter=67; x=(-0.13, -0.22, 0.71); f(x)=-10.12; grad f(x)=(0.63, 0.51, -4.85)
# iter=68; x=(-0.13, -0.22, 0.72); f(x)=-10.14; grad f(x)=(0.60, 0.46, -4.75)
# iter=69; x=(-0.13, -0.22, 0.72); f(x)=-10.16; grad f(x)=(0.58, 0.42, -4.66)
# iter=70; x=(-0.13, -0.22, 0.73); f(x)=-10.19; grad f(x)=(0.56, 0.38, -4.57)
# iter=71; x=(-0.13, -0.22, 0.73); f(x)=-10.21; grad f(x)=(0.54, 0.34, -4.48)
# iter=72; x=(-0.13, -0.22, 0.74); f(x)=-10.23; grad f(x)=(0.52, 0.30, -4.40)
# iter=73; x=(-0.13, -0.23, 0.74); f(x)=-10.25; grad f(x)=(0.50, 0.26, -4.32)
# iter=74; x=(-0.13, -0.23, 0.75); f(x)=-10.27; grad f(x)=(0.48, 0.23, -4.23)
# iter=75; x=(-0.13, -0.23, 0.75); f(x)=-10.28; grad f(x)=(0.46, 0.19, -4.15)
# iter=76; x=(-0.13, -0.23, 0.75); f(x)=-10.30; grad f(x)=(0.44, 0.16, -4.08)
# iter=77; x=(-0.13, -0.23, 0.76); f(x)=-10.32; grad f(x)=(0.43, 0.12, -4.00)
# iter=78; x=(-0.14, -0.23, 0.76); f(x)=-10.33; grad f(x)=(0.41, 0.09, -3.92)
# iter=79; x=(-0.14, -0.23, 0.77); f(x)=-10.35; grad f(x)=(0.39, 0.06, -3.85)
# iter=80; x=(-0.14, -0.23, 0.77); f(x)=-10.36; grad f(x)=(0.37, 0.03, -3.78)
# iter=81; x=(-0.14, -0.23, 0.77); f(x)=-10.38; grad f(x)=(0.36, -0.00, -3.71)
# iter=82; x=(-0.14, -0.23, 0.78); f(x)=-10.39; grad f(x)=(0.34, -0.03, -3.64)
# iter=83; x=(-0.14, -0.23, 0.78); f(x)=-10.41; grad f(x)=(0.33, -0.06, -3.58)
# iter=84; x=(-0.14, -0.23, 0.78); f(x)=-10.42; grad f(x)=(0.31, -0.09, -3.51)
# iter=85; x=(-0.14, -0.23, 0.79); f(x)=-10.43; grad f(x)=(0.29, -0.12, -3.45)
# iter=86; x=(-0.14, -0.23, 0.79); f(x)=-10.44; grad f(x)=(0.28, -0.14, -3.38)
# iter=87; x=(-0.14, -0.23, 0.80); f(x)=-10.45; grad f(x)=(0.26, -0.17, -3.32)
# iter=88; x=(-0.14, -0.23, 0.80); f(x)=-10.47; grad f(x)=(0.25, -0.19, -3.26)
# iter=89; x=(-0.14, -0.23, 0.80); f(x)=-10.48; grad f(x)=(0.24, -0.22, -3.21)
# iter=90; x=(-0.14, -0.23, 0.81); f(x)=-10.49; grad f(x)=(0.22, -0.24, -3.15)
# iter=91; x=(-0.14, -0.23, 0.81); f(x)=-10.50; grad f(x)=(0.21, -0.27, -3.09)
# iter=92; x=(-0.14, -0.22, 0.81); f(x)=-10.51; grad f(x)=(0.20, -0.29, -3.04)
# iter=93; x=(-0.14, -0.22, 0.81); f(x)=-10.52; grad f(x)=(0.18, -0.31, -2.99)
# iter=94; x=(-0.14, -0.22, 0.82); f(x)=-10.52; grad f(x)=(0.17, -0.33, -2.93)
# iter=95; x=(-0.14, -0.22, 0.82); f(x)=-10.53; grad f(x)=(0.16, -0.35, -2.88)
# iter=96; x=(-0.14, -0.22, 0.82); f(x)=-10.54; grad f(x)=(0.15, -0.37, -2.83)
# iter=97; x=(-0.14, -0.22, 0.83); f(x)=-10.55; grad f(x)=(0.13, -0.39, -2.78)
# iter=98; x=(-0.14, -0.22, 0.83); f(x)=-10.56; grad f(x)=(0.12, -0.41, -2.74)
# iter=99; x=(-0.14, -0.22, 0.83); f(x)=-10.56; grad f(x)=(0.11, -0.43, -2.69)
# iter=100; x=(-0.14, -0.22, 0.83); f(x)=-10.57; grad f(x)=(0.10, -0.45, -2.64)
# iter=101; x=(-0.14, -0.22, 0.84); f(x)=-10.58; grad f(x)=(0.09, -0.47, -2.60)
# iter=102; x=(-0.14, -0.22, 0.84); f(x)=-10.59; grad f(x)=(0.08, -0.48, -2.56)
# iter=103; x=(-0.14, -0.22, 0.84); f(x)=-10.59; grad f(x)=(0.07, -0.50, -2.51)
# iter=104; x=(-0.14, -0.22, 0.84); f(x)=-10.60; grad f(x)=(0.06, -0.52, -2.47)
# iter=105; x=(-0.14, -0.22, 0.85); f(x)=-10.61; grad f(x)=(0.05, -0.53, -2.43)
# iter=106; x=(-0.14, -0.22, 0.85); f(x)=-10.61; grad f(x)=(0.04, -0.55, -2.39)
# iter=107; x=(-0.14, -0.22, 0.85); f(x)=-10.62; grad f(x)=(0.03, -0.56, -2.35)
# iter=108; x=(-0.14, -0.22, 0.85); f(x)=-10.62; grad f(x)=(0.02, -0.58, -2.32)
# iter=109; x=(-0.14, -0.22, 0.86); f(x)=-10.63; grad f(x)=(0.01, -0.59, -2.28)
# iter=110; x=(-0.14, -0.22, 0.86); f(x)=-10.63; grad f(x)=(-0.00, -0.60, -2.24)
# iter=111; x=(-0.14, -0.22, 0.86); f(x)=-10.64; grad f(x)=(-0.01, -0.62, -2.21)
# iter=112; x=(-0.14, -0.22, 0.86); f(x)=-10.65; grad f(x)=(-0.02, -0.63, -2.17)
# iter=113; x=(-0.14, -0.21, 0.87); f(x)=-10.65; grad f(x)=(-0.03, -0.64, -2.14)
# iter=114; x=(-0.14, -0.21, 0.87); f(x)=-10.66; grad f(x)=(-0.04, -0.65, -2.10)
# iter=115; x=(-0.14, -0.21, 0.87); f(x)=-10.66; grad f(x)=(-0.04, -0.67, -2.07)
# iter=116; x=(-0.14, -0.21, 0.87); f(x)=-10.67; grad f(x)=(-0.05, -0.68, -2.04)
# iter=117; x=(-0.14, -0.21, 0.87); f(x)=-10.67; grad f(x)=(-0.06, -0.69, -2.01)
# iter=118; x=(-0.14, -0.21, 0.88); f(x)=-10.67; grad f(x)=(-0.07, -0.70, -1.98)
# iter=119; x=(-0.14, -0.21, 0.88); f(x)=-10.68; grad f(x)=(-0.08, -0.71, -1.95)
# iter=120; x=(-0.14, -0.21, 0.88); f(x)=-10.68; grad f(x)=(-0.08, -0.72, -1.92)
# iter=121; x=(-0.14, -0.21, 0.88); f(x)=-10.69; grad f(x)=(-0.09, -0.73, -1.89)
# iter=122; x=(-0.14, -0.21, 0.88); f(x)=-10.69; grad f(x)=(-0.10, -0.74, -1.86)
# iter=123; x=(-0.14, -0.21, 0.89); f(x)=-10.70; grad f(x)=(-0.10, -0.75, -1.84)
# iter=124; x=(-0.14, -0.21, 0.89); f(x)=-10.70; grad f(x)=(-0.11, -0.76, -1.81)
# iter=125; x=(-0.14, -0.21, 0.89); f(x)=-10.70; grad f(x)=(-0.12, -0.76, -1.78)
# iter=126; x=(-0.14, -0.21, 0.89); f(x)=-10.71; grad f(x)=(-0.12, -0.77, -1.76)
# iter=127; x=(-0.14, -0.20, 0.89); f(x)=-10.71; grad f(x)=(-0.13, -0.78, -1.73)
# iter=128; x=(-0.14, -0.20, 0.89); f(x)=-10.71; grad f(x)=(-0.14, -0.79, -1.71)
# iter=129; x=(-0.14, -0.20, 0.90); f(x)=-10.72; grad f(x)=(-0.14, -0.79, -1.69)
# iter=130; x=(-0.14, -0.20, 0.90); f(x)=-10.72; grad f(x)=(-0.15, -0.80, -1.66)
# iter=131; x=(-0.14, -0.20, 0.90); f(x)=-10.72; grad f(x)=(-0.16, -0.81, -1.64)
# iter=132; x=(-0.14, -0.20, 0.90); f(x)=-10.73; grad f(x)=(-0.16, -0.82, -1.62)
# iter=133; x=(-0.14, -0.20, 0.90); f(x)=-10.73; grad f(x)=(-0.17, -0.82, -1.59)
# iter=134; x=(-0.14, -0.20, 0.90); f(x)=-10.73; grad f(x)=(-0.17, -0.83, -1.57)
# iter=135; x=(-0.14, -0.20, 0.91); f(x)=-10.74; grad f(x)=(-0.18, -0.83, -1.55)
# iter=136; x=(-0.14, -0.20, 0.91); f(x)=-10.74; grad f(x)=(-0.18, -0.84, -1.53)
# iter=137; x=(-0.14, -0.20, 0.91); f(x)=-10.74; grad f(x)=(-0.19, -0.85, -1.51)
# iter=138; x=(-0.14, -0.20, 0.91); f(x)=-10.75; grad f(x)=(-0.20, -0.85, -1.49)
# iter=139; x=(-0.14, -0.20, 0.91); f(x)=-10.75; grad f(x)=(-0.20, -0.86, -1.47)
# iter=140; x=(-0.14, -0.19, 0.91); f(x)=-10.75; grad f(x)=(-0.21, -0.86, -1.45)
# iter=141; x=(-0.14, -0.19, 0.91); f(x)=-10.76; grad f(x)=(-0.21, -0.87, -1.44)
# iter=142; x=(-0.14, -0.19, 0.92); f(x)=-10.76; grad f(x)=(-0.22, -0.87, -1.42)
# iter=143; x=(-0.14, -0.19, 0.92); f(x)=-10.76; grad f(x)=(-0.22, -0.87, -1.40)
# iter=144; x=(-0.14, -0.19, 0.92); f(x)=-10.76; grad f(x)=(-0.23, -0.88, -1.38)
# iter=145; x=(-0.14, -0.19, 0.92); f(x)=-10.77; grad f(x)=(-0.23, -0.88, -1.37)
# iter=146; x=(-0.14, -0.19, 0.92); f(x)=-10.77; grad f(x)=(-0.23, -0.89, -1.35)
# iter=147; x=(-0.14, -0.19, 0.92); f(x)=-10.77; grad f(x)=(-0.24, -0.89, -1.33)
# iter=148; x=(-0.14, -0.19, 0.92); f(x)=-10.77; grad f(x)=(-0.24, -0.89, -1.32)
# iter=149; x=(-0.14, -0.19, 0.93); f(x)=-10.78; grad f(x)=(-0.25, -0.90, -1.30)
# iter=150; x=(-0.14, -0.19, 0.93); f(x)=-10.78; grad f(x)=(-0.25, -0.90, -1.29)
# iter=151; x=(-0.14, -0.18, 0.93); f(x)=-10.78; grad f(x)=(-0.26, -0.90, -1.27)
# iter=152; x=(-0.14, -0.18, 0.93); f(x)=-10.78; grad f(x)=(-0.26, -0.91, -1.26)
# iter=153; x=(-0.14, -0.18, 0.93); f(x)=-10.79; grad f(x)=(-0.26, -0.91, -1.24)
# iter=154; x=(-0.13, -0.18, 0.93); f(x)=-10.79; grad f(x)=(-0.27, -0.91, -1.23)
# iter=155; x=(-0.13, -0.18, 0.93); f(x)=-10.79; grad f(x)=(-0.27, -0.91, -1.21)
# iter=156; x=(-0.13, -0.18, 0.93); f(x)=-10.79; grad f(x)=(-0.28, -0.92, -1.20)
# iter=157; x=(-0.13, -0.18, 0.94); f(x)=-10.80; grad f(x)=(-0.28, -0.92, -1.19)
# iter=158; x=(-0.13, -0.18, 0.94); f(x)=-10.80; grad f(x)=(-0.28, -0.92, -1.17)
# iter=159; x=(-0.13, -0.18, 0.94); f(x)=-10.80; grad f(x)=(-0.29, -0.92, -1.16)
# iter=160; x=(-0.13, -0.18, 0.94); f(x)=-10.80; grad f(x)=(-0.29, -0.92, -1.15)
# iter=161; x=(-0.13, -0.18, 0.94); f(x)=-10.81; grad f(x)=(-0.29, -0.93, -1.14)
# iter=162; x=(-0.13, -0.17, 0.94); f(x)=-10.81; grad f(x)=(-0.30, -0.93, -1.13)
# iter=163; x=(-0.13, -0.17, 0.94); f(x)=-10.81; grad f(x)=(-0.30, -0.93, -1.11)
# iter=164; x=(-0.13, -0.17, 0.94); f(x)=-10.81; grad f(x)=(-0.30, -0.93, -1.10)
# iter=165; x=(-0.13, -0.17, 0.94); f(x)=-10.81; grad f(x)=(-0.31, -0.93, -1.09)
# iter=166; x=(-0.13, -0.17, 0.95); f(x)=-10.82; grad f(x)=(-0.31, -0.93, -1.08)
# iter=167; x=(-0.13, -0.17, 0.95); f(x)=-10.82; grad f(x)=(-0.31, -0.94, -1.07)
# iter=168; x=(-0.13, -0.17, 0.95); f(x)=-10.82; grad f(x)=(-0.32, -0.94, -1.06)
# iter=169; x=(-0.13, -0.17, 0.95); f(x)=-10.82; grad f(x)=(-0.32, -0.94, -1.05)
# iter=170; x=(-0.13, -0.17, 0.95); f(x)=-10.83; grad f(x)=(-0.32, -0.94, -1.04)
# iter=171; x=(-0.13, -0.17, 0.95); f(x)=-10.83; grad f(x)=(-0.32, -0.94, -1.03)
# iter=172; x=(-0.13, -0.17, 0.95); f(x)=-10.83; grad f(x)=(-0.33, -0.94, -1.02)
# iter=173; x=(-0.13, -0.16, 0.95); f(x)=-10.83; grad f(x)=(-0.33, -0.94, -1.01)
# iter=174; x=(-0.13, -0.16, 0.95); f(x)=-10.83; grad f(x)=(-0.33, -0.94, -1.00)
# iter=175; x=(-0.13, -0.16, 0.96); f(x)=-10.84; grad f(x)=(-0.34, -0.94, -0.99)
# iter=176; x=(-0.13, -0.16, 0.96); f(x)=-10.84; grad f(x)=(-0.34, -0.94, -0.98)
# iter=177; x=(-0.13, -0.16, 0.96); f(x)=-10.84; grad f(x)=(-0.34, -0.94, -0.97)
# iter=178; x=(-0.13, -0.16, 0.96); f(x)=-10.84; grad f(x)=(-0.34, -0.94, -0.96)
# iter=179; x=(-0.13, -0.16, 0.96); f(x)=-10.84; grad f(x)=(-0.35, -0.94, -0.96)
# iter=180; x=(-0.13, -0.16, 0.96); f(x)=-10.85; grad f(x)=(-0.35, -0.94, -0.95)
# iter=181; x=(-0.13, -0.16, 0.96); f(x)=-10.85; grad f(x)=(-0.35, -0.94, -0.94)
# iter=182; x=(-0.13, -0.16, 0.96); f(x)=-10.85; grad f(x)=(-0.35, -0.94, -0.93)
# iter=183; x=(-0.13, -0.15, 0.96); f(x)=-10.85; grad f(x)=(-0.36, -0.94, -0.92)
# iter=184; x=(-0.13, -0.15, 0.96); f(x)=-10.85; grad f(x)=(-0.36, -0.94, -0.92)
# iter=185; x=(-0.13, -0.15, 0.96); f(x)=-10.85; grad f(x)=(-0.36, -0.94, -0.91)
# iter=186; x=(-0.12, -0.15, 0.97); f(x)=-10.86; grad f(x)=(-0.36, -0.94, -0.90)
# iter=187; x=(-0.12, -0.15, 0.97); f(x)=-10.86; grad f(x)=(-0.36, -0.94, -0.89)
# iter=188; x=(-0.12, -0.15, 0.97); f(x)=-10.86; grad f(x)=(-0.37, -0.94, -0.89)
# iter=189; x=(-0.12, -0.15, 0.97); f(x)=-10.86; grad f(x)=(-0.37, -0.94, -0.88)
# iter=190; x=(-0.12, -0.15, 0.97); f(x)=-10.86; grad f(x)=(-0.37, -0.94, -0.87)
# iter=191; x=(-0.12, -0.15, 0.97); f(x)=-10.87; grad f(x)=(-0.37, -0.94, -0.87)
# iter=192; x=(-0.12, -0.15, 0.97); f(x)=-10.87; grad f(x)=(-0.37, -0.94, -0.86)
# iter=193; x=(-0.12, -0.15, 0.97); f(x)=-10.87; grad f(x)=(-0.38, -0.94, -0.85)
# iter=194; x=(-0.12, -0.14, 0.97); f(x)=-10.87; grad f(x)=(-0.38, -0.94, -0.85)
# iter=195; x=(-0.12, -0.14, 0.97); f(x)=-10.87; grad f(x)=(-0.38, -0.94, -0.84)
# iter=196; x=(-0.12, -0.14, 0.97); f(x)=-10.87; grad f(x)=(-0.38, -0.94, -0.83)
# iter=197; x=(-0.12, -0.14, 0.98); f(x)=-10.88; grad f(x)=(-0.38, -0.94, -0.83)
# iter=198; x=(-0.12, -0.14, 0.98); f(x)=-10.88; grad f(x)=(-0.39, -0.93, -0.82)
# iter=199; x=(-0.12, -0.14, 0.98); f(x)=-10.88; grad f(x)=(-0.39, -0.93, -0.82)
# iter=200; x=(-0.12, -0.14, 0.98); f(x)=-10.88; grad f(x)=(-0.39, -0.93, -0.81)
# iter=201; x=(-0.12, -0.14, 0.98); f(x)=-10.88; grad f(x)=(-0.39, -0.93, -0.81)
# iter=202; x=(-0.12, -0.14, 0.98); f(x)=-10.88; grad f(x)=(-0.39, -0.93, -0.80)
# iter=203; x=(-0.12, -0.14, 0.98); f(x)=-10.89; grad f(x)=(-0.39, -0.93, -0.79)
# iter=204; x=(-0.12, -0.14, 0.98); f(x)=-10.89; grad f(x)=(-0.40, -0.93, -0.79)
# iter=205; x=(-0.12, -0.13, 0.98); f(x)=-10.89; grad f(x)=(-0.40, -0.93, -0.78)
# iter=206; x=(-0.12, -0.13, 0.98); f(x)=-10.89; grad f(x)=(-0.40, -0.93, -0.78)
# iter=207; x=(-0.12, -0.13, 0.98); f(x)=-10.89; grad f(x)=(-0.40, -0.93, -0.77)
# iter=208; x=(-0.12, -0.13, 0.98); f(x)=-10.89; grad f(x)=(-0.40, -0.92, -0.77)
# iter=209; x=(-0.12, -0.13, 0.98); f(x)=-10.90; grad f(x)=(-0.40, -0.92, -0.76)
# iter=210; x=(-0.12, -0.13, 0.99); f(x)=-10.90; grad f(x)=(-0.40, -0.92, -0.76)
# iter=211; x=(-0.12, -0.13, 0.99); f(x)=-10.90; grad f(x)=(-0.41, -0.92, -0.75)
# iter=212; x=(-0.11, -0.13, 0.99); f(x)=-10.90; grad f(x)=(-0.41, -0.92, -0.75)
# iter=213; x=(-0.11, -0.13, 0.99); f(x)=-10.90; grad f(x)=(-0.41, -0.92, -0.75)
# iter=214; x=(-0.11, -0.13, 0.99); f(x)=-10.90; grad f(x)=(-0.41, -0.92, -0.74)
# iter=215; x=(-0.11, -0.12, 0.99); f(x)=-10.91; grad f(x)=(-0.41, -0.91, -0.74)
# iter=216; x=(-0.11, -0.12, 0.99); f(x)=-10.91; grad f(x)=(-0.41, -0.91, -0.73)
# iter=217; x=(-0.11, -0.12, 0.99); f(x)=-10.91; grad f(x)=(-0.41, -0.91, -0.73)
# iter=218; x=(-0.11, -0.12, 0.99); f(x)=-10.91; grad f(x)=(-0.42, -0.91, -0.72)
# iter=219; x=(-0.11, -0.12, 0.99); f(x)=-10.91; grad f(x)=(-0.42, -0.91, -0.72)
# iter=220; x=(-0.11, -0.12, 0.99); f(x)=-10.91; grad f(x)=(-0.42, -0.91, -0.72)
# iter=221; x=(-0.11, -0.12, 0.99); f(x)=-10.91; grad f(x)=(-0.42, -0.91, -0.71)
# iter=222; x=(-0.11, -0.12, 0.99); f(x)=-10.92; grad f(x)=(-0.42, -0.90, -0.71)
# iter=223; x=(-0.11, -0.12, 1.00); f(x)=-10.92; grad f(x)=(-0.42, -0.90, -0.70)
# iter=224; x=(-0.11, -0.12, 1.00); f(x)=-10.92; grad f(x)=(-0.42, -0.90, -0.70)
# iter=225; x=(-0.11, -0.12, 1.00); f(x)=-10.92; grad f(x)=(-0.42, -0.90, -0.70)
# iter=226; x=(-0.11, -0.11, 1.00); f(x)=-10.92; grad f(x)=(-0.42, -0.90, -0.69)
# iter=227; x=(-0.11, -0.11, 1.00); f(x)=-10.92; grad f(x)=(-0.43, -0.90, -0.69)
# iter=228; x=(-0.11, -0.11, 1.00); f(x)=-10.92; grad f(x)=(-0.43, -0.89, -0.69)
# iter=229; x=(-0.11, -0.11, 1.00); f(x)=-10.93; grad f(x)=(-0.43, -0.89, -0.68)
# iter=230; x=(-0.11, -0.11, 1.00); f(x)=-10.93; grad f(x)=(-0.43, -0.89, -0.68)
# iter=231; x=(-0.11, -0.11, 1.00); f(x)=-10.93; grad f(x)=(-0.43, -0.89, -0.68)
# iter=232; x=(-0.11, -0.11, 1.00); f(x)=-10.93; grad f(x)=(-0.43, -0.89, -0.67)
# iter=233; x=(-0.11, -0.11, 1.00); f(x)=-10.93; grad f(x)=(-0.43, -0.89, -0.67)
# iter=234; x=(-0.11, -0.11, 1.00); f(x)=-10.93; grad f(x)=(-0.43, -0.88, -0.67)
# iter=235; x=(-0.10, -0.11, 1.00); f(x)=-10.93; grad f(x)=(-0.43, -0.88, -0.66)
# iter=236; x=(-0.10, -0.11, 1.00); f(x)=-10.94; grad f(x)=(-0.43, -0.88, -0.66)
# iter=237; x=(-0.10, -0.11, 1.00); f(x)=-10.94; grad f(x)=(-0.44, -0.88, -0.66)
# iter=238; x=(-0.10, -0.10, 1.01); f(x)=-10.94; grad f(x)=(-0.44, -0.88, -0.65)
# iter=239; x=(-0.10, -0.10, 1.01); f(x)=-10.94; grad f(x)=(-0.44, -0.88, -0.65)
# iter=240; x=(-0.10, -0.10, 1.01); f(x)=-10.94; grad f(x)=(-0.44, -0.87, -0.65)
# iter=241; x=(-0.10, -0.10, 1.01); f(x)=-10.94; grad f(x)=(-0.44, -0.87, -0.64)
# iter=242; x=(-0.10, -0.10, 1.01); f(x)=-10.94; grad f(x)=(-0.44, -0.87, -0.64)
# iter=243; x=(-0.10, -0.10, 1.01); f(x)=-10.95; grad f(x)=(-0.44, -0.87, -0.64)
# iter=244; x=(-0.10, -0.10, 1.01); f(x)=-10.95; grad f(x)=(-0.44, -0.87, -0.64)
# iter=245; x=(-0.10, -0.10, 1.01); f(x)=-10.95; grad f(x)=(-0.44, -0.86, -0.63)
# iter=246; x=(-0.10, -0.10, 1.01); f(x)=-10.95; grad f(x)=(-0.44, -0.86, -0.63)
# iter=247; x=(-0.10, -0.10, 1.01); f(x)=-10.95; grad f(x)=(-0.44, -0.86, -0.63)
# iter=248; x=(-0.10, -0.10, 1.01); f(x)=-10.95; grad f(x)=(-0.44, -0.86, -0.63)
# iter=249; x=(-0.10, -0.09, 1.01); f(x)=-10.95; grad f(x)=(-0.45, -0.86, -0.62)
# iter=250; x=(-0.10, -0.09, 1.01); f(x)=-10.96; grad f(x)=(-0.45, -0.86, -0.62)
# iter=251; x=(-0.10, -0.09, 1.01); f(x)=-10.96; grad f(x)=(-0.45, -0.85, -0.62)
# iter=252; x=(-0.10, -0.09, 1.01); f(x)=-10.96; grad f(x)=(-0.45, -0.85, -0.62)
# iter=253; x=(-0.10, -0.09, 1.01); f(x)=-10.96; grad f(x)=(-0.45, -0.85, -0.61)
# iter=254; x=(-0.10, -0.09, 1.02); f(x)=-10.96; grad f(x)=(-0.45, -0.85, -0.61)
# iter=255; x=(-0.10, -0.09, 1.02); f(x)=-10.96; grad f(x)=(-0.45, -0.85, -0.61)
# iter=256; x=(-0.10, -0.09, 1.02); f(x)=-10.96; grad f(x)=(-0.45, -0.84, -0.61)
# iter=257; x=(-0.10, -0.09, 1.02); f(x)=-10.96; grad f(x)=(-0.45, -0.84, -0.60)
# iter=258; x=(-0.09, -0.09, 1.02); f(x)=-10.97; grad f(x)=(-0.45, -0.84, -0.60)
# iter=259; x=(-0.09, -0.09, 1.02); f(x)=-10.97; grad f(x)=(-0.45, -0.84, -0.60)
# iter=260; x=(-0.09, -0.09, 1.02); f(x)=-10.97; grad f(x)=(-0.45, -0.84, -0.60)
# iter=261; x=(-0.09, -0.08, 1.02); f(x)=-10.97; grad f(x)=(-0.45, -0.83, -0.59)
# iter=262; x=(-0.09, -0.08, 1.02); f(x)=-10.97; grad f(x)=(-0.45, -0.83, -0.59)
# iter=263; x=(-0.09, -0.08, 1.02); f(x)=-10.97; grad f(x)=(-0.45, -0.83, -0.59)
# iter=264; x=(-0.09, -0.08, 1.02); f(x)=-10.97; grad f(x)=(-0.45, -0.83, -0.59)
# iter=265; x=(-0.09, -0.08, 1.02); f(x)=-10.97; grad f(x)=(-0.45, -0.83, -0.59)
# iter=266; x=(-0.09, -0.08, 1.02); f(x)=-10.98; grad f(x)=(-0.46, -0.82, -0.58)
# iter=267; x=(-0.09, -0.08, 1.02); f(x)=-10.98; grad f(x)=(-0.46, -0.82, -0.58)
# iter=268; x=(-0.09, -0.08, 1.02); f(x)=-10.98; grad f(x)=(-0.46, -0.82, -0.58)
# iter=269; x=(-0.09, -0.08, 1.02); f(x)=-10.98; grad f(x)=(-0.46, -0.82, -0.58)
# iter=270; x=(-0.09, -0.08, 1.03); f(x)=-10.98; grad f(x)=(-0.46, -0.82, -0.58)
# iter=271; x=(-0.09, -0.08, 1.03); f(x)=-10.98; grad f(x)=(-0.46, -0.82, -0.57)
# iter=272; x=(-0.09, -0.08, 1.03); f(x)=-10.98; grad f(x)=(-0.46, -0.81, -0.57)
# iter=273; x=(-0.09, -0.07, 1.03); f(x)=-10.98; grad f(x)=(-0.46, -0.81, -0.57)
# iter=274; x=(-0.09, -0.07, 1.03); f(x)=-10.99; grad f(x)=(-0.46, -0.81, -0.57)
# iter=275; x=(-0.09, -0.07, 1.03); f(x)=-10.99; grad f(x)=(-0.46, -0.81, -0.57)
# iter=276; x=(-0.09, -0.07, 1.03); f(x)=-10.99; grad f(x)=(-0.46, -0.81, -0.56)
# iter=277; x=(-0.09, -0.07, 1.03); f(x)=-10.99; grad f(x)=(-0.46, -0.80, -0.56)
# iter=278; x=(-0.09, -0.07, 1.03); f(x)=-10.99; grad f(x)=(-0.46, -0.80, -0.56)
# iter=279; x=(-0.09, -0.07, 1.03); f(x)=-10.99; grad f(x)=(-0.46, -0.80, -0.56)
# iter=280; x=(-0.08, -0.07, 1.03); f(x)=-10.99; grad f(x)=(-0.46, -0.80, -0.56)
# iter=281; x=(-0.08, -0.07, 1.03); f(x)=-10.99; grad f(x)=(-0.46, -0.80, -0.55)
# iter=282; x=(-0.08, -0.07, 1.03); f(x)=-10.99; grad f(x)=(-0.46, -0.79, -0.55)
# iter=283; x=(-0.08, -0.07, 1.03); f(x)=-11.00; grad f(x)=(-0.46, -0.79, -0.55)
# iter=284; x=(-0.08, -0.07, 1.03); f(x)=-11.00; grad f(x)=(-0.46, -0.79, -0.55)
# iter=285; x=(-0.08, -0.07, 1.03); f(x)=-11.00; grad f(x)=(-0.46, -0.79, -0.55)
# iter=286; x=(-0.08, -0.06, 1.03); f(x)=-11.00; grad f(x)=(-0.46, -0.79, -0.55)
# iter=287; x=(-0.08, -0.06, 1.03); f(x)=-11.00; grad f(x)=(-0.46, -0.78, -0.54)
# iter=288; x=(-0.08, -0.06, 1.04); f(x)=-11.00; grad f(x)=(-0.46, -0.78, -0.54)
# iter=289; x=(-0.08, -0.06, 1.04); f(x)=-11.00; grad f(x)=(-0.46, -0.78, -0.54)
# iter=290; x=(-0.08, -0.06, 1.04); f(x)=-11.00; grad f(x)=(-0.47, -0.78, -0.54)
# iter=291; x=(-0.08, -0.06, 1.04); f(x)=-11.00; grad f(x)=(-0.47, -0.78, -0.54)
# iter=292; x=(-0.08, -0.06, 1.04); f(x)=-11.01; grad f(x)=(-0.47, -0.77, -0.54)
# iter=293; x=(-0.08, -0.06, 1.04); f(x)=-11.01; grad f(x)=(-0.47, -0.77, -0.53)
# iter=294; x=(-0.08, -0.06, 1.04); f(x)=-11.01; grad f(x)=(-0.47, -0.77, -0.53)
# iter=295; x=(-0.08, -0.06, 1.04); f(x)=-11.01; grad f(x)=(-0.47, -0.77, -0.53)
# iter=296; x=(-0.08, -0.06, 1.04); f(x)=-11.01; grad f(x)=(-0.47, -0.77, -0.53)
# iter=297; x=(-0.08, -0.06, 1.04); f(x)=-11.01; grad f(x)=(-0.47, -0.77, -0.53)
# iter=298; x=(-0.08, -0.05, 1.04); f(x)=-11.01; grad f(x)=(-0.47, -0.76, -0.53)
# iter=299; x=(-0.08, -0.05, 1.04); f(x)=-11.01; grad f(x)=(-0.47, -0.76, -0.53)
# iter=300; x=(-0.08, -0.05, 1.04); f(x)=-11.01; grad f(x)=(-0.47, -0.76, -0.52)
# iter=301; x=(-0.07, -0.05, 1.04); f(x)=-11.02; grad f(x)=(-0.47, -0.76, -0.52)
# iter=302; x=(-0.07, -0.05, 1.04); f(x)=-11.02; grad f(x)=(-0.47, -0.76, -0.52)
# iter=303; x=(-0.07, -0.05, 1.04); f(x)=-11.02; grad f(x)=(-0.47, -0.75, -0.52)
# iter=304; x=(-0.07, -0.05, 1.04); f(x)=-11.02; grad f(x)=(-0.47, -0.75, -0.52)
# iter=305; x=(-0.07, -0.05, 1.04); f(x)=-11.02; grad f(x)=(-0.47, -0.75, -0.52)
# iter=306; x=(-0.07, -0.05, 1.04); f(x)=-11.02; grad f(x)=(-0.47, -0.75, -0.51)
# iter=307; x=(-0.07, -0.05, 1.05); f(x)=-11.02; grad f(x)=(-0.47, -0.75, -0.51)
# iter=308; x=(-0.07, -0.05, 1.05); f(x)=-11.02; grad f(x)=(-0.47, -0.74, -0.51)
# iter=309; x=(-0.07, -0.05, 1.05); f(x)=-11.02; grad f(x)=(-0.47, -0.74, -0.51)
# iter=310; x=(-0.07, -0.05, 1.05); f(x)=-11.02; grad f(x)=(-0.47, -0.74, -0.51)
# iter=311; x=(-0.07, -0.05, 1.05); f(x)=-11.03; grad f(x)=(-0.47, -0.74, -0.51)
# iter=312; x=(-0.07, -0.04, 1.05); f(x)=-11.03; grad f(x)=(-0.47, -0.74, -0.51)
# iter=313; x=(-0.07, -0.04, 1.05); f(x)=-11.03; grad f(x)=(-0.47, -0.74, -0.51)
# iter=314; x=(-0.07, -0.04, 1.05); f(x)=-11.03; grad f(x)=(-0.47, -0.73, -0.50)
# iter=315; x=(-0.07, -0.04, 1.05); f(x)=-11.03; grad f(x)=(-0.47, -0.73, -0.50)
# iter=316; x=(-0.07, -0.04, 1.05); f(x)=-11.03; grad f(x)=(-0.47, -0.73, -0.50)
# iter=317; x=(-0.07, -0.04, 1.05); f(x)=-11.03; grad f(x)=(-0.47, -0.73, -0.50)
# iter=318; x=(-0.07, -0.04, 1.05); f(x)=-11.03; grad f(x)=(-0.47, -0.73, -0.50)
# iter=319; x=(-0.07, -0.04, 1.05); f(x)=-11.03; grad f(x)=(-0.47, -0.72, -0.50)
# iter=320; x=(-0.07, -0.04, 1.05); f(x)=-11.04; grad f(x)=(-0.47, -0.72, -0.50)
# iter=321; x=(-0.07, -0.04, 1.05); f(x)=-11.04; grad f(x)=(-0.47, -0.72, -0.49)
# iter=322; x=(-0.07, -0.04, 1.05); f(x)=-11.04; grad f(x)=(-0.47, -0.72, -0.49)
# iter=323; x=(-0.06, -0.04, 1.05); f(x)=-11.04; grad f(x)=(-0.47, -0.72, -0.49)
# iter=324; x=(-0.06, -0.04, 1.05); f(x)=-11.04; grad f(x)=(-0.47, -0.72, -0.49)
# iter=325; x=(-0.06, -0.03, 1.05); f(x)=-11.04; grad f(x)=(-0.47, -0.71, -0.49)
# iter=326; x=(-0.06, -0.03, 1.05); f(x)=-11.04; grad f(x)=(-0.47, -0.71, -0.49)
# iter=327; x=(-0.06, -0.03, 1.06); f(x)=-11.04; grad f(x)=(-0.47, -0.71, -0.49)
# iter=328; x=(-0.06, -0.03, 1.06); f(x)=-11.04; grad f(x)=(-0.47, -0.71, -0.49)
# iter=329; x=(-0.06, -0.03, 1.06); f(x)=-11.04; grad f(x)=(-0.47, -0.71, -0.49)
# iter=330; x=(-0.06, -0.03, 1.06); f(x)=-11.04; grad f(x)=(-0.47, -0.70, -0.48)
# iter=331; x=(-0.06, -0.03, 1.06); f(x)=-11.05; grad f(x)=(-0.47, -0.70, -0.48)
# iter=332; x=(-0.06, -0.03, 1.06); f(x)=-11.05; grad f(x)=(-0.47, -0.70, -0.48)
# iter=333; x=(-0.06, -0.03, 1.06); f(x)=-11.05; grad f(x)=(-0.47, -0.70, -0.48)
# iter=334; x=(-0.06, -0.03, 1.06); f(x)=-11.05; grad f(x)=(-0.47, -0.70, -0.48)
# iter=335; x=(-0.06, -0.03, 1.06); f(x)=-11.05; grad f(x)=(-0.47, -0.70, -0.48)
# iter=336; x=(-0.06, -0.03, 1.06); f(x)=-11.05; grad f(x)=(-0.47, -0.69, -0.48)
# iter=337; x=(-0.06, -0.03, 1.06); f(x)=-11.05; grad f(x)=(-0.47, -0.69, -0.48)
# iter=338; x=(-0.06, -0.03, 1.06); f(x)=-11.05; grad f(x)=(-0.47, -0.69, -0.47)
# iter=339; x=(-0.06, -0.03, 1.06); f(x)=-11.05; grad f(x)=(-0.47, -0.69, -0.47)
# iter=340; x=(-0.06, -0.02, 1.06); f(x)=-11.05; grad f(x)=(-0.47, -0.69, -0.47)
# iter=341; x=(-0.06, -0.02, 1.06); f(x)=-11.06; grad f(x)=(-0.47, -0.69, -0.47)
# iter=342; x=(-0.06, -0.02, 1.06); f(x)=-11.06; grad f(x)=(-0.47, -0.68, -0.47)
# iter=343; x=(-0.06, -0.02, 1.06); f(x)=-11.06; grad f(x)=(-0.47, -0.68, -0.47)
# iter=344; x=(-0.05, -0.02, 1.06); f(x)=-11.06; grad f(x)=(-0.47, -0.68, -0.47)
# iter=345; x=(-0.05, -0.02, 1.06); f(x)=-11.06; grad f(x)=(-0.47, -0.68, -0.47)
# iter=346; x=(-0.05, -0.02, 1.06); f(x)=-11.06; grad f(x)=(-0.47, -0.68, -0.47)
# iter=347; x=(-0.05, -0.02, 1.06); f(x)=-11.06; grad f(x)=(-0.47, -0.68, -0.46)
# iter=348; x=(-0.05, -0.02, 1.07); f(x)=-11.06; grad f(x)=(-0.47, -0.67, -0.46)
# iter=349; x=(-0.05, -0.02, 1.07); f(x)=-11.06; grad f(x)=(-0.47, -0.67, -0.46)
# iter=350; x=(-0.05, -0.02, 1.07); f(x)=-11.06; grad f(x)=(-0.47, -0.67, -0.46)
# iter=351; x=(-0.05, -0.02, 1.07); f(x)=-11.06; grad f(x)=(-0.47, -0.67, -0.46)
# iter=352; x=(-0.05, -0.02, 1.07); f(x)=-11.06; grad f(x)=(-0.47, -0.67, -0.46)
# iter=353; x=(-0.05, -0.02, 1.07); f(x)=-11.07; grad f(x)=(-0.47, -0.67, -0.46)
# iter=354; x=(-0.05, -0.02, 1.07); f(x)=-11.07; grad f(x)=(-0.47, -0.66, -0.46)
# iter=355; x=(-0.05, -0.01, 1.07); f(x)=-11.07; grad f(x)=(-0.47, -0.66, -0.46)
# iter=356; x=(-0.05, -0.01, 1.07); f(x)=-11.07; grad f(x)=(-0.47, -0.66, -0.46)
# iter=357; x=(-0.05, -0.01, 1.07); f(x)=-11.07; grad f(x)=(-0.47, -0.66, -0.45)
# iter=358; x=(-0.05, -0.01, 1.07); f(x)=-11.07; grad f(x)=(-0.47, -0.66, -0.45)
# iter=359; x=(-0.05, -0.01, 1.07); f(x)=-11.07; grad f(x)=(-0.47, -0.66, -0.45)
# iter=360; x=(-0.05, -0.01, 1.07); f(x)=-11.07; grad f(x)=(-0.47, -0.65, -0.45)
# iter=361; x=(-0.05, -0.01, 1.07); f(x)=-11.07; grad f(x)=(-0.47, -0.65, -0.45)
# iter=362; x=(-0.05, -0.01, 1.07); f(x)=-11.07; grad f(x)=(-0.47, -0.65, -0.45)
# iter=363; x=(-0.05, -0.01, 1.07); f(x)=-11.07; grad f(x)=(-0.47, -0.65, -0.45)
# iter=364; x=(-0.05, -0.01, 1.07); f(x)=-11.08; grad f(x)=(-0.47, -0.65, -0.45)
# iter=365; x=(-0.04, -0.01, 1.07); f(x)=-11.08; grad f(x)=(-0.47, -0.65, -0.45)
# iter=366; x=(-0.04, -0.01, 1.07); f(x)=-11.08; grad f(x)=(-0.47, -0.64, -0.45)
# iter=367; x=(-0.04, -0.01, 1.07); f(x)=-11.08; grad f(x)=(-0.47, -0.64, -0.44)
# iter=368; x=(-0.04, -0.01, 1.07); f(x)=-11.08; grad f(x)=(-0.47, -0.64, -0.44)
# iter=369; x=(-0.04, -0.01, 1.07); f(x)=-11.08; grad f(x)=(-0.47, -0.64, -0.44)
# iter=370; x=(-0.04, -0.00, 1.08); f(x)=-11.08; grad f(x)=(-0.47, -0.64, -0.44)
# iter=371; x=(-0.04, -0.00, 1.08); f(x)=-11.08; grad f(x)=(-0.47, -0.64, -0.44)
# iter=372; x=(-0.04, -0.00, 1.08); f(x)=-11.08; grad f(x)=(-0.47, -0.63, -0.44)
# iter=373; x=(-0.04, -0.00, 1.08); f(x)=-11.08; grad f(x)=(-0.47, -0.63, -0.44)
# iter=374; x=(-0.04, -0.00, 1.08); f(x)=-11.08; grad f(x)=(-0.47, -0.63, -0.44)
# iter=375; x=(-0.04, -0.00, 1.08); f(x)=-11.08; grad f(x)=(-0.47, -0.63, -0.44)
# iter=376; x=(-0.04, -0.00, 1.08); f(x)=-11.09; grad f(x)=(-0.47, -0.63, -0.44)
# iter=377; x=(-0.04, -0.00, 1.08); f(x)=-11.09; grad f(x)=(-0.47, -0.63, -0.43)
# iter=378; x=(-0.04, 0.00, 1.08); f(x)=-11.09; grad f(x)=(-0.47, -0.63, -0.43)
# iter=379; x=(-0.04, 0.00, 1.08); f(x)=-11.09; grad f(x)=(-0.47, -0.62, -0.43)
# iter=380; x=(-0.04, 0.00, 1.08); f(x)=-11.09; grad f(x)=(-0.47, -0.62, -0.43)
# iter=381; x=(-0.04, 0.00, 1.08); f(x)=-11.09; grad f(x)=(-0.47, -0.62, -0.43)
# iter=382; x=(-0.04, 0.00, 1.08); f(x)=-11.09; grad f(x)=(-0.47, -0.62, -0.43)
# iter=383; x=(-0.04, 0.00, 1.08); f(x)=-11.09; grad f(x)=(-0.47, -0.62, -0.43)
# iter=384; x=(-0.04, 0.00, 1.08); f(x)=-11.09; grad f(x)=(-0.47, -0.62, -0.43)
# iter=385; x=(-0.04, 0.00, 1.08); f(x)=-11.09; grad f(x)=(-0.47, -0.61, -0.43)
# iter=386; x=(-0.03, 0.01, 1.08); f(x)=-11.09; grad f(x)=(-0.47, -0.61, -0.43)
# iter=387; x=(-0.03, 0.01, 1.08); f(x)=-11.09; grad f(x)=(-0.47, -0.61, -0.43)
# iter=388; x=(-0.03, 0.01, 1.08); f(x)=-11.09; grad f(x)=(-0.47, -0.61, -0.42)
# iter=389; x=(-0.03, 0.01, 1.08); f(x)=-11.10; grad f(x)=(-0.47, -0.61, -0.42)
# iter=390; x=(-0.03, 0.01, 1.08); f(x)=-11.10; grad f(x)=(-0.47, -0.61, -0.42)
# iter=391; x=(-0.03, 0.01, 1.08); f(x)=-11.10; grad f(x)=(-0.47, -0.61, -0.42)
# iter=392; x=(-0.03, 0.01, 1.08); f(x)=-11.10; grad f(x)=(-0.47, -0.60, -0.42)
# iter=393; x=(-0.03, 0.01, 1.09); f(x)=-11.10; grad f(x)=(-0.47, -0.60, -0.42)
# iter=394; x=(-0.03, 0.01, 1.09); f(x)=-11.10; grad f(x)=(-0.47, -0.60, -0.42)
# iter=395; x=(-0.03, 0.01, 1.09); f(x)=-11.10; grad f(x)=(-0.47, -0.60, -0.42)
# iter=396; x=(-0.03, 0.01, 1.09); f(x)=-11.10; grad f(x)=(-0.47, -0.60, -0.42)
# iter=397; x=(-0.03, 0.01, 1.09); f(x)=-11.10; grad f(x)=(-0.47, -0.60, -0.42)
# iter=398; x=(-0.03, 0.01, 1.09); f(x)=-11.10; grad f(x)=(-0.47, -0.60, -0.42)
# iter=399; x=(-0.03, 0.01, 1.09); f(x)=-11.10; grad f(x)=(-0.47, -0.59, -0.41)
# iter=400; x=(-0.03, 0.01, 1.09); f(x)=-11.10; grad f(x)=(-0.47, -0.59, -0.41)
# iter=401; x=(-0.03, 0.01, 1.09); f(x)=-11.10; grad f(x)=(-0.47, -0.59, -0.41)
# iter=402; x=(-0.03, 0.02, 1.09); f(x)=-11.11; grad f(x)=(-0.47, -0.59, -0.41)
# iter=403; x=(-0.03, 0.02, 1.09); f(x)=-11.11; grad f(x)=(-0.46, -0.59, -0.41)
# iter=404; x=(-0.03, 0.02, 1.09); f(x)=-11.11; grad f(x)=(-0.46, -0.59, -0.41)
# iter=405; x=(-0.03, 0.02, 1.09); f(x)=-11.11; grad f(x)=(-0.46, -0.59, -0.41)
# iter=406; x=(-0.03, 0.02, 1.09); f(x)=-11.11; grad f(x)=(-0.46, -0.58, -0.41)
# iter=407; x=(-0.03, 0.02, 1.09); f(x)=-11.11; grad f(x)=(-0.46, -0.58, -0.41)
# iter=408; x=(-0.02, 0.02, 1.09); f(x)=-11.11; grad f(x)=(-0.46, -0.58, -0.41)
# iter=409; x=(-0.02, 0.02, 1.09); f(x)=-11.11; grad f(x)=(-0.46, -0.58, -0.41)
# iter=410; x=(-0.02, 0.02, 1.09); f(x)=-11.11; grad f(x)=(-0.46, -0.58, -0.41)
# iter=411; x=(-0.02, 0.02, 1.09); f(x)=-11.11; grad f(x)=(-0.46, -0.58, -0.40)
# iter=412; x=(-0.02, 0.02, 1.09); f(x)=-11.11; grad f(x)=(-0.46, -0.58, -0.40)
# iter=413; x=(-0.02, 0.02, 1.09); f(x)=-11.11; grad f(x)=(-0.46, -0.57, -0.40)
# iter=414; x=(-0.02, 0.02, 1.09); f(x)=-11.11; grad f(x)=(-0.46, -0.57, -0.40)
# iter=415; x=(-0.02, 0.02, 1.09); f(x)=-11.11; grad f(x)=(-0.46, -0.57, -0.40)
# iter=416; x=(-0.02, 0.02, 1.09); f(x)=-11.12; grad f(x)=(-0.46, -0.57, -0.40)
# iter=417; x=(-0.02, 0.02, 1.09); f(x)=-11.12; grad f(x)=(-0.46, -0.57, -0.40)
# iter=418; x=(-0.02, 0.02, 1.10); f(x)=-11.12; grad f(x)=(-0.46, -0.57, -0.40)
# iter=419; x=(-0.02, 0.02, 1.10); f(x)=-11.12; grad f(x)=(-0.46, -0.57, -0.40)
# iter=420; x=(-0.02, 0.03, 1.10); f(x)=-11.12; grad f(x)=(-0.46, -0.56, -0.40)
# iter=421; x=(-0.02, 0.03, 1.10); f(x)=-11.12; grad f(x)=(-0.46, -0.56, -0.40)
# iter=422; x=(-0.02, 0.03, 1.10); f(x)=-11.12; grad f(x)=(-0.46, -0.56, -0.40)
# iter=423; x=(-0.02, 0.03, 1.10); f(x)=-11.12; grad f(x)=(-0.46, -0.56, -0.40)
# iter=424; x=(-0.02, 0.03, 1.10); f(x)=-11.12; grad f(x)=(-0.46, -0.56, -0.39)
# iter=425; x=(-0.02, 0.03, 1.10); f(x)=-11.12; grad f(x)=(-0.46, -0.56, -0.39)
# iter=426; x=(-0.02, 0.03, 1.10); f(x)=-11.12; grad f(x)=(-0.46, -0.56, -0.39)
# iter=427; x=(-0.02, 0.03, 1.10); f(x)=-11.12; grad f(x)=(-0.46, -0.56, -0.39)
# iter=428; x=(-0.02, 0.03, 1.10); f(x)=-11.12; grad f(x)=(-0.46, -0.55, -0.39)
# iter=429; x=(-0.02, 0.03, 1.10); f(x)=-11.12; grad f(x)=(-0.46, -0.55, -0.39)
# iter=430; x=(-0.01, 0.03, 1.10); f(x)=-11.12; grad f(x)=(-0.46, -0.55, -0.39)
# iter=431; x=(-0.01, 0.03, 1.10); f(x)=-11.13; grad f(x)=(-0.46, -0.55, -0.39)
# iter=432; x=(-0.01, 0.03, 1.10); f(x)=-11.13; grad f(x)=(-0.46, -0.55, -0.39)
# iter=433; x=(-0.01, 0.03, 1.10); f(x)=-11.13; grad f(x)=(-0.46, -0.55, -0.39)
# iter=434; x=(-0.01, 0.03, 1.10); f(x)=-11.13; grad f(x)=(-0.46, -0.55, -0.39)
# iter=435; x=(-0.01, 0.03, 1.10); f(x)=-11.13; grad f(x)=(-0.46, -0.55, -0.39)
# iter=436; x=(-0.01, 0.03, 1.10); f(x)=-11.13; grad f(x)=(-0.46, -0.54, -0.39)
# iter=437; x=(-0.01, 0.03, 1.10); f(x)=-11.13; grad f(x)=(-0.46, -0.54, -0.38)
# iter=438; x=(-0.01, 0.04, 1.10); f(x)=-11.13; grad f(x)=(-0.46, -0.54, -0.38)
# iter=439; x=(-0.01, 0.04, 1.10); f(x)=-11.13; grad f(x)=(-0.46, -0.54, -0.38)
# iter=440; x=(-0.01, 0.04, 1.10); f(x)=-11.13; grad f(x)=(-0.46, -0.54, -0.38)
# iter=441; x=(-0.01, 0.04, 1.10); f(x)=-11.13; grad f(x)=(-0.46, -0.54, -0.38)
# iter=442; x=(-0.01, 0.04, 1.10); f(x)=-11.13; grad f(x)=(-0.45, -0.54, -0.38)
# iter=443; x=(-0.01, 0.04, 1.11); f(x)=-11.13; grad f(x)=(-0.45, -0.54, -0.38)
# iter=444; x=(-0.01, 0.04, 1.11); f(x)=-11.13; grad f(x)=(-0.45, -0.53, -0.38)
# iter=445; x=(-0.01, 0.04, 1.11); f(x)=-11.13; grad f(x)=(-0.45, -0.53, -0.38)
# iter=446; x=(-0.01, 0.04, 1.11); f(x)=-11.14; grad f(x)=(-0.45, -0.53, -0.38)
# iter=447; x=(-0.01, 0.04, 1.11); f(x)=-11.14; grad f(x)=(-0.45, -0.53, -0.38)
# iter=448; x=(-0.01, 0.04, 1.11); f(x)=-11.14; grad f(x)=(-0.45, -0.53, -0.38)
# iter=449; x=(-0.01, 0.04, 1.11); f(x)=-11.14; grad f(x)=(-0.45, -0.53, -0.38)
# iter=450; x=(-0.01, 0.04, 1.11); f(x)=-11.14; grad f(x)=(-0.45, -0.53, -0.37)
# iter=451; x=(-0.00, 0.04, 1.11); f(x)=-11.14; grad f(x)=(-0.45, -0.53, -0.37)
# iter=452; x=(-0.00, 0.04, 1.11); f(x)=-11.14; grad f(x)=(-0.45, -0.52, -0.37)
# iter=453; x=(-0.00, 0.04, 1.11); f(x)=-11.14; grad f(x)=(-0.45, -0.52, -0.37)
# iter=454; x=(-0.00, 0.04, 1.11); f(x)=-11.14; grad f(x)=(-0.45, -0.52, -0.37)
# iter=455; x=(-0.00, 0.04, 1.11); f(x)=-11.14; grad f(x)=(-0.45, -0.52, -0.37)
# iter=456; x=(-0.00, 0.04, 1.11); f(x)=-11.14; grad f(x)=(-0.45, -0.52, -0.37)
# iter=457; x=(-0.00, 0.05, 1.11); f(x)=-11.14; grad f(x)=(-0.45, -0.52, -0.37)
# iter=458; x=(-0.00, 0.05, 1.11); f(x)=-11.14; grad f(x)=(-0.45, -0.52, -0.37)
# iter=459; x=(-0.00, 0.05, 1.11); f(x)=-11.14; grad f(x)=(-0.45, -0.52, -0.37)
# iter=460; x=(-0.00, 0.05, 1.11); f(x)=-11.14; grad f(x)=(-0.45, -0.51, -0.37)
# iter=461; x=(-0.00, 0.05, 1.11); f(x)=-11.14; grad f(x)=(-0.45, -0.51, -0.37)
# iter=462; x=(-0.00, 0.05, 1.11); f(x)=-11.14; grad f(x)=(-0.45, -0.51, -0.37)
# iter=463; x=(0.00, 0.05, 1.11); f(x)=-11.15; grad f(x)=(-0.45, -0.51, -0.37)
# iter=464; x=(0.00, 0.05, 1.11); f(x)=-11.15; grad f(x)=(-0.45, -0.51, -0.36)
# iter=465; x=(0.00, 0.05, 1.11); f(x)=-11.15; grad f(x)=(-0.45, -0.51, -0.36)
# iter=466; x=(0.00, 0.05, 1.11); f(x)=-11.15; grad f(x)=(-0.45, -0.51, -0.36)
# iter=467; x=(0.00, 0.05, 1.11); f(x)=-11.15; grad f(x)=(-0.45, -0.51, -0.36)
# iter=468; x=(0.00, 0.05, 1.11); f(x)=-11.15; grad f(x)=(-0.45, -0.51, -0.36)
# iter=469; x=(0.00, 0.05, 1.11); f(x)=-11.15; grad f(x)=(-0.45, -0.50, -0.36)
# iter=470; x=(0.00, 0.05, 1.12); f(x)=-11.15; grad f(x)=(-0.45, -0.50, -0.36)
# iter=471; x=(0.00, 0.05, 1.12); f(x)=-11.15; grad f(x)=(-0.45, -0.50, -0.36)
# iter=472; x=(0.00, 0.05, 1.12); f(x)=-11.15; grad f(x)=(-0.45, -0.50, -0.36)
# iter=473; x=(0.00, 0.05, 1.12); f(x)=-11.15; grad f(x)=(-0.44, -0.50, -0.36)
# iter=474; x=(0.01, 0.05, 1.12); f(x)=-11.15; grad f(x)=(-0.44, -0.50, -0.36)
# iter=475; x=(0.01, 0.05, 1.12); f(x)=-11.15; grad f(x)=(-0.44, -0.50, -0.36)
# iter=476; x=(0.01, 0.06, 1.12); f(x)=-11.15; grad f(x)=(-0.44, -0.50, -0.36)
# iter=477; x=(0.01, 0.06, 1.12); f(x)=-11.15; grad f(x)=(-0.44, -0.50, -0.36)
# iter=478; x=(0.01, 0.06, 1.12); f(x)=-11.15; grad f(x)=(-0.44, -0.49, -0.36)
# iter=479; x=(0.01, 0.06, 1.12); f(x)=-11.15; grad f(x)=(-0.44, -0.49, -0.35)
# iter=480; x=(0.01, 0.06, 1.12); f(x)=-11.16; grad f(x)=(-0.44, -0.49, -0.35)
# iter=481; x=(0.01, 0.06, 1.12); f(x)=-11.16; grad f(x)=(-0.44, -0.49, -0.35)
# iter=482; x=(0.01, 0.06, 1.12); f(x)=-11.16; grad f(x)=(-0.44, -0.49, -0.35)
# iter=483; x=(0.01, 0.06, 1.12); f(x)=-11.16; grad f(x)=(-0.44, -0.49, -0.35)
# iter=484; x=(0.01, 0.06, 1.12); f(x)=-11.16; grad f(x)=(-0.44, -0.49, -0.35)
# iter=485; x=(0.01, 0.06, 1.12); f(x)=-11.16; grad f(x)=(-0.44, -0.49, -0.35)
# iter=486; x=(0.01, 0.06, 1.12); f(x)=-11.16; grad f(x)=(-0.44, -0.49, -0.35)
# iter=487; x=(0.01, 0.06, 1.12); f(x)=-11.16; grad f(x)=(-0.44, -0.48, -0.35)
# iter=488; x=(0.01, 0.06, 1.12); f(x)=-11.16; grad f(x)=(-0.44, -0.48, -0.35)
# iter=489; x=(0.01, 0.06, 1.12); f(x)=-11.16; grad f(x)=(-0.44, -0.48, -0.35)
# iter=490; x=(0.01, 0.06, 1.12); f(x)=-11.16; grad f(x)=(-0.44, -0.48, -0.35)
# iter=491; x=(0.01, 0.06, 1.12); f(x)=-11.16; grad f(x)=(-0.44, -0.48, -0.35)
# iter=492; x=(0.01, 0.06, 1.12); f(x)=-11.16; grad f(x)=(-0.44, -0.48, -0.35)
# iter=493; x=(0.01, 0.06, 1.12); f(x)=-11.16; grad f(x)=(-0.44, -0.48, -0.35)
# iter=494; x=(0.01, 0.06, 1.12); f(x)=-11.16; grad f(x)=(-0.44, -0.48, -0.34)
# iter=495; x=(0.01, 0.06, 1.12); f(x)=-11.16; grad f(x)=(-0.44, -0.48, -0.34)
# iter=496; x=(0.02, 0.06, 1.12); f(x)=-11.16; grad f(x)=(-0.44, -0.47, -0.34)
# iter=497; x=(0.02, 0.07, 1.12); f(x)=-11.16; grad f(x)=(-0.44, -0.47, -0.34)
# iter=498; x=(0.02, 0.07, 1.12); f(x)=-11.17; grad f(x)=(-0.44, -0.47, -0.34)
# iter=499; x=(0.02, 0.07, 1.13); f(x)=-11.17; grad f(x)=(-0.44, -0.47, -0.34)
# iter=500; x=(0.02, 0.07, 1.13); f(x)=-11.17; grad f(x)=(-0.44, -0.47, -0.34)
# iter=501; x=(0.02, 0.07, 1.13); f(x)=-11.17; grad f(x)=(-0.43, -0.47, -0.34)
# iter=502; x=(0.02, 0.07, 1.13); f(x)=-11.17; grad f(x)=(-0.43, -0.47, -0.34)
# iter=503; x=(0.02, 0.07, 1.13); f(x)=-11.17; grad f(x)=(-0.43, -0.47, -0.34)
# iter=504; x=(0.02, 0.07, 1.13); f(x)=-11.17; grad f(x)=(-0.43, -0.47, -0.34)
# iter=505; x=(0.02, 0.07, 1.13); f(x)=-11.17; grad f(x)=(-0.43, -0.47, -0.34)
# iter=506; x=(0.02, 0.07, 1.13); f(x)=-11.17; grad f(x)=(-0.43, -0.46, -0.34)
# iter=507; x=(0.02, 0.07, 1.13); f(x)=-11.17; grad f(x)=(-0.43, -0.46, -0.34)
# iter=508; x=(0.02, 0.07, 1.13); f(x)=-11.17; grad f(x)=(-0.43, -0.46, -0.34)
# iter=509; x=(0.02, 0.07, 1.13); f(x)=-11.17; grad f(x)=(-0.43, -0.46, -0.34)
# iter=510; x=(0.02, 0.07, 1.13); f(x)=-11.17; grad f(x)=(-0.43, -0.46, -0.33)
# iter=511; x=(0.02, 0.07, 1.13); f(x)=-11.17; grad f(x)=(-0.43, -0.46, -0.33)
# iter=512; x=(0.02, 0.07, 1.13); f(x)=-11.17; grad f(x)=(-0.43, -0.46, -0.33)
# iter=513; x=(0.02, 0.07, 1.13); f(x)=-11.17; grad f(x)=(-0.43, -0.46, -0.33)
# iter=514; x=(0.02, 0.07, 1.13); f(x)=-11.17; grad f(x)=(-0.43, -0.46, -0.33)
# iter=515; x=(0.02, 0.07, 1.13); f(x)=-11.17; grad f(x)=(-0.43, -0.46, -0.33)
# iter=516; x=(0.02, 0.07, 1.13); f(x)=-11.17; grad f(x)=(-0.43, -0.45, -0.33)
# iter=517; x=(0.02, 0.07, 1.13); f(x)=-11.18; grad f(x)=(-0.43, -0.45, -0.33)
# iter=518; x=(0.02, 0.08, 1.13); f(x)=-11.18; grad f(x)=(-0.43, -0.45, -0.33)
# iter=519; x=(0.02, 0.08, 1.13); f(x)=-11.18; grad f(x)=(-0.43, -0.45, -0.33)
# iter=520; x=(0.03, 0.08, 1.13); f(x)=-11.18; grad f(x)=(-0.43, -0.45, -0.33)
# iter=521; x=(0.03, 0.08, 1.13); f(x)=-11.18; grad f(x)=(-0.43, -0.45, -0.33)
# iter=522; x=(0.03, 0.08, 1.13); f(x)=-11.18; grad f(x)=(-0.43, -0.45, -0.33)
# iter=523; x=(0.03, 0.08, 1.13); f(x)=-11.18; grad f(x)=(-0.43, -0.45, -0.33)
# iter=524; x=(0.03, 0.08, 1.13); f(x)=-11.18; grad f(x)=(-0.43, -0.45, -0.33)
# iter=525; x=(0.03, 0.08, 1.13); f(x)=-11.18; grad f(x)=(-0.43, -0.45, -0.33)
# iter=526; x=(0.03, 0.08, 1.13); f(x)=-11.18; grad f(x)=(-0.43, -0.44, -0.33)
# iter=527; x=(0.03, 0.08, 1.13); f(x)=-11.18; grad f(x)=(-0.42, -0.44, -0.32)
# iter=528; x=(0.03, 0.08, 1.13); f(x)=-11.18; grad f(x)=(-0.42, -0.44, -0.32)
# iter=529; x=(0.03, 0.08, 1.14); f(x)=-11.18; grad f(x)=(-0.42, -0.44, -0.32)
# iter=530; x=(0.03, 0.08, 1.14); f(x)=-11.18; grad f(x)=(-0.42, -0.44, -0.32)
# iter=531; x=(0.03, 0.08, 1.14); f(x)=-11.18; grad f(x)=(-0.42, -0.44, -0.32)
# iter=532; x=(0.03, 0.08, 1.14); f(x)=-11.18; grad f(x)=(-0.42, -0.44, -0.32)
# iter=533; x=(0.03, 0.08, 1.14); f(x)=-11.18; grad f(x)=(-0.42, -0.44, -0.32)
# iter=534; x=(0.03, 0.08, 1.14); f(x)=-11.18; grad f(x)=(-0.42, -0.44, -0.32)
# iter=535; x=(0.03, 0.08, 1.14); f(x)=-11.18; grad f(x)=(-0.42, -0.44, -0.32)
# iter=536; x=(0.03, 0.08, 1.14); f(x)=-11.18; grad f(x)=(-0.42, -0.44, -0.32)
# iter=537; x=(0.03, 0.08, 1.14); f(x)=-11.18; grad f(x)=(-0.42, -0.43, -0.32)
# iter=538; x=(0.03, 0.08, 1.14); f(x)=-11.19; grad f(x)=(-0.42, -0.43, -0.32)
# iter=539; x=(0.03, 0.08, 1.14); f(x)=-11.19; grad f(x)=(-0.42, -0.43, -0.32)
# iter=540; x=(0.03, 0.08, 1.14); f(x)=-11.19; grad f(x)=(-0.42, -0.43, -0.32)
# iter=541; x=(0.03, 0.09, 1.14); f(x)=-11.19; grad f(x)=(-0.42, -0.43, -0.32)
# iter=542; x=(0.03, 0.09, 1.14); f(x)=-11.19; grad f(x)=(-0.42, -0.43, -0.32)
# iter=543; x=(0.04, 0.09, 1.14); f(x)=-11.19; grad f(x)=(-0.42, -0.43, -0.32)
# iter=544; x=(0.04, 0.09, 1.14); f(x)=-11.19; grad f(x)=(-0.42, -0.43, -0.31)
# iter=545; x=(0.04, 0.09, 1.14); f(x)=-11.19; grad f(x)=(-0.42, -0.43, -0.31)
# iter=546; x=(0.04, 0.09, 1.14); f(x)=-11.19; grad f(x)=(-0.42, -0.43, -0.31)
# iter=547; x=(0.04, 0.09, 1.14); f(x)=-11.19; grad f(x)=(-0.42, -0.43, -0.31)
# iter=548; x=(0.04, 0.09, 1.14); f(x)=-11.19; grad f(x)=(-0.42, -0.42, -0.31)
# iter=549; x=(0.04, 0.09, 1.14); f(x)=-11.19; grad f(x)=(-0.42, -0.42, -0.31)
# iter=550; x=(0.04, 0.09, 1.14); f(x)=-11.19; grad f(x)=(-0.42, -0.42, -0.31)
# iter=551; x=(0.04, 0.09, 1.14); f(x)=-11.19; grad f(x)=(-0.41, -0.42, -0.31)
# iter=552; x=(0.04, 0.09, 1.14); f(x)=-11.19; grad f(x)=(-0.41, -0.42, -0.31)
# iter=553; x=(0.04, 0.09, 1.14); f(x)=-11.19; grad f(x)=(-0.41, -0.42, -0.31)
# iter=554; x=(0.04, 0.09, 1.14); f(x)=-11.19; grad f(x)=(-0.41, -0.42, -0.31)
# iter=555; x=(0.04, 0.09, 1.14); f(x)=-11.19; grad f(x)=(-0.41, -0.42, -0.31)
# iter=556; x=(0.04, 0.09, 1.14); f(x)=-11.19; grad f(x)=(-0.41, -0.42, -0.31)
# iter=557; x=(0.04, 0.09, 1.14); f(x)=-11.19; grad f(x)=(-0.41, -0.42, -0.31)
# iter=558; x=(0.04, 0.09, 1.14); f(x)=-11.19; grad f(x)=(-0.41, -0.42, -0.31)
# iter=559; x=(0.04, 0.09, 1.14); f(x)=-11.19; grad f(x)=(-0.41, -0.41, -0.31)
# iter=560; x=(0.04, 0.09, 1.14); f(x)=-11.20; grad f(x)=(-0.41, -0.41, -0.31)
# iter=561; x=(0.04, 0.09, 1.15); f(x)=-11.20; grad f(x)=(-0.41, -0.41, -0.31)
# iter=562; x=(0.04, 0.09, 1.15); f(x)=-11.20; grad f(x)=(-0.41, -0.41, -0.30)
# iter=563; x=(0.04, 0.09, 1.15); f(x)=-11.20; grad f(x)=(-0.41, -0.41, -0.30)
# iter=564; x=(0.04, 0.09, 1.15); f(x)=-11.20; grad f(x)=(-0.41, -0.41, -0.30)
# iter=565; x=(0.04, 0.10, 1.15); f(x)=-11.20; grad f(x)=(-0.41, -0.41, -0.30)
# iter=566; x=(0.04, 0.10, 1.15); f(x)=-11.20; grad f(x)=(-0.41, -0.41, -0.30)
# iter=567; x=(0.05, 0.10, 1.15); f(x)=-11.20; grad f(x)=(-0.41, -0.41, -0.30)
# iter=568; x=(0.05, 0.10, 1.15); f(x)=-11.20; grad f(x)=(-0.41, -0.41, -0.30)
# iter=569; x=(0.05, 0.10, 1.15); f(x)=-11.20; grad f(x)=(-0.41, -0.41, -0.30)
# iter=570; x=(0.05, 0.10, 1.15); f(x)=-11.20; grad f(x)=(-0.41, -0.41, -0.30)
# iter=571; x=(0.05, 0.10, 1.15); f(x)=-11.20; grad f(x)=(-0.41, -0.40, -0.30)
# iter=572; x=(0.05, 0.10, 1.15); f(x)=-11.20; grad f(x)=(-0.41, -0.40, -0.30)
# iter=573; x=(0.05, 0.10, 1.15); f(x)=-11.20; grad f(x)=(-0.41, -0.40, -0.30)
# iter=574; x=(0.05, 0.10, 1.15); f(x)=-11.20; grad f(x)=(-0.41, -0.40, -0.30)
# iter=575; x=(0.05, 0.10, 1.15); f(x)=-11.20; grad f(x)=(-0.40, -0.40, -0.30)
# iter=576; x=(0.05, 0.10, 1.15); f(x)=-11.20; grad f(x)=(-0.40, -0.40, -0.30)
# iter=577; x=(0.05, 0.10, 1.15); f(x)=-11.20; grad f(x)=(-0.40, -0.40, -0.30)
# iter=578; x=(0.05, 0.10, 1.15); f(x)=-11.20; grad f(x)=(-0.40, -0.40, -0.30)
# iter=579; x=(0.05, 0.10, 1.15); f(x)=-11.20; grad f(x)=(-0.40, -0.40, -0.30)
# iter=580; x=(0.05, 0.10, 1.15); f(x)=-11.20; grad f(x)=(-0.40, -0.40, -0.29)
# iter=581; x=(0.05, 0.10, 1.15); f(x)=-11.20; grad f(x)=(-0.40, -0.40, -0.29)
# iter=582; x=(0.05, 0.10, 1.15); f(x)=-11.20; grad f(x)=(-0.40, -0.40, -0.29)
# iter=583; x=(0.05, 0.10, 1.15); f(x)=-11.20; grad f(x)=(-0.40, -0.39, -0.29)
# iter=584; x=(0.05, 0.10, 1.15); f(x)=-11.21; grad f(x)=(-0.40, -0.39, -0.29)
# iter=585; x=(0.05, 0.10, 1.15); f(x)=-11.21; grad f(x)=(-0.40, -0.39, -0.29)
# iter=586; x=(0.05, 0.10, 1.15); f(x)=-11.21; grad f(x)=(-0.40, -0.39, -0.29)
# iter=587; x=(0.05, 0.10, 1.15); f(x)=-11.21; grad f(x)=(-0.40, -0.39, -0.29)
# iter=588; x=(0.05, 0.10, 1.15); f(x)=-11.21; grad f(x)=(-0.40, -0.39, -0.29)
# iter=589; x=(0.05, 0.10, 1.15); f(x)=-11.21; grad f(x)=(-0.40, -0.39, -0.29)
# iter=590; x=(0.05, 0.11, 1.15); f(x)=-11.21; grad f(x)=(-0.40, -0.39, -0.29)
# iter=591; x=(0.05, 0.11, 1.15); f(x)=-11.21; grad f(x)=(-0.40, -0.39, -0.29)
# iter=592; x=(0.06, 0.11, 1.15); f(x)=-11.21; grad f(x)=(-0.40, -0.39, -0.29)
# iter=593; x=(0.06, 0.11, 1.15); f(x)=-11.21; grad f(x)=(-0.40, -0.39, -0.29)
# iter=594; x=(0.06, 0.11, 1.16); f(x)=-11.21; grad f(x)=(-0.40, -0.39, -0.29)
# iter=595; x=(0.06, 0.11, 1.16); f(x)=-11.21; grad f(x)=(-0.40, -0.38, -0.29)
# iter=596; x=(0.06, 0.11, 1.16); f(x)=-11.21; grad f(x)=(-0.40, -0.38, -0.29)
# iter=597; x=(0.06, 0.11, 1.16); f(x)=-11.21; grad f(x)=(-0.40, -0.38, -0.29)
# iter=598; x=(0.06, 0.11, 1.16); f(x)=-11.21; grad f(x)=(-0.39, -0.38, -0.29)
# iter=599; x=(0.06, 0.11, 1.16); f(x)=-11.21; grad f(x)=(-0.39, -0.38, -0.29)
# iter=600; x=(0.06, 0.11, 1.16); f(x)=-11.21; grad f(x)=(-0.39, -0.38, -0.28)
# iter=601; x=(0.06, 0.11, 1.16); f(x)=-11.21; grad f(x)=(-0.39, -0.38, -0.28)
# iter=602; x=(0.06, 0.11, 1.16); f(x)=-11.21; grad f(x)=(-0.39, -0.38, -0.28)
# iter=603; x=(0.06, 0.11, 1.16); f(x)=-11.21; grad f(x)=(-0.39, -0.38, -0.28)
# iter=604; x=(0.06, 0.11, 1.16); f(x)=-11.21; grad f(x)=(-0.39, -0.38, -0.28)
# iter=605; x=(0.06, 0.11, 1.16); f(x)=-11.21; grad f(x)=(-0.39, -0.38, -0.28)
# iter=606; x=(0.06, 0.11, 1.16); f(x)=-11.21; grad f(x)=(-0.39, -0.38, -0.28)
# iter=607; x=(0.06, 0.11, 1.16); f(x)=-11.21; grad f(x)=(-0.39, -0.38, -0.28)
# iter=608; x=(0.06, 0.11, 1.16); f(x)=-11.21; grad f(x)=(-0.39, -0.37, -0.28)
# iter=609; x=(0.06, 0.11, 1.16); f(x)=-11.21; grad f(x)=(-0.39, -0.37, -0.28)
# iter=610; x=(0.06, 0.11, 1.16); f(x)=-11.22; grad f(x)=(-0.39, -0.37, -0.28)
# iter=611; x=(0.06, 0.11, 1.16); f(x)=-11.22; grad f(x)=(-0.39, -0.37, -0.28)
# iter=612; x=(0.06, 0.11, 1.16); f(x)=-11.22; grad f(x)=(-0.39, -0.37, -0.28)
# iter=613; x=(0.06, 0.11, 1.16); f(x)=-11.22; grad f(x)=(-0.39, -0.37, -0.28)
# iter=614; x=(0.06, 0.11, 1.16); f(x)=-11.22; grad f(x)=(-0.39, -0.37, -0.28)
# iter=615; x=(0.06, 0.11, 1.16); f(x)=-11.22; grad f(x)=(-0.39, -0.37, -0.28)
# iter=616; x=(0.06, 0.12, 1.16); f(x)=-11.22; grad f(x)=(-0.39, -0.37, -0.28)
# ...
# iter=9797; x=(0.33, 0.33, 1.33); f(x)=-11.33; grad f(x)=(-0.00, -0.00, -0.00)
# iter=9798; x=(0.33, 0.33, 1.33); f(x)=-11.33; grad f(x)=(-0.00, -0.00, -0.00)
# iter=9799; x=(0.33, 0.33, 1.33); f(x)=-11.33; grad f(x)=(-0.00, -0.00, -0.00)
# iter=9800; x=(0.33, 0.33, 1.33); f(x)=-11.33; grad f(x)=(-0.00, -0.00, -0.00)
# iter=9801; x=(0.33, 0.33, 1.33); f(x)=-11.33; grad f(x)=(-0.00, -0.00, -0.00)
# iter=9802; x=(0.33, 0.33, 1.33); f(x)=-11.33; grad f(x)=(-0.00, -0.00, -0.00)
# iter=9803; x=(0.33, 0.33, 1.33); f(x)=-11.33; grad f(x)=(-0.00, -0.00, -0.00)
# iter=9804; x=(0.33, 0.33, 1.33); f(x)=-11.33; grad f(x)=(-0.00, -0.00, -0.00)
# iter=9805; x=(0.33, 0.33, 1.33); f(x)=-11.33; grad f(x)=(-0.00, -0.00, -0.00)
# iter=9806; x=(0.33, 0.33, 1.33); f(x)=-11.33; grad f(x)=(-0.00, -0.00, -0.00)
# iter=9807; x=(0.33, 0.33, 1.33); f(x)=-11.33; grad f(x)=(-0.00, -0.00, -0.00)
# iter=9808; x=(0.33, 0.33, 1.33); f(x)=-11.33; grad f(x)=(-0.00, -0.00, -0.00)
# iter=9809; x=(0.33, 0.33, 1.33); f(x)=-11.33; grad f(x)=(-0.00, -0.00, -0.00)
# iter=9810; x=(0.33, 0.33, 1.33); f(x)=-11.33; grad f(x)=(-0.00, -0.00, -0.00)
# iter=9811; x=(0.33, 0.33, 1.33); f(x)=-11.33; grad f(x)=(-0.00, -0.00, -0.00)
# iter=9812; x=(0.33, 0.33, 1.33); f(x)=-11.33; grad f(x)=(-0.00, -0.00, -0.00)
# iter=9813; x=(0.33, 0.33, 1.33); f(x)=-11.33; grad f(x)=(-0.00, -0.00, -0.00)
# iter=9814; x=(0.33, 0.33, 1.33); f(x)=-11.33; grad f(x)=(-0.00, -0.00, -0.00)
# iter=9815; x=(0.33, 0.33, 1.33); f(x)=-11.33; grad f(x)=(-0.00, -0.00, -0.00)
# iter=9816; x=(0.33, 0.33, 1.33); f(x)=-11.33; grad f(x)=(-0.00, -0.00, -0.00)
# iter=9817; x=(0.33, 0.33, 1.33); f(x)=-11.33; grad f(x)=(-0.00, -0.00, -0.00)
# iter=9818; x=(0.33, 0.33, 1.33); f(x)=-11.33; grad f(x)=(-0.00, -0.00, -0.00)
# iter=9819; x=(0.33, 0.33, 1.33); f(x)=-11.33; grad f(x)=(-0.00, -0.00, -0.00)
# iter=9820; x=(0.33, 0.33, 1.33); f(x)=-11.33; grad f(x)=(-0.00, -0.00, -0.00)
# iter=9821; x=(0.33, 0.33, 1.33); f(x)=-11.33; grad f(x)=(-0.00, -0.00, -0.00)
# iter=9822; x=(0.33, 0.33, 1.33); f(x)=-11.33; grad f(x)=(-0.00, -0.00, -0.00)
# iter=9823; x=(0.33, 0.33, 1.33); f(x)=-11.33; grad f(x)=(-0.00, -0.00, -0.00)
# iter=9824; x=(0.33, 0.33, 1.33); f(x)=-11.33; grad f(x)=(-0.00, -0.00, -0.00)
# iter=9825; x=(0.33, 0.33, 1.33); f(x)=-11.33; grad f(x)=(-0.00, -0.00, -0.00)
# iter=9826; x=(0.33, 0.33, 1.33); f(x)=-11.33; grad f(x)=(-0.00, -0.00, -0.00)
# iter=9827; x=(0.33, 0.33, 1.33); f(x)=-11.33; grad f(x)=(-0.00, -0.00, -0.00)
# iter=9828; x=(0.33, 0.33, 1.33); f(x)=-11.33; grad f(x)=(-0.00, -0.00, -0.00)
# iter=9829; x=(0.33, 0.33, 1.33); f(x)=-11.33; grad f(x)=(-0.00, -0.00, -0.00)
# iter=9830; x=(0.33, 0.33, 1.33); f(x)=-11.33; grad f(x)=(-0.00, -0.00, -0.00)
# iter=9831; x=(0.33, 0.33, 1.33); f(x)=-11.33; grad f(x)=(-0.00, -0.00, -0.00)
# iter=9832; x=(0.33, 0.33, 1.33); f(x)=-11.33; grad f(x)=(-0.00, -0.00, -0.00)
# iter=9833; x=(0.33, 0.33, 1.33); f(x)=-11.33; grad f(x)=(-0.00, -0.00, -0.00)
# iter=9834; x=(0.33, 0.33, 1.33); f(x)=-11.33; grad f(x)=(-0.00, -0.00, -0.00)
# iter=9835; x=(0.33, 0.33, 1.33); f(x)=-11.33; grad f(x)=(-0.00, -0.00, -0.00)
# iter=9836; x=(0.33, 0.33, 1.33); f(x)=-11.33; grad f(x)=(-0.00, -0.00, -0.00)
# iter=9837; x=(0.33, 0.33, 1.33); f(x)=-11.33; grad f(x)=(-0.00, -0.00, -0.00)
# iter=9838; x=(0.33, 0.33, 1.33); f(x)=-11.33; grad f(x)=(-0.00, -0.00, -0.00)
# iter=9839; x=(0.33, 0.33, 1.33); f(x)=-11.33; grad f(x)=(-0.00, -0.00, -0.00)
# iter=9840; x=(0.33, 0.33, 1.33); f(x)=-11.33; grad f(x)=(-0.00, -0.00, -0.00)
# iter=9841; x=(0.33, 0.33, 1.33); f(x)=-11.33; grad f(x)=(-0.00, -0.00, -0.00)
# iter=9842; x=(0.33, 0.33, 1.33); f(x)=-11.33; grad f(x)=(-0.00, -0.00, -0.00)
# iter=9843; x=(0.33, 0.33, 1.33); f(x)=-11.33; grad f(x)=(-0.00, -0.00, -0.00)
# iter=9844; x=(0.33, 0.33, 1.33); f(x)=-11.33; grad f(x)=(-0.00, -0.00, -0.00)
# iter=9845; x=(0.33, 0.33, 1.33); f(x)=-11.33; grad f(x)=(-0.00, -0.00, -0.00)
# iter=9846; x=(0.33, 0.33, 1.33); f(x)=-11.33; grad f(x)=(-0.00, -0.00, -0.00)
# iter=9847; x=(0.33, 0.33, 1.33); f(x)=-11.33; grad f(x)=(-0.00, -0.00, -0.00)
# iter=9848; x=(0.33, 0.33, 1.33); f(x)=-11.33; grad f(x)=(-0.00, -0.00, -0.00)
# iter=9849; x=(0.33, 0.33, 1.33); f(x)=-11.33; grad f(x)=(-0.00, -0.00, -0.00)
# iter=9850; x=(0.33, 0.33, 1.33); f(x)=-11.33; grad f(x)=(-0.00, -0.00, -0.00)
# iter=9851; x=(0.33, 0.33, 1.33); f(x)=-11.33; grad f(x)=(-0.00, -0.00, -0.00)
# iter=9852; x=(0.33, 0.33, 1.33); f(x)=-11.33; grad f(x)=(-0.00, -0.00, -0.00)
# iter=9853; x=(0.33, 0.33, 1.33); f(x)=-11.33; grad f(x)=(-0.00, -0.00, -0.00)
# iter=9854; x=(0.33, 0.33, 1.33); f(x)=-11.33; grad f(x)=(-0.00, -0.00, -0.00)
# iter=9855; x=(0.33, 0.33, 1.33); f(x)=-11.33; grad f(x)=(-0.00, -0.00, -0.00)
# iter=9856; x=(0.33, 0.33, 1.33); f(x)=-11.33; grad f(x)=(-0.00, -0.00, -0.00)
# iter=9857; x=(0.33, 0.33, 1.33); f(x)=-11.33; grad f(x)=(-0.00, -0.00, -0.00)
# iter=9858; x=(0.33, 0.33, 1.33); f(x)=-11.33; grad f(x)=(-0.00, -0.00, -0.00)
# iter=9859; x=(0.33, 0.33, 1.33); f(x)=-11.33; grad f(x)=(-0.00, -0.00, -0.00)
# iter=9860; x=(0.33, 0.33, 1.33); f(x)=-11.33; grad f(x)=(-0.00, -0.00, -0.00)
# iter=9861; x=(0.33, 0.33, 1.33); f(x)=-11.33; grad f(x)=(-0.00, -0.00, -0.00)
# iter=9862; x=(0.33, 0.33, 1.33); f(x)=-11.33; grad f(x)=(-0.00, -0.00, -0.00)
# iter=9863; x=(0.33, 0.33, 1.33); f(x)=-11.33; grad f(x)=(-0.00, -0.00, -0.00)
# iter=9864; x=(0.33, 0.33, 1.33); f(x)=-11.33; grad f(x)=(-0.00, -0.00, -0.00)
# iter=9865; x=(0.33, 0.33, 1.33); f(x)=-11.33; grad f(x)=(-0.00, -0.00, -0.00)
# iter=9866; x=(0.33, 0.33, 1.33); f(x)=-11.33; grad f(x)=(-0.00, -0.00, -0.00)
# iter=9867; x=(0.33, 0.33, 1.33); f(x)=-11.33; grad f(x)=(-0.00, -0.00, -0.00)
# iter=9868; x=(0.33, 0.33, 1.33); f(x)=-11.33; grad f(x)=(-0.00, -0.00, -0.00)
# iter=9869; x=(0.33, 0.33, 1.33); f(x)=-11.33; grad f(x)=(-0.00, -0.00, -0.00)
# iter=9870; x=(0.33, 0.33, 1.33); f(x)=-11.33; grad f(x)=(-0.00, -0.00, -0.00)
# iter=9871; x=(0.33, 0.33, 1.33); f(x)=-11.33; grad f(x)=(-0.00, -0.00, -0.00)
# iter=9872; x=(0.33, 0.33, 1.33); f(x)=-11.33; grad f(x)=(-0.00, -0.00, -0.00)
# iter=9873; x=(0.33, 0.33, 1.33); f(x)=-11.33; grad f(x)=(-0.00, -0.00, -0.00)
# iter=9874; x=(0.33, 0.33, 1.33); f(x)=-11.33; grad f(x)=(-0.00, -0.00, -0.00)
# iter=9875; x=(0.33, 0.33, 1.33); f(x)=-11.33; grad f(x)=(-0.00, -0.00, -0.00)
# iter=9876; x=(0.33, 0.33, 1.33); f(x)=-11.33; grad f(x)=(-0.00, -0.00, -0.00)
# iter=9877; x=(0.33, 0.33, 1.33); f(x)=-11.33; grad f(x)=(-0.00, -0.00, -0.00)
# iter=9878; x=(0.33, 0.33, 1.33); f(x)=-11.33; grad f(x)=(-0.00, -0.00, -0.00)
# iter=9879; x=(0.33, 0.33, 1.33); f(x)=-11.33; grad f(x)=(-0.00, -0.00, -0.00)
# iter=9880; x=(0.33, 0.33, 1.33); f(x)=-11.33; grad f(x)=(-0.00, -0.00, -0.00)
# iter=9881; x=(0.33, 0.33, 1.33); f(x)=-11.33; grad f(x)=(-0.00, -0.00, -0.00)
# iter=9882; x=(0.33, 0.33, 1.33); f(x)=-11.33; grad f(x)=(-0.00, -0.00, -0.00)
# iter=9883; x=(0.33, 0.33, 1.33); f(x)=-11.33; grad f(x)=(-0.00, -0.00, -0.00)
# iter=9884; x=(0.33, 0.33, 1.33); f(x)=-11.33; grad f(x)=(-0.00, -0.00, -0.00)
# iter=9885; x=(0.33, 0.33, 1.33); f(x)=-11.33; grad f(x)=(-0.00, -0.00, -0.00)
# iter=9886; x=(0.33, 0.33, 1.33); f(x)=-11.33; grad f(x)=(-0.00, -0.00, -0.00)
# iter=9887; x=(0.33, 0.33, 1.33); f(x)=-11.33; grad f(x)=(-0.00, -0.00, -0.00)
# iter=9888; x=(0.33, 0.33, 1.33); f(x)=-11.33; grad f(x)=(-0.00, -0.00, -0.00)
# iter=9889; x=(0.33, 0.33, 1.33); f(x)=-11.33; grad f(x)=(-0.00, -0.00, -0.00)
# iter=9890; x=(0.33, 0.33, 1.33); f(x)=-11.33; grad f(x)=(-0.00, -0.00, -0.00)
# iter=9891; x=(0.33, 0.33, 1.33); f(x)=-11.33; grad f(x)=(-0.00, -0.00, -0.00)
# iter=9892; x=(0.33, 0.33, 1.33); f(x)=-11.33; grad f(x)=(-0.00, -0.00, -0.00)
# iter=9893; x=(0.33, 0.33, 1.33); f(x)=-11.33; grad f(x)=(-0.00, -0.00, -0.00)
# iter=9894; x=(0.33, 0.33, 1.33); f(x)=-11.33; grad f(x)=(-0.00, -0.00, -0.00)
# iter=9895; x=(0.33, 0.33, 1.33); f(x)=-11.33; grad f(x)=(-0.00, -0.00, -0.00)
# iter=9896; x=(0.33, 0.33, 1.33); f(x)=-11.33; grad f(x)=(-0.00, -0.00, -0.00)
# iter=9897; x=(0.33, 0.33, 1.33); f(x)=-11.33; grad f(x)=(-0.00, -0.00, -0.00)
# iter=9898; x=(0.33, 0.33, 1.33); f(x)=-11.33; grad f(x)=(-0.00, -0.00, -0.00)
# iter=9899; x=(0.33, 0.33, 1.33); f(x)=-11.33; grad f(x)=(-0.00, -0.00, -0.00)
# iter=9900; x=(0.33, 0.33, 1.33); f(x)=-11.33; grad f(x)=(-0.00, -0.00, -0.00)
# iter=9901; x=(0.33, 0.33, 1.33); f(x)=-11.33; grad f(x)=(-0.00, -0.00, -0.00)
# iter=9902; x=(0.33, 0.33, 1.33); f(x)=-11.33; grad f(x)=(-0.00, -0.00, -0.00)
# iter=9903; x=(0.33, 0.33, 1.33); f(x)=-11.33; grad f(x)=(-0.00, -0.00, -0.00)
# iter=9904; x=(0.33, 0.33, 1.33); f(x)=-11.33; grad f(x)=(-0.00, -0.00, -0.00)
# iter=9905; x=(0.33, 0.33, 1.33); f(x)=-11.33; grad f(x)=(-0.00, -0.00, -0.00)
# iter=9906; x=(0.33, 0.33, 1.33); f(x)=-11.33; grad f(x)=(-0.00, -0.00, -0.00)
# iter=9907; x=(0.33, 0.33, 1.33); f(x)=-11.33; grad f(x)=(-0.00, -0.00, -0.00)
# iter=9908; x=(0.33, 0.33, 1.33); f(x)=-11.33; grad f(x)=(-0.00, -0.00, -0.00)
# iter=9909; x=(0.33, 0.33, 1.33); f(x)=-11.33; grad f(x)=(-0.00, -0.00, -0.00)
# iter=9910; x=(0.33, 0.33, 1.33); f(x)=-11.33; grad f(x)=(-0.00, -0.00, -0.00)
# iter=9911; x=(0.33, 0.33, 1.33); f(x)=-11.33; grad f(x)=(-0.00, -0.00, -0.00)
# iter=9912; x=(0.33, 0.33, 1.33); f(x)=-11.33; grad f(x)=(-0.00, -0.00, -0.00)
# iter=9913; x=(0.33, 0.33, 1.33); f(x)=-11.33; grad f(x)=(-0.00, -0.00, -0.00)
# iter=9914; x=(0.33, 0.33, 1.33); f(x)=-11.33; grad f(x)=(-0.00, -0.00, -0.00)
# iter=9915; x=(0.33, 0.33, 1.33); f(x)=-11.33; grad f(x)=(-0.00, -0.00, -0.00)
# iter=9916; x=(0.33, 0.33, 1.33); f(x)=-11.33; grad f(x)=(-0.00, -0.00, -0.00)
# iter=9917; x=(0.33, 0.33, 1.33); f(x)=-11.33; grad f(x)=(-0.00, -0.00, -0.00)
# iter=9918; x=(0.33, 0.33, 1.33); f(x)=-11.33; grad f(x)=(-0.00, -0.00, -0.00)
# iter=9919; x=(0.33, 0.33, 1.33); f(x)=-11.33; grad f(x)=(-0.00, -0.00, -0.00)
# iter=9920; x=(0.33, 0.33, 1.33); f(x)=-11.33; grad f(x)=(-0.00, -0.00, -0.00)
# iter=9921; x=(0.33, 0.33, 1.33); f(x)=-11.33; grad f(x)=(-0.00, -0.00, -0.00)
# iter=9922; x=(0.33, 0.33, 1.33); f(x)=-11.33; grad f(x)=(-0.00, -0.00, -0.00)
# iter=9923; x=(0.33, 0.33, 1.33); f(x)=-11.33; grad f(x)=(-0.00, -0.00, -0.00)
# iter=9924; x=(0.33, 0.33, 1.33); f(x)=-11.33; grad f(x)=(-0.00, -0.00, -0.00)
# iter=9925; x=(0.33, 0.33, 1.33); f(x)=-11.33; grad f(x)=(-0.00, -0.00, -0.00)
# iter=9926; x=(0.33, 0.33, 1.33); f(x)=-11.33; grad f(x)=(-0.00, -0.00, -0.00)
# iter=9927; x=(0.33, 0.33, 1.33); f(x)=-11.33; grad f(x)=(-0.00, -0.00, -0.00)
# iter=9928; x=(0.33, 0.33, 1.33); f(x)=-11.33; grad f(x)=(-0.00, -0.00, -0.00)
# iter=9929; x=(0.33, 0.33, 1.33); f(x)=-11.33; grad f(x)=(-0.00, -0.00, -0.00)
# iter=9930; x=(0.33, 0.33, 1.33); f(x)=-11.33; grad f(x)=(-0.00, -0.00, -0.00)
# iter=9931; x=(0.33, 0.33, 1.33); f(x)=-11.33; grad f(x)=(-0.00, -0.00, -0.00)
# iter=9932; x=(0.33, 0.33, 1.33); f(x)=-11.33; grad f(x)=(-0.00, -0.00, -0.00)
# iter=9933; x=(0.33, 0.33, 1.33); f(x)=-11.33; grad f(x)=(-0.00, -0.00, -0.00)
# iter=9934; x=(0.33, 0.33, 1.33); f(x)=-11.33; grad f(x)=(-0.00, -0.00, -0.00)
# iter=9935; x=(0.33, 0.33, 1.33); f(x)=-11.33; grad f(x)=(-0.00, -0.00, -0.00)
# iter=9936; x=(0.33, 0.33, 1.33); f(x)=-11.33; grad f(x)=(-0.00, -0.00, -0.00)
# iter=9937; x=(0.33, 0.33, 1.33); f(x)=-11.33; grad f(x)=(-0.00, -0.00, -0.00)
# iter=9938; x=(0.33, 0.33, 1.33); f(x)=-11.33; grad f(x)=(-0.00, -0.00, -0.00)
# iter=9939; x=(0.33, 0.33, 1.33); f(x)=-11.33; grad f(x)=(-0.00, -0.00, -0.00)
# iter=9940; x=(0.33, 0.33, 1.33); f(x)=-11.33; grad f(x)=(-0.00, -0.00, -0.00)
# iter=9941; x=(0.33, 0.33, 1.33); f(x)=-11.33; grad f(x)=(-0.00, -0.00, -0.00)
# iter=9942; x=(0.33, 0.33, 1.33); f(x)=-11.33; grad f(x)=(-0.00, -0.00, -0.00)
# iter=9943; x=(0.33, 0.33, 1.33); f(x)=-11.33; grad f(x)=(-0.00, -0.00, -0.00)
# iter=9944; x=(0.33, 0.33, 1.33); f(x)=-11.33; grad f(x)=(-0.00, -0.00, -0.00)
# iter=9945; x=(0.33, 0.33, 1.33); f(x)=-11.33; grad f(x)=(-0.00, -0.00, -0.00)
# iter=9946; x=(0.33, 0.33, 1.33); f(x)=-11.33; grad f(x)=(-0.00, -0.00, -0.00)
# iter=9947; x=(0.33, 0.33, 1.33); f(x)=-11.33; grad f(x)=(-0.00, -0.00, -0.00)
# iter=9948; x=(0.33, 0.33, 1.33); f(x)=-11.33; grad f(x)=(-0.00, -0.00, -0.00)
# iter=9949; x=(0.33, 0.33, 1.33); f(x)=-11.33; grad f(x)=(-0.00, -0.00, -0.00)
# iter=9950; x=(0.33, 0.33, 1.33); f(x)=-11.33; grad f(x)=(-0.00, -0.00, -0.00)
# iter=9951; x=(0.33, 0.33, 1.33); f(x)=-11.33; grad f(x)=(-0.00, -0.00, -0.00)
# iter=9952; x=(0.33, 0.33, 1.33); f(x)=-11.33; grad f(x)=(-0.00, -0.00, -0.00)
# iter=9953; x=(0.33, 0.33, 1.33); f(x)=-11.33; grad f(x)=(-0.00, -0.00, -0.00)
# iter=9954; x=(0.33, 0.33, 1.33); f(x)=-11.33; grad f(x)=(-0.00, -0.00, -0.00)
# iter=9955; x=(0.33, 0.33, 1.33); f(x)=-11.33; grad f(x)=(-0.00, -0.00, -0.00)
# iter=9956; x=(0.33, 0.33, 1.33); f(x)=-11.33; grad f(x)=(-0.00, -0.00, -0.00)
# iter=9957; x=(0.33, 0.33, 1.33); f(x)=-11.33; grad f(x)=(-0.00, -0.00, -0.00)
# iter=9958; x=(0.33, 0.33, 1.33); f(x)=-11.33; grad f(x)=(-0.00, -0.00, -0.00)
# iter=9959; x=(0.33, 0.33, 1.33); f(x)=-11.33; grad f(x)=(-0.00, -0.00, -0.00)
# iter=9960; x=(0.33, 0.33, 1.33); f(x)=-11.33; grad f(x)=(-0.00, -0.00, -0.00)
# iter=9961; x=(0.33, 0.33, 1.33); f(x)=-11.33; grad f(x)=(-0.00, -0.00, -0.00)
# iter=9962; x=(0.33, 0.33, 1.33); f(x)=-11.33; grad f(x)=(-0.00, -0.00, -0.00)
# iter=9963; x=(0.33, 0.33, 1.33); f(x)=-11.33; grad f(x)=(-0.00, -0.00, -0.00)
# iter=9964; x=(0.33, 0.33, 1.33); f(x)=-11.33; grad f(x)=(-0.00, -0.00, -0.00)
# iter=9965; x=(0.33, 0.33, 1.33); f(x)=-11.33; grad f(x)=(-0.00, -0.00, -0.00)
# iter=9966; x=(0.33, 0.33, 1.33); f(x)=-11.33; grad f(x)=(-0.00, -0.00, -0.00)
# iter=9967; x=(0.33, 0.33, 1.33); f(x)=-11.33; grad f(x)=(-0.00, -0.00, -0.00)
# iter=9968; x=(0.33, 0.33, 1.33); f(x)=-11.33; grad f(x)=(-0.00, -0.00, -0.00)
# iter=9969; x=(0.33, 0.33, 1.33); f(x)=-11.33; grad f(x)=(-0.00, -0.00, -0.00)
# iter=9970; x=(0.33, 0.33, 1.33); f(x)=-11.33; grad f(x)=(-0.00, -0.00, -0.00)
# iter=9971; x=(0.33, 0.33, 1.33); f(x)=-11.33; grad f(x)=(-0.00, -0.00, -0.00)
# iter=9972; x=(0.33, 0.33, 1.33); f(x)=-11.33; grad f(x)=(-0.00, -0.00, -0.00)
# iter=9973; x=(0.33, 0.33, 1.33); f(x)=-11.33; grad f(x)=(-0.00, -0.00, -0.00)
# iter=9974; x=(0.33, 0.33, 1.33); f(x)=-11.33; grad f(x)=(-0.00, -0.00, -0.00)
# iter=9975; x=(0.33, 0.33, 1.33); f(x)=-11.33; grad f(x)=(-0.00, -0.00, -0.00)
# iter=9976; x=(0.33, 0.33, 1.33); f(x)=-11.33; grad f(x)=(-0.00, -0.00, -0.00)
# iter=9977; x=(0.33, 0.33, 1.33); f(x)=-11.33; grad f(x)=(-0.00, -0.00, -0.00)
# iter=9978; x=(0.33, 0.33, 1.33); f(x)=-11.33; grad f(x)=(-0.00, -0.00, -0.00)
# iter=9979; x=(0.33, 0.33, 1.33); f(x)=-11.33; grad f(x)=(-0.00, -0.00, -0.00)
# iter=9980; x=(0.33, 0.33, 1.33); f(x)=-11.33; grad f(x)=(-0.00, -0.00, -0.00)
# iter=9981; x=(0.33, 0.33, 1.33); f(x)=-11.33; grad f(x)=(-0.00, -0.00, -0.00)
# iter=9982; x=(0.33, 0.33, 1.33); f(x)=-11.33; grad f(x)=(-0.00, -0.00, -0.00)
# iter=9983; x=(0.33, 0.33, 1.33); f(x)=-11.33; grad f(x)=(-0.00, -0.00, -0.00)
# iter=9984; x=(0.33, 0.33, 1.33); f(x)=-11.33; grad f(x)=(-0.00, -0.00, -0.00)
# iter=9985; x=(0.33, 0.33, 1.33); f(x)=-11.33; grad f(x)=(-0.00, -0.00, -0.00)
# iter=9986; x=(0.33, 0.33, 1.33); f(x)=-11.33; grad f(x)=(-0.00, -0.00, -0.00)
# iter=9987; x=(0.33, 0.33, 1.33); f(x)=-11.33; grad f(x)=(-0.00, -0.00, -0.00)
# iter=9988; x=(0.33, 0.33, 1.33); f(x)=-11.33; grad f(x)=(-0.00, -0.00, -0.00)
# iter=9989; x=(0.33, 0.33, 1.33); f(x)=-11.33; grad f(x)=(-0.00, -0.00, -0.00)
# iter=9990; x=(0.33, 0.33, 1.33); f(x)=-11.33; grad f(x)=(-0.00, -0.00, -0.00)
# iter=9991; x=(0.33, 0.33, 1.33); f(x)=-11.33; grad f(x)=(-0.00, -0.00, -0.00)
# iter=9992; x=(0.33, 0.33, 1.33); f(x)=-11.33; grad f(x)=(-0.00, -0.00, -0.00)
# iter=9993; x=(0.33, 0.33, 1.33); f(x)=-11.33; grad f(x)=(-0.00, -0.00, -0.00)
# iter=9994; x=(0.33, 0.33, 1.33); f(x)=-11.33; grad f(x)=(-0.00, -0.00, -0.00)
# iter=9995; x=(0.33, 0.33, 1.33); f(x)=-11.33; grad f(x)=(-0.00, -0.00, -0.00)
# iter=9996; x=(0.33, 0.33, 1.33); f(x)=-11.33; grad f(x)=(-0.00, -0.00, -0.00)
# iter=9997; x=(0.33, 0.33, 1.33); f(x)=-11.33; grad f(x)=(-0.00, -0.00, -0.00)
# iter=9998; x=(0.33, 0.33, 1.33); f(x)=-11.33; grad f(x)=(-0.00, -0.00, -0.00)
# iter=9999; x=(0.33, 0.33, 1.33); f(x)=-11.33; grad f(x)=(-0.00, -0.00, -0.00)
# iter=10000; x=(0.33, 0.33, 1.33); f(x)=-11.33; grad f(x)=(-0.00, -0.00, -0.00)
# iter=10001; x=(0.33, 0.33, 1.33); f(x)=-11.33; grad f(x)=(-0.00, -0.00, -0.00)

# %%
plt.plot(vals)

# %%
# по x: 4x - 4z + 4
# по y: 8y - 8z + 8
# по z: -4x - 8y + 18z -20
# Точка у нас: (1,2,-5)
# Тогда градиент: (28,64,-130)
# Пишу уравнение для x(n+1) = (1,2,-5) - 0.25 * (28,64,-130) + 1 * (1,2,-5),
# И результат не сходится с ответом (-5,-12,22.5)
def df(x,y,z):
    dx = 4*x - 4*z+4
    dy = 8*y-8*z +8
    dz = -4*x -8*y+18*z -20
    return np.array([dx,dy,dz])
x0 = np.array([0,0,0])
x1 = np.array([1,2,-5])
gam = 0.25
alf = 1
x2 = x1 - gam * df(*x1) + alf *(x1-x0)
display(df(*x1), x2)
# Out:
# array([  28,   64, -130])
# array([ -5. , -12. ,  22.5])
