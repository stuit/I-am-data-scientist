# %% [markdown]
# **Importing the Libraries**

# %%
import numpy as np
np.random.seed(42)

# %% [markdown]
# -------------------------------

# %% [markdown]
# **Nodes in each layer**

# %%
input_nodes = 5
hidden_1_nodes = 3
hidden_2_nodes = 5
output_nodes = 4

# %% [markdown]
# -------------------------

# %% [markdown]
# **Inputs and true outputs**

# %%
x = np.random.randint(1, 100, size = (input_nodes, 1)) / 100
x
# Out:
# array([[0.52],
#        [0.93],
#        [0.15],
#        [0.72],
#        [0.61]])

# %%
y = np.random.randint(1, 100, size = (output_nodes, 1)) / 100
y
# Out:
# array([[0.21],
#        [0.83],
#        [0.87],
#        [0.75]])

# %% [markdown]
# ------------------------------

# %% [markdown]
# **Defining Activation functions and loss with their derivatives**

# %% [markdown]
# Relu for first hidden layer

# %%
def relu(x, leak = 0):
    return np.where(x <= 0, leak * x, x)

# %%
def relu_dash(x, leak = 0):
    return np.where(x <= 0, leak, 1)

# %% [markdown]
# <br>

# %% [markdown]
# Sigmoid for second hidden layer and output layer

# %%
def sig(x):
    return 1/(1 + np.exp(-x))

# %%
def sig_dash(x):
    return sig(x) * (1 - sig(x))

# %% [markdown]
# <br>

# %% [markdown]
# Mean square loss

# %%
def mse(y_true, y_pred):
    return np.mean((y_true - y_pred)**2)

# %%
def mse_grad(y_true, y_pred):
    
    N = y_true.shape[0]
    
    return -2*(y_true - y_pred)/N

# %% [markdown]
# --------------------------------------------

# %% [markdown]
# **Random initialization of weights and biases**

# %%
w1 = np.random.random(size = (hidden_1_nodes, input_nodes))
b1 = np.zeros(shape = (hidden_1_nodes, 1))

print(w1, b1)
# Out:
# [[0.04666566 0.97375552 0.23277134 0.09060643 0.61838601]
#  [0.38246199 0.98323089 0.46676289 0.85994041 0.68030754]
#  [0.45049925 0.01326496 0.94220176 0.56328822 0.3854165 ]] [[0.]
#  [0.]
#  [0.]]

# %%
w2 = np.random.random(size = (hidden_2_nodes, hidden_1_nodes))
b2 = np.zeros(shape = (hidden_2_nodes, 1))

print(w2, b2)
# Out:
# [[0.01596625 0.23089383 0.24102547]
#  [0.68326352 0.60999666 0.83319491]
#  [0.17336465 0.39106061 0.18223609]
#  [0.75536141 0.42515587 0.20794166]
#  [0.56770033 0.03131329 0.84228477]] [[0.]
#  [0.]
#  [0.]
#  [0.]
#  [0.]]

# %%
w3 = np.random.random(size = (output_nodes, hidden_2_nodes))
b3 = np.zeros(shape = (output_nodes, 1))

print(w3, b3)
# Out:
# [[0.44975413 0.39515024 0.92665887 0.727272   0.32654077]
#  [0.57044397 0.52083426 0.96117202 0.84453385 0.74732011]
#  [0.53969213 0.58675117 0.96525531 0.60703425 0.27599918]
#  [0.29627351 0.16526694 0.01563641 0.42340148 0.39488152]] [[0.]
#  [0.]
#  [0.]
#  [0.]]

# %% [markdown]
# -----------------------------------

# %% [markdown]
# **Forward feed before training**

# %%
in_hidden_1 = w1.dot(x) + b1
out_hidden_1 = relu(in_hidden_1, leak = 0.1)

in_hidden_2 = w2.dot(out_hidden_1) + b2
out_hidden_2 = sig(in_hidden_2)

in_output_layer = w3.dot(out_hidden_2) + b3
y_hat = sig(in_output_layer)

y_hat
# Out:
# array([[0.91288614],
#        [0.95449609],
#        [0.92229189],
#        [0.74871256]])

# %%
y
# Out:
# array([[0.21],
#        [0.83],
#        [0.87],
#        [0.75]])

# %%
mse(y, y_hat)
# Out:
# 0.1280710759216072

# %% [markdown]
# ----------------------

# %% [markdown]
# **SGD**

# %%
learning_rate = 0.01

# %% [markdown]
# ------------------------

# %% [markdown]
# **Total number of epochs**

# %%
epochs = 10000

# %% [markdown]
# -------------------

# %% [markdown]
# **Backpropagation in ANNs**

# %%
for epoch in range(epochs):

#------------------------------------------Forward Propagation-------------------------------------------------
    
    in_hidden_1 = w1.dot(x) + b1
    out_hidden_1 = relu(in_hidden_1, leak = 0.1)

    in_hidden_2 = w2.dot(out_hidden_1) + b2
    out_hidden_2 = sig(in_hidden_2)

    in_output_layer = w3.dot(out_hidden_2) + b3
    y_hat = sig(in_output_layer)
    
    loss = mse(y, y_hat)
    print(f'loss before training is {loss} -- epoch number {epoch + 1}')
    print('\n')
    
#-----------------------------------------Gradient Calculations via Back Propagation---------------------------
    
    grad_w3 = mse_grad(y, y_hat) * sig_dash(in_output_layer) .dot( out_hidden_2.T )
    
    grad_b3 = mse_grad(y, y_hat) * sig_dash(in_output_layer)
    
    #-----------------------------------------
    
    error_grad_upto_H2 = np.sum(mse_grad(y, y_hat) * sig_dash(in_output_layer) * w3, axis = 0) .reshape((-1, 1))
    
    grad_w2 = error_grad_upto_H2 * sig_dash(in_hidden_2) .dot( out_hidden_1.T )
    
    grad_b2 = error_grad_upto_H2 * sig_dash(in_hidden_2)
    
    #-----------------------------------------
    
    error_grad_upto_H1 = np.sum(error_grad_upto_H2 * sig_dash(in_hidden_2) * w2, axis = 0) .reshape((-1, 1))
    
    grad_w1 = error_grad_upto_H1 * relu_dash(in_hidden_1, leak = 0.1) .dot( x.T )
    
    grad_b1 = error_grad_upto_H1 * relu_dash(in_hidden_1, leak = 0.1)
    
#-----------------------------------------Updating weights and biases with SGD---------------------------------

    update_w1 = - learning_rate * grad_w1
    w1 += update_w1
    
    update_b1 = - learning_rate * grad_b1
    b1 += update_b1
    
    update_w2 = - learning_rate * grad_w2
    w2 += update_w2
    
    update_b2 = - learning_rate * grad_b2
    b2 += update_b2
    
    update_w3 = - learning_rate * grad_w3
    w3 += update_w3
    
    update_b3 = - learning_rate * grad_b3
    b3 += update_b3
# Out:
# loss before training is 0.1280710759216072 -- epoch number 1
#
#
# loss before training is 0.1280298111486201 -- epoch number 2
#
#
# loss before training is 0.12798846929994118 -- epoch number 3
#
#
# loss before training is 0.12794705020473168 -- epoch number 4
#
#
# loss before training is 0.12790555369182613 -- epoch number 5
#
#
# loss before training is 0.1278639795897324 -- epoch number 6
#
#
# loss before training is 0.12782232772663207 -- epoch number 7
#
#
# loss before training is 0.12778059793038052 -- epoch number 8
#
#
# loss before training is 0.12773879002850724 -- epoch number 9
#
#
# loss before training is 0.12769690384821603 -- epoch number 10
#
#
# loss before training is 0.1276549392163852 -- epoch number 11
#
#
# loss before training is 0.12761289595956804 -- epoch number 12
#
#
# loss before training is 0.12757077390399263 -- epoch number 13
#
#
# loss before training is 0.12752857287556285 -- epoch number 14
#
#
# loss before training is 0.12748629269985778 -- epoch number 15
#
#
# loss before training is 0.12744393320213282 -- epoch number 16
#
#
# loss before training is 0.1274014942073195 -- epoch number 17
#
#
# loss before training is 0.1273589755400258 -- epoch number 18
#
#
# loss before training is 0.12731637702453683 -- epoch number 19
#
#
# loss before training is 0.12727369848481485 -- epoch number 20
#
#
# loss before training is 0.1272309397444997 -- epoch number 21
#
#
# loss before training is 0.12718810062690922 -- epoch number 22
#
#
# loss before training is 0.12714518095503963 -- epoch number 23
#
#
# loss before training is 0.12710218055156577 -- epoch number 24
#
#
# loss before training is 0.12705909923884162 -- epoch number 25
#
#
# loss before training is 0.12701593683890092 -- epoch number 26
#
#
# loss before training is 0.12697269317345689 -- epoch number 27
#
#
# loss before training is 0.1269293680639036 -- epoch number 28
#
#
# loss before training is 0.1268859613313155 -- epoch number 29
#
#
# loss before training is 0.12684247279644872 -- epoch number 30
#
#
# loss before training is 0.12679890227974075 -- epoch number 31
#
#
# loss before training is 0.12675524960131157 -- epoch number 32
#
#
# loss before training is 0.12671151458096366 -- epoch number 33
#
#
# loss before training is 0.1266676970381827 -- epoch number 34
#
#
# loss before training is 0.12662379679213823 -- epoch number 35
#
#
# loss before training is 0.12657981366168386 -- epoch number 36
#
#
# loss before training is 0.126535747465358 -- epoch number 37
#
#
# loss before training is 0.12649159802138446 -- epoch number 38
#
#
# loss before training is 0.12644736514767285 -- epoch number 39
#
#
# loss before training is 0.1264030486618191 -- epoch number 40
#
#
# loss before training is 0.1263586483811065 -- epoch number 41
#
#
# loss before training is 0.1263141641225056 -- epoch number 42
#
#
# loss before training is 0.12626959570267562 -- epoch number 43
#
#
# loss before training is 0.12622494293796424 -- epoch number 44
#
#
# loss before training is 0.12618020564440896 -- epoch number 45
#
#
# loss before training is 0.12613538363773727 -- epoch number 46
#
#
# loss before training is 0.12609047673336757 -- epoch number 47
#
#
# loss before training is 0.12604548474640975 -- epoch number 48
#
#
# loss before training is 0.12600040749166613 -- epoch number 49
#
#
# loss before training is 0.1259552447836315 -- epoch number 50
#
#
# loss before training is 0.12590999643649475 -- epoch number 51
#
#
# loss before training is 0.12586466226413884 -- epoch number 52
#
#
# loss before training is 0.12581924208014206 -- epoch number 53
#
#
# loss before training is 0.12577373569777844 -- epoch number 54
#
#
# loss before training is 0.12572814293001877 -- epoch number 55
#
#
# loss before training is 0.1256824635895314 -- epoch number 56
#
#
# loss before training is 0.12563669748868267 -- epoch number 57
#
#
# loss before training is 0.12559084443953833 -- epoch number 58
#
#
# loss before training is 0.12554490425386394 -- epoch number 59
#
#
# loss before training is 0.12549887674312585 -- epoch number 60
#
#
# loss before training is 0.1254527617184921 -- epoch number 61
#
#
# loss before training is 0.12540655899083325 -- epoch number 62
#
#
# loss before training is 0.12536026837072334 -- epoch number 63
#
#
# loss before training is 0.12531388966844062 -- epoch number 64
#
#
# loss before training is 0.12526742269396893 -- epoch number 65
#
#
# loss before training is 0.12522086725699808 -- epoch number 66
#
#
# loss before training is 0.1251742231669253 -- epoch number 67
#
#
# loss before training is 0.12512749023285574 -- epoch number 68
#
#
# loss before training is 0.12508066826360403 -- epoch number 69
#
#
# loss before training is 0.12503375706769468 -- epoch number 70
#
#
# loss before training is 0.12498675645336367 -- epoch number 71
#
#
# loss before training is 0.12493966622855922 -- epoch number 72
#
#
# loss before training is 0.12489248620094262 -- epoch number 73
#
#
# loss before training is 0.1248452161778899 -- epoch number 74
#
#
# loss before training is 0.12479785596649232 -- epoch number 75
#
#
# loss before training is 0.12475040537355797 -- epoch number 76
#
#
# loss before training is 0.12470286420561247 -- epoch number 77
#
#
# loss before training is 0.12465523226890049 -- epoch number 78
#
#
# loss before training is 0.12460750936938668 -- epoch number 79
#
#
# loss before training is 0.12455969531275697 -- epoch number 80
#
#
# loss before training is 0.12451178990441966 -- epoch number 81
#
#
# loss before training is 0.12446379294950675 -- epoch number 82
#
#
# loss before training is 0.1244157042528753 -- epoch number 83
#
#
# loss before training is 0.12436752361910808 -- epoch number 84
#
#
# loss before training is 0.12431925085251572 -- epoch number 85
#
#
# loss before training is 0.12427088575713745 -- epoch number 86
#
#
# loss before training is 0.1242224281367423 -- epoch number 87
#
#
# loss before training is 0.12417387779483105 -- epoch number 88
#
#
# loss before training is 0.12412523453463686 -- epoch number 89
#
#
# loss before training is 0.1240764981591271 -- epoch number 90
#
#
# loss before training is 0.12402766847100463 -- epoch number 91
#
#
# loss before training is 0.12397874527270905 -- epoch number 92
#
#
# loss before training is 0.12392972836641845 -- epoch number 93
#
#
# loss before training is 0.12388061755405048 -- epoch number 94
#
#
# loss before training is 0.12383141263726409 -- epoch number 95
#
#
# loss before training is 0.123782113417461 -- epoch number 96
#
#
# loss before training is 0.12373271969578688 -- epoch number 97
#
#
# loss before training is 0.12368323127313341 -- epoch number 98
#
#
# loss before training is 0.1236336479501395 -- epoch number 99
#
#
# loss before training is 0.12358396952719275 -- epoch number 100
#
#
# loss before training is 0.12353419580443127 -- epoch number 101
#
#
# loss before training is 0.12348432658174541 -- epoch number 102
#
#
# loss before training is 0.12343436165877886 -- epoch number 103
#
#
# loss before training is 0.12338430083493099 -- epoch number 104
#
#
# loss before training is 0.12333414390935786 -- epoch number 105
#
#
# loss before training is 0.12328389068097438 -- epoch number 106
#
#
# loss before training is 0.12323354094845594 -- epoch number 107
#
#
# loss before training is 0.12318309451023998 -- epoch number 108
#
#
# loss before training is 0.12313255116452801 -- epoch number 109
#
#
# loss before training is 0.1230819107092871 -- epoch number 110
#
#
# loss before training is 0.12303117294225188 -- epoch number 111
#
#
# loss before training is 0.12298033766092636 -- epoch number 112
#
#
# loss before training is 0.12292940466258566 -- epoch number 113
#
#
# loss before training is 0.12287837374427811 -- epoch number 114
#
#
# loss before training is 0.12282724470282678 -- epoch number 115
#
#
# loss before training is 0.12277601733483193 -- epoch number 116
#
#
# loss before training is 0.12272469143667249 -- epoch number 117
#
#
# loss before training is 0.12267326680450813 -- epoch number 118
#
#
# loss before training is 0.12262174323428139 -- epoch number 119
#
#
# loss before training is 0.12257012052171982 -- epoch number 120
#
#
# loss before training is 0.12251839846233736 -- epoch number 121
#
#
# loss before training is 0.12246657685143743 -- epoch number 122
#
#
# loss before training is 0.12241465548411395 -- epoch number 123
#
#
# loss before training is 0.12236263415525427 -- epoch number 124
#
#
# loss before training is 0.12231051265954095 -- epoch number 125
#
#
# loss before training is 0.12225829079145384 -- epoch number 126
#
#
# loss before training is 0.12220596834527266 -- epoch number 127
#
#
# loss before training is 0.12215354511507862 -- epoch number 128
#
#
# loss before training is 0.12210102089475737 -- epoch number 129
#
#
# loss before training is 0.12204839547800052 -- epoch number 130
#
#
# loss before training is 0.12199566865830862 -- epoch number 131
#
#
# loss before training is 0.12194284022899299 -- epoch number 132
#
#
# loss before training is 0.12188990998317827 -- epoch number 133
#
#
# loss before training is 0.12183687771380473 -- epoch number 134
#
#
# loss before training is 0.12178374321363082 -- epoch number 135
#
#
# loss before training is 0.12173050627523524 -- epoch number 136
#
#
# loss before training is 0.12167716669101976 -- epoch number 137
#
#
# loss before training is 0.12162372425321162 -- epoch number 138
#
#
# loss before training is 0.12157017875386585 -- epoch number 139
#
#
# loss before training is 0.1215165299848679 -- epoch number 140
#
#
# loss before training is 0.1214627777379364 -- epoch number 141
#
#
# loss before training is 0.1214089218046252 -- epoch number 142
#
#
# loss before training is 0.12135496197632685 -- epoch number 143
#
#
# loss before training is 0.12130089804427434 -- epoch number 144
#
#
# loss before training is 0.12124672979954437 -- epoch number 145
#
#
# loss before training is 0.12119245703305977 -- epoch number 146
#
#
# loss before training is 0.12113807953559236 -- epoch number 147
#
#
# loss before training is 0.12108359709776578 -- epoch number 148
#
#
# loss before training is 0.12102900951005799 -- epoch number 149
#
#
# loss before training is 0.12097431656280427 -- epoch number 150
#
#
# loss before training is 0.12091951804620024 -- epoch number 151
#
#
# loss before training is 0.12086461375030437 -- epoch number 152
#
#
# loss before training is 0.12080960346504112 -- epoch number 153
#
#
# loss before training is 0.12075448698020391 -- epoch number 154
#
#
# loss before training is 0.12069926408545792 -- epoch number 155
#
#
# loss before training is 0.12064393457034323 -- epoch number 156
#
#
# loss before training is 0.12058849822427774 -- epoch number 157
#
#
# loss before training is 0.12053295483656026 -- epoch number 158
#
#
# loss before training is 0.12047730419637377 -- epoch number 159
#
#
# loss before training is 0.12042154609278821 -- epoch number 160
#
#
# loss before training is 0.12036568031476387 -- epoch number 161
#
#
# loss before training is 0.12030970665115454 -- epoch number 162
#
#
# loss before training is 0.12025362489071077 -- epoch number 163
#
#
# loss before training is 0.12019743482208296 -- epoch number 164
#
#
# loss before training is 0.12014113623382477 -- epoch number 165
#
#
# loss before training is 0.12008472891439632 -- epoch number 166
#
#
# loss before training is 0.12002821265216775 -- epoch number 167
#
#
# loss before training is 0.1199715872354223 -- epoch number 168
#
#
# loss before training is 0.11991485245236004 -- epoch number 169
#
#
# loss before training is 0.1198580080911011 -- epoch number 170
#
#
# loss before training is 0.11980105393968912 -- epoch number 171
#
#
# loss before training is 0.11974398978609493 -- epoch number 172
#
#
# loss before training is 0.11968681541822 -- epoch number 173
#
#
# loss before training is 0.11962953062390003 -- epoch number 174
#
#
# loss before training is 0.11957213519090854 -- epoch number 175
#
#
# loss before training is 0.11951462890696057 -- epoch number 176
#
#
# loss before training is 0.11945701155971628 -- epoch number 177
#
#
# loss before training is 0.11939928293678488 -- epoch number 178
#
#
# loss before training is 0.11934144282572791 -- epoch number 179
#
#
# loss before training is 0.11928349101406378 -- epoch number 180
#
#
# loss before training is 0.11922542728927071 -- epoch number 181
#
#
# loss before training is 0.11916725143879146 -- epoch number 182
#
#
# loss before training is 0.11910896325003636 -- epoch number 183
#
#
# loss before training is 0.119050562510388 -- epoch number 184
#
#
# loss before training is 0.11899204900720482 -- epoch number 185
#
#
# loss before training is 0.11893342252782509 -- epoch number 186
#
#
# loss before training is 0.11887468285957101 -- epoch number 187
#
#
# loss before training is 0.11881582978975291 -- epoch number 188
#
#
# loss before training is 0.11875686310567332 -- epoch number 189
#
#
# loss before training is 0.11869778259463082 -- epoch number 190
#
#
# loss before training is 0.11863858804392474 -- epoch number 191
#
#
# loss before training is 0.11857927924085881 -- epoch number 192
#
#
# loss before training is 0.11851985597274606 -- epoch number 193
#
#
# loss before training is 0.11846031802691258 -- epoch number 194
#
#
# loss before training is 0.11840066519070212 -- epoch number 195
#
#
# loss before training is 0.11834089725148052 -- epoch number 196
#
#
# loss before training is 0.11828101399663997 -- epoch number 197
#
#
# loss before training is 0.11822101521360343 -- epoch number 198
#
#
# loss before training is 0.11816090068982922 -- epoch number 199
#
#
# loss before training is 0.11810067021281578 -- epoch number 200
#
#
# loss before training is 0.11804032357010587 -- epoch number 201
#
#
# loss before training is 0.11797986054929127 -- epoch number 202
#
#
# loss before training is 0.11791928093801766 -- epoch number 203
#
#
# loss before training is 0.11785858452398902 -- epoch number 204
#
#
# loss before training is 0.11779777109497258 -- epoch number 205
#
#
# loss before training is 0.11773684043880348 -- epoch number 206
#
#
# loss before training is 0.11767579234338955 -- epoch number 207
#
#
# loss before training is 0.11761462659671643 -- epoch number 208
#
#
# loss before training is 0.11755334298685201 -- epoch number 209
#
#
# loss before training is 0.11749194130195191 -- epoch number 210
#
#
# loss before training is 0.1174304213302639 -- epoch number 211
#
#
# loss before training is 0.11736878286013346 -- epoch number 212
#
#
# loss before training is 0.1173070256800084 -- epoch number 213
#
#
# loss before training is 0.11724514957844429 -- epoch number 214
#
#
# loss before training is 0.11718315434410935 -- epoch number 215
#
#
# loss before training is 0.11712103976578987 -- epoch number 216
#
#
# loss before training is 0.11705880563239526 -- epoch number 217
#
#
# loss before training is 0.11699645173296346 -- epoch number 218
#
#
# loss before training is 0.11693397785666615 -- epoch number 219
#
#
# loss before training is 0.11687138379281418 -- epoch number 220
#
#
# loss before training is 0.11680866933086313 -- epoch number 221
#
#
# loss before training is 0.1167458342604182 -- epoch number 222
#
#
# loss before training is 0.11668287837124047 -- epoch number 223
#
#
# loss before training is 0.11661980145325199 -- epoch number 224
#
#
# loss before training is 0.11655660329654129 -- epoch number 225
#
#
# loss before training is 0.1164932836913693 -- epoch number 226
#
#
# loss before training is 0.11642984242817485 -- epoch number 227
#
#
# loss before training is 0.11636627929758024 -- epoch number 228
#
#
# loss before training is 0.1163025940903975 -- epoch number 229
#
#
# loss before training is 0.1162387865976336 -- epoch number 230
#
#
# loss before training is 0.11617485661049673 -- epoch number 231
#
#
# loss before training is 0.11611080392040189 -- epoch number 232
#
#
# loss before training is 0.11604662831897725 -- epoch number 233
#
#
# loss before training is 0.11598232959806962 -- epoch number 234
#
#
# loss before training is 0.11591790754975076 -- epoch number 235
#
#
# loss before training is 0.1158533619663236 -- epoch number 236
#
#
# loss before training is 0.11578869264032811 -- epoch number 237
#
#
# loss before training is 0.11572389936454763 -- epoch number 238
#
#
# loss before training is 0.11565898193201504 -- epoch number 239
#
#
# loss before training is 0.11559394013601895 -- epoch number 240
#
#
# loss before training is 0.11552877377011016 -- epoch number 241
#
#
# loss before training is 0.11546348262810803 -- epoch number 242
#
#
# loss before training is 0.11539806650410668 -- epoch number 243
#
#
# loss before training is 0.1153325251924818 -- epoch number 244
#
#
# loss before training is 0.11526685848789674 -- epoch number 245
#
#
# loss before training is 0.11520106618530934 -- epoch number 246
#
#
# loss before training is 0.11513514807997874 -- epoch number 247
#
#
# loss before training is 0.11506910396747133 -- epoch number 248
#
#
# loss before training is 0.11500293364366823 -- epoch number 249
#
#
# loss before training is 0.11493663690477154 -- epoch number 250
#
#
# loss before training is 0.1148702135473114 -- epoch number 251
#
#
# loss before training is 0.11480366336815272 -- epoch number 252
#
#
# loss before training is 0.11473698616450208 -- epoch number 253
#
#
# loss before training is 0.11467018173391469 -- epoch number 254
#
#
# loss before training is 0.1146032498743015 -- epoch number 255
#
#
# loss before training is 0.11453619038393593 -- epoch number 256
#
#
# loss before training is 0.11446900306146152 -- epoch number 257
#
#
# loss before training is 0.11440168770589837 -- epoch number 258
#
#
# loss before training is 0.11433424411665111 -- epoch number 259
#
#
# loss before training is 0.11426667209351539 -- epoch number 260
#
#
# loss before training is 0.11419897143668586 -- epoch number 261
#
#
# loss before training is 0.11413114194676287 -- epoch number 262
#
#
# loss before training is 0.1140631834247605 -- epoch number 263
#
#
# loss before training is 0.1139950956721136 -- epoch number 264
#
#
# loss before training is 0.11392687849068549 -- epoch number 265
#
#
# loss before training is 0.11385853168277524 -- epoch number 266
#
#
# loss before training is 0.11379005505112574 -- epoch number 267
#
#
# loss before training is 0.1137214483989309 -- epoch number 268
#
#
# loss before training is 0.11365271152984369 -- epoch number 269
#
#
# loss before training is 0.11358384424798366 -- epoch number 270
#
#
# loss before training is 0.11351484635794504 -- epoch number 271
#
#
# loss before training is 0.11344571766480423 -- epoch number 272
#
#
# loss before training is 0.11337645797412797 -- epoch number 273
#
#
# loss before training is 0.11330706709198142 -- epoch number 274
#
#
# loss before training is 0.11323754482493578 -- epoch number 275
#
#
# loss before training is 0.11316789098007692 -- epoch number 276
#
#
# loss before training is 0.11309810536501293 -- epoch number 277
#
#
# loss before training is 0.1130281877878828 -- epoch number 278
#
#
# loss before training is 0.11295813805736422 -- epoch number 279
#
#
# loss before training is 0.11288795598268236 -- epoch number 280
#
#
# loss before training is 0.11281764137361774 -- epoch number 281
#
#
# loss before training is 0.11274719404051481 -- epoch number 282
#
#
# loss before training is 0.11267661379429059 -- epoch number 283
#
#
# loss before training is 0.11260590044644284 -- epoch number 284
#
#
# loss before training is 0.11253505380905887 -- epoch number 285
#
#
# loss before training is 0.11246407369482411 -- epoch number 286
#
#
# loss before training is 0.1123929599170306 -- epoch number 287
#
#
# loss before training is 0.11232171228958586 -- epoch number 288
#
#
# loss before training is 0.11225033062702176 -- epoch number 289
#
#
# loss before training is 0.11217881474450313 -- epoch number 290
#
#
# loss before training is 0.1121071644578367 -- epoch number 291
#
#
# loss before training is 0.11203537958348023 -- epoch number 292
#
#
# loss before training is 0.11196345993855113 -- epoch number 293
#
#
# loss before training is 0.11189140534083594 -- epoch number 294
#
#
# loss before training is 0.11181921560879919 -- epoch number 295
#
#
# loss before training is 0.1117468905615923 -- epoch number 296
#
#
# loss before training is 0.11167443001906348 -- epoch number 297
#
#
# loss before training is 0.11160183380176626 -- epoch number 298
#
#
# loss before training is 0.11152910173096929 -- epoch number 299
#
#
# loss before training is 0.11145623362866545 -- epoch number 300
#
#
# loss before training is 0.11138322931758153 -- epoch number 301
#
#
# loss before training is 0.11131008862118738 -- epoch number 302
#
#
# loss before training is 0.11123681136370582 -- epoch number 303
#
#
# loss before training is 0.11116339737012186 -- epoch number 304
#
#
# loss before training is 0.11108984646619266 -- epoch number 305
#
#
# loss before training is 0.11101615847845708 -- epoch number 306
#
#
# loss before training is 0.11094233323424552 -- epoch number 307
#
#
# loss before training is 0.11086837056168952 -- epoch number 308
#
#
# loss before training is 0.11079427028973196 -- epoch number 309
#
#
# loss before training is 0.11072003224813667 -- epoch number 310
#
#
# loss before training is 0.11064565626749877 -- epoch number 311
#
#
# loss before training is 0.11057114217925419 -- epoch number 312
#
#
# loss before training is 0.11049648981569032 -- epoch number 313
#
#
# loss before training is 0.11042169900995567 -- epoch number 314
#
#
# loss before training is 0.11034676959607055 -- epoch number 315
#
#
# loss before training is 0.11027170140893683 -- epoch number 316
#
#
# loss before training is 0.11019649428434854 -- epoch number 317
#
#
# loss before training is 0.11012114805900225 -- epoch number 318
#
#
# loss before training is 0.11004566257050738 -- epoch number 319
#
#
# loss before training is 0.10997003765739678 -- epoch number 320
#
#
# loss before training is 0.10989427315913704 -- epoch number 321
#
#
# loss before training is 0.10981836891613933 -- epoch number 322
#
#
# loss before training is 0.10974232476976996 -- epoch number 323
#
#
# loss before training is 0.10966614056236104 -- epoch number 324
#
#
# loss before training is 0.10958981613722123 -- epoch number 325
#
#
# loss before training is 0.10951335133864651 -- epoch number 326
#
#
# loss before training is 0.10943674601193118 -- epoch number 327
#
#
# loss before training is 0.10936000000337857 -- epoch number 328
#
#
# loss before training is 0.10928311316031224 -- epoch number 329
#
#
# loss before training is 0.10920608533108675 -- epoch number 330
#
#
# loss before training is 0.10912891636509897 -- epoch number 331
#
#
# loss before training is 0.10905160611279915 -- epoch number 332
#
#
# loss before training is 0.10897415442570185 -- epoch number 333
#
#
# loss before training is 0.10889656115639755 -- epoch number 334
#
#
# loss before training is 0.10881882615856377 -- epoch number 335
#
#
# loss before training is 0.10874094928697635 -- epoch number 336
#
#
# loss before training is 0.10866293039752108 -- epoch number 337
#
#
# loss before training is 0.1085847693472048 -- epoch number 338
#
#
# loss before training is 0.10850646599416726 -- epoch number 339
#
#
# loss before training is 0.10842802019769247 -- epoch number 340
#
#
# loss before training is 0.10834943181822036 -- epoch number 341
#
#
# loss before training is 0.1082707007173585 -- epoch number 342
#
#
# loss before training is 0.10819182675789366 -- epoch number 343
#
#
# loss before training is 0.1081128098038039 -- epoch number 344
#
#
# loss before training is 0.10803364972026995 -- epoch number 345
#
#
# loss before training is 0.1079543463736875 -- epoch number 346
#
#
# loss before training is 0.10787489963167893 -- epoch number 347
#
#
# loss before training is 0.10779530936310512 -- epoch number 348
#
#
# loss before training is 0.10771557543807804 -- epoch number 349
#
#
# loss before training is 0.1076356977279721 -- epoch number 350
#
#
# loss before training is 0.10755567610543686 -- epoch number 351
#
#
# loss before training is 0.10747551044440895 -- epoch number 352
#
#
# loss before training is 0.1073952006201243 -- epoch number 353
#
#
# loss before training is 0.10731474650913053 -- epoch number 354
#
#
# loss before training is 0.10723414798929937 -- epoch number 355
#
#
# loss before training is 0.10715340493983862 -- epoch number 356
#
#
# loss before training is 0.10707251724130518 -- epoch number 357
#
#
# loss before training is 0.10699148477561711 -- epoch number 358
#
#
# loss before training is 0.1069103074260663 -- epoch number 359
#
#
# loss before training is 0.10682898507733103 -- epoch number 360
#
#
# loss before training is 0.10674751761548859 -- epoch number 361
#
#
# loss before training is 0.10666590492802813 -- epoch number 362
#
#
# loss before training is 0.1065841469038632 -- epoch number 363
#
#
# loss before training is 0.10650224343334447 -- epoch number 364
#
#
# loss before training is 0.10642019440827268 -- epoch number 365
#
#
# loss before training is 0.10633799972191164 -- epoch number 366
#
#
# loss before training is 0.10625565926900088 -- epoch number 367
#
#
# loss before training is 0.10617317294576874 -- epoch number 368
#
#
# loss before training is 0.10609054064994534 -- epoch number 369
#
#
# loss before training is 0.10600776228077581 -- epoch number 370
#
#
# loss before training is 0.10592483773903312 -- epoch number 371
#
#
# loss before training is 0.10584176692703141 -- epoch number 372
#
#
# loss before training is 0.10575854974863916 -- epoch number 373
#
#
# loss before training is 0.10567518610929225 -- epoch number 374
#
#
# loss before training is 0.10559167591600756 -- epoch number 375
#
#
# loss before training is 0.10550801907739597 -- epoch number 376
#
#
# loss before training is 0.10542421550367602 -- epoch number 377
#
#
# loss before training is 0.10534026510668706 -- epoch number 378
#
#
# loss before training is 0.10525616779990288 -- epoch number 379
#
#
# loss before training is 0.10517192349844512 -- epoch number 380
#
#
# loss before training is 0.1050875321190966 -- epoch number 381
#
#
# loss before training is 0.10500299358031552 -- epoch number 382
#
#
# loss before training is 0.10491830780224828 -- epoch number 383
#
#
# loss before training is 0.10483347470674377 -- epoch number 384
#
#
# loss before training is 0.10474849421736661 -- epoch number 385
#
#
# loss before training is 0.10466336625941118 -- epoch number 386
#
#
# loss before training is 0.10457809075991539 -- epoch number 387
#
#
# loss before training is 0.10449266764767429 -- epoch number 388
#
#
# loss before training is 0.10440709685325382 -- epoch number 389
#
#
# loss before training is 0.10432137830900527 -- epoch number 390
#
#
# loss before training is 0.1042355119490785 -- epoch number 391
#
#
# loss before training is 0.10414949770943639 -- epoch number 392
#
#
# loss before training is 0.10406333552786856 -- epoch number 393
#
#
# loss before training is 0.1039770253440055 -- epoch number 394
#
#
# loss before training is 0.1038905670993326 -- epoch number 395
#
#
# loss before training is 0.10380396073720424 -- epoch number 396
#
#
# loss before training is 0.10371720620285795 -- epoch number 397
#
#
# loss before training is 0.10363030344342856 -- epoch number 398
#
#
# loss before training is 0.10354325240796229 -- epoch number 399
#
#
# loss before training is 0.10345605304743102 -- epoch number 400
#
#
# loss before training is 0.10336870531474668 -- epoch number 401
#
#
# loss before training is 0.10328120916477528 -- epoch number 402
#
#
# loss before training is 0.10319356455435147 -- epoch number 403
#
#
# loss before training is 0.10310577144229267 -- epoch number 404
#
#
# loss before training is 0.10301782978941351 -- epoch number 405
#
#
# loss before training is 0.1029297395585402 -- epoch number 406
#
#
# loss before training is 0.10284150071452502 -- epoch number 407
#
#
# loss before training is 0.1027531132242607 -- epoch number 408
#
#
# loss before training is 0.10266457705669478 -- epoch number 409
#
#
# loss before training is 0.10257589218284434 -- epoch number 410
#
#
# loss before training is 0.1024870585758104 -- epoch number 411
#
#
# loss before training is 0.10239807621079226 -- epoch number 412
#
#
# loss before training is 0.1023089450651023 -- epoch number 413
#
#
# loss before training is 0.10221966511818074 -- epoch number 414
#
#
# loss before training is 0.10213023635160953 -- epoch number 415
#
#
# loss before training is 0.10204065874912786 -- epoch number 416
#
#
# loss before training is 0.10195093229664612 -- epoch number 417
#
#
# loss before training is 0.10186105698226075 -- epoch number 418
#
#
# loss before training is 0.10177103279626909 -- epoch number 419
#
#
# loss before training is 0.10168085973118395 -- epoch number 420
#
#
# loss before training is 0.10159053778174817 -- epoch number 421
#
#
# loss before training is 0.10150006694494945 -- epoch number 422
#
#
# loss before training is 0.10140944722003517 -- epoch number 423
#
#
# loss before training is 0.10131867860852706 -- epoch number 424
#
#
# loss before training is 0.10122776111423583 -- epoch number 425
#
#
# loss before training is 0.10113669474327609 -- epoch number 426
#
#
# loss before training is 0.10104547950408106 -- epoch number 427
#
#
# loss before training is 0.10095411540741743 -- epoch number 428
#
#
# loss before training is 0.10086260246640005 -- epoch number 429
#
#
# loss before training is 0.10077094069650665 -- epoch number 430
#
#
# loss before training is 0.10067913011559287 -- epoch number 431
#
#
# loss before training is 0.10058717074390705 -- epoch number 432
#
#
# loss before training is 0.10049506260410473 -- epoch number 433
#
#
# loss before training is 0.10040280572126381 -- epoch number 434
#
#
# loss before training is 0.10031040012289924 -- epoch number 435
#
#
# loss before training is 0.10021784583897775 -- epoch number 436
#
#
# loss before training is 0.10012514290193285 -- epoch number 437
#
#
# loss before training is 0.10003229134667944 -- epoch number 438
#
#
# loss before training is 0.09993929121062886 -- epoch number 439
#
#
# loss before training is 0.09984614253370346 -- epoch number 440
#
#
# loss before training is 0.09975284535835165 -- epoch number 441
#
#
# loss before training is 0.09965939972956248 -- epoch number 442
#
#
# loss before training is 0.09956580569488048 -- epoch number 443
#
#
# loss before training is 0.09947206330442072 -- epoch number 444
#
#
# loss before training is 0.09937817261088305 -- epoch number 445
#
#
# loss before training is 0.0992841336695675 -- epoch number 446
#
#
# loss before training is 0.09918994653838847 -- epoch number 447
#
#
# loss before training is 0.09909561127788989 -- epoch number 448
#
#
# loss before training is 0.09900112795125977 -- epoch number 449
#
#
# loss before training is 0.09890649662434485 -- epoch number 450
#
#
# loss before training is 0.09881171736566542 -- epoch number 451
#
#
# loss before training is 0.09871679024643013 -- epoch number 452
#
#
# loss before training is 0.0986217153405503 -- epoch number 453
#
#
# loss before training is 0.09852649272465487 -- epoch number 454
#
#
# loss before training is 0.09843112247810491 -- epoch number 455
#
#
# loss before training is 0.0983356046830083 -- epoch number 456
#
#
# loss before training is 0.09823993942423417 -- epoch number 457
#
#
# loss before training is 0.09814412678942763 -- epoch number 458
#
#
# loss before training is 0.09804816686902414 -- epoch number 459
#
#
# loss before training is 0.09795205975626409 -- epoch number 460
#
#
# loss before training is 0.09785580554720738 -- epoch number 461
#
#
# loss before training is 0.09775940434074769 -- epoch number 462
#
#
# loss before training is 0.09766285623862701 -- epoch number 463
#
#
# loss before training is 0.09756616134544999 -- epoch number 464
#
#
# loss before training is 0.09746931976869816 -- epoch number 465
#
#
# loss before training is 0.09737233161874452 -- epoch number 466
#
#
# loss before training is 0.09727519700886773 -- epoch number 467
#
#
# loss before training is 0.09717791605526604 -- epoch number 468
#
#
# loss before training is 0.09708048887707209 -- epoch number 469
#
#
# loss before training is 0.09698291559636643 -- epoch number 470
#
#
# loss before training is 0.09688519633819202 -- epoch number 471
#
#
# loss before training is 0.09678733123056833 -- epoch number 472
#
#
# loss before training is 0.0966893204045052 -- epoch number 473
#
#
# loss before training is 0.09659116399401688 -- epoch number 474
#
#
# loss before training is 0.09649286213613593 -- epoch number 475
#
#
# loss before training is 0.09639441497092735 -- epoch number 476
#
#
# loss before training is 0.09629582264150198 -- epoch number 477
#
#
# loss before training is 0.09619708529403076 -- epoch number 478
#
#
# loss before training is 0.0960982030777581 -- epoch number 479
#
#
# loss before training is 0.09599917614501567 -- epoch number 480
#
#
# loss before training is 0.09590000465123619 -- epoch number 481
#
#
# loss before training is 0.09580068875496674 -- epoch number 482
#
#
# loss before training is 0.0957012286178823 -- epoch number 483
#
#
# loss before training is 0.09560162440479952 -- epoch number 484
#
#
# loss before training is 0.0955018762836896 -- epoch number 485
#
#
# loss before training is 0.09540198442569191 -- epoch number 486
#
#
# loss before training is 0.09530194900512716 -- epoch number 487
#
#
# loss before training is 0.09520177019951065 -- epoch number 488
#
#
# loss before training is 0.09510144818956541 -- epoch number 489
#
#
# loss before training is 0.09500098315923491 -- epoch number 490
#
#
# loss before training is 0.0949003752956965 -- epoch number 491
#
#
# loss before training is 0.09479962478937402 -- epoch number 492
#
#
# loss before training is 0.09469873183395064 -- epoch number 493
#
#
# loss before training is 0.09459769662638164 -- epoch number 494
#
#
# loss before training is 0.09449651936690727 -- epoch number 495
#
#
# loss before training is 0.0943952002590648 -- epoch number 496
#
#
# loss before training is 0.09429373950970169 -- epoch number 497
#
#
# loss before training is 0.0941921373289875 -- epoch number 498
#
#
# loss before training is 0.09409039393042652 -- epoch number 499
#
#
# loss before training is 0.09398850953086971 -- epoch number 500
#
#
# loss before training is 0.09388648435052732 -- epoch number 501
#
#
# loss before training is 0.09378431861298045 -- epoch number 502
#
#
# loss before training is 0.09368201254519341 -- epoch number 503
#
#
# loss before training is 0.09357956637752533 -- epoch number 504
#
#
# loss before training is 0.09347698034374209 -- epoch number 505
#
#
# loss before training is 0.09337425468102799 -- epoch number 506
#
#
# loss before training is 0.09327138962999747 -- epoch number 507
#
#
# loss before training is 0.09316838543470604 -- epoch number 508
#
#
# loss before training is 0.09306524234266249 -- epoch number 509
#
#
# loss before training is 0.09296196060483963 -- epoch number 510
#
#
# loss before training is 0.09285854047568551 -- epoch number 511
#
#
# loss before training is 0.09275498221313459 -- epoch number 512
#
#
# loss before training is 0.09265128607861879 -- epoch number 513
#
#
# loss before training is 0.09254745233707797 -- epoch number 514
#
#
# loss before training is 0.09244348125697113 -- epoch number 515
#
#
# loss before training is 0.0923393731102868 -- epoch number 516
#
#
# loss before training is 0.09223512817255333 -- epoch number 517
#
#
# loss before training is 0.09213074672284965 -- epoch number 518
#
#
# loss before training is 0.09202622904381547 -- epoch number 519
#
#
# loss before training is 0.09192157542166106 -- epoch number 520
#
#
# loss before training is 0.09181678614617773 -- epoch number 521
#
#
# loss before training is 0.09171186151074746 -- epoch number 522
#
#
# loss before training is 0.09160680181235265 -- epoch number 523
#
#
# loss before training is 0.09150160735158586 -- epoch number 524
#
#
# loss before training is 0.09139627843265936 -- epoch number 525
#
#
# loss before training is 0.09129081536341424 -- epoch number 526
#
#
# loss before training is 0.09118521845533 -- epoch number 527
#
#
# loss before training is 0.0910794880235333 -- epoch number 528
#
#
# loss before training is 0.0909736243868072 -- epoch number 529
#
#
# loss before training is 0.09086762786759985 -- epoch number 530
#
#
# loss before training is 0.09076149879203316 -- epoch number 531
#
#
# loss before training is 0.09065523748991132 -- epoch number 532
#
#
# loss before training is 0.09054884429472934 -- epoch number 533
#
#
# loss before training is 0.0904423195436811 -- epoch number 534
#
#
# loss before training is 0.09033566357766745 -- epoch number 535
#
#
# loss before training is 0.0902288767413044 -- epoch number 536
#
#
# loss before training is 0.09012195938293054 -- epoch number 537
#
#
# loss before training is 0.09001491185461502 -- epoch number 538
#
#
# loss before training is 0.08990773451216476 -- epoch number 539
#
#
# loss before training is 0.0898004277151319 -- epoch number 540
#
#
# loss before training is 0.08969299182682094 -- epoch number 541
#
#
# loss before training is 0.0895854272142958 -- epoch number 542
#
#
# loss before training is 0.08947773424838643 -- epoch number 543
#
#
# loss before training is 0.08936991330369579 -- epoch number 544
#
#
# loss before training is 0.08926196475860604 -- epoch number 545
#
#
# loss before training is 0.08915388899528519 -- epoch number 546
#
#
# loss before training is 0.08904568639969293 -- epoch number 547
#
#
# loss before training is 0.08893735736158684 -- epoch number 548
#
#
# loss before training is 0.0888289022745281 -- epoch number 549
#
#
# loss before training is 0.08872032153588708 -- epoch number 550
#
#
# loss before training is 0.08861161554684914 -- epoch number 551
#
#
# loss before training is 0.08850278471241942 -- epoch number 552
#
#
# loss before training is 0.08839382944142812 -- epoch number 553
#
#
# loss before training is 0.08828475014653554 -- epoch number 554
#
#
# loss before training is 0.08817554724423676 -- epoch number 555
#
#
# loss before training is 0.08806622115486598 -- epoch number 556
#
#
# loss before training is 0.08795677230260114 -- epoch number 557
#
#
# loss before training is 0.08784720111546779 -- epoch number 558
#
#
# loss before training is 0.0877375080253434 -- epoch number 559
#
#
# loss before training is 0.08762769346796094 -- epoch number 560
#
#
# loss before training is 0.08751775788291234 -- epoch number 561
#
#
# loss before training is 0.08740770171365204 -- epoch number 562
#
#
# loss before training is 0.08729752540750012 -- epoch number 563
#
#
# loss before training is 0.08718722941564537 -- epoch number 564
#
#
# loss before training is 0.08707681419314786 -- epoch number 565
#
#
# loss before training is 0.08696628019894166 -- epoch number 566
#
#
# loss before training is 0.08685562789583716 -- epoch number 567
#
#
# loss before training is 0.0867448577505234 -- epoch number 568
#
#
# loss before training is 0.08663397023356945 -- epoch number 569
#
#
# loss before training is 0.08652296581942698 -- epoch number 570
#
#
# loss before training is 0.08641184498643117 -- epoch number 571
#
#
# loss before training is 0.08630060821680206 -- epoch number 572
#
#
# loss before training is 0.08618925599664616 -- epoch number 573
#
#
# loss before training is 0.08607778881595642 -- epoch number 574
#
#
# loss before training is 0.08596620716861393 -- epoch number 575
#
#
# loss before training is 0.08585451155238756 -- epoch number 576
#
#
# loss before training is 0.08574270246893449 -- epoch number 577
#
#
# loss before training is 0.08563078042380014 -- epoch number 578
#
#
# loss before training is 0.08551874592641798 -- epoch number 579
#
#
# loss before training is 0.08540659949010909 -- epoch number 580
#
#
# loss before training is 0.08529434163208124 -- epoch number 581
#
#
# loss before training is 0.08518197287342845 -- epoch number 582
#
#
# loss before training is 0.08506949373912924 -- epoch number 583
#
#
# loss before training is 0.08495690475804558 -- epoch number 584
#
#
# loss before training is 0.08484420646292144 -- epoch number 585
#
#
# loss before training is 0.08473139939038044 -- epoch number 586
#
#
# loss before training is 0.08461848408092423 -- epoch number 587
#
#
# loss before training is 0.08450546107892976 -- epoch number 588
#
#
# loss before training is 0.0843923309326471 -- epoch number 589
#
#
# loss before training is 0.08427909419419634 -- epoch number 590
#
#
# loss before training is 0.08416575141956463 -- epoch number 591
#
#
# loss before training is 0.08405230316860293 -- epoch number 592
#
#
# loss before training is 0.08393875000502221 -- epoch number 593
#
#
# loss before training is 0.08382509249639017 -- epoch number 594
#
#
# loss before training is 0.08371133121412658 -- epoch number 595
#
#
# loss before training is 0.08359746673349948 -- epoch number 596
#
#
# loss before training is 0.08348349963362042 -- epoch number 597
#
#
# loss before training is 0.08336943049743961 -- epoch number 598
#
#
# loss before training is 0.08325525991174103 -- epoch number 599
#
#
# loss before training is 0.08314098846713715 -- epoch number 600
#
#
# loss before training is 0.08302661675806311 -- epoch number 601
#
#
# loss before training is 0.08291214538277122 -- epoch number 602
#
#
# loss before training is 0.08279757494332468 -- epoch number 603
#
#
# loss before training is 0.08268290604559148 -- epoch number 604
#
#
# loss before training is 0.08256813929923755 -- epoch number 605
#
#
# loss before training is 0.08245327531772 -- epoch number 606
#
#
# loss before training is 0.08233831471828011 -- epoch number 607
#
#
# loss before training is 0.08222325812193597 -- epoch number 608
#
#
# loss before training is 0.08210810615347461 -- epoch number 609
#
#
# loss before training is 0.08199285944144448 -- epoch number 610
#
#
# loss before training is 0.08187751861814684 -- epoch number 611
#
#
# loss before training is 0.08176208431962764 -- epoch number 612
#
#
# loss before training is 0.08164655718566892 -- epoch number 613
#
#
# loss before training is 0.08153093785977938 -- epoch number 614
#
#
# loss before training is 0.0814152269891857 -- epoch number 615
#
#
# loss before training is 0.08129942522482253 -- epoch number 616
#
#
# loss before training is 0.08118353322132325 -- epoch number 617
#
#
# loss before training is 0.08106755163700936 -- epoch number 618
#
#
# loss before training is 0.08095148113388062 -- epoch number 619
#
#
# loss before training is 0.08083532237760425 -- epoch number 620
#
#
# loss before training is 0.08071907603750401 -- epoch number 621
#
#
# loss before training is 0.08060274278654934 -- epoch number 622
#
#
# loss before training is 0.08048632330134366 -- epoch number 623
#
#
# loss before training is 0.08036981826211274 -- epoch number 624
#
#
# loss before training is 0.08025322835269291 -- epoch number 625
#
#
# loss before training is 0.08013655426051874 -- epoch number 626
#
#
# loss before training is 0.08001979667661041 -- epoch number 627
#
#
# loss before training is 0.07990295629556109 -- epoch number 628
#
#
# loss before training is 0.07978603381552381 -- epoch number 629
#
#
# loss before training is 0.07966902993819809 -- epoch number 630
#
#
# loss before training is 0.07955194536881634 -- epoch number 631
#
#
# loss before training is 0.07943478081613005 -- epoch number 632
#
#
# loss before training is 0.07931753699239547 -- epoch number 633
#
#
# loss before training is 0.07920021461335928 -- epoch number 634
#
#
# loss before training is 0.07908281439824368 -- epoch number 635
#
#
# loss before training is 0.07896533706973176 -- epoch number 636
#
#
# loss before training is 0.07884778335395172 -- epoch number 637
#
#
# loss before training is 0.07873015398046171 -- epoch number 638
#
#
# loss before training is 0.0786124496822337 -- epoch number 639
#
#
# loss before training is 0.07849467119563742 -- epoch number 640
#
#
# loss before training is 0.07837681926042421 -- epoch number 641
#
#
# loss before training is 0.07825889461971001 -- epoch number 642
#
#
# loss before training is 0.07814089801995848 -- epoch number 643
#
#
# loss before training is 0.07802283021096384 -- epoch number 644
#
#
# loss before training is 0.07790469194583335 -- epoch number 645
#
#
# loss before training is 0.07778648398096931 -- epoch number 646
#
#
# loss before training is 0.07766820707605136 -- epoch number 647
#
#
# loss before training is 0.07754986199401771 -- epoch number 648
#
#
# loss before training is 0.07743144950104676 -- epoch number 649
#
#
# loss before training is 0.07731297036653816 -- epoch number 650
#
#
# loss before training is 0.07719442536309361 -- epoch number 651
#
#
# loss before training is 0.07707581526649729 -- epoch number 652
#
#
# loss before training is 0.07695714085569622 -- epoch number 653
#
#
# loss before training is 0.07683840291278025 -- epoch number 654
#
#
# loss before training is 0.07671960222296173 -- epoch number 655
#
#
# loss before training is 0.07660073957455497 -- epoch number 656
#
#
# loss before training is 0.0764818157589554 -- epoch number 657
#
#
# loss before training is 0.07636283157061836 -- epoch number 658
#
#
# loss before training is 0.07624378780703786 -- epoch number 659
#
#
# loss before training is 0.07612468526872489 -- epoch number 660
#
#
# loss before training is 0.07600552475918529 -- epoch number 661
#
#
# loss before training is 0.07588630708489782 -- epoch number 662
#
#
# loss before training is 0.07576703305529166 -- epoch number 663
#
#
# loss before training is 0.07564770348272336 -- epoch number 664
#
#
# loss before training is 0.07552831918245419 -- epoch number 665
#
#
# loss before training is 0.07540888097262671 -- epoch number 666
#
#
# loss before training is 0.0752893896742413 -- epoch number 667
#
#
# loss before training is 0.07516984611113219 -- epoch number 668
#
#
# loss before training is 0.0750502511099435 -- epoch number 669
#
#
# loss before training is 0.07493060550010495 -- epoch number 670
#
#
# loss before training is 0.07481091011380722 -- epoch number 671
#
#
# loss before training is 0.07469116578597701 -- epoch number 672
#
#
# loss before training is 0.07457137335425201 -- epoch number 673
#
#
# loss before training is 0.07445153365895556 -- epoch number 674
#
#
# loss before training is 0.07433164754307088 -- epoch number 675
#
#
# loss before training is 0.07421171585221531 -- epoch number 676
#
#
# loss before training is 0.07409173943461415 -- epoch number 677
#
#
# loss before training is 0.07397171914107414 -- epoch number 678
#
#
# loss before training is 0.07385165582495688 -- epoch number 679
#
#
# loss before training is 0.0737315503421521 -- epoch number 680
#
#
# loss before training is 0.0736114035510503 -- epoch number 681
#
#
# loss before training is 0.07349121631251525 -- epoch number 682
#
#
# loss before training is 0.07337098948985682 -- epoch number 683
#
#
# loss before training is 0.07325072394880248 -- epoch number 684
#
#
# loss before training is 0.07313042055746974 -- epoch number 685
#
#
# loss before training is 0.07301008018633733 -- epoch number 686
#
#
# loss before training is 0.07288970370821693 -- epoch number 687
#
#
# loss before training is 0.07276929199822414 -- epoch number 688
#
#
# loss before training is 0.07264884593374939 -- epoch number 689
#
#
# loss before training is 0.07252836639442885 -- epoch number 690
#
#
# loss before training is 0.07240785426211449 -- epoch number 691
#
#
# loss before training is 0.07228731042084473 -- epoch number 692
#
#
# loss before training is 0.07216673575681419 -- epoch number 693
#
#
# loss before training is 0.07204613115834353 -- epoch number 694
#
#
# loss before training is 0.07192549751584891 -- epoch number 695
#
#
# loss before training is 0.07180483572181155 -- epoch number 696
#
#
# loss before training is 0.07168414667074664 -- epoch number 697
#
#
# loss before training is 0.0715634312591722 -- epoch number 698
#
#
# loss before training is 0.07144269038557799 -- epoch number 699
#
#
# loss before training is 0.07132192495039369 -- epoch number 700
#
#
# loss before training is 0.07120113585595733 -- epoch number 701
#
#
# loss before training is 0.0710803240064834 -- epoch number 702
#
#
# loss before training is 0.07095949030803045 -- epoch number 703
#
#
# loss before training is 0.07083863566846894 -- epoch number 704
#
#
# loss before training is 0.07071776099744866 -- epoch number 705
#
#
# loss before training is 0.07059686720636568 -- epoch number 706
#
#
# loss before training is 0.0704759552083299 -- epoch number 707
#
#
# loss before training is 0.07035502591813149 -- epoch number 708
#
#
# loss before training is 0.07023408025220758 -- epoch number 709
#
#
# loss before training is 0.07011311912860901 -- epoch number 710
#
#
# loss before training is 0.06999214346696632 -- epoch number 711
#
#
# loss before training is 0.06987115418845595 -- epoch number 712
#
#
# loss before training is 0.06975015221576611 -- epoch number 713
#
#
# loss before training is 0.06962913847306275 -- epoch number 714
#
#
# loss before training is 0.06950811388595478 -- epoch number 715
#
#
# loss before training is 0.0693870793814596 -- epoch number 716
#
#
# loss before training is 0.06926603588796854 -- epoch number 717
#
#
# loss before training is 0.06914498433521149 -- epoch number 718
#
#
# loss before training is 0.06902392565422225 -- epoch number 719
#
#
# loss before training is 0.06890286077730289 -- epoch number 720
#
#
# loss before training is 0.06878179063798857 -- epoch number 721
#
#
# loss before training is 0.06866071617101178 -- epoch number 722
#
#
# loss before training is 0.06853963831226678 -- epoch number 723
#
#
# loss before training is 0.06841855799877354 -- epoch number 724
#
#
# loss before training is 0.06829747616864192 -- epoch number 725
#
#
# loss before training is 0.06817639376103521 -- epoch number 726
#
#
# loss before training is 0.06805531171613412 -- epoch number 727
#
#
# loss before training is 0.0679342309751002 -- epoch number 728
#
#
# loss before training is 0.06781315248003918 -- epoch number 729
#
#
# loss before training is 0.06769207717396433 -- epoch number 730
#
#
# ...
#
#
# loss before training is 2.870044562065209e-05 -- epoch number 9772
#
#
# loss before training is 2.8679599842705964e-05 -- epoch number 9773
#
#
# loss before training is 2.8658768958730003e-05 -- epoch number 9774
#
#
# loss before training is 2.8637952958626917e-05 -- epoch number 9775
#
#
# loss before training is 2.8617151832305752e-05 -- epoch number 9776
#
#
# loss before training is 2.859636556967795e-05 -- epoch number 9777
#
#
# loss before training is 2.8575594160666454e-05 -- epoch number 9778
#
#
# loss before training is 2.8554837595196324e-05 -- epoch number 9779
#
#
# loss before training is 2.8534095863198657e-05 -- epoch number 9780
#
#
# loss before training is 2.851336895461428e-05 -- epoch number 9781
#
#
# loss before training is 2.8492656859385834e-05 -- epoch number 9782
#
#
# loss before training is 2.8471959567465815e-05 -- epoch number 9783
#
#
# loss before training is 2.8451277068808403e-05 -- epoch number 9784
#
#
# loss before training is 2.8430609353378866e-05 -- epoch number 9785
#
#
# loss before training is 2.8409956411143725e-05 -- epoch number 9786
#
#
# loss before training is 2.8389318232079935e-05 -- epoch number 9787
#
#
# loss before training is 2.8368694806168e-05 -- epoch number 9788
#
#
# loss before training is 2.8348086123394065e-05 -- epoch number 9789
#
#
# loss before training is 2.8327492173752283e-05 -- epoch number 9790
#
#
# loss before training is 2.8306912947241717e-05 -- epoch number 9791
#
#
# loss before training is 2.8286348433866927e-05 -- epoch number 9792
#
#
# loss before training is 2.8265798623640656e-05 -- epoch number 9793
#
#
# loss before training is 2.8245263506579124e-05 -- epoch number 9794
#
#
# loss before training is 2.8224743072706718e-05 -- epoch number 9795
#
#
# loss before training is 2.8204237312050924e-05 -- epoch number 9796
#
#
# loss before training is 2.8183746214650158e-05 -- epoch number 9797
#
#
# loss before training is 2.8163269770543884e-05 -- epoch number 9798
#
#
# loss before training is 2.814280796978054e-05 -- epoch number 9799
#
#
# loss before training is 2.812236080241374e-05 -- epoch number 9800
#
#
# loss before training is 2.8101928258503067e-05 -- epoch number 9801
#
#
# loss before training is 2.808151032811513e-05 -- epoch number 9802
#
#
# loss before training is 2.806110700132037e-05 -- epoch number 9803
#
#
# loss before training is 2.804071826819772e-05 -- epoch number 9804
#
#
# loss before training is 2.8020344118830043e-05 -- epoch number 9805
#
#
# loss before training is 2.799998454330802e-05 -- epoch number 9806
#
#
# loss before training is 2.797963953172644e-05 -- epoch number 9807
#
#
# loss before training is 2.7959309074188885e-05 -- epoch number 9808
#
#
# loss before training is 2.793899316080189e-05 -- epoch number 9809
#
#
# loss before training is 2.7918691781680106e-05 -- epoch number 9810
#
#
# loss before training is 2.789840492694281e-05 -- epoch number 9811
#
#
# loss before training is 2.787813258671609e-05 -- epoch number 9812
#
#
# loss before training is 2.7857874751133603e-05 -- epoch number 9813
#
#
# loss before training is 2.783763141033066e-05 -- epoch number 9814
#
#
# loss before training is 2.7817402554452156e-05 -- epoch number 9815
#
#
# loss before training is 2.7797188173648723e-05 -- epoch number 9816
#
#
# loss before training is 2.7776988258076637e-05 -- epoch number 9817
#
#
# loss before training is 2.7756802797895682e-05 -- epoch number 9818
#
#
# loss before training is 2.7736631783274927e-05 -- epoch number 9819
#
#
# loss before training is 2.7716475204389778e-05 -- epoch number 9820
#
#
# loss before training is 2.7696333051417537e-05 -- epoch number 9821
#
#
# loss before training is 2.7676205314546062e-05 -- epoch number 9822
#
#
# loss before training is 2.7656091983966672e-05 -- epoch number 9823
#
#
# loss before training is 2.7635993049876205e-05 -- epoch number 9824
#
#
# loss before training is 2.7615908502479483e-05 -- epoch number 9825
#
#
# loss before training is 2.759583833198514e-05 -- epoch number 9826
#
#
# loss before training is 2.7575782528609927e-05 -- epoch number 9827
#
#
# loss before training is 2.7555741082576226e-05 -- epoch number 9828
#
#
# loss before training is 2.753571398410926e-05 -- epoch number 9829
#
#
# loss before training is 2.751570122344456e-05 -- epoch number 9830
#
#
# loss before training is 2.749570279082066e-05 -- epoch number 9831
#
#
# loss before training is 2.747571867648432e-05 -- epoch number 9832
#
#
# loss before training is 2.745574887068504e-05 -- epoch number 9833
#
#
# loss before training is 2.7435793363682368e-05 -- epoch number 9834
#
#
# loss before training is 2.741585214573745e-05 -- epoch number 9835
#
#
# loss before training is 2.7395925207121383e-05 -- epoch number 9836
#
#
# loss before training is 2.7376012538107932e-05 -- epoch number 9837
#
#
# loss before training is 2.7356114128979352e-05 -- epoch number 9838
#
#
# loss before training is 2.733622997002135e-05 -- epoch number 9839
#
#
# loss before training is 2.7316360051528e-05 -- epoch number 9840
#
#
# loss before training is 2.7296504363798204e-05 -- epoch number 9841
#
#
# loss before training is 2.7276662897136463e-05 -- epoch number 9842
#
#
# loss before training is 2.7256835641853143e-05 -- epoch number 9843
#
#
# loss before training is 2.7237022588265765e-05 -- epoch number 9844
#
#
# loss before training is 2.721722372669617e-05 -- epoch number 9845
#
#
# loss before training is 2.7197439047472766e-05 -- epoch number 9846
#
#
# loss before training is 2.7177668540931234e-05 -- epoch number 9847
#
#
# loss before training is 2.7157912197411314e-05 -- epoch number 9848
#
#
# loss before training is 2.713817000725745e-05 -- epoch number 9849
#
#
# loss before training is 2.7118441960824e-05 -- epoch number 9850
#
#
# loss before training is 2.709872804846767e-05 -- epoch number 9851
#
#
# loss before training is 2.7079028260553182e-05 -- epoch number 9852
#
#
# loss before training is 2.705934258744921e-05 -- epoch number 9853
#
#
# loss before training is 2.7039671019532653e-05 -- epoch number 9854
#
#
# loss before training is 2.7020013547185013e-05 -- epoch number 9855
#
#
# loss before training is 2.700037016079256e-05 -- epoch number 9856
#
#
# loss before training is 2.698074085075044e-05 -- epoch number 9857
#
#
# loss before training is 2.6961125607455052e-05 -- epoch number 9858
#
#
# loss before training is 2.694152442131475e-05 -- epoch number 9859
#
#
# loss before training is 2.6921937282737848e-05 -- epoch number 9860
#
#
# loss before training is 2.6902364182142895e-05 -- epoch number 9861
#
#
# loss before training is 2.6882805109950917e-05 -- epoch number 9862
#
#
# loss before training is 2.6863260056592424e-05 -- epoch number 9863
#
#
# loss before training is 2.6843729012499765e-05 -- epoch number 9864
#
#
# loss before training is 2.6824211968115182e-05 -- epoch number 9865
#
#
# loss before training is 2.6804708913883582e-05 -- epoch number 9866
#
#
# loss before training is 2.6785219840257227e-05 -- epoch number 9867
#
#
# loss before training is 2.6765744737693124e-05 -- epoch number 9868
#
#
# loss before training is 2.6746283596656488e-05 -- epoch number 9869
#
#
# loss before training is 2.672683640761638e-05 -- epoch number 9870
#
#
# loss before training is 2.670740316104704e-05 -- epoch number 9871
#
#
# loss before training is 2.6687983847431388e-05 -- epoch number 9872
#
#
# loss before training is 2.6668578457255013e-05 -- epoch number 9873
#
#
# loss before training is 2.664918698101081e-05 -- epoch number 9874
#
#
# loss before training is 2.6629809409198776e-05 -- epoch number 9875
#
#
# loss before training is 2.661044573232221e-05 -- epoch number 9876
#
#
# loss before training is 2.659109594089164e-05 -- epoch number 9877
#
#
# loss before training is 2.6571760025423598e-05 -- epoch number 9878
#
#
# loss before training is 2.6552437976439776e-05 -- epoch number 9879
#
#
# loss before training is 2.6533129784469076e-05 -- epoch number 9880
#
#
# loss before training is 2.6513835440043214e-05 -- epoch number 9881
#
#
# loss before training is 2.6494554933701646e-05 -- epoch number 9882
#
#
# loss before training is 2.6475288255991725e-05 -- epoch number 9883
#
#
# loss before training is 2.6456035397462975e-05 -- epoch number 9884
#
#
# loss before training is 2.6436796348672164e-05 -- epoch number 9885
#
#
# loss before training is 2.6417571100182324e-05 -- epoch number 9886
#
#
# loss before training is 2.639835964256188e-05 -- epoch number 9887
#
#
# loss before training is 2.6379161966384755e-05 -- epoch number 9888
#
#
# loss before training is 2.635997806223115e-05 -- epoch number 9889
#
#
# loss before training is 2.6340807920687256e-05 -- epoch number 9890
#
#
# loss before training is 2.632165153234439e-05 -- epoch number 9891
#
#
# loss before training is 2.630250888779932e-05 -- epoch number 9892
#
#
# loss before training is 2.6283379977655964e-05 -- epoch number 9893
#
#
# loss before training is 2.6264264792522813e-05 -- epoch number 9894
#
#
# loss before training is 2.6245163323015082e-05 -- epoch number 9895
#
#
# loss before training is 2.6226075559753027e-05 -- epoch number 9896
#
#
# loss before training is 2.620700149336276e-05 -- epoch number 9897
#
#
# loss before training is 2.618794111447563e-05 -- epoch number 9898
#
#
# loss before training is 2.6168894413730163e-05 -- epoch number 9899
#
#
# loss before training is 2.614986138177015e-05 -- epoch number 9900
#
#
# loss before training is 2.613084200924509e-05 -- epoch number 9901
#
#
# loss before training is 2.6111836286808624e-05 -- epoch number 9902
#
#
# loss before training is 2.609284420512241e-05 -- epoch number 9903
#
#
# loss before training is 2.6073865754853576e-05 -- epoch number 9904
#
#
# loss before training is 2.6054900926674007e-05 -- epoch number 9905
#
#
# loss before training is 2.603594971126094e-05 -- epoch number 9906
#
#
# loss before training is 2.6017012099299744e-05 -- epoch number 9907
#
#
# loss before training is 2.5998088081477907e-05 -- epoch number 9908
#
#
# loss before training is 2.5979177648492518e-05 -- epoch number 9909
#
#
# loss before training is 2.5960280791043322e-05 -- epoch number 9910
#
#
# loss before training is 2.594139749983809e-05 -- epoch number 9911
#
#
# loss before training is 2.592252776558732e-05 -- epoch number 9912
#
#
# loss before training is 2.5903671579012442e-05 -- epoch number 9913
#
#
# loss before training is 2.588482893083417e-05 -- epoch number 9914
#
#
# loss before training is 2.586599981178402e-05 -- epoch number 9915
#
#
# loss before training is 2.5847184212596435e-05 -- epoch number 9916
#
#
# loss before training is 2.5828382124012748e-05 -- epoch number 9917
#
#
# loss before training is 2.5809593536779177e-05 -- epoch number 9918
#
#
# loss before training is 2.57908184416495e-05 -- epoch number 9919
#
#
# loss before training is 2.577205682938018e-05 -- epoch number 9920
#
#
# loss before training is 2.5753308690737335e-05 -- epoch number 9921
#
#
# loss before training is 2.5734574016487728e-05 -- epoch number 9922
#
#
# loss before training is 2.5715852797408886e-05 -- epoch number 9923
#
#
# loss before training is 2.56971450242803e-05 -- epoch number 9924
#
#
# loss before training is 2.567845068788989e-05 -- epoch number 9925
#
#
# loss before training is 2.565976977902925e-05 -- epoch number 9926
#
#
# loss before training is 2.5641102288496714e-05 -- epoch number 9927
#
#
# loss before training is 2.5622448207095048e-05 -- epoch number 9928
#
#
# loss before training is 2.5603807525634874e-05 -- epoch number 9929
#
#
# loss before training is 2.558518023492999e-05 -- epoch number 9930
#
#
# loss before training is 2.5566566325803285e-05 -- epoch number 9931
#
#
# loss before training is 2.5547965789078178e-05 -- epoch number 9932
#
#
# loss before training is 2.5529378615589576e-05 -- epoch number 9933
#
#
# loss before training is 2.5510804796173427e-05 -- epoch number 9934
#
#
# loss before training is 2.5492244321673918e-05 -- epoch number 9935
#
#
# loss before training is 2.547369718293928e-05 -- epoch number 9936
#
#
# loss before training is 2.5455163370825737e-05 -- epoch number 9937
#
#
# loss before training is 2.5436642876192234e-05 -- epoch number 9938
#
#
# loss before training is 2.5418135689905377e-05 -- epoch number 9939
#
#
# loss before training is 2.5399641802836708e-05 -- epoch number 9940
#
#
# loss before training is 2.538116120586415e-05 -- epoch number 9941
#
#
# loss before training is 2.5362693889869644e-05 -- epoch number 9942
#
#
# loss before training is 2.534423984574258e-05 -- epoch number 9943
#
#
# loss before training is 2.5325799064376718e-05 -- epoch number 9944
#
#
# loss before training is 2.5307371536672494e-05 -- epoch number 9945
#
#
# loss before training is 2.5288957253535386e-05 -- epoch number 9946
#
#
# loss before training is 2.5270556205876553e-05 -- epoch number 9947
#
#
# loss before training is 2.525216838461185e-05 -- epoch number 9948
#
#
# loss before training is 2.523379378066533e-05 -- epoch number 9949
#
#
# loss before training is 2.5215432384963556e-05 -- epoch number 9950
#
#
# loss before training is 2.5197084188439995e-05 -- epoch number 9951
#
#
# loss before training is 2.5178749182035716e-05 -- epoch number 9952
#
#
# loss before training is 2.516042735669464e-05 -- epoch number 9953
#
#
# loss before training is 2.5142118703366453e-05 -- epoch number 9954
#
#
# loss before training is 2.512382321300767e-05 -- epoch number 9955
#
#
# loss before training is 2.5105540876581124e-05 -- epoch number 9956
#
#
# loss before training is 2.5087271685053814e-05 -- epoch number 9957
#
#
# loss before training is 2.506901562939726e-05 -- epoch number 9958
#
#
# loss before training is 2.5050772700590387e-05 -- epoch number 9959
#
#
# loss before training is 2.5032542889618182e-05 -- epoch number 9960
#
#
# loss before training is 2.501432618747044e-05 -- epoch number 9961
#
#
# loss before training is 2.499612258514228e-05 -- epoch number 9962
#
#
# loss before training is 2.4977932073633073e-05 -- epoch number 9963
#
#
# loss before training is 2.4959754643951284e-05 -- epoch number 9964
#
#
# loss before training is 2.4941590287107955e-05 -- epoch number 9965
#
#
# loss before training is 2.4923438994120113e-05 -- epoch number 9966
#
#
# loss before training is 2.4905300756012447e-05 -- epoch number 9967
#
#
# loss before training is 2.488717556381261e-05 -- epoch number 9968
#
#
# loss before training is 2.486906340855601e-05 -- epoch number 9969
#
#
# loss before training is 2.485096428128165e-05 -- epoch number 9970
#
#
# loss before training is 2.4832878173034876e-05 -- epoch number 9971
#
#
# loss before training is 2.481480507486639e-05 -- epoch number 9972
#
#
# loss before training is 2.4796744977834356e-05 -- epoch number 9973
#
#
# loss before training is 2.4778697873000086e-05 -- epoch number 9974
#
#
# loss before training is 2.476066375143106e-05 -- epoch number 9975
#
#
# loss before training is 2.4742642604200603e-05 -- epoch number 9976
#
#
# loss before training is 2.472463442238718e-05 -- epoch number 9977
#
#
# loss before training is 2.4706639197075434e-05 -- epoch number 9978
#
#
# loss before training is 2.4688656919355618e-05 -- epoch number 9979
#
#
# loss before training is 2.4670687580322894e-05 -- epoch number 9980
#
#
# loss before training is 2.4652731171079195e-05 -- epoch number 9981
#
#
# loss before training is 2.4634787682729377e-05 -- epoch number 9982
#
#
# loss before training is 2.461685710638589e-05 -- epoch number 9983
#
#
# loss before training is 2.459893943316611e-05 -- epoch number 9984
#
#
# loss before training is 2.458103465419522e-05 -- epoch number 9985
#
#
# loss before training is 2.4563142760598382e-05 -- epoch number 9986
#
#
# loss before training is 2.4545263743512788e-05 -- epoch number 9987
#
#
# loss before training is 2.4527397594076512e-05 -- epoch number 9988
#
#
# loss before training is 2.4509544303434856e-05 -- epoch number 9989
#
#
# loss before training is 2.4491703862739303e-05 -- epoch number 9990
#
#
# loss before training is 2.4473876263145033e-05 -- epoch number 9991
#
#
# loss before training is 2.445606149581337e-05 -- epoch number 9992
#
#
# loss before training is 2.4438259551913466e-05 -- epoch number 9993
#
#
# loss before training is 2.4420470422616053e-05 -- epoch number 9994
#
#
# loss before training is 2.4402694099100645e-05 -- epoch number 9995
#
#
# loss before training is 2.4384930572550098e-05 -- epoch number 9996
#
#
# loss before training is 2.4367179834154884e-05 -- epoch number 9997
#
#
# loss before training is 2.4349441875107752e-05 -- epoch number 9998
#
#
# loss before training is 2.4331716686610457e-05 -- epoch number 9999
#
#
# loss before training is 2.4314004259867898e-05 -- epoch number 10000

# %% [markdown]
# --------------------------------

# %% [markdown]
# **Forward feed after training**

# %%
in_hidden_1 = w1.dot(x) + b1
out_hidden_1 = relu(in_hidden_1, leak = 0.1)

in_hidden_2 = w2.dot(out_hidden_1) + b2
out_hidden_2 = sig(in_hidden_2)

in_output_layer = w3.dot(out_hidden_2) + b3
y_hat = sig(in_output_layer)

y_hat
# Out:
# array([[0.2107099 ],
#        [0.8395499 ],
#        [0.86775392],
#        [0.74933989]])

# %%
y
# Out:
# array([[0.21],
#        [0.83],
#        [0.87],
#        [0.75]])

# %%
mse(y, y_hat)
# Out:
# 2.4296304586091913e-05

# %%
w1
# Out:
# array([[ 0.01384127,  0.91505036,  0.22330277,  0.04515728,  0.57988047],
#        [ 0.34599997,  0.91801996,  0.456245  ,  0.80945453,  0.63753478],
#        [ 0.41832215, -0.04428255,  0.9329199 ,  0.51873531,  0.34767029]])
