# %%
import pandas as pd

# %%
data = pd.Series(["Январь", "Февраль", "Март", "Апрель"],
                 index = ['Первый', "Второй", "Третий", "Четвёртый"])
display(data)
# Out:
# Первый        Январь
# Второй       Февраль
# Третий          Март
# Четвёртый     Апрель
# dtype: object

# %%
data.loc["Первый"]
# Out:
# 'Январь'

# %%
data.loc[["Первый", "Третий"]]
# Out:
# Первый    Январь
# Третий      Март
# dtype: object

# %%
data.iloc[0]
# Out:
# 'Январь'

# %%
data.iloc[[0, 2]]
# Out:
# Первый    Январь
# Третий      Март
# dtype: object

# %%
data = pd.Series(list(range(10, 1001)))
print(data)
# Out:
# 0        10
# 1        11
# 2        12
# 3        13
# 4        14
#        ...
# 986     996
# 987     997
# 988     998
# 989     999
# 990    1000
# Length: 991, dtype: int64

# %%
print(data.loc[10] + data.loc[23] - data.loc[245] + data.iloc[122])
# Out:
# -70

# %%
data.iloc[122]
# Out:
# 132

# %%
df = pd.DataFrame({'col1': [1, 2], 'col2': [3, 4]})
display(df)
# Out:
#    col1  col2
# 0     1     3
# 1     2     4

# %%
df = pd.DataFrame([ [1,2,3], [2,3,4] ],
                  columns = ['foo', 'bar', 'baz'], 
                  index = ['foobar', 'foobaz'])
display(df)
# Out:
#         foo  bar  baz
# foobar    1    2    3
# foobaz    2    3    4

# %%
df = pd.read_csv("data_sf.csv")
display(df)
# Out:
#        Unnamed: 0                Name  Age Nationality                 Club  \
# 0               0            L. Messi   31   Argentina         FC Barcelona
# 1               1   Cristiano Ronaldo   33    Portugal             Juventus
# 2               2           Neymar Jr   26      Brazil  Paris Saint-Germain
# 3               3              De Gea   27       Spain    Manchester United
# 4               4        K. De Bruyne   27     Belgium      Manchester City
# ...           ...                 ...  ...         ...                  ...
# 12892       13121        J. Lundstram   19     England      Crewe Alexandra
# 12893       13122  N. Christoffersson   19      Sweden       Trelleborgs FF
# 12894       13123           B. Worman   16     England     Cambridge United
# 12895       13124      D. Walker-Rice   17     England      Tranmere Rovers
# 12896       13125           G. Nugent   16     England      Tranmere Rovers
#
# ...

# %%
football = pd.read_csv('data_sf.csv')
display(football.head())
# Out:
#    Unnamed: 0               Name  Age Nationality                 Club  \
# 0           0           L. Messi   31   Argentina         FC Barcelona
# 1           1  Cristiano Ronaldo   33    Portugal             Juventus
# 2           2          Neymar Jr   26      Brazil  Paris Saint-Germain
# 3           3             De Gea   27       Spain    Manchester United
# 4           4       K. De Bruyne   27     Belgium      Manchester City
#
#        Value    Wage Position  Crossing  Finishing  ...  Penalties  Composure  \
# 0  110500000  565000       RF        84         95  ...         75         96
# 1   77000000  405000       ST        84         94  ...         85         95
# 2  118500000  290000       LW        79         87  ...         81         94
# 3   72000000  260000       GK        17         13  ...         40         68
# 4  102000000  355000      RCM        93         82  ...         79         88
#
# ...

# %%
football = pd.read_csv('data_sf.csv')
display(football.tail(7))
# Out:
#        Unnamed: 0                Name  Age          Nationality  \
# 12890       13119            J. Young   18             Scotland
# 12891       13120            D. Walsh   18  Republic of Ireland
# 12892       13121        J. Lundstram   19              England
# 12893       13122  N. Christoffersson   19               Sweden
# 12894       13123           B. Worman   16              England
# 12895       13124      D. Walker-Rice   17              England
# 12896       13125           G. Nugent   16              England
#
#                    Club    Value  Wage Position  Crossing  Finishing  ...  \
# 12890      Swindon Town   450000  1000       ST        28         47  ...
# 12891      Waterford FC    60000  1000       RB        22         23  ...
# 12892   Crewe Alexandra  1100000  1000       CM        34         38  ...
# 12893    Trelleborgs FF    60000  1000       ST        23         52  ...
# 12894  Cambridge United    60000  1000       ST        25         40  ...
# ...

# %%
football = pd.read_csv('data_sf.csv')
display(football.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12897 entries, 0 to 12896
# Data columns (total 42 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Unnamed: 0       12897 non-null  int64
#  1   Name             12897 non-null  object
#  2   Age              12897 non-null  int64
#  3   Nationality      12897 non-null  object
#  4   Club             12897 non-null  object
#  5   Value            12897 non-null  int64
#  6   Wage             12897 non-null  int64
#  7   Position         12897 non-null  object
#  8   Crossing         12897 non-null  int64
#  9   Finishing        12897 non-null  int64
#  10  HeadingAccuracy  12897 non-null  int64
#  11  ShortPassing     12897 non-null  int64
#  12  Volleys          12897 non-null  int64
#  13  Dribbling        12897 non-null  int64
#  14  Curve            12897 non-null  int64
#  15  FKAccuracy       12897 non-null  int64
#  16  LongPassing      12897 non-null  int64
# ...

# %%
display(football.info(null_counts=False))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12897 entries, 0 to 12896
# Data columns (total 42 columns):
#  #   Column           Dtype
# ---  ------           -----
#  0   Unnamed: 0       int64
#  1   Name             object
#  2   Age              int64
#  3   Nationality      object
#  4   Club             object
#  5   Value            int64
#  6   Wage             int64
#  7   Position         object
#  8   Crossing         int64
#  9   Finishing        int64
#  10  HeadingAccuracy  int64
#  11  ShortPassing     int64
#  12  Volleys          int64
#  13  Dribbling        int64
#  14  Curve            int64
#  15  FKAccuracy       int64
#  16  LongPassing      int64
#  17  BallControl      int64
#  18  Acceleration     int64
#  19  SprintSpeed      int64
#  20  Agility          int64
#  21  Reactions        int64
#  22  Balance          int64
#  23  ShotPower        int64
#  24  Jumping          int64
#  25  Stamina          int64
#  26  Strength         int64
# ...

# %%
football.describe()
# Out:
#          Unnamed: 0           Age         Value           Wage      Crossing  \
# count  12897.000000  12897.000000  1.289700e+04   12897.000000  12897.000000
# mean    6605.040862     24.795379  2.112449e+06    7517.562224     47.076374
# std     3782.545526      4.872212  6.498424e+06   23061.985387     18.043470
# min        0.000000     16.000000  0.000000e+00    1000.000000      5.000000
# 25%     3357.000000     21.000000  2.500000e+05    1000.000000     35.000000
# 50%     6622.000000     24.000000  5.000000e+05    2000.000000     51.000000
# 75%     9876.000000     28.000000  8.500000e+05    4000.000000     61.000000
# max    13125.000000     45.000000  1.185000e+08  565000.000000     93.000000
#
#           Finishing  HeadingAccuracy  ShortPassing       Volleys  \
# count  12897.000000     12897.000000  12897.000000  12897.000000
# mean      42.876328        50.202528     56.026983     40.295030
# std       19.096935        17.281593     14.740436     17.080687
# ...

# %%
football.describe(include = ['object'])
# Out:
#                 Name Nationality             Club Position
# count          12897       12897            12897    12897
# unique         12326         156              650       27
# top     J. Rodríguez     England  Shonan Bellmare       GK
# freq               9        1368               30     1641

# %%
with pd.option_context('display.max_rows', None, 'display.max_columns', None):
    display(football.describe())
# Out:
#          Unnamed: 0           Age         Value           Wage      Crossing  \
# count  12897.000000  12897.000000  1.289700e+04   12897.000000  12897.000000
# mean    6605.040862     24.795379  2.112449e+06    7517.562224     47.076374
# std     3782.545526      4.872212  6.498424e+06   23061.985387     18.043470
# min        0.000000     16.000000  0.000000e+00    1000.000000      5.000000
# 25%     3357.000000     21.000000  2.500000e+05    1000.000000     35.000000
# 50%     6622.000000     24.000000  5.000000e+05    2000.000000     51.000000
# 75%     9876.000000     28.000000  8.500000e+05    4000.000000     61.000000
# max    13125.000000     45.000000  1.185000e+08  565000.000000     93.000000
#
#           Finishing  HeadingAccuracy  ShortPassing       Volleys  \
# count  12897.000000     12897.000000  12897.000000  12897.000000
# mean      42.876328        50.202528     56.026983     40.295030
# std       19.096935        17.281593     14.740436     17.080687
# ...

# %%
df = pd.DataFrame([[i,i+1.2,i+2, 'hi'] for i in range(10)],
                  columns = ['foo', 'bar', 'baz', 'foobar'])
df.mean()
# Out:
# foo    4.5
# bar    5.7
# baz    6.5
# dtype: float64

# %%
display(df)
# Out:
#    foo   bar  baz foobar
# 0    0   1.2    2     hi
# 1    1   2.2    3     hi
# 2    2   3.2    4     hi
# 3    3   4.2    5     hi
# 4    4   5.2    6     hi
# 5    5   6.2    7     hi
# 6    6   7.2    8     hi
# 7    7   8.2    9     hi
# 8    8   9.2   10     hi
# 9    9  10.2   11     hi

# %%
df = pd.DataFrame([[i,i+1.2,i+2, 'hi'] for i in range(10)],
                  columns = ['foo', 'bar', 'baz', 'foobar'])
df['foo']
df.bar
# Out:
# 0     1.2
# 1     2.2
# 2     3.2
# 3     4.2
# 4     5.2
# 5     6.2
# 6     7.2
# 7     8.2
# 8     9.2
# 9    10.2
# Name: bar, dtype: float64

# %%
df = pd.DataFrame([[i,i+1.2,i+2, 'hi'] for i in range(10)],
                  columns = ['foo', 'bar', 'baz', 'foobar'])
df.bar.mean()
# Out:
# 5.7

# %%
football.Wage.sum()
# Out:
# 96954000

# %%
football[football.Age == 20]
# Out:
#        Unnamed: 0           Name  Age          Nationality  \
# 231           231    M. Rashford   20              England
# 350           352   V. Tsygankov   20              Ukraine
# 356           358    L. Martínez   20            Argentina
# 363           366    S. Bergwijn   20          Netherlands
# 447           451   Éder Militão   20               Brazil
# ...           ...            ...  ...                  ...
# 12832       13061        Liu Bin   20             China PR
# 12841       13070  C. Levingston   20  Republic of Ireland
# 12850       13079       L. Jagne   20              England
# 12863       13092       R. Takae   20                Japan
# 12876       13105   Zhang Yufeng   20             China PR
#
#                                       Club     Value    Wage Position  \
# 231                      Manchester United  27000000  110000       LW
# 350                            Dynamo Kyiv  18000000    1000       RM
# ...

# %%
football[(football.Age < football.Age.mean())|
        (football.Club == 'FC Barcelona')]
# Out:
#        Unnamed: 0                Name  Age Nationality               Club  \
# 0               0            L. Messi   31   Argentina       FC Barcelona
# 7               7           L. Suárez   31     Uruguay       FC Barcelona
# 15             15           P. Dybala   24   Argentina           Juventus
# 16             16             H. Kane   24     England  Tottenham Hotspur
# 18             18       M. ter Stegen   26     Germany       FC Barcelona
# ...           ...                 ...  ...         ...                ...
# 12892       13121        J. Lundstram   19     England    Crewe Alexandra
# 12893       13122  N. Christoffersson   19      Sweden     Trelleborgs FF
# 12894       13123           B. Worman   16     England   Cambridge United
# 12895       13124      D. Walker-Rice   17     England    Tranmere Rovers
# 12896       13125           G. Nugent   16     England    Tranmere Rovers
#
#            Value    Wage Position  Crossing  Finishing  ...  Penalties  \
# ...

# %%
football[(football.Age < football.Age.mean())&
        (football.Club == 'FC Barcelona')].Wage.mean()
# Out:
# 77454.54545454546

# %%
football.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12897 entries, 0 to 12896
# Data columns (total 42 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Unnamed: 0       12897 non-null  int64
#  1   Name             12897 non-null  object
#  2   Age              12897 non-null  int64
#  3   Nationality      12897 non-null  object
#  4   Club             12897 non-null  object
#  5   Value            12897 non-null  int64
#  6   Wage             12897 non-null  int64
#  7   Position         12897 non-null  object
#  8   Crossing         12897 non-null  int64
#  9   Finishing        12897 non-null  int64
#  10  HeadingAccuracy  12897 non-null  int64
#  11  ShortPassing     12897 non-null  int64
#  12  Volleys          12897 non-null  int64
#  13  Dribbling        12897 non-null  int64
#  14  Curve            12897 non-null  int64
#  15  FKAccuracy       12897 non-null  int64
#  16  LongPassing      12897 non-null  int64
# ...

# %%
football[football.Wage > football.Wage.mean()].SprintSpeed.mean()
# Out:
# 67.56638061585058

# %%
football[football.Wage < football.Wage.mean()].SprintSpeed.mean()
# Out:
# 62.41425430560645

# %%
football[football.Wage == football.Wage.max()].Position
# Out:
# 0    RF
# Name: Position, dtype: object

# %%
football[football.Nationality == "Brazil"].Penalties.sum()
# Out:
# 22789

# %%
football[football.HeadingAccuracy > 50].Age.mean()
# Out:
# 25.58771113179944

# %%
football.filter(items=['Age','Composure','Reactions'])
# Out:
#        Age  Composure  Reactions
# 0       31         96         95
# 1       33         95         96
# 2       26         94         94
# 3       27         68         90
# 4       27         88         91
# ...    ...        ...        ...
# 12892   19         45         49
# 12893   19         42         40
# 12894   16         41         47
# 12895   17         46         21
# 12896   16         43         51
#
# [12897 rows x 3 columns]

# %%
football[(football.Composure > football.Composure.max()*0.9) & (football.Reactions > football.Reactions.max()*0.9)].filter(items=['Age','Composure','Reactions']).Age.min()
# Out:
# 24

# %%
football[football.Age == football.Age.max()].Reactions.mean()
# Out:
# 72.0

# %%
football[football.Age == football.Age.min()].Reactions.mean()
# Out:
# 49.357142857142854

# %%
72.0 - 49.357142857142854
# Out:
# 22.642857142857146

# %%
newDf = football[football.Value > football.Value.mean()].groupby(['Nationality']).count()
newDf[newDf.Name == newDf.Name.max()]
# Out:
#              Unnamed: 0  Name  Age  Club  Value  Wage  Position  Crossing  \
# Nationality
# Spain               211   211  211   211    211   211       211       211
#
#              Finishing  HeadingAccuracy  ...  Penalties  Composure  Marking  \
# Nationality                              ...
# Spain              211              211  ...        211        211      211
#
#              StandingTackle  SlidingTackle  GKDiving  GKHandling  GKKicking  \
# Nationality
# Spain                   211            211       211         211        211
#
#              GKPositioning  GKReflexes
# Nationality
# Spain                  211         211
#
# [1 rows x 41 columns]

# %%
display(football[(football.Position == 'GK') & (football.GKReflexes == football.GKReflexes.max())].Wage)
display(football[(football.Position == 'GK') & (football.GKHandling == football.GKHandling.max())].Wage) #.filter(items=['Position','Wage','GKReflexes','GKHandling'])
260000.0/94000.0
# Out:
# 3    260000
# Name: Wage, dtype: int64
# 9    94000
# Name: Wage, dtype: int64
# 2.765957446808511

# %%
display(football[football.Aggression == football.Aggression.max()].ShotPower.mean())
display(football[football.Aggression == football.Aggression.min()].ShotPower.mean())
63.0/30.333333333333332
# Out:
# 63.0
# 30.333333333333332
# 2.076923076923077

# %%
football.filter(items=['Age','Value']).plot()
# Out:
# <AxesSubplot:>

# %%
football[football.Value > football.Value.mean()].Nationality.value_counts()
# Out:
# Spain           211
# Brazil          130
# France          123
# Argentina       122
# England         113
#                ...
# Iraq              1
# Mozambique        1
# Saudi Arabia      1
# Iceland           1
# Cyprus            1
# Name: Nationality, Length: 98, dtype: int64
